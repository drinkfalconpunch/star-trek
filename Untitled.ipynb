# %%
import requests
import selenium
from bs4 import BeautifulSoup

# %%
tng_url = 'http://leethomson.myzen.co.uk/Star_Trek/2_The_Next_Generation/Star_Trek_-_The_Next_Generation_Season_{season}/Star_Trek_-_The_Next_Generation_{season}x{episode}_-_{name}.pdf'

# %%
url_base = 'https://sites.google.com/site/tvwriting/us-drama/show-collections/star-trek-{}'
series = set(['tng', 'tos', 'ds9', 'voyager', 'enterprise'])

# %%
html = driver

# %%
xpath = '//*[@class="dhtgD"]'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

class StarTrekSpider():
    def __init__(self, url):
        self.url_to_crawl = url
        self.items = []
        
    def open_webdriver(self):
        self.driver = webdriver.Chrome('chromedriver.exe')
        print('Webdriver opened')
        sleep(5)
    
    def close_webdriver(self):
        self.driver.quit()
        print('Webdriver closed')
    
    def get_url(self, url=None):
        if not url:
            url = self.url_to_crawl
        self.driver.get(url)
        sleep(3)
    
    def _populate_dictionary(self, xpath):
        return self.driver.find_elements(By.XPATH, xpath)

# %%
tng = StarTrekSpider(url=url_base.format('tng'))

# %%
tng.open_webdriver()
# Out:
# Webdriver opened

# %%
tng.get_url()

# %%
tng._populate_dictionary(xpath=xpath)

# %%
url_base.format('tng')
# Out:
# 'https://sites.google.com/site/tvwriting/us-drama/show-collections/star-trek-tng'

# %%
r = requests.get(url_base.format('tng'))

# %%
episodes = {}

# %%
soup = BeautifulSoup(r.content, 'lxml')

# %%
st_classes = {'tng': 'dhtgD'}

# %%
class StarTrekPreprocessing():
    _classes = {'tng': 'dhtgD'}
    _full_name = 'Star Trek - {}'
    _series_names = {'tng': 'The Next Generation', 'tos': 'The Original Series', 'voy': 'Voyager', 'ds9': 'Deep Space Nine'}
    
    def __init__(self, show='tng', url=None):
        self.show = show
        self.url = url
    
    def _populate_episodes(self):
        self.file_names = [s.contents[0] for s in soup.find_all('a', class_=self._classes[self.show])]

# %%
_classes = {'tng': 'dhtgD'}
_full_name = 'Star Trek - {}'
_series_names = {'tng': 'The Next Generation', 'tos': 'The Original Series', 'voy': 'Voyager', 'ds9': 'Deep Space Nine'}

# %%
from episode import Episode

# %%
import os
from pathlib import Path
import re

episode_name_regex = r"(?<=\-\s).*(?=\.)" # (?<=\-\s) matches after '- ', (?=\.) matches before '.', and '.*' is everything inside.

# %%
episode_pattern = re.compile(episode_name_regex)
for s in soup.find_all('a', class_=_classes['tng']):
    content = s.contents[0]
    episode_name = re.findall(episode_pattern, content) #s.contents[0][len(_full_name.format(_series_names['tng']))+1:])
    if episode_name:
        print(episode_name)
# Out:
# ['The Next Generation Bible']
# ['The Next Generation 1x01-102 - Encounter at Farpoint']
# ['The Next Generation 1x03 - The Naked Now']
# ['The Next Generation 1x04 - Code of Honor']
# ['The Next Generation 1x05 - Haven aka Eye of The Beholder']
# ['The Next Generation 1x06 - Where None Have Gone Before']
# ['The Next Generation 1x07 - The Last Outpost']
# ['The Next Generation 1x08 - Lonely Among Us']
# ['The Next Generation 1x09 - Justice']
# ['The Next Generation 1x10 - The Battle']
# ['The Next Generation 1x11 - Hide And Q']
# ['The Next Generation 1x12 - Too Short A Season']
# ['The Next Generation 1x13 - The Big Good-bye']
# ['The Next Generation 1x14 - Datalore']
# ['The Next Generation 1x15 - Angel One']
# ['The Next Generation 1x16 - 11001001 aka 10101001']
# ['The Next Generation 1x17 - Home Soil']
# ['The Next Generation 1x18 - When the Bough Breaks']
# ['The Next Generation 1x19 - Coming Of Age aka Starfleet Academy']
# ['The Next Generation 1x20 - Heart Of Glory']
# ['The Next Generation 1x21 - The Arsenal Of Freedom aka Among The Missing']
# ['The Next Generation 1x22 - Skin of Evil aka The Shroud']
# ['The Next Generation 1x23 - Symbiosis']
# ["The Next Generation 1x24 - We'll Always Have Paris"]
# ['The Next Generation 1x25 - Conspiracy']
# ['The Next Generation 1x26 - The Neutral Zone']
# ['The Next Generation 2x01 - The Child']
# ['The Next Generation 2x02 - Where Silence Has Lease']
# ['The Next Generation 2x03 - Elementary, Dear Data']
# ['The Next Generation 2x04 - The Outrageous Okona']
# ['The Next Generation 2x05 - Loud as a Whisper']
# ['The Next Generation 2x06 - The Schizoid Man']
# ['The Next Generation 2x07 - Unnatural Selection']
# ['The Next Generation 2x08 - A Matter of Honor']
# ['The Next Generation 2x09 - The Measure of a Man']
# ['The Next Generation 2x10 - The Dauphin']
# ['The Next Generation 2x11 - Contagion']
# ['The Next Generation 2x12 - The Royale']
# ['The Next Generation 2x13 - Time Squared']
# ['The Next Generation 2x14 - The Icarus Factor']
# ['The Next Generation 2x15 - Pen Pals']
# ['The Next Generation 2x16 - Q Who']
# ['The Next Generation 2x17 - Samaritan Snare']
# ['The Next Generation 2x18 - Up the Long Ladder']
# ['The Next Generation 2x19 - Manhunt']
# ['The Next Generation 2x20 - The Emissary']
# ['The Next Generation 2x21 - Peak Performance']
# ['The Next Generation 2x22 - Shades of Gray']
# ['The Next Generation 3x01 - Evolution']
# ['The Next Generation 3x02 - The Ensigns of Command']
# ['The Next Generation 3x03 - The Survivors']
# ['The Next Generation 3x04 - Who Watches the Watchers']
# ['The Next Generation 3x05 - The Bonding']
# ['The Next Generation 3x06 - Booby Trap']
# ['The Next Generation 3x07 - The Enemy']
# ['The Next Generation 3x08 - The Price']
# ['The Next Generation 3x09 - The Vengeance Factor']
# ['The Next Generation 3x10 - The Defector']
# ['The Next Generation 3x11 - The Hunted']
# ['The Next Generation 3x12 - The High Ground']
# ['The Next Generation 3x13 - Deja Q']
# ['The Next Generation 3x14 - A Matter of Perspective']
# ["The Next Generation 3x15 - Yesterday's Enterprise"]
# ['The Next Generation 3x16 - The Offspring']
# ['The Next Generation 3x17 - Sins of the Father']
# ['The Next Generation 3x18 - Allegiance']
# ["The Next Generation 3x19 - Captain's Holiday"]
# ['The Next Generation 3x20 - Tin Man']
# ['The Next Generation 3x21 - Hollow Pursuits']
# ['The Next Generation 3x22 - The Most Toys']
# ['The Next Generation 3x23 - Sarek']
# ['The Next Generation 3x24 - Menage a Troi']
# ['The Next Generation 3x25 - Transfigurations']
# ['The Next Generation 3x26 - The Best of Both Worlds, Part I']
# ['The Next Generation 4x01 - The Best of Both Worlds, Part II']
# ['The Next Generation 4x02 - Family']
# ['The Next Generation 4x03 - Brothers']
# ['The Next Generation 4x04 - Suddenly Human']
# ['The Next Generation 4x05 - Remember Me']
# ['The Next Generation 4x06 - Legacy']
# ['The Next Generation 4x07 - Reunion']
# ['The Next Generation 4x08 - Future Imperfect']
# ['The Next Generation 4x09 - Final Mission']
# ['The Next Generation 4x10 - The Loss']
# ["The Next Generation 4x11 - Data's Day"]
# ['The Next Generation 4x12 - The Wounded']
# ["The Next Generation 4x13 - Devil's Due"]
# ['The Next Generation 4x14 - Clues']
# ['The Next Generation 4x15 - First Contact']
# ["The Next Generation 4x16 - Galaxy's Child"]
# ['The Next Generation 4x17 - Night Terrors']
# ['The Next Generation 4x18 - Identity Crisis']
# ['The Next Generation 4x19 - The Nth Degree']
# ['The Next Generation 4x20 - Qpid']
# ['The Next Generation 4x21 - The Drumhead']
# ['The Next Generation 4x22 - Half a Life']
# ['The Next Generation 4x23 - The Host']
# ["The Next Generation 4x24 - The Mind's Eye"]
# ['The Next Generation 4x25 - In Theory']
# ['The Next Generation 4x26 - Redemption, Part I']
# ['The Next Generation 5x01 - Redemption, Part II']
# ['The Next Generation 5x02 - Darmok']
# ['The Next Generation 5x03 - Ensign Ro']
# ['The Next Generation 5x04 - Silicon Avatar']
# ['The Next Generation 5x05 - Disaster']
# ['The Next Generation 5x06 - The Game']
# ['The Next Generation 5x07 - Unification Part I']
# ['The Next Generation 5x08 - Unification Part II']
# ['The Next Generation 5x09 - A Matter of Time']
# ['The Next Generation 5x10 - New Ground']
# ['The Next Generation 5x11 - Hero Worship']
# ['The Next Generation 5x12 - Violations']
# ['The Next Generation 5x13 - The Masterpiece Society']
# ['The Next Generation 5x14 - Conundrum']
# ['The Next Generation 5x15 - Power Play']
# ['The Next Generation 5x16 - Ethics']
# ['The Next Generation 5x17 - The Outcast']
# ['The Next Generation 5x18 - Cause and Effect']
# ['The Next Generation 5x19 - The First Duty']
# ['The Next Generation 5x20 - Cost of Living']
# ['The Next Generation 5x21 - The Perfect Mate']
# ['The Next Generation 5x22 - Imaginary Friend']
# ['The Next Generation 5x23 - I, Borg']
# ['The Next Generation 5x24 - The Next Phase']
# ['The Next Generation 5x25 - The Inner Light']
# ["The Next Generation 5x26 - Time's Arrow, Part I"]
# ["The Next Generation 6x01 - Time's Arrow, Part II"]
# ['The Next Generation 6x02 - Realm of Fear']
# ['The Next Generation 6x03 - Man of the People']
# ['The Next Generation 6x04 - Relics']
# ['The Next Generation 6x05 - Schisms']
# ['The Next Generation 6x06 - True Q']
# ['The Next Generation 6x07 - Rascals']
# ['The Next Generation 6x08 - A Fistful of Datas']
# ['The Next Generation 6x09 - The Quality of Life']
# ['The Next Generation 6x10 - Chain of Command, Part I']
# ['The Next Generation 6x11 - Chain of Command, Part II']
# ['The Next Generation 6x12 - Ship in a Bottle']
# ['The Next Generation 6x13 - Aquiel']
# ['The Next Generation 6x14 - Face of the Enemy']
# ['The Next Generation 6x15 - Tapestry']
# ['The Next Generation 6x16 - Birthright']
# ['The Next Generation 6x17 - Birthright Part II']
# ['The Next Generation 6x18 - Starship Mine']
# ['The Next Generation 6x19 - Lessons']
# ['The Next Generation 6x20 - The Chase']
# ['The Next Generation 6x21 - Frame of Mind']
# ['The Next Generation 6x22 - Suspicions']
# ['The Next Generation 6x23 - Rightful Heir']
# ['The Next Generation 6x24 - Second Chances']
# ['The Next Generation 6x25 - Timescape']
# ['The Next Generation 6x26 - Descent, Part I']
# ['The Next Generation 7x01 - Descent, Part II']
# ['The Next Generation 7x02 - Liaisons']
# ['The Next Generation 7x03 - Interface']
# ['The Next Generation 7x04 - Gambit, Part I']
# ['The Next Generation 7x05 - Gambit, Part II']
# ['The Next Generation 7x06 - Phantasms']
# ['The Next Generation 7x07 - Dark Page']
# ['The Next Generation 7x08 - Attached']
# ['The Next Generation 7x09 - Force of Nature']
# ['The Next Generation 7x10 - Inheritance']
# ['The Next Generation 7x11 - Parallels']
# ['The Next Generation 7x12 - The Pegasus']
# ['The Next Generation 7x13 - Homeward']
# ['The Next Generation 7x14 - Sub Rosa']
# ['The Next Generation 7x15 - Lower Decks']
# ['The Next Generation 7x16 - Thine Own Self']
# ['The Next Generation 7x17 - Masks']
# ['The Next Generation 7x18 - Eye of the Beholder']
# ['The Next Generation 7x19 - Genesis']
# ["The Next Generation 7x20 - Journey's End"]
# ['The Next Generation 7x21 - Firstborn']
# ['The Next Generation 7x22 - Bloodlines']
# ['The Next Generation 7x23 - Emergence']
# ['The Next Generation 7x24 - Preemptive Strike']
# ['The Next Generation 7x25 - All Good Things']

# %%
(s.contents[0][len(_full_name.format(_series_names['tng']))+1:]) for s in soup.find_all('a', class_='dhtgD')]
# Out:
# ['Bible.pdf',
#  '1x01-102 - Encounter at Farpoint.pdf',
#  '1x03 - The Naked Now.pdf',
#  '1x04 - Code of Honor.pdf',
#  '1x05 - Haven aka Eye of The Beholder.pdf',
#  '1x06 - Where None Have Gone Before.pdf',
#  '1x07 - The Last Outpost.pdf',
#  '1x08 - Lonely Among Us.pdf',
#  '1x09 - Justice.pdf',
#  '1x10 - The Battle.pdf',
#  '1x11 - Hide And Q.pdf',
#  '1x12 - Too Short A Season.pdf',
#  '1x13 - The Big Good-bye.pdf',
#  '1x14 - Datalore.pdf',
#  '1x15 - Angel One.pdf',
#  '1x16 - 11001001 aka 10101001.pdf',
#  '1x17 - Home Soil.pdf',
#  '1x18 - When the Bough Breaks.pdf',
#  '1x19 - Coming Of Age aka Starfleet Academy.pdf',
#  '1x20 - Heart Of Glory.pdf',
#  '1x21 - The Arsenal Of Freedom aka Among The Missing.pdf',
#  '1x22 - Skin of Evil aka The Shroud.pdf',
#  '1x23 - Symbiosis.pdf',
#  "1x24 - We'll Always Have Paris.pdf",
#  '1x25 - Conspiracy.pdf',
#  '1x26 - The Neutral Zone.pdf',
#  '2x01 - The Child.pdf',
#  '2x02 - Where Silence Has Lease.pdf',
#  '2x03 - Elementary, Dear Data.pdf',
#  '2x04 - The Outrageous Okona.pdf',
#  '2x05 - Loud as a Whisper.pdf',
#  '2x06 - The Schizoid Man.pdf',
#  '2x07 - Unnatural Selection.pdf',
#  '2x08 - A Matter of Honor.pdf',
#  '2x09 - The Measure of a Man.pdf',
#  '2x10 - The Dauphin.pdf',
#  '2x11 - Contagion.pdf',
#  '2x12 - The Royale.pdf',
#  '2x13 - Time Squared.pdf',
#  '2x14 - The Icarus Factor.pdf',
#  '2x15 - Pen Pals.pdf',
#  '2x16 - Q Who.pdf',
#  '2x17 - Samaritan Snare.pdf',
#  '2x18 - Up the Long Ladder.pdf',
#  '2x19 - Manhunt.pdf',
#  '2x20 - The Emissary.pdf',
#  '2x21 - Peak Performance.pdf',
#  '2x22 - Shades of Gray.pdf',
#  '3x01 - Evolution.pdf',
#  '3x02 - The Ensigns of Command.pdf',
#  '3x03 - The Survivors.pdf',
#  '3x04 - Who Watches the Watchers.pdf',
#  '3x05 - The Bonding.pdf',
#  '3x06 - Booby Trap.pdf',
#  '3x07 - The Enemy.pdf',
#  '3x08 - The Price.pdf',
#  '3x09 - The Vengeance Factor.pdf',
#  '3x10 - The Defector.pdf',
#  '3x11 - The Hunted.pdf',
#  '3x12 - The High Ground.pdf',
#  '3x13 - Deja Q.pdf',
#  '3x14 - A Matter of Perspective.pdf',
#  "3x15 - Yesterday's Enterprise.pdf",
#  '3x16 - The Offspring.pdf',
#  '3x17 - Sins of the Father.pdf',
#  '3x18 - Allegiance.pdf',
#  "3x19 - Captain's Holiday.pdf",
#  '3x20 - Tin Man.pdf',
#  '3x21 - Hollow Pursuits.pdf',
#  '3x22 - The Most Toys.pdf',
#  '3x23 - Sarek.pdf',
#  '3x24 - Menage a Troi.pdf',
#  '3x25 - Transfigurations.pdf',
#  '3x26 - The Best of Both Worlds, Part I.pdf',
#  '4x01 - The Best of Both Worlds, Part II.pdf',
#  '4x02 - Family.pdf',
#  '4x03 - Brothers.pdf',
#  '4x04 - Suddenly Human.pdf',
#  '4x05 - Remember Me.pdf',
#  '4x06 - Legacy.pdf',
#  '4x07 - Reunion.pdf',
#  '4x08 - Future Imperfect.pdf',
#  '4x09 - Final Mission.pdf',
#  '4x10 - The Loss.pdf',
#  "4x11 - Data's Day.pdf",
#  '4x12 - The Wounded.pdf',
#  "4x13 - Devil's Due.pdf",
#  '4x14 - Clues.pdf',
#  '4x15 - First Contact.pdf',
#  "4x16 - Galaxy's Child.pdf",
#  '4x17 - Night Terrors.pdf',
#  '4x18 - Identity Crisis.pdf',
#  '4x19 - The Nth Degree.pdf',
#  '4x20 - Qpid.pdf',
#  '4x21 - The Drumhead.pdf',
#  '4x22 - Half a Life.pdf',
#  '4x23 - The Host.pdf',
#  "4x24 - The Mind's Eye.pdf",
#  '4x25 - In Theory.pdf',
#  '4x26 - Redemption, Part I.pdf',
#  '5x01 - Redemption, Part II.txt',
#  '5x02 - Darmok.txt',
#  '5x03 - Ensign Ro.txt',
#  '5x04 - Silicon Avatar.txt',
#  '5x05 - Disaster.txt',
#  '5x06 - The Game.txt',
#  '5x07 - Unification Part I.txt',
#  '5x08 - Unification Part II.txt',
#  '5x09 - A Matter of Time.txt',
#  '5x10 - New Ground.txt',
#  '5x11 - Hero Worship.txt',
#  '5x12 - Violations.txt',
#  '5x13 - The Masterpiece Society.txt',
#  '5x14 - Conundrum.txt',
#  '5x15 - Power Play.txt',
#  '5x16 - Ethics.txt',
#  '5x17 - The Outcast.txt',
#  '5x18 - Cause and Effect.txt',
#  '5x19 - The First Duty.txt',
#  '5x20 - Cost of Living.txt',
#  '5x21 - The Perfect Mate.txt',
#  '5x22 - Imaginary Friend.txt',
#  '5x23 - I, Borg.txt',
#  '5x24 - The Next Phase.txt',
#  '5x25 - The Inner Light.txt',
#  "5x26 - Time's Arrow, Part I.txt",
#  "6x01 - Time's Arrow, Part II.txt",
#  '6x02 - Realm of Fear.txt',
#  '6x03 - Man of the People.txt',
#  '6x04 - Relics.txt',
#  '6x05 - Schisms.txt',
#  '6x06 - True Q.txt',
#  '6x07 - Rascals.txt',
#  '6x08 - A Fistful of Datas.txt',
#  '6x09 - The Quality of Life.txt',
#  '6x10 - Chain of Command, Part I.txt',
#  '6x11 - Chain of Command, Part II.txt',
#  '6x12 - Ship in a Bottle.txt',
#  '6x13 - Aquiel.txt',
#  '6x14 - Face of the Enemy.txt',
#  '6x15 - Tapestry.txt',
#  '6x16 - Birthright.txt',
#  '6x17 - Birthright Part II.txt',
#  '6x18 - Starship Mine.txt',
#  '6x19 - Lessons.txt',
#  '6x20 - The Chase.txt',
#  '6x21 - Frame of Mind.txt',
#  '6x22 - Suspicions.txt',
#  '6x23 - Rightful Heir.txt',
#  '6x24 - Second Chances.txt',
#  '6x25 - Timescape.txt',
#  '6x26 - Descent, Part I.txt',
#  '7x01 - Descent, Part II.txt',
#  '7x02 - Liaisons.txt',
#  '7x03 - Interface.txt',
#  '7x04 - Gambit, Part I.txt',
#  '7x05 - Gambit, Part II.txt',
#  '7x06 - Phantasms.txt',
#  '7x07 - Dark Page.txt',
#  '7x08 - Attached.txt',
#  '7x09 - Force of Nature.txt',
#  '7x10 - Inheritance.txt',
#  '7x11 - Parallels.txt',
#  '7x12 - The Pegasus.txt',
#  '7x13 - Homeward.txt',
#  '7x14 - Sub Rosa.txt',
#  '7x15 - Lower Decks.txt',
#  '7x16 - Thine Own Self.txt',
#  '7x17 - Masks.txt',
#  '7x18 - Eye of the Beholder.txt',
#  '7x19 - Genesis.txt',
#  "7x20 - Journey's End.txt",
#  '7x21 - Firstborn.txt',
#  '7x22 - Bloodlines.txt',
#  '7x23 - Emergence.txt',
#  '7x24 - Preemptive Strike.txt',
#  '7x25 - All Good Things.txt']

# %%
# Extract episode numbers, names, and filetypes from source and store in dict
[s.contents[0][len(_full_name.format(_series_names['tng']))+1:] for s in soup.find_all('a', class_='dhtgD')]
# Out:
# ['Bible.pdf',
#  '1x01-102 - Encounter at Farpoint.pdf',
#  '1x03 - The Naked Now.pdf',
#  '1x04 - Code of Honor.pdf',
#  '1x05 - Haven aka Eye of The Beholder.pdf',
#  '1x06 - Where None Have Gone Before.pdf',
#  '1x07 - The Last Outpost.pdf',
#  '1x08 - Lonely Among Us.pdf',
#  '1x09 - Justice.pdf',
#  '1x10 - The Battle.pdf',
#  '1x11 - Hide And Q.pdf',
#  '1x12 - Too Short A Season.pdf',
#  '1x13 - The Big Good-bye.pdf',
#  '1x14 - Datalore.pdf',
#  '1x15 - Angel One.pdf',
#  '1x16 - 11001001 aka 10101001.pdf',
#  '1x17 - Home Soil.pdf',
#  '1x18 - When the Bough Breaks.pdf',
#  '1x19 - Coming Of Age aka Starfleet Academy.pdf',
#  '1x20 - Heart Of Glory.pdf',
#  '1x21 - The Arsenal Of Freedom aka Among The Missing.pdf',
#  '1x22 - Skin of Evil aka The Shroud.pdf',
#  '1x23 - Symbiosis.pdf',
#  "1x24 - We'll Always Have Paris.pdf",
#  '1x25 - Conspiracy.pdf',
#  '1x26 - The Neutral Zone.pdf',
#  '2x01 - The Child.pdf',
#  '2x02 - Where Silence Has Lease.pdf',
#  '2x03 - Elementary, Dear Data.pdf',
#  '2x04 - The Outrageous Okona.pdf',
#  '2x05 - Loud as a Whisper.pdf',
#  '2x06 - The Schizoid Man.pdf',
#  '2x07 - Unnatural Selection.pdf',
#  '2x08 - A Matter of Honor.pdf',
#  '2x09 - The Measure of a Man.pdf',
#  '2x10 - The Dauphin.pdf',
#  '2x11 - Contagion.pdf',
#  '2x12 - The Royale.pdf',
#  '2x13 - Time Squared.pdf',
#  '2x14 - The Icarus Factor.pdf',
#  '2x15 - Pen Pals.pdf',
#  '2x16 - Q Who.pdf',
#  '2x17 - Samaritan Snare.pdf',
#  '2x18 - Up the Long Ladder.pdf',
#  '2x19 - Manhunt.pdf',
#  '2x20 - The Emissary.pdf',
#  '2x21 - Peak Performance.pdf',
#  '2x22 - Shades of Gray.pdf',
#  '3x01 - Evolution.pdf',
#  '3x02 - The Ensigns of Command.pdf',
#  '3x03 - The Survivors.pdf',
#  '3x04 - Who Watches the Watchers.pdf',
#  '3x05 - The Bonding.pdf',
#  '3x06 - Booby Trap.pdf',
#  '3x07 - The Enemy.pdf',
#  '3x08 - The Price.pdf',
#  '3x09 - The Vengeance Factor.pdf',
#  '3x10 - The Defector.pdf',
#  '3x11 - The Hunted.pdf',
#  '3x12 - The High Ground.pdf',
#  '3x13 - Deja Q.pdf',
#  '3x14 - A Matter of Perspective.pdf',
#  "3x15 - Yesterday's Enterprise.pdf",
#  '3x16 - The Offspring.pdf',
#  '3x17 - Sins of the Father.pdf',
#  '3x18 - Allegiance.pdf',
#  "3x19 - Captain's Holiday.pdf",
#  '3x20 - Tin Man.pdf',
#  '3x21 - Hollow Pursuits.pdf',
#  '3x22 - The Most Toys.pdf',
#  '3x23 - Sarek.pdf',
#  '3x24 - Menage a Troi.pdf',
#  '3x25 - Transfigurations.pdf',
#  '3x26 - The Best of Both Worlds, Part I.pdf',
#  '4x01 - The Best of Both Worlds, Part II.pdf',
#  '4x02 - Family.pdf',
#  '4x03 - Brothers.pdf',
#  '4x04 - Suddenly Human.pdf',
#  '4x05 - Remember Me.pdf',
#  '4x06 - Legacy.pdf',
#  '4x07 - Reunion.pdf',
#  '4x08 - Future Imperfect.pdf',
#  '4x09 - Final Mission.pdf',
#  '4x10 - The Loss.pdf',
#  "4x11 - Data's Day.pdf",
#  '4x12 - The Wounded.pdf',
#  "4x13 - Devil's Due.pdf",
#  '4x14 - Clues.pdf',
#  '4x15 - First Contact.pdf',
#  "4x16 - Galaxy's Child.pdf",
#  '4x17 - Night Terrors.pdf',
#  '4x18 - Identity Crisis.pdf',
#  '4x19 - The Nth Degree.pdf',
#  '4x20 - Qpid.pdf',
#  '4x21 - The Drumhead.pdf',
#  '4x22 - Half a Life.pdf',
#  '4x23 - The Host.pdf',
#  "4x24 - The Mind's Eye.pdf",
#  '4x25 - In Theory.pdf',
#  '4x26 - Redemption, Part I.pdf',
#  '5x01 - Redemption, Part II.txt',
#  '5x02 - Darmok.txt',
#  '5x03 - Ensign Ro.txt',
#  '5x04 - Silicon Avatar.txt',
#  '5x05 - Disaster.txt',
#  '5x06 - The Game.txt',
#  '5x07 - Unification Part I.txt',
#  '5x08 - Unification Part II.txt',
#  '5x09 - A Matter of Time.txt',
#  '5x10 - New Ground.txt',
#  '5x11 - Hero Worship.txt',
#  '5x12 - Violations.txt',
#  '5x13 - The Masterpiece Society.txt',
#  '5x14 - Conundrum.txt',
#  '5x15 - Power Play.txt',
#  '5x16 - Ethics.txt',
#  '5x17 - The Outcast.txt',
#  '5x18 - Cause and Effect.txt',
#  '5x19 - The First Duty.txt',
#  '5x20 - Cost of Living.txt',
#  '5x21 - The Perfect Mate.txt',
#  '5x22 - Imaginary Friend.txt',
#  '5x23 - I, Borg.txt',
#  '5x24 - The Next Phase.txt',
#  '5x25 - The Inner Light.txt',
#  "5x26 - Time's Arrow, Part I.txt",
#  "6x01 - Time's Arrow, Part II.txt",
#  '6x02 - Realm of Fear.txt',
#  '6x03 - Man of the People.txt',
#  '6x04 - Relics.txt',
#  '6x05 - Schisms.txt',
#  '6x06 - True Q.txt',
#  '6x07 - Rascals.txt',
#  '6x08 - A Fistful of Datas.txt',
#  '6x09 - The Quality of Life.txt',
#  '6x10 - Chain of Command, Part I.txt',
#  '6x11 - Chain of Command, Part II.txt',
#  '6x12 - Ship in a Bottle.txt',
#  '6x13 - Aquiel.txt',
#  '6x14 - Face of the Enemy.txt',
#  '6x15 - Tapestry.txt',
#  '6x16 - Birthright.txt',
#  '6x17 - Birthright Part II.txt',
#  '6x18 - Starship Mine.txt',
#  '6x19 - Lessons.txt',
#  '6x20 - The Chase.txt',
#  '6x21 - Frame of Mind.txt',
#  '6x22 - Suspicions.txt',
#  '6x23 - Rightful Heir.txt',
#  '6x24 - Second Chances.txt',
#  '6x25 - Timescape.txt',
#  '6x26 - Descent, Part I.txt',
#  '7x01 - Descent, Part II.txt',
#  '7x02 - Liaisons.txt',
#  '7x03 - Interface.txt',
#  '7x04 - Gambit, Part I.txt',
#  '7x05 - Gambit, Part II.txt',
#  '7x06 - Phantasms.txt',
#  '7x07 - Dark Page.txt',
#  '7x08 - Attached.txt',
#  '7x09 - Force of Nature.txt',
#  '7x10 - Inheritance.txt',
#  '7x11 - Parallels.txt',
#  '7x12 - The Pegasus.txt',
#  '7x13 - Homeward.txt',
#  '7x14 - Sub Rosa.txt',
#  '7x15 - Lower Decks.txt',
#  '7x16 - Thine Own Self.txt',
#  '7x17 - Masks.txt',
#  '7x18 - Eye of the Beholder.txt',
#  '7x19 - Genesis.txt',
#  "7x20 - Journey's End.txt",
#  '7x21 - Firstborn.txt',
#  '7x22 - Bloodlines.txt',
#  '7x23 - Emergence.txt',
#  '7x24 - Preemptive Strike.txt',
#  '7x25 - All Good Things.txt']

# %%
def pdf_url(series='tng', season, episode):
