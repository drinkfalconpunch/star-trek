# %%
import requests
import selenium
from bs4 import BeautifulSoup

# %%
tng_url = 'http://leethomson.myzen.co.uk/Star_Trek/2_The_Next_Generation/Star_Trek_-_The_Next_Generation_Season_{season}/Star_Trek_-_The_Next_Generation_{season}x{episode}_-_{name}.pdf'

# %%
url_base = 'https://sites.google.com/site/tvwriting/us-drama/show-collections/star-trek-{}'
series = set(['tng', 'tos', 'ds9', 'voyager', 'enterprise'])

# %%
html = driver

# %%
xpath = '//*[@class="dhtgD"]'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

class StarTrekSpider():
    def __init__(self, url):
        self.url_to_crawl = url
        self.items = []
        
    def open_webdriver(self):
        self.driver = webdriver.Chrome('chromedriver.exe')
        print('Webdriver opened')
        sleep(5)
    
    def close_webdriver(self):
        self.driver.quit()
        print('Webdriver closed')
    
    def get_url(self, url=None):
        if not url:
            url = self.url_to_crawl
        self.driver.get(url)
        sleep(3)
    
    def _populate_dictionary(self, xpath):
        return self.driver.find_elements(By.XPATH, xpath)

# %%
tng = StarTrekSpider(url=url_base.format('tng'))

# %%
tng.open_webdriver()
# Out:
# Webdriver opened

# %%
tng.get_url()

# %%
tng._populate_dictionary(xpath=xpath)

# %%
url_base.format('tng')
# Out:
# 'https://sites.google.com/site/tvwriting/us-drama/show-collections/star-trek-tng'

# %%
r = requests.get(url_base.format('tng'))

# %%
episodes = {}

# %%
soup = BeautifulSoup(r.content, 'lxml')

# %%
st_classes = {'tng': 'dhtgD'}

# %%
class StarTrekPreprocessing():
    _classes = {'tng': 'dhtgD'}
    _full_name = 'Star Trek - {}'
    _series_names = {'tng': 'The Next Generation', 'tos': 'The Original Series', 'voy': 'Voyager', 'ds9': 'Deep Space Nine'}
    
    def __init__(self, show='tng', url=None):
        self.show = show
        self.url = url
    
    def _populate_episodes(self):
        self.file_names = [s.contents[0] for s in soup.find_all('a', class_=self._classes[self.show])]

# %%
_classes = {'tng': 'dhtgD'}
_full_name = 'Star Trek - {}'
_series_names = {'tng': 'The Next Generation', 'tos': 'The Original Series', 'voy': 'Voyager', 'ds9': 'Deep Space Nine'}

# %%
from episode import Episode

# %%
import os
from pathlib import Path
import re

episode_name_regex = r"(?<=\-\s).*(?=\.)" # (?<=\-\s) matches after '- ', (?=\.) matches before '.', and '.*' is everything inside.

# %%
for s in soup.find_all('a', class_=_classes['tng']):
    print(re.search(episode_name_regex, s.contents[0][len(_full_name.format(_series_names['tng']))+1:]))
# Out:
# None
# <re.Match object; span=(11, 32), match='Encounter at Farpoint'>
# <re.Match object; span=(7, 20), match='The Naked Now'>
# <re.Match object; span=(7, 20), match='Code of Honor'>
# <re.Match object; span=(7, 36), match='Haven aka Eye of The Beholder'>
# <re.Match object; span=(7, 34), match='Where None Have Gone Before'>
# <re.Match object; span=(7, 23), match='The Last Outpost'>
# <re.Match object; span=(7, 22), match='Lonely Among Us'>
# <re.Match object; span=(7, 14), match='Justice'>
# <re.Match object; span=(7, 17), match='The Battle'>
# <re.Match object; span=(7, 17), match='Hide And Q'>
# <re.Match object; span=(7, 25), match='Too Short A Season'>
# <re.Match object; span=(7, 23), match='The Big Good-bye'>
# <re.Match object; span=(7, 15), match='Datalore'>
# <re.Match object; span=(7, 16), match='Angel One'>
# <re.Match object; span=(7, 28), match='11001001 aka 10101001'>
# <re.Match object; span=(7, 16), match='Home Soil'>
# <re.Match object; span=(7, 28), match='When the Bough Breaks'>
# <re.Match object; span=(7, 42), match='Coming Of Age aka Starfleet Academy'>
# <re.Match object; span=(7, 21), match='Heart Of Glory'>
# <re.Match object; span=(7, 51), match='The Arsenal Of Freedom aka Among The Missing'>
# <re.Match object; span=(7, 34), match='Skin of Evil aka The Shroud'>
# <re.Match object; span=(7, 16), match='Symbiosis'>
# <re.Match object; span=(7, 30), match="We'll Always Have Paris">
# <re.Match object; span=(7, 17), match='Conspiracy'>
# <re.Match object; span=(7, 23), match='The Neutral Zone'>
# <re.Match object; span=(7, 16), match='The Child'>
# <re.Match object; span=(7, 30), match='Where Silence Has Lease'>
# <re.Match object; span=(7, 28), match='Elementary, Dear Data'>
# <re.Match object; span=(7, 27), match='The Outrageous Okona'>
# <re.Match object; span=(7, 24), match='Loud as a Whisper'>
# <re.Match object; span=(7, 23), match='The Schizoid Man'>
# <re.Match object; span=(7, 26), match='Unnatural Selection'>
# <re.Match object; span=(7, 24), match='A Matter of Honor'>
# <re.Match object; span=(7, 27), match='The Measure of a Man'>
# <re.Match object; span=(7, 18), match='The Dauphin'>
# <re.Match object; span=(7, 16), match='Contagion'>
# <re.Match object; span=(7, 17), match='The Royale'>
# <re.Match object; span=(7, 19), match='Time Squared'>
# <re.Match object; span=(7, 24), match='The Icarus Factor'>
# <re.Match object; span=(7, 15), match='Pen Pals'>
# <re.Match object; span=(7, 12), match='Q Who'>
# <re.Match object; span=(7, 22), match='Samaritan Snare'>
# <re.Match object; span=(7, 25), match='Up the Long Ladder'>
# <re.Match object; span=(7, 14), match='Manhunt'>
# <re.Match object; span=(7, 19), match='The Emissary'>
# <re.Match object; span=(7, 23), match='Peak Performance'>
# <re.Match object; span=(7, 21), match='Shades of Gray'>
# <re.Match object; span=(7, 16), match='Evolution'>
# <re.Match object; span=(7, 29), match='The Ensigns of Command'>
# <re.Match object; span=(7, 20), match='The Survivors'>
# <re.Match object; span=(7, 31), match='Who Watches the Watchers'>
# <re.Match object; span=(7, 18), match='The Bonding'>
# <re.Match object; span=(7, 17), match='Booby Trap'>
# <re.Match object; span=(7, 16), match='The Enemy'>
# <re.Match object; span=(7, 16), match='The Price'>
# <re.Match object; span=(7, 27), match='The Vengeance Factor'>
# <re.Match object; span=(7, 19), match='The Defector'>
# <re.Match object; span=(7, 17), match='The Hunted'>
# <re.Match object; span=(7, 22), match='The High Ground'>
# <re.Match object; span=(7, 13), match='Deja Q'>
# <re.Match object; span=(7, 30), match='A Matter of Perspective'>
# <re.Match object; span=(7, 29), match="Yesterday's Enterprise">
# <re.Match object; span=(7, 20), match='The Offspring'>
# <re.Match object; span=(7, 25), match='Sins of the Father'>
# <re.Match object; span=(7, 17), match='Allegiance'>
# <re.Match object; span=(7, 24), match="Captain's Holiday">
# <re.Match object; span=(7, 14), match='Tin Man'>
# <re.Match object; span=(7, 22), match='Hollow Pursuits'>
# <re.Match object; span=(7, 20), match='The Most Toys'>
# <re.Match object; span=(7, 12), match='Sarek'>
# <re.Match object; span=(7, 20), match='Menage a Troi'>
# <re.Match object; span=(7, 23), match='Transfigurations'>
# <re.Match object; span=(7, 38), match='The Best of Both Worlds, Part I'>
# <re.Match object; span=(7, 39), match='The Best of Both Worlds, Part II'>
# <re.Match object; span=(7, 13), match='Family'>
# <re.Match object; span=(7, 15), match='Brothers'>
# <re.Match object; span=(7, 21), match='Suddenly Human'>
# <re.Match object; span=(7, 18), match='Remember Me'>
# <re.Match object; span=(7, 13), match='Legacy'>
# <re.Match object; span=(7, 14), match='Reunion'>
# <re.Match object; span=(7, 23), match='Future Imperfect'>
# <re.Match object; span=(7, 20), match='Final Mission'>
# <re.Match object; span=(7, 15), match='The Loss'>
# <re.Match object; span=(7, 17), match="Data's Day">
# <re.Match object; span=(7, 18), match='The Wounded'>
# <re.Match object; span=(7, 18), match="Devil's Due">
# <re.Match object; span=(7, 12), match='Clues'>
# <re.Match object; span=(7, 20), match='First Contact'>
# <re.Match object; span=(7, 21), match="Galaxy's Child">
# <re.Match object; span=(7, 20), match='Night Terrors'>
# <re.Match object; span=(7, 22), match='Identity Crisis'>
# <re.Match object; span=(7, 21), match='The Nth Degree'>
# <re.Match object; span=(7, 11), match='Qpid'>
# <re.Match object; span=(7, 19), match='The Drumhead'>
# <re.Match object; span=(7, 18), match='Half a Life'>
# <re.Match object; span=(7, 15), match='The Host'>
# <re.Match object; span=(7, 21), match="The Mind's Eye">
# <re.Match object; span=(7, 16), match='In Theory'>
# <re.Match object; span=(7, 25), match='Redemption, Part I'>
# <re.Match object; span=(7, 26), match='Redemption, Part II'>
# <re.Match object; span=(7, 13), match='Darmok'>
# <re.Match object; span=(7, 16), match='Ensign Ro'>
# <re.Match object; span=(7, 21), match='Silicon Avatar'>
# <re.Match object; span=(7, 15), match='Disaster'>
# <re.Match object; span=(7, 15), match='The Game'>
# <re.Match object; span=(7, 25), match='Unification Part I'>
# <re.Match object; span=(7, 26), match='Unification Part II'>
# <re.Match object; span=(7, 23), match='A Matter of Time'>
# <re.Match object; span=(7, 17), match='New Ground'>
# <re.Match object; span=(7, 19), match='Hero Worship'>
# <re.Match object; span=(7, 17), match='Violations'>
# <re.Match object; span=(7, 30), match='The Masterpiece Society'>
# <re.Match object; span=(7, 16), match='Conundrum'>
# <re.Match object; span=(7, 17), match='Power Play'>
# <re.Match object; span=(7, 13), match='Ethics'>
# <re.Match object; span=(7, 18), match='The Outcast'>
# <re.Match object; span=(7, 23), match='Cause and Effect'>
# <re.Match object; span=(7, 21), match='The First Duty'>
# <re.Match object; span=(7, 21), match='Cost of Living'>
# <re.Match object; span=(7, 23), match='The Perfect Mate'>
# <re.Match object; span=(7, 23), match='Imaginary Friend'>
# <re.Match object; span=(7, 14), match='I, Borg'>
# <re.Match object; span=(7, 21), match='The Next Phase'>
# <re.Match object; span=(7, 22), match='The Inner Light'>
# <re.Match object; span=(7, 27), match="Time's Arrow, Part I">
# <re.Match object; span=(7, 28), match="Time's Arrow, Part II">
# <re.Match object; span=(7, 20), match='Realm of Fear'>
# <re.Match object; span=(7, 24), match='Man of the People'>
# <re.Match object; span=(7, 13), match='Relics'>
# <re.Match object; span=(7, 14), match='Schisms'>
# <re.Match object; span=(7, 13), match='True Q'>
# <re.Match object; span=(7, 14), match='Rascals'>
# <re.Match object; span=(7, 25), match='A Fistful of Datas'>
# <re.Match object; span=(7, 26), match='The Quality of Life'>
# <re.Match object; span=(7, 31), match='Chain of Command, Part I'>
# <re.Match object; span=(7, 32), match='Chain of Command, Part II'>
# <re.Match object; span=(7, 23), match='Ship in a Bottle'>
# <re.Match object; span=(7, 13), match='Aquiel'>
# <re.Match object; span=(7, 24), match='Face of the Enemy'>
# <re.Match object; span=(7, 15), match='Tapestry'>
# <re.Match object; span=(7, 17), match='Birthright'>
# <re.Match object; span=(7, 25), match='Birthright Part II'>
# <re.Match object; span=(7, 20), match='Starship Mine'>
# <re.Match object; span=(7, 14), match='Lessons'>
# <re.Match object; span=(7, 16), match='The Chase'>
# <re.Match object; span=(7, 20), match='Frame of Mind'>
# <re.Match object; span=(7, 17), match='Suspicions'>
# <re.Match object; span=(7, 20), match='Rightful Heir'>
# <re.Match object; span=(7, 21), match='Second Chances'>
# <re.Match object; span=(7, 16), match='Timescape'>
# <re.Match object; span=(7, 22), match='Descent, Part I'>
# <re.Match object; span=(7, 23), match='Descent, Part II'>
# <re.Match object; span=(7, 15), match='Liaisons'>
# <re.Match object; span=(7, 16), match='Interface'>
# <re.Match object; span=(7, 21), match='Gambit, Part I'>
# <re.Match object; span=(7, 22), match='Gambit, Part II'>
# <re.Match object; span=(7, 16), match='Phantasms'>
# <re.Match object; span=(7, 16), match='Dark Page'>
# <re.Match object; span=(7, 15), match='Attached'>
# <re.Match object; span=(7, 22), match='Force of Nature'>
# <re.Match object; span=(7, 18), match='Inheritance'>
# <re.Match object; span=(7, 16), match='Parallels'>
# <re.Match object; span=(7, 18), match='The Pegasus'>
# <re.Match object; span=(7, 15), match='Homeward'>
# <re.Match object; span=(7, 15), match='Sub Rosa'>
# <re.Match object; span=(7, 18), match='Lower Decks'>
# <re.Match object; span=(7, 21), match='Thine Own Self'>
# <re.Match object; span=(7, 12), match='Masks'>
# <re.Match object; span=(7, 26), match='Eye of the Beholder'>
# <re.Match object; span=(7, 14), match='Genesis'>
# <re.Match object; span=(7, 20), match="Journey's End">
# <re.Match object; span=(7, 16), match='Firstborn'>
# <re.Match object; span=(7, 17), match='Bloodlines'>
# <re.Match object; span=(7, 16), match='Emergence'>
# <re.Match object; span=(7, 24), match='Preemptive Strike'>
# <re.Match object; span=(7, 22), match='All Good Things'>

# %%
[(s.contents[0][len(_full_name.format(_series_names['tng']))+1:]) for s in soup.find_all('a', class_='dhtgD')]
# Out:
# ['Bible.pdf',
#  '1x01-102 - Encounter at Farpoint.pdf',
#  '1x03 - The Naked Now.pdf',
#  '1x04 - Code of Honor.pdf',
#  '1x05 - Haven aka Eye of The Beholder.pdf',
#  '1x06 - Where None Have Gone Before.pdf',
#  '1x07 - The Last Outpost.pdf',
#  '1x08 - Lonely Among Us.pdf',
#  '1x09 - Justice.pdf',
#  '1x10 - The Battle.pdf',
#  '1x11 - Hide And Q.pdf',
#  '1x12 - Too Short A Season.pdf',
#  '1x13 - The Big Good-bye.pdf',
#  '1x14 - Datalore.pdf',
#  '1x15 - Angel One.pdf',
#  '1x16 - 11001001 aka 10101001.pdf',
#  '1x17 - Home Soil.pdf',
#  '1x18 - When the Bough Breaks.pdf',
#  '1x19 - Coming Of Age aka Starfleet Academy.pdf',
#  '1x20 - Heart Of Glory.pdf',
#  '1x21 - The Arsenal Of Freedom aka Among The Missing.pdf',
#  '1x22 - Skin of Evil aka The Shroud.pdf',
#  '1x23 - Symbiosis.pdf',
#  "1x24 - We'll Always Have Paris.pdf",
#  '1x25 - Conspiracy.pdf',
#  '1x26 - The Neutral Zone.pdf',
#  '2x01 - The Child.pdf',
#  '2x02 - Where Silence Has Lease.pdf',
#  '2x03 - Elementary, Dear Data.pdf',
#  '2x04 - The Outrageous Okona.pdf',
#  '2x05 - Loud as a Whisper.pdf',
#  '2x06 - The Schizoid Man.pdf',
#  '2x07 - Unnatural Selection.pdf',
#  '2x08 - A Matter of Honor.pdf',
#  '2x09 - The Measure of a Man.pdf',
#  '2x10 - The Dauphin.pdf',
#  '2x11 - Contagion.pdf',
#  '2x12 - The Royale.pdf',
#  '2x13 - Time Squared.pdf',
#  '2x14 - The Icarus Factor.pdf',
#  '2x15 - Pen Pals.pdf',
#  '2x16 - Q Who.pdf',
#  '2x17 - Samaritan Snare.pdf',
#  '2x18 - Up the Long Ladder.pdf',
#  '2x19 - Manhunt.pdf',
#  '2x20 - The Emissary.pdf',
#  '2x21 - Peak Performance.pdf',
#  '2x22 - Shades of Gray.pdf',
#  '3x01 - Evolution.pdf',
#  '3x02 - The Ensigns of Command.pdf',
#  '3x03 - The Survivors.pdf',
#  '3x04 - Who Watches the Watchers.pdf',
#  '3x05 - The Bonding.pdf',
#  '3x06 - Booby Trap.pdf',
#  '3x07 - The Enemy.pdf',
#  '3x08 - The Price.pdf',
#  '3x09 - The Vengeance Factor.pdf',
#  '3x10 - The Defector.pdf',
#  '3x11 - The Hunted.pdf',
#  '3x12 - The High Ground.pdf',
#  '3x13 - Deja Q.pdf',
#  '3x14 - A Matter of Perspective.pdf',
#  "3x15 - Yesterday's Enterprise.pdf",
#  '3x16 - The Offspring.pdf',
#  '3x17 - Sins of the Father.pdf',
#  '3x18 - Allegiance.pdf',
#  "3x19 - Captain's Holiday.pdf",
#  '3x20 - Tin Man.pdf',
#  '3x21 - Hollow Pursuits.pdf',
#  '3x22 - The Most Toys.pdf',
#  '3x23 - Sarek.pdf',
#  '3x24 - Menage a Troi.pdf',
#  '3x25 - Transfigurations.pdf',
#  '3x26 - The Best of Both Worlds, Part I.pdf',
#  '4x01 - The Best of Both Worlds, Part II.pdf',
#  '4x02 - Family.pdf',
#  '4x03 - Brothers.pdf',
#  '4x04 - Suddenly Human.pdf',
#  '4x05 - Remember Me.pdf',
#  '4x06 - Legacy.pdf',
#  '4x07 - Reunion.pdf',
#  '4x08 - Future Imperfect.pdf',
#  '4x09 - Final Mission.pdf',
#  '4x10 - The Loss.pdf',
#  "4x11 - Data's Day.pdf",
#  '4x12 - The Wounded.pdf',
#  "4x13 - Devil's Due.pdf",
#  '4x14 - Clues.pdf',
#  '4x15 - First Contact.pdf',
#  "4x16 - Galaxy's Child.pdf",
#  '4x17 - Night Terrors.pdf',
#  '4x18 - Identity Crisis.pdf',
#  '4x19 - The Nth Degree.pdf',
#  '4x20 - Qpid.pdf',
#  '4x21 - The Drumhead.pdf',
#  '4x22 - Half a Life.pdf',
#  '4x23 - The Host.pdf',
#  "4x24 - The Mind's Eye.pdf",
#  '4x25 - In Theory.pdf',
#  '4x26 - Redemption, Part I.pdf',
#  '5x01 - Redemption, Part II.txt',
#  '5x02 - Darmok.txt',
#  '5x03 - Ensign Ro.txt',
#  '5x04 - Silicon Avatar.txt',
#  '5x05 - Disaster.txt',
#  '5x06 - The Game.txt',
#  '5x07 - Unification Part I.txt',
#  '5x08 - Unification Part II.txt',
#  '5x09 - A Matter of Time.txt',
#  '5x10 - New Ground.txt',
#  '5x11 - Hero Worship.txt',
#  '5x12 - Violations.txt',
#  '5x13 - The Masterpiece Society.txt',
#  '5x14 - Conundrum.txt',
#  '5x15 - Power Play.txt',
#  '5x16 - Ethics.txt',
#  '5x17 - The Outcast.txt',
#  '5x18 - Cause and Effect.txt',
#  '5x19 - The First Duty.txt',
#  '5x20 - Cost of Living.txt',
#  '5x21 - The Perfect Mate.txt',
#  '5x22 - Imaginary Friend.txt',
#  '5x23 - I, Borg.txt',
#  '5x24 - The Next Phase.txt',
#  '5x25 - The Inner Light.txt',
#  "5x26 - Time's Arrow, Part I.txt",
#  "6x01 - Time's Arrow, Part II.txt",
#  '6x02 - Realm of Fear.txt',
#  '6x03 - Man of the People.txt',
#  '6x04 - Relics.txt',
#  '6x05 - Schisms.txt',
#  '6x06 - True Q.txt',
#  '6x07 - Rascals.txt',
#  '6x08 - A Fistful of Datas.txt',
#  '6x09 - The Quality of Life.txt',
#  '6x10 - Chain of Command, Part I.txt',
#  '6x11 - Chain of Command, Part II.txt',
#  '6x12 - Ship in a Bottle.txt',
#  '6x13 - Aquiel.txt',
#  '6x14 - Face of the Enemy.txt',
#  '6x15 - Tapestry.txt',
#  '6x16 - Birthright.txt',
#  '6x17 - Birthright Part II.txt',
#  '6x18 - Starship Mine.txt',
#  '6x19 - Lessons.txt',
#  '6x20 - The Chase.txt',
#  '6x21 - Frame of Mind.txt',
#  '6x22 - Suspicions.txt',
#  '6x23 - Rightful Heir.txt',
#  '6x24 - Second Chances.txt',
#  '6x25 - Timescape.txt',
#  '6x26 - Descent, Part I.txt',
#  '7x01 - Descent, Part II.txt',
#  '7x02 - Liaisons.txt',
#  '7x03 - Interface.txt',
#  '7x04 - Gambit, Part I.txt',
#  '7x05 - Gambit, Part II.txt',
#  '7x06 - Phantasms.txt',
#  '7x07 - Dark Page.txt',
#  '7x08 - Attached.txt',
#  '7x09 - Force of Nature.txt',
#  '7x10 - Inheritance.txt',
#  '7x11 - Parallels.txt',
#  '7x12 - The Pegasus.txt',
#  '7x13 - Homeward.txt',
#  '7x14 - Sub Rosa.txt',
#  '7x15 - Lower Decks.txt',
#  '7x16 - Thine Own Self.txt',
#  '7x17 - Masks.txt',
#  '7x18 - Eye of the Beholder.txt',
#  '7x19 - Genesis.txt',
#  "7x20 - Journey's End.txt",
#  '7x21 - Firstborn.txt',
#  '7x22 - Bloodlines.txt',
#  '7x23 - Emergence.txt',
#  '7x24 - Preemptive Strike.txt',
#  '7x25 - All Good Things.txt']

# %%
# Extract episode numbers, names, and filetypes from source and store in dict
[s.contents[0][len(_full_name.format(_series_names['tng']))+1:] for s in soup.find_all('a', class_='dhtgD')]
# Out:
# ['Bible.pdf',
#  '1x01-102 - Encounter at Farpoint.pdf',
#  '1x03 - The Naked Now.pdf',
#  '1x04 - Code of Honor.pdf',
#  '1x05 - Haven aka Eye of The Beholder.pdf',
#  '1x06 - Where None Have Gone Before.pdf',
#  '1x07 - The Last Outpost.pdf',
#  '1x08 - Lonely Among Us.pdf',
#  '1x09 - Justice.pdf',
#  '1x10 - The Battle.pdf',
#  '1x11 - Hide And Q.pdf',
#  '1x12 - Too Short A Season.pdf',
#  '1x13 - The Big Good-bye.pdf',
#  '1x14 - Datalore.pdf',
#  '1x15 - Angel One.pdf',
#  '1x16 - 11001001 aka 10101001.pdf',
#  '1x17 - Home Soil.pdf',
#  '1x18 - When the Bough Breaks.pdf',
#  '1x19 - Coming Of Age aka Starfleet Academy.pdf',
#  '1x20 - Heart Of Glory.pdf',
#  '1x21 - The Arsenal Of Freedom aka Among The Missing.pdf',
#  '1x22 - Skin of Evil aka The Shroud.pdf',
#  '1x23 - Symbiosis.pdf',
#  "1x24 - We'll Always Have Paris.pdf",
#  '1x25 - Conspiracy.pdf',
#  '1x26 - The Neutral Zone.pdf',
#  '2x01 - The Child.pdf',
#  '2x02 - Where Silence Has Lease.pdf',
#  '2x03 - Elementary, Dear Data.pdf',
#  '2x04 - The Outrageous Okona.pdf',
#  '2x05 - Loud as a Whisper.pdf',
#  '2x06 - The Schizoid Man.pdf',
#  '2x07 - Unnatural Selection.pdf',
#  '2x08 - A Matter of Honor.pdf',
#  '2x09 - The Measure of a Man.pdf',
#  '2x10 - The Dauphin.pdf',
#  '2x11 - Contagion.pdf',
#  '2x12 - The Royale.pdf',
#  '2x13 - Time Squared.pdf',
#  '2x14 - The Icarus Factor.pdf',
#  '2x15 - Pen Pals.pdf',
#  '2x16 - Q Who.pdf',
#  '2x17 - Samaritan Snare.pdf',
#  '2x18 - Up the Long Ladder.pdf',
#  '2x19 - Manhunt.pdf',
#  '2x20 - The Emissary.pdf',
#  '2x21 - Peak Performance.pdf',
#  '2x22 - Shades of Gray.pdf',
#  '3x01 - Evolution.pdf',
#  '3x02 - The Ensigns of Command.pdf',
#  '3x03 - The Survivors.pdf',
#  '3x04 - Who Watches the Watchers.pdf',
#  '3x05 - The Bonding.pdf',
#  '3x06 - Booby Trap.pdf',
#  '3x07 - The Enemy.pdf',
#  '3x08 - The Price.pdf',
#  '3x09 - The Vengeance Factor.pdf',
#  '3x10 - The Defector.pdf',
#  '3x11 - The Hunted.pdf',
#  '3x12 - The High Ground.pdf',
#  '3x13 - Deja Q.pdf',
#  '3x14 - A Matter of Perspective.pdf',
#  "3x15 - Yesterday's Enterprise.pdf",
#  '3x16 - The Offspring.pdf',
#  '3x17 - Sins of the Father.pdf',
#  '3x18 - Allegiance.pdf',
#  "3x19 - Captain's Holiday.pdf",
#  '3x20 - Tin Man.pdf',
#  '3x21 - Hollow Pursuits.pdf',
#  '3x22 - The Most Toys.pdf',
#  '3x23 - Sarek.pdf',
#  '3x24 - Menage a Troi.pdf',
#  '3x25 - Transfigurations.pdf',
#  '3x26 - The Best of Both Worlds, Part I.pdf',
#  '4x01 - The Best of Both Worlds, Part II.pdf',
#  '4x02 - Family.pdf',
#  '4x03 - Brothers.pdf',
#  '4x04 - Suddenly Human.pdf',
#  '4x05 - Remember Me.pdf',
#  '4x06 - Legacy.pdf',
#  '4x07 - Reunion.pdf',
#  '4x08 - Future Imperfect.pdf',
#  '4x09 - Final Mission.pdf',
#  '4x10 - The Loss.pdf',
#  "4x11 - Data's Day.pdf",
#  '4x12 - The Wounded.pdf',
#  "4x13 - Devil's Due.pdf",
#  '4x14 - Clues.pdf',
#  '4x15 - First Contact.pdf',
#  "4x16 - Galaxy's Child.pdf",
#  '4x17 - Night Terrors.pdf',
#  '4x18 - Identity Crisis.pdf',
#  '4x19 - The Nth Degree.pdf',
#  '4x20 - Qpid.pdf',
#  '4x21 - The Drumhead.pdf',
#  '4x22 - Half a Life.pdf',
#  '4x23 - The Host.pdf',
#  "4x24 - The Mind's Eye.pdf",
#  '4x25 - In Theory.pdf',
#  '4x26 - Redemption, Part I.pdf',
#  '5x01 - Redemption, Part II.txt',
#  '5x02 - Darmok.txt',
#  '5x03 - Ensign Ro.txt',
#  '5x04 - Silicon Avatar.txt',
#  '5x05 - Disaster.txt',
#  '5x06 - The Game.txt',
#  '5x07 - Unification Part I.txt',
#  '5x08 - Unification Part II.txt',
#  '5x09 - A Matter of Time.txt',
#  '5x10 - New Ground.txt',
#  '5x11 - Hero Worship.txt',
#  '5x12 - Violations.txt',
#  '5x13 - The Masterpiece Society.txt',
#  '5x14 - Conundrum.txt',
#  '5x15 - Power Play.txt',
#  '5x16 - Ethics.txt',
#  '5x17 - The Outcast.txt',
#  '5x18 - Cause and Effect.txt',
#  '5x19 - The First Duty.txt',
#  '5x20 - Cost of Living.txt',
#  '5x21 - The Perfect Mate.txt',
#  '5x22 - Imaginary Friend.txt',
#  '5x23 - I, Borg.txt',
#  '5x24 - The Next Phase.txt',
#  '5x25 - The Inner Light.txt',
#  "5x26 - Time's Arrow, Part I.txt",
#  "6x01 - Time's Arrow, Part II.txt",
#  '6x02 - Realm of Fear.txt',
#  '6x03 - Man of the People.txt',
#  '6x04 - Relics.txt',
#  '6x05 - Schisms.txt',
#  '6x06 - True Q.txt',
#  '6x07 - Rascals.txt',
#  '6x08 - A Fistful of Datas.txt',
#  '6x09 - The Quality of Life.txt',
#  '6x10 - Chain of Command, Part I.txt',
#  '6x11 - Chain of Command, Part II.txt',
#  '6x12 - Ship in a Bottle.txt',
#  '6x13 - Aquiel.txt',
#  '6x14 - Face of the Enemy.txt',
#  '6x15 - Tapestry.txt',
#  '6x16 - Birthright.txt',
#  '6x17 - Birthright Part II.txt',
#  '6x18 - Starship Mine.txt',
#  '6x19 - Lessons.txt',
#  '6x20 - The Chase.txt',
#  '6x21 - Frame of Mind.txt',
#  '6x22 - Suspicions.txt',
#  '6x23 - Rightful Heir.txt',
#  '6x24 - Second Chances.txt',
#  '6x25 - Timescape.txt',
#  '6x26 - Descent, Part I.txt',
#  '7x01 - Descent, Part II.txt',
#  '7x02 - Liaisons.txt',
#  '7x03 - Interface.txt',
#  '7x04 - Gambit, Part I.txt',
#  '7x05 - Gambit, Part II.txt',
#  '7x06 - Phantasms.txt',
#  '7x07 - Dark Page.txt',
#  '7x08 - Attached.txt',
#  '7x09 - Force of Nature.txt',
#  '7x10 - Inheritance.txt',
#  '7x11 - Parallels.txt',
#  '7x12 - The Pegasus.txt',
#  '7x13 - Homeward.txt',
#  '7x14 - Sub Rosa.txt',
#  '7x15 - Lower Decks.txt',
#  '7x16 - Thine Own Self.txt',
#  '7x17 - Masks.txt',
#  '7x18 - Eye of the Beholder.txt',
#  '7x19 - Genesis.txt',
#  "7x20 - Journey's End.txt",
#  '7x21 - Firstborn.txt',
#  '7x22 - Bloodlines.txt',
#  '7x23 - Emergence.txt',
#  '7x24 - Preemptive Strike.txt',
#  '7x25 - All Good Things.txt']

# %%
def pdf_url(series='tng', season, episode):
