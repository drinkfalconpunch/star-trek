# %%
from preprocess import StarTrekPreprocessing

# %%
tng = StarTrekPreprocessing('tng', 'https://sites.google.com/site/tvwriting/us-drama/show-collections/star-trek-{}')

# %%
tng._populate_episodes()

# %%
tng.episodes
# Out:
# [Episode(series_name='The Next Generation', season_number=0, episode_number=0, episode_name='', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='01', episode_name='Encounter at Farpoint', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='03', episode_name='The Naked Now', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='04', episode_name='Code of Honor', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='05', episode_name='Haven', alt_name='Eye of The Beholder', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='06', episode_name='Where None Have Gone Before', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='07', episode_name='The Last Outpost', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='08', episode_name='Lonely Among Us', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='09', episode_name='Justice', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='10', episode_name='The Battle', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='11', episode_name='Hide And Q', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='12', episode_name='Too Short A Season', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='13', episode_name='The Big Good-bye', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='14', episode_name='Datalore', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='15', episode_name='Angel One', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='16', episode_name='11001001', alt_name='10101001', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='17', episode_name='Home Soil', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='18', episode_name='When the Bough Breaks', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='19', episode_name='Coming Of Age', alt_name='Starfleet Academy', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='20', episode_name='Heart Of Glory', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='21', episode_name='The Arsenal Of Freedom', alt_name='Among The Missing', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='22', episode_name='Skin of Evil', alt_name='The Shroud', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='23', episode_name='Symbiosis', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='24', episode_name="We'll Always Have Paris", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='25', episode_name='Conspiracy', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='1', episode_number='26', episode_name='The Neutral Zone', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='01', episode_name='The Child', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='02', episode_name='Where Silence Has Lease', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='03', episode_name='Elementary, Dear Data', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='04', episode_name='The Outrageous Okona', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='05', episode_name='Loud as a Whisper', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='06', episode_name='The Schizoid Man', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='07', episode_name='Unnatural Selection', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='08', episode_name='A Matter of Honor', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='09', episode_name='The Measure of a Man', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='10', episode_name='The Dauphin', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='11', episode_name='Contagion', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='12', episode_name='The Royale', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='13', episode_name='Time Squared', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='14', episode_name='The Icarus Factor', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='15', episode_name='Pen Pals', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='16', episode_name='Q Who', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='17', episode_name='Samaritan Snare', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='18', episode_name='Up the Long Ladder', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='19', episode_name='Manhunt', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='20', episode_name='The Emissary', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='21', episode_name='Peak Performance', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='2', episode_number='22', episode_name='Shades of Gray', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='01', episode_name='Evolution', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='02', episode_name='The Ensigns of Command', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='03', episode_name='The Survivors', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='04', episode_name='Who Watches the Watchers', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='05', episode_name='The Bonding', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='06', episode_name='Booby Trap', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='07', episode_name='The Enemy', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='08', episode_name='The Price', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='09', episode_name='The Vengeance Factor', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='10', episode_name='The Defector', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='11', episode_name='The Hunted', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='12', episode_name='The High Ground', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='13', episode_name='Deja Q', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='14', episode_name='A Matter of Perspective', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='15', episode_name="Yesterday's Enterprise", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='16', episode_name='The Offspring', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='17', episode_name='Sins of the Father', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='18', episode_name='Allegiance', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='19', episode_name="Captain's Holiday", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='20', episode_name='Tin Man', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='21', episode_name='Hollow Pursuits', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='22', episode_name='The Most Toys', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='23', episode_name='Sarek', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='24', episode_name='Menage a Troi', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='25', episode_name='Transfigurations', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='3', episode_number='26', episode_name='The Best of Both Worlds, Part I', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='01', episode_name='The Best of Both Worlds, Part II', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='02', episode_name='Family', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='03', episode_name='Brothers', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='04', episode_name='Suddenly Human', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='05', episode_name='Remember Me', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='06', episode_name='Legacy', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='07', episode_name='Reunion', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='08', episode_name='Future Imperfect', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='09', episode_name='Final Mission', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='10', episode_name='The Loss', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='11', episode_name="Data's Day", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='12', episode_name='The Wounded', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='13', episode_name="Devil's Due", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='14', episode_name='Clues', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='15', episode_name='First Contact', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='16', episode_name="Galaxy's Child", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='17', episode_name='Night Terrors', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='18', episode_name='Identity Crisis', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='19', episode_name='The Nth Degree', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='20', episode_name='Qpid', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='21', episode_name='The Drumhead', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='22', episode_name='Half a Life', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='23', episode_name='The Host', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='24', episode_name="The Mind's Eye", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='25', episode_name='In Theory', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='4', episode_number='26', episode_name='Redemption, Part I', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='01', episode_name='Redemption, Part II', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='02', episode_name='Darmok', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='03', episode_name='Ensign Ro', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='04', episode_name='Silicon Avatar', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='05', episode_name='Disaster', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='06', episode_name='The Game', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='07', episode_name='Unification Part I', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='08', episode_name='Unification Part II', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='09', episode_name='A Matter of Time', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='10', episode_name='New Ground', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='11', episode_name='Hero Worship', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='12', episode_name='Violations', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='13', episode_name='The Masterpiece Society', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='14', episode_name='Conundrum', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='15', episode_name='Power Play', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='16', episode_name='Ethics', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='17', episode_name='The Outcast', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='18', episode_name='Cause and Effect', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='19', episode_name='The First Duty', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='20', episode_name='Cost of Living', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='21', episode_name='The Perfect Mate', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='22', episode_name='Imaginary Friend', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='23', episode_name='I, Borg', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='24', episode_name='The Next Phase', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='25', episode_name='The Inner Light', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='5', episode_number='26', episode_name="Time's Arrow, Part I", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='01', episode_name="Time's Arrow, Part II", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='02', episode_name='Realm of Fear', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='03', episode_name='Man of the People', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='04', episode_name='Relics', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='05', episode_name='Schisms', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='06', episode_name='True Q', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='07', episode_name='Rascals', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='08', episode_name='A Fistful of Datas', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='09', episode_name='The Quality of Life', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='10', episode_name='Chain of Command, Part I', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='11', episode_name='Chain of Command, Part II', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='12', episode_name='Ship in a Bottle', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='13', episode_name='Aquiel', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='14', episode_name='Face of the Enemy', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='15', episode_name='Tapestry', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='16', episode_name='Birthright', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='17', episode_name='Birthright Part II', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='18', episode_name='Starship Mine', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='19', episode_name='Lessons', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='20', episode_name='The Chase', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='21', episode_name='Frame of Mind', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='22', episode_name='Suspicions', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='23', episode_name='Rightful Heir', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='24', episode_name='Second Chances', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='25', episode_name='Timescape', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='6', episode_number='26', episode_name='Descent, Part I', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='01', episode_name='Descent, Part II', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='02', episode_name='Liaisons', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='03', episode_name='Interface', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='04', episode_name='Gambit, Part I', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='05', episode_name='Gambit, Part II', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='06', episode_name='Phantasms', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='07', episode_name='Dark Page', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='08', episode_name='Attached', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='09', episode_name='Force of Nature', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='10', episode_name='Inheritance', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='11', episode_name='Parallels', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='12', episode_name='The Pegasus', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='13', episode_name='Homeward', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='14', episode_name='Sub Rosa', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='15', episode_name='Lower Decks', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='16', episode_name='Thine Own Self', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='17', episode_name='Masks', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='18', episode_name='Eye of the Beholder', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='19', episode_name='Genesis', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='20', episode_name="Journey's End", alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='21', episode_name='Firstborn', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='22', episode_name='Bloodlines', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='23', episode_name='Emergence', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='24', episode_name='Preemptive Strike', alt_name='', multi_part=False, script_file_type='', script=''),
#  Episode(series_name='The Next Generation', season_number='7', episode_number='25', episode_name='All Good Things', alt_name='', multi_part=False, script_file_type='', script='')]

# %%
import requests
import selenium
from bs4 import BeautifulSoup

# %%
tng_url = 'http://leethomson.myzen.co.uk/Star_Trek/2_The_Next_Generation/Star_Trek_-_The_Next_Generation_Season_{season}/Star_Trek_-_The_Next_Generation_{season}x{episode}_-_{name}.pdf'

# %%
url_base = 'https://sites.google.com/site/tvwriting/us-drama/show-collections/star-trek-{}'
series = set(['tng', 'tos', 'ds9', 'voyager', 'enterprise'])

# %%
html = driver
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f036bb29c2f2> in <module>
# ----> 1 html = driver
#
# NameError: name 'driver' is not defined

# %%
xpath = '//*[@class="dhtgD"]'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

class StarTrekSpider():
    def __init__(self, url):
        self.url_to_crawl = url
        self.items = []
        
    def open_webdriver(self):
        self.driver = webdriver.Chrome('chromedriver.exe')
        print('Webdriver opened')
        sleep(5)
    
    def close_webdriver(self):
        self.driver.quit()
        print('Webdriver closed')
    
    def get_url(self, url=None):
        if not url:
            url = self.url_to_crawl
        self.driver.get(url)
        sleep(3)
    
    def _populate_dictionary(self, xpath):
        return self.driver.find_elements(By.XPATH, xpath)

# %%
tng = StarTrekSpider(url=url_base.format('tng'))

# %%
tng.open_webdriver()
# Out:
# Webdriver opened

# %%
tng.get_url()

# %%
tng._populate_dictionary(xpath=xpath)

# %%
url_base.format('tng')
# Out:
# 'https://sites.google.com/site/tvwriting/us-drama/show-collections/star-trek-tng'

# %%
r = requests.get(url_base.format('tng'))

# %%
episodes = {}

# %%
soup = BeautifulSoup(r.content, 'lxml')

# %%
st_classes = {'tng': 'dhtgD'}

# %%
class StarTrekPreprocessing():
    _classes = {'tng': 'dhtgD'}
    _full_name = 'Star Trek - {}'
    _series_names = {'tng': 'The Next Generation', 'tos': 'The Original Series', 'voy': 'Voyager', 'ds9': 'Deep Space Nine'}
    
    def __init__(self, show='tng', url=None):
        self.show = show
        self.url = url
        self.episodes = []
    
    def _populate_episodes(self):
        self.file_names = [s.contents[0] for s in soup.find_all('a', class_=self._classes[self.show])]

# %%
from episode import Episode

# %%
import os
from pathlib import Path
import re
import requests
import selenium
from bs4 import BeautifulSoup

from episode import Episode

url_base = 'https://sites.google.com/site/tvwriting/us-drama/show-collections/star-trek-{}'
series = set(['tng', 'tos', 'ds9', 'voyager', 'enterprise'])

r = requests.get(url_base.format('tng'))
soup = BeautifulSoup(r.content, 'lxml')

_classes = {'tng': 'dhtgD'}
_full_name = 'Star Trek - {}'
_series_names = {'tng': 'The Next Generation', 'tos': 'The Original Series', 'voy': 'Voyager', 'ds9': 'Deep Space Nine'}

episode_name_regex = r"(?<=\-\s).*(?=\.)" # (?<=\-\s) matches after '- ', (?=\.) matches before '.', and '.*' is everything inside.
alt_name_regex = r"(?<=aka\s).*$"
original_name_regex = r"^(.+?)\saka*"

episode_pattern = re.compile(episode_name_regex)
alt_name_pattern = re.compile(alt_name_regex)
original_name_pattern = re.compile(original_name_regex)

series = 'tng'

for s in soup.find_all('a', class_=_classes[series]):
    episode = Episode()
    episode.series_name = _series_names[series]
    content = s.contents[0][len(_full_name.format(_series_names[series]))+1:] # cause googling how to get after the second - is not working atm
    episode_name = re.findall(episode_pattern, content) #s.contents[0][len(_full_name.format(_series_names['tng']))+1:])
    if episode_name:
        alt_name = re.findall(alt_name_pattern, episode_name[0])
        try:
            episode.episode_name = episode_name[0].split(' aka')[0]
        except KeyError:
            pass
        if alt_name:
            episode.alt_name = alt_name[0]
        episode.script_file_path = Path(content).suffix
        episode.season_number = content[0]
        episode.episode_number = content[2:4]
    print(episode)
# Out:
# Episode(series_name='The Next Generation', season_number=0, episode_number=0, episode_name='', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='01', episode_name='Encounter at Farpoint', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='03', episode_name='The Naked Now', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='04', episode_name='Code of Honor', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='05', episode_name='Haven', alt_name='Eye of The Beholder', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='06', episode_name='Where None Have Gone Before', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='07', episode_name='The Last Outpost', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='08', episode_name='Lonely Among Us', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='09', episode_name='Justice', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='10', episode_name='The Battle', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='11', episode_name='Hide And Q', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='12', episode_name='Too Short A Season', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='13', episode_name='The Big Good-bye', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='14', episode_name='Datalore', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='15', episode_name='Angel One', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='16', episode_name='11001001', alt_name='10101001', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='17', episode_name='Home Soil', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='18', episode_name='When the Bough Breaks', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='19', episode_name='Coming Of Age', alt_name='Starfleet Academy', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='20', episode_name='Heart Of Glory', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='21', episode_name='The Arsenal Of Freedom', alt_name='Among The Missing', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='22', episode_name='Skin of Evil', alt_name='The Shroud', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='23', episode_name='Symbiosis', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='24', episode_name="We'll Always Have Paris", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='25', episode_name='Conspiracy', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='1', episode_number='26', episode_name='The Neutral Zone', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='01', episode_name='The Child', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='02', episode_name='Where Silence Has Lease', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='03', episode_name='Elementary, Dear Data', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='04', episode_name='The Outrageous Okona', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='05', episode_name='Loud as a Whisper', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='06', episode_name='The Schizoid Man', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='07', episode_name='Unnatural Selection', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='08', episode_name='A Matter of Honor', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='09', episode_name='The Measure of a Man', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='10', episode_name='The Dauphin', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='11', episode_name='Contagion', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='12', episode_name='The Royale', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='13', episode_name='Time Squared', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='14', episode_name='The Icarus Factor', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='15', episode_name='Pen Pals', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='16', episode_name='Q Who', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='17', episode_name='Samaritan Snare', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='18', episode_name='Up the Long Ladder', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='19', episode_name='Manhunt', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='20', episode_name='The Emissary', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='21', episode_name='Peak Performance', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='2', episode_number='22', episode_name='Shades of Gray', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='01', episode_name='Evolution', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='02', episode_name='The Ensigns of Command', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='03', episode_name='The Survivors', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='04', episode_name='Who Watches the Watchers', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='05', episode_name='The Bonding', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='06', episode_name='Booby Trap', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='07', episode_name='The Enemy', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='08', episode_name='The Price', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='09', episode_name='The Vengeance Factor', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='10', episode_name='The Defector', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='11', episode_name='The Hunted', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='12', episode_name='The High Ground', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='13', episode_name='Deja Q', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='14', episode_name='A Matter of Perspective', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='15', episode_name="Yesterday's Enterprise", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='16', episode_name='The Offspring', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='17', episode_name='Sins of the Father', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='18', episode_name='Allegiance', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='19', episode_name="Captain's Holiday", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='20', episode_name='Tin Man', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='21', episode_name='Hollow Pursuits', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='22', episode_name='The Most Toys', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='23', episode_name='Sarek', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='24', episode_name='Menage a Troi', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='25', episode_name='Transfigurations', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='3', episode_number='26', episode_name='The Best of Both Worlds, Part I', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='01', episode_name='The Best of Both Worlds, Part II', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='02', episode_name='Family', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='03', episode_name='Brothers', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='04', episode_name='Suddenly Human', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='05', episode_name='Remember Me', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='06', episode_name='Legacy', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='07', episode_name='Reunion', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='08', episode_name='Future Imperfect', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='09', episode_name='Final Mission', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='10', episode_name='The Loss', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='11', episode_name="Data's Day", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='12', episode_name='The Wounded', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='13', episode_name="Devil's Due", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='14', episode_name='Clues', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='15', episode_name='First Contact', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='16', episode_name="Galaxy's Child", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='17', episode_name='Night Terrors', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='18', episode_name='Identity Crisis', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='19', episode_name='The Nth Degree', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='20', episode_name='Qpid', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='21', episode_name='The Drumhead', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='22', episode_name='Half a Life', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='23', episode_name='The Host', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='24', episode_name="The Mind's Eye", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='25', episode_name='In Theory', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='4', episode_number='26', episode_name='Redemption, Part I', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='01', episode_name='Redemption, Part II', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='02', episode_name='Darmok', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='03', episode_name='Ensign Ro', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='04', episode_name='Silicon Avatar', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='05', episode_name='Disaster', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='06', episode_name='The Game', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='07', episode_name='Unification Part I', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='08', episode_name='Unification Part II', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='09', episode_name='A Matter of Time', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='10', episode_name='New Ground', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='11', episode_name='Hero Worship', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='12', episode_name='Violations', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='13', episode_name='The Masterpiece Society', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='14', episode_name='Conundrum', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='15', episode_name='Power Play', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='16', episode_name='Ethics', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='17', episode_name='The Outcast', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='18', episode_name='Cause and Effect', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='19', episode_name='The First Duty', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='20', episode_name='Cost of Living', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='21', episode_name='The Perfect Mate', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='22', episode_name='Imaginary Friend', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='23', episode_name='I, Borg', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='24', episode_name='The Next Phase', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='25', episode_name='The Inner Light', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='5', episode_number='26', episode_name="Time's Arrow, Part I", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='01', episode_name="Time's Arrow, Part II", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='02', episode_name='Realm of Fear', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='03', episode_name='Man of the People', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='04', episode_name='Relics', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='05', episode_name='Schisms', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='06', episode_name='True Q', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='07', episode_name='Rascals', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='08', episode_name='A Fistful of Datas', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='09', episode_name='The Quality of Life', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='10', episode_name='Chain of Command, Part I', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='11', episode_name='Chain of Command, Part II', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='12', episode_name='Ship in a Bottle', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='13', episode_name='Aquiel', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='14', episode_name='Face of the Enemy', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='15', episode_name='Tapestry', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='16', episode_name='Birthright', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='17', episode_name='Birthright Part II', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='18', episode_name='Starship Mine', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='19', episode_name='Lessons', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='20', episode_name='The Chase', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='21', episode_name='Frame of Mind', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='22', episode_name='Suspicions', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='23', episode_name='Rightful Heir', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='24', episode_name='Second Chances', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='25', episode_name='Timescape', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='6', episode_number='26', episode_name='Descent, Part I', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='01', episode_name='Descent, Part II', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='02', episode_name='Liaisons', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='03', episode_name='Interface', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='04', episode_name='Gambit, Part I', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='05', episode_name='Gambit, Part II', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='06', episode_name='Phantasms', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='07', episode_name='Dark Page', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='08', episode_name='Attached', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='09', episode_name='Force of Nature', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='10', episode_name='Inheritance', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='11', episode_name='Parallels', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='12', episode_name='The Pegasus', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='13', episode_name='Homeward', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='14', episode_name='Sub Rosa', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='15', episode_name='Lower Decks', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='16', episode_name='Thine Own Self', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='17', episode_name='Masks', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='18', episode_name='Eye of the Beholder', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='19', episode_name='Genesis', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='20', episode_name="Journey's End", alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='21', episode_name='Firstborn', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='22', episode_name='Bloodlines', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='23', episode_name='Emergence', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='24', episode_name='Preemptive Strike', alt_name='', multi_part=False, script_file_type='', script='')
# Episode(series_name='The Next Generation', season_number='7', episode_number='25', episode_name='All Good Things', alt_name='', multi_part=False, script_file_type='', script='')

# %%
# Extract episode numbers, names, and filetypes from source and store in dict
[s.contents[0][len(_full_name.format(_series_names['tng']))+1:] for s in soup.find_all('a', class_='dhtgD')]
# Out:
# ['Bible.pdf',
#  '1x01-102 - Encounter at Farpoint.pdf',
#  '1x03 - The Naked Now.pdf',
#  '1x04 - Code of Honor.pdf',
#  '1x05 - Haven aka Eye of The Beholder.pdf',
#  '1x06 - Where None Have Gone Before.pdf',
#  '1x07 - The Last Outpost.pdf',
#  '1x08 - Lonely Among Us.pdf',
#  '1x09 - Justice.pdf',
#  '1x10 - The Battle.pdf',
#  '1x11 - Hide And Q.pdf',
#  '1x12 - Too Short A Season.pdf',
#  '1x13 - The Big Good-bye.pdf',
#  '1x14 - Datalore.pdf',
#  '1x15 - Angel One.pdf',
#  '1x16 - 11001001 aka 10101001.pdf',
#  '1x17 - Home Soil.pdf',
#  '1x18 - When the Bough Breaks.pdf',
#  '1x19 - Coming Of Age aka Starfleet Academy.pdf',
#  '1x20 - Heart Of Glory.pdf',
#  '1x21 - The Arsenal Of Freedom aka Among The Missing.pdf',
#  '1x22 - Skin of Evil aka The Shroud.pdf',
#  '1x23 - Symbiosis.pdf',
#  "1x24 - We'll Always Have Paris.pdf",
#  '1x25 - Conspiracy.pdf',
#  '1x26 - The Neutral Zone.pdf',
#  '2x01 - The Child.pdf',
#  '2x02 - Where Silence Has Lease.pdf',
#  '2x03 - Elementary, Dear Data.pdf',
#  '2x04 - The Outrageous Okona.pdf',
#  '2x05 - Loud as a Whisper.pdf',
#  '2x06 - The Schizoid Man.pdf',
#  '2x07 - Unnatural Selection.pdf',
#  '2x08 - A Matter of Honor.pdf',
#  '2x09 - The Measure of a Man.pdf',
#  '2x10 - The Dauphin.pdf',
#  '2x11 - Contagion.pdf',
#  '2x12 - The Royale.pdf',
#  '2x13 - Time Squared.pdf',
#  '2x14 - The Icarus Factor.pdf',
#  '2x15 - Pen Pals.pdf',
#  '2x16 - Q Who.pdf',
#  '2x17 - Samaritan Snare.pdf',
#  '2x18 - Up the Long Ladder.pdf',
#  '2x19 - Manhunt.pdf',
#  '2x20 - The Emissary.pdf',
#  '2x21 - Peak Performance.pdf',
#  '2x22 - Shades of Gray.pdf',
#  '3x01 - Evolution.pdf',
#  '3x02 - The Ensigns of Command.pdf',
#  '3x03 - The Survivors.pdf',
#  '3x04 - Who Watches the Watchers.pdf',
#  '3x05 - The Bonding.pdf',
#  '3x06 - Booby Trap.pdf',
#  '3x07 - The Enemy.pdf',
#  '3x08 - The Price.pdf',
#  '3x09 - The Vengeance Factor.pdf',
#  '3x10 - The Defector.pdf',
#  '3x11 - The Hunted.pdf',
#  '3x12 - The High Ground.pdf',
#  '3x13 - Deja Q.pdf',
#  '3x14 - A Matter of Perspective.pdf',
#  "3x15 - Yesterday's Enterprise.pdf",
#  '3x16 - The Offspring.pdf',
#  '3x17 - Sins of the Father.pdf',
#  '3x18 - Allegiance.pdf',
#  "3x19 - Captain's Holiday.pdf",
#  '3x20 - Tin Man.pdf',
#  '3x21 - Hollow Pursuits.pdf',
#  '3x22 - The Most Toys.pdf',
#  '3x23 - Sarek.pdf',
#  '3x24 - Menage a Troi.pdf',
#  '3x25 - Transfigurations.pdf',
#  '3x26 - The Best of Both Worlds, Part I.pdf',
#  '4x01 - The Best of Both Worlds, Part II.pdf',
#  '4x02 - Family.pdf',
#  '4x03 - Brothers.pdf',
#  '4x04 - Suddenly Human.pdf',
#  '4x05 - Remember Me.pdf',
#  '4x06 - Legacy.pdf',
#  '4x07 - Reunion.pdf',
#  '4x08 - Future Imperfect.pdf',
#  '4x09 - Final Mission.pdf',
#  '4x10 - The Loss.pdf',
#  "4x11 - Data's Day.pdf",
#  '4x12 - The Wounded.pdf',
#  "4x13 - Devil's Due.pdf",
#  '4x14 - Clues.pdf',
#  '4x15 - First Contact.pdf',
#  "4x16 - Galaxy's Child.pdf",
#  '4x17 - Night Terrors.pdf',
#  '4x18 - Identity Crisis.pdf',
#  '4x19 - The Nth Degree.pdf',
#  '4x20 - Qpid.pdf',
#  '4x21 - The Drumhead.pdf',
#  '4x22 - Half a Life.pdf',
#  '4x23 - The Host.pdf',
#  "4x24 - The Mind's Eye.pdf",
#  '4x25 - In Theory.pdf',
#  '4x26 - Redemption, Part I.pdf',
#  '5x01 - Redemption, Part II.txt',
#  '5x02 - Darmok.txt',
#  '5x03 - Ensign Ro.txt',
#  '5x04 - Silicon Avatar.txt',
#  '5x05 - Disaster.txt',
#  '5x06 - The Game.txt',
#  '5x07 - Unification Part I.txt',
#  '5x08 - Unification Part II.txt',
#  '5x09 - A Matter of Time.txt',
#  '5x10 - New Ground.txt',
#  '5x11 - Hero Worship.txt',
#  '5x12 - Violations.txt',
#  '5x13 - The Masterpiece Society.txt',
#  '5x14 - Conundrum.txt',
#  '5x15 - Power Play.txt',
#  '5x16 - Ethics.txt',
#  '5x17 - The Outcast.txt',
#  '5x18 - Cause and Effect.txt',
#  '5x19 - The First Duty.txt',
#  '5x20 - Cost of Living.txt',
#  '5x21 - The Perfect Mate.txt',
#  '5x22 - Imaginary Friend.txt',
#  '5x23 - I, Borg.txt',
#  '5x24 - The Next Phase.txt',
#  '5x25 - The Inner Light.txt',
#  "5x26 - Time's Arrow, Part I.txt",
#  "6x01 - Time's Arrow, Part II.txt",
#  '6x02 - Realm of Fear.txt',
#  '6x03 - Man of the People.txt',
#  '6x04 - Relics.txt',
#  '6x05 - Schisms.txt',
#  '6x06 - True Q.txt',
#  '6x07 - Rascals.txt',
#  '6x08 - A Fistful of Datas.txt',
#  '6x09 - The Quality of Life.txt',
#  '6x10 - Chain of Command, Part I.txt',
#  '6x11 - Chain of Command, Part II.txt',
#  '6x12 - Ship in a Bottle.txt',
#  '6x13 - Aquiel.txt',
#  '6x14 - Face of the Enemy.txt',
#  '6x15 - Tapestry.txt',
#  '6x16 - Birthright.txt',
#  '6x17 - Birthright Part II.txt',
#  '6x18 - Starship Mine.txt',
#  '6x19 - Lessons.txt',
#  '6x20 - The Chase.txt',
#  '6x21 - Frame of Mind.txt',
#  '6x22 - Suspicions.txt',
#  '6x23 - Rightful Heir.txt',
#  '6x24 - Second Chances.txt',
#  '6x25 - Timescape.txt',
#  '6x26 - Descent, Part I.txt',
#  '7x01 - Descent, Part II.txt',
#  '7x02 - Liaisons.txt',
#  '7x03 - Interface.txt',
#  '7x04 - Gambit, Part I.txt',
#  '7x05 - Gambit, Part II.txt',
#  '7x06 - Phantasms.txt',
#  '7x07 - Dark Page.txt',
#  '7x08 - Attached.txt',
#  '7x09 - Force of Nature.txt',
#  '7x10 - Inheritance.txt',
#  '7x11 - Parallels.txt',
#  '7x12 - The Pegasus.txt',
#  '7x13 - Homeward.txt',
#  '7x14 - Sub Rosa.txt',
#  '7x15 - Lower Decks.txt',
#  '7x16 - Thine Own Self.txt',
#  '7x17 - Masks.txt',
#  '7x18 - Eye of the Beholder.txt',
#  '7x19 - Genesis.txt',
#  "7x20 - Journey's End.txt",
#  '7x21 - Firstborn.txt',
#  '7x22 - Bloodlines.txt',
#  '7x23 - Emergence.txt',
#  '7x24 - Preemptive Strike.txt',
#  '7x25 - All Good Things.txt']

# %%
def pdf_url(series='tng', season, episode):
