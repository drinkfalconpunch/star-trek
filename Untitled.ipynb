# %%
from startrek.script import Script

# %%
a = Script('tng', script_path='./scripts/tng/Episode 49 - The Ensigns of Command.txt')

# %%
a.dialogue

# %%
a.extract_dialogue_from_script()

# %%
from collections import defaultdict
from itertools import tee
import re

# %%
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

# %%
def _number_header_from_line(line):
    line = line.split()
    return line[0], ' '.join(line[1:])

# %%
def get_between_indices(s, begin, end):
    return s[begin:end]

# %%
sections, indices = section_headers(a.dialogue)

# %%
sections

# %%
from collections import deque
import copy
import itertools

# %%
b = sectioned_script(a.dialogue, indices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-4f074f67842e> in <module>
# ----> 1 b = sectioned_script(a.dialogue, indices)
#
# NameError: name 'sectioned_script' is not defined

# %%
chars = get_characters(a.dialogue)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-417702689e02> in <module>
# ----> 1 chars = get_characters(a.dialogue)
#
# <ipython-input-9-493419766679> in get_characters(dialogue)
#      49
#      50     characters = set()
# ---> 51     for line in dialogue:
#      52         matches = re.findall(regex_character, line.strip())
#      53         if matches:
#
# TypeError: 'NoneType' object is not iterable

# %%
chars
# Out:
# {"ARD'RIAN",
#  'BEVERLY',
#  'DATA',
#  'GEORDI',
#  'GOSHEVEN',
#  'HARITATH',
#  'KENTOR',
#  "O'BRIEN",
#  'PICARD',
#  'RIKER',
#  'SHELIAK',
#  'TROI',
#  'WESLEY',
#  'WORF'}

# %%
def section_headers(dialogue):
    '''Returns the section headers from a block of dialogue and their
    respective line numbers in said block. Run once.'''

    sections = {}
    indices = []
    _regex_number = r'^\d{1,3}?[a-zA-Z]{0,1}'
    regex_number = re.compile(_regex_number)

    for index, line in enumerate(dialogue):
        words = line.split()
        if not words:
            continue
        try:
            int(words[0][0])
            number = words[0]
            name = " ".join(words[1:]).replace(':', '')
            if not name:
                name = 'OMITTED'
            # Corner case check if year is in section number
            # if not re.findall(regex_number, number):
            #     print(number, re.findall(regex_number, number))
            if len(number) > 3 and number[3].isdigit():
                continue
            # Check for same section number
            if number in sections.keys():
                sections[number].append(name)
            else:
                sections[number] = [name]
            indices.append(index)
        except:
            continue
    return sections, indices

def get_characters(dialogue):
    """
    Gets a set of all the characters with dialogue from a sectioned script.
    """
    ACT = ['ACT']
    END = ['END OF']
    NUMBERS = ['ONE', 'TWO', 'THREE', 'FOUR', 'FIVE', 'SIX', 'SEVEN', 'EIGHT', 'NINE', 'TEN']
    SKIPS = ['THE END', 'END OF TEASER', 'FADE OUT', 'FADE OUT.', 'FADE OUT:', 'END OF THE TEASER', 'ENTER.', 'ENTERS.']
    for combo in itertools.product(END, ACT, NUMBERS):
        SKIPS.append(' '.join(combo))
    for combo in itertools.product(ACT, NUMBERS):
        SKIPS.append(' '.join(combo))
    _regex_character = r"^\s*([A-Z-.'\"() ]+)\s*$"
    regex_character = re.compile(_regex_character)

    characters = set()
    for line in dialogue:
        matches = re.findall(regex_character, line.strip())
        if matches:
            for match in matches:
                # Yay random corner cases!
                if match in SKIPS:
                    continue
                parens = match.find('(')
                quote = match.find('\'')
                if parens != -1:
                    match = match[:parens - 1]
                if quote != -1:
                    # Taking a stab at possesive names instead of names with random asterisks 
                    # in them to sound all scify and bullshit for this project.
                    if match[quote+1] == 'S':
                        match = match[:quote]
                if 'VOICE' in match:
                    match = match.replace('VOICE', '')
                if match.endswith('.'):
                    while match.endswith('.'):
                        match = match[:-1]
                if match.startswith('('):
                    continue
                if match.endswith(')'):
                    continue
                characters.add(match.replace('"', '').strip())

    return characters

def _separate_dialogue_block(block, characters):
    """
    Takes a list of lines of dialogue and character names and returns a dictionary
    with each character's lines Dict[name, text].
    """
    block = deque(block)
    dialogue = {}
    temp = ''

    # Check if any initial lines are text and save them.
    while True:
        if not block:
            break
        line = block.popleft()
        if not line.isupper():
            # First line is dialogue/text
            temp = f"{temp} {line}"
        else:
            block.appendleft(line)
            break

    if temp:
        dialogue[0] = dict(name='None', text=temp.strip())
        index = 1
    else:
        index = 0

    name = ''
    text = ''
    for line in block:
        if not line:
            continue
        if line.isupper():
            # Denotes a character's name on it's own line, indicating dialogue.
            if name == line:
                # Character continuing dialogue.
                continue
            else:
                # Different character dialogue.
                if name:
                    # New dialogue. Push dialogue into dict and start over.
                    dialogue[index] = dict(name=_character_name(name, characters), text=text.strip())
                    name = line
                    text = ''
                    index += 1
                else:
                    # Character name
                    name = line
                    continue
        else:
            # Dialogue line
            text = f"{text} {line}"

    return dialogue

def _character_name(input_name, characters):
    """
    Cleans up character names. E.g., remove posession or voice over notes.
    """
    for character in characters:
        if character in input_name:
            return character
    return 'None'

def separate_lines_by_character(dialogue, characters=None):
#     temp_sectioned = _sectioned_script(dialogue, indices)
#     sectioned = copy.deepcopy(temp_sectioned)
    if not characters:
        characters = get_characters(dialogue)
    sectioned = copy.deepcopy(dialogue)
    for number, section in dialogue.items():
        for index, part in enumerate(section):
            block = part['part']
            if block:
                block = _separate_dialogue_block(block, characters)
#                 print(sectioned[number][index])
                sectioned[number][index]['part'] = block
            else:
                del sectioned[number]
                continue
            
    return sectioned

def _sectioned_script(dialogue, header_indices):
    """
    Separates dialogue into sections using the indices of the headers found in the dialogue list of lines.
    """
    sections = {}
    index_pairs = pairwise(header_indices)

    for pair in index_pairs:
        # Get the lines between two indices
        part = get_between_indices(dialogue, *pair)
        # The first line is the header of the section
        head = part.pop(0)
        # The header is composed of a number and text.
        number, header = _number_header_from_line(head)
        # Make a dictionary with the header and text.
        d = dict(header=header, part=part)
        # Check if the section number already exists.
        if number in sections.keys():
            sections[number].append(d)
        else:
            sections[number] = [d]

    return sections

# %%
# a -> extract dialogue into list (extract_dialogue_from_script) -> get headers and locations (section_headers) 
# -> split dialogue into sections (_sectioned_script) -> split lines by characters

# %%
q = _sectioned_script(a.dialogue, indices)

# %%
r = _sectioned_script(a.dialogue, indices)

# %%
get_characters(a.dialogue)
# Out:
# {"ARD'RIAN",
#  'BEVERLY',
#  'DATA',
#  'GEORDI',
#  'GOSHEVEN',
#  'HARITATH',
#  'KENTOR',
#  "O'BRIEN",
#  'PICARD',
#  'RIKER',
#  'SHELIAK',
#  'TROI',
#  'WESLEY',
#  'WORF'}

# %%
separate_lines_by_character(q)
# Out:
# {'1': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'Moving at impulse near some extraordinarily interesting astronomical object.'}}}],
#  '2': [{'header': 'INT. TEN-FORWARD',
#    'part': {0: {'name': 'None',
#      'text': "Present are PICARD, BEVERLY, and TWELVE N.D. CREWMEMBERS. A VULCAN and ONE WOMAN are seated, holding their instruments -- a violin and a viola. O'BRIEN tunes his cello. DATA ENTERS carrying a violin. He checks at the door, startled to see the captain. Picard beckons, and Data crosses to him."},
#     1: {'name': 'None',
#      'text': 'Captain, Doctor, I am honored by your presence, but may I suggest you attend the second concert.'},
#     2: {'name': 'None', 'text': 'Why, Data?'},
#     3: {'name': 'None',
#      'text': 'Ensign Ortiz will perform the violin part. My rendition will be less enjoyable.'},
#     4: {'name': 'None', 'text': 'Oh?'},
#     5: {'name': 'None',
#      'text': 'While I am quite proficient Technically, according to my fellow performers, I lack soul.'},
#     6: {'name': 'None',
#      'text': "Data, telling us why you're going to fail before you make the attempt is never wise."}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'Excessive honesty can be disastrous... particularly in a commander.'},
#     1: {'name': 'None', 'text': '(very intrigued) Indeed?'},
#     2: {'name': 'None',
#      'text': 'Knowing your limitations is one thing. Advertising them to a crew can damage your ability to lead.'},
#     3: {'name': 'None', 'text': 'Because you lose their respect?'}}}],
#  '2A': [{'header': 'ANGLE ON PICARD AND BEVERLY',
#    'part': {0: {'name': 'None',
#      'text': 'O.s., the string quartet TUNES. There is the SOUND of the communicator hail.'},
#     1: {'name': 'None',
#      'text': "Captain, we're receiving a message from the Sheliak Corporate. Picard reacts with surprise, stands and EXITS. As he leaves, the quartet starts to PLAY."}}}],
#  '3': [{'header': 'INT. MAIN BRIDGE',
#    'part': {0: {'name': 'None',
#      'text': 'Picard ENTERS. RIKER and WORF at their usual stations. Supernumeraries at CONN and OPS.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'Origin point of the message confirmed. It is from the Shelia star system.'},
#     1: {'name': 'None',
#      'text': 'The Sheliak have not attempted to communicate with the Federation for a hundred and eleven years.'}}}],
#  '4': [{'header': 'ANGLE ON VIEWSCREEN (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'What appears is the text of a treaty. English on one side, Sheliak on the other. Sheliak is not symbols as we know them, but rather a pattern of lights. A recorded message begins.'},
#     1: {'name': 'None',
#      'text': 'Federation creatures, there are humans on the fifth planet of Tau Cygna. This planet was ceded to the corporate in section one hundred and thirty-three, paragraph seventy-seven of the Treaty of Armens. We will begin settlement of this world in four days. Remove the humans. Riker is up, and heading for Science One.'},
#     2: {'name': 'None', 'text': 'What the devil --'},
#     3: {'name': 'None',
#      'text': 'Federation creatures, there are humans on the fifth planet --'},
#     4: {'name': 'None', 'text': 'Cancel message. Inquiring look to Riker.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "Humans can't survive in such an environment. Exposure to hyperonic radiation is fatal."},
#     1: {'name': 'None',
#      'text': 'Then the Sheliak are asking us to chase ghosts.'},
#     2: {'name': 'None',
#      'text': "No, Number One. The Sheliak haven't broken a century of silence to send us after phantoms. An investigation is in order. Set course for Tau Cygna Five. Off Picard's expression:"},
#     3: {'name': 'None', 'text': ''},
#     4: {'name': 'None', 'text': ''},
#     5: {'name': 'None', 'text': ''}}}],
#  '5': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': {0: {'name': 'None', 'text': 'entering orbit around a planet.'}}}],
#  '6': [{'header': 'INT. MAIN BRIDGE',
#    'part': {0: {'name': 'None',
#      'text': 'Picard, Riker, Data, Beverly and Worf. Supernumerary at CONN.'},
#     1: {'name': 'None', 'text': 'Human life form readings from the planet.'},
#     2: {'name': 'None', 'text': "So, the Sheliak weren't hallucinating."},
#     3: {'name': 'None', 'text': 'Numbers?'},
#     4: {'name': 'None',
#      'text': 'Impossible to get an accurate reading, Captain. The high radiation levels are disrupting our sensors.'},
#     5: {'name': 'None',
#      'text': "Hyperonic radiation also interferes with ship's transporters; they are now inoperable."},
#     6: {'name': 'None', 'text': "So are the ship's phasers."},
#     7: {'name': 'None', 'text': 'How can humans survive down there?'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "Well, whoever they are and however they've survived, we've got to get them off the planet."},
#     1: {'name': 'None',
#      'text': 'By treaty, this world does belong to the Sheliak...'},
#     2: {'name': 'None',
#      'text': '... who are within their rights to demand the removal of these "trespassers."'},
#     3: {'name': 'None',
#      'text': "And if we don't remove them, the Sheliak will."},
#     4: {'name': 'None', 'text': 'How forcefully?'},
#     5: {'name': 'None',
#      'text': "To the Sheliak, humans are a lower life form. They'd have no compunctions about exterminating the intruders. Beverly is taken aback. Riker's dead serious."},
#     6: {'name': 'None',
#      'text': 'Mister Data. As you are unaffected by hyperonic radiation, you will go to the planet via shuttlecraft and commence evacuation procedures.'},
#     7: {'name': 'None',
#      'text': 'Aye, sir. Without a word wasted the android is out of his chair, and EXITS the bridge.'},
#     8: {'name': 'None',
#      'text': "Any speculation as to what he'll find, Number One?"},
#     9: {'name': 'None',
#      'text': 'A lost survey ship would be my guess. A dozen or so survivors at most.'}}}],
#  '7': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': {0: {'name': 'None',
#      'text': 'Data is outside the shuttle, scanning with his tricorder.'}}}],
#  '7A': [{'header': 'NEW ANGLE',
#    'part': {0: {'name': 'None',
#      'text': 'as HARITATH and KENTOR (two male humans) and TWO N.D. WORKERS cautiously approach the shuttle from the other side (the shuttle blocks their view of Data).'},
#     1: {'name': 'None', 'text': '(in wonder) A shuttlecraft!'},
#     2: {'name': 'None', 'text': "Where's it from?"},
#     3: {'name': 'None',
#      'text': "Look at the markings. I think it's from the Federation. Data steps into their view from around the shuttle."},
#     4: {'name': 'None', 'text': 'Hello. The four humans jump, startled.'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': "The first visitor we've ever had. They take a closer look at Data."},
#     1: {'name': 'None', 'text': "You're -- not human."},
#     2: {'name': 'None',
#      'text': 'That is correct. I am an android. I am Lieutenant Commander Data of the Federation Starship Enterprise.'},
#     3: {'name': 'None',
#      'text': "(excited) Our great-grandparents were citizens of the Federation. (realizing) But you don't want to waste time talking to us..."},
#     4: {'name': 'None',
#      'text': "You'll want to speak with Gosheven. We'll take you to him."},
#     5: {'name': 'None', 'text': 'Excellent.'},
#     6: {'name': 'None',
#      'text': "I'm sure the Federation will be very proud of us. Wait until you see all we've accomplished."},
#     7: {'name': 'None', 'text': 'And who, precisely, is "we?"'},
#     8: {'name': 'None',
#      'text': "You don't know? No, I guess you wouldn't, would you? We are the descendants of the original settlers -- from the colony ship Artemis."}}}],
#  '8': [{'header': 'INT. ENTERPRISE - MAIN BRIDGE',
#    'part': {0: {'name': 'None',
#      'text': 'Picard and Worf in their usual places. Riker at Science One. Supernumeraries at Conn and Ops.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'Got it. The Artemis, launched one hundred forty-two years ago, destination Septimis Minor. When they failed to check in, Starfleet began an extensive search.'}}}],
#  '9': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': {0: {'name': 'None',
#      'text': 'Haritath and Kentor wait patiently for Data to finish him communication.'}}}],
#  '10': [{'header': 'INTERCUTS',
#    'part': {0: {'name': 'None', 'text': 'Understood. How many are there?'},
#     1: {'name': 'None',
#      'text': 'Approximately fifteen thousand. Reactions from the bridge crew. Now they really have got a problem.'},
#     2: {'name': 'None',
#      'text': "(to Picard) We've only got three days. Without working transporters, we couldn't have them out in time."},
#     3: {'name': 'None',
#      'text': 'Shuttles? Worf does some figuring on his console.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'Then we need more time. Mister Data, prepare the colonists for an evacuation.'},
#     1: {'name': 'None', 'text': 'Aye, sir. Picard closes the com line.'},
#     2: {'name': 'None',
#      'text': '(continuing) Mister Worf, get me the Sheliak.'},
#     3: {'name': 'None',
#      'text': 'Their home world is quite distant, Captain. This will take some time.'}}}],
#  '11': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': {0: {'name': 'None',
#      'text': 'The main pumping station of Tau Cygna V. In the distance are mountains. A thin white line descends from the mountains, and as it comes closer we realize it is an aqueduct. Along the line of the aqueduct are lush fields, a veritable Garden of Eden, which ends like a knife-cut and the desert returns. It culminates in a strange cubistic-shaped purifying station. In a pool, the water churns into a white froth. GOSHEVEN, the leader, supervises TWO WORKERS testing the water in the pool. Data, Haritath, and Kentor approach.'},
#     1: {'name': 'None',
#      'text': "Gosheven, look what's come -- Gosheven sees Data, looks him up and down very carefully. Gosheven's as surprised as Haritath was, but keeps a lid on it -- Data may represent a threat, so Gosheven's attempting a poker face."}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None', 'text': "He's an android."},
#     1: {'name': 'None',
#      'text': "So he is. (a beat) Well, you're here -- what do you want?"},
#     2: {'name': 'None',
#      'text': 'My mission is to prepare this colony for evacuation. Reactions from the men. Gosheven is calm, almost amused:'},
#     3: {'name': 'None', 'text': 'Why?'},
#     4: {'name': 'None', 'text': 'Because this planet belongs to the Sheliak.'},
#     5: {'name': 'None', 'text': 'And just who is this Sheliak?'},
#     6: {'name': 'None',
#      'text': 'The term is plural. The Sheliak are an intelligent, non-humanoid life form, classification R-3 --'},
#     7: {'name': 'None',
#      'text': "(interrupting) This colony's been here for a hundred and forty years -- and no one's ever seen a Sheliak. I'd say that makes Tau Cygna Five our planet. (ALTERNATE: ninety years)"},
#     8: {'name': 'None',
#      'text': 'But the original destination of the Artemis was Septimis Minor.'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': 'And when they did, the radiation started killing them.'},
#     1: {'name': 'None',
#      'text': 'Hyperonic radiation took the lives of a third of the colonists before they learned they could adapt to it.'},
#     2: {'name': 'None', 'text': 'But the colony survived -- and prospered.'},
#     3: {'name': 'None',
#      'text': "(with pride) Look around. We've brought water to the desert, built a community."},
#     4: {'name': 'None',
#      'text': 'Your accomplishments are indeed remarkable. However, the Sheliak and the Federation have a treaty that clearly makes this planet Sheliak domain.'},
#     5: {'name': 'None', 'text': 'Then change the treaty.'},
#     6: {'name': 'None',
#      'text': 'That may not be possible. The Sheliak wish to colonize this planet, and they are unwilling to share it with humans.'}}},
#   {'header': 'CONTINUED: (3)',
#    'part': {0: {'name': 'None',
#      'text': "DATA (cont'd) If you are still here when the Sheliak colony ship arrives, they will eradicate you. Haritath and Kentor exchange a worried glance, but Gosheven is unfazed."},
#     1: {'name': 'None', 'text': 'They would kill us all?'},
#     2: {'name': 'None',
#      'text': 'They have little regard for human life. Thus, our most sensible course is to prepare a contingency plan for the evacuation of your people.'}}},
#   {'header': 'CONTINUED: (4)',
#    'part': {0: {'name': 'None',
#      'text': 'Perhaps I have not made myself clear.'}}}],
#  '11A': [{'header': 'ON DATA',
#    'part': {0: {'name': 'None',
#      'text': 'as he considers his next move. Then -- an object comes flying at Data. With android speed and reflexes, Data catches the object and examines it. It is an iron bar.'}}}],
#  '11B': [{'header': 'WIDER',
#    'part': {0: {'name': 'None',
#      'text': "ARD'RIAN, an attractive female, approaches."},
#     1: {'name': 'None',
#      'text': 'Sorry to test you like that -- but I was curious.'},
#     2: {'name': 'None', 'text': '(amused) Found a new toy, have we, Ardy?'},
#     3: {'name': 'None',
#      'text': "Toy? This is the most incredible android I've ever seen."},
#     4: {'name': 'None', 'text': 'Have you seen many?'},
#     5: {'name': 'None', 'text': "Actually, no. You're the first."},
#     6: {'name': 'None',
#      'text': "(to Ard'rian) Only you would get this excited over a walking calculator."},
#     7: {'name': 'None',
#      'text': "(bridling) He's more interesting than anything else walking around here... Gosheven CHUCKLES -- he's succeeded in getting under her skin."}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "Ard'rian's had enough of Gosheven's male conceit. She moves away, motions for Data to follow. Data does."},
#     1: {'name': 'None',
#      'text': '(to Data) Cybernetic intelligence fascinates me. Are your neural pathways duotronic?'},
#     2: {'name': 'None', 'text': 'No -- they are positronic.'},
#     3: {'name': 'None',
#      'text': "I didn't know that was possible! What's your memory capacity? How many operations per second? I have a million questions..."},
#     4: {'name': 'None',
#      'text': 'I am afraid I have no time to answer one million questions. I have a mission to accomplish.'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': "DATA (cont'd) I need to know more about your people, and Gosheven seems unwilling to talk to me further."},
#     1: {'name': 'None',
#      'text': "(extending a hand) I'm Ard'rian McKenzie. Perhaps I can help you. As Data shakes her hand, we:"}}}],
#  '12': [{'header': 'INT. OBSERVATION LOUNGE',
#    'part': {0: {'name': 'None',
#      'text': "Picard, Riker and TROI are seated as GEORDI, O'Brien"},
#     1: {'name': 'None', 'text': ''},
#     2: {'name': 'None',
#      'text': "Gentlemen, we're giving you an assignment, and the one thing we don't want to hear is that it is impossible. Riker defers to Picard. Geordi and O'Brien cast wary glances at Picard. Now what the hell is he going to want?"},
#     3: {'name': 'None',
#      'text': 'I need the transporters to function despite the hyperonic radiation.'},
#     4: {'name': 'None',
#      'text': "Impossi -- Yes, sir. Geordi and O'Brien EXIT. Riker, Troi and Picard study each other seriously."}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'Captain, when the treaty was negotiated the Federation sent three hundred and seventy-two legal experts. What have we got?'},
#     1: {'name': 'None',
#      'text': "Thee... and me. Off Troi's very dubious expression as we:"},
#     2: {'name': 'None', 'text': ''},
#     3: {'name': 'None', 'text': ''},
#     4: {'name': 'None', 'text': ''}}}],
#  '13': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': {0: {'name': 'None', 'text': 'in orbit around Tau Cygna V.'}}}],
#  '14': [{'header': 'INT. MAIN BRIDGE',
#    'part': {0: {'name': 'None',
#      'text': 'Picard pacing, Troi seated as they wait for the call. Worf at his station. Supernumeraries at Conn and Ops.'},
#     1: {'name': 'None', 'text': 'No response.'},
#     2: {'name': 'None',
#      'text': 'Try again. Boost signal strength. Worf makes adjustments.'}}}],
#  '15': [{'header': 'ANGLE ON VIEWSCREEN - (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'as it changes from a view of stars to -- someplace? a bridge? Wherever the SHELIAK are calling from it is a disturbing place for humans. Darkness, mirrored surfaces, and hidden in the shadows a creature who is decidedly unsettling for the crew. Its shape is constantly shifting like oozing sludge, and there is a hint of flickering eyes -- too many eyes.'},
#     1: {'name': 'None',
#      'text': 'Conversation is neither required nor desired. Picard schools his features into an expression of polite interest.'},
#     2: {'name': 'None',
#      'text': 'Conversation is necessary if we are to find a solution to our mutual problem.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None', 'text': 'Both parties are involved, sir.'},
#     1: {'name': 'None',
#      'text': 'Remove the humans from the Tau Cygna system. Three Earth days remain. Troi leans in, and whispers:'},
#     2: {'name': 'None',
#      'text': 'Their culture is extremely formal, almost ritualistic. An apology might smooth matters.'},
#     3: {'name': 'None',
#      'text': 'I apologize for our inadvertent violation of the treaty.'},
#     4: {'name': 'None',
#      'text': 'Acknowledged and accepted. Now remove the human creatures.'},
#     5: {'name': 'None', 'text': 'Let us negotiate in good faith...'},
#     6: {'name': 'None',
#      'text': 'Negotiate to what purpose? The treaty is signed.'},
#     7: {'name': 'None',
#      'text': 'There is a thriving colony on the planet. Rather than uproot these people may I offer a compromise?'},
#     8: {'name': 'None', 'text': 'Denied.'},
#     9: {'name': 'None', 'text': 'Why?!'},
#     10: {'name': 'None', 'text': 'The law is paramount. We are entitled.'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': "But Picard's talking to a blank screen. The Sheliak have hung up on him."},
#     1: {'name': 'None',
#      'text': "... jacket. Off Picard's annoyed expression."}}}],
#  '17': [{'header': "INT. ARD'RIAN'S FRONT ROOM - DAY",
#    'part': {0: {'name': 'None',
#      'text': "A comfortable room constructed of stone with a heavy beamed ceiling. The furniture is hand hewn, durable but comfortable. Contrasting with this are various computer parts and consoles, both assembled and in pieces, strewn about. Ard'rian and Data ENTER."},
#     1: {'name': 'None',
#      'text': "... you really think we'll have to leave Tau Cygna Five?"}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "Maybe because you're an android. I don't think Gosheven likes the idea of machines ordering him around."},
#     1: {'name': 'None',
#      'text': 'I am not ordering him to do anything; I am merely trying to persuade him that his people should prepare to evacuate. (thinks) Do you believe my suggested course of action should be followed?'},
#     2: {'name': 'None', 'text': 'Of course.'},
#     3: {'name': 'None', 'text': 'In spite of the fact that I am an android?'},
#     4: {'name': 'None',
#      'text': 'Because of that fact. I don\'t have any silly prejudices against computers -- I like them. SHe gestures around the room, a bit apologetically: ARD\'RIAN (cont\'d) Not that any computer we have is half as sophisticated as you... Data looks at a particularly "primitive" computer:'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': "ARD'RIAN (cont'd) People can be selfish, irrational, stubborn, malicious -- you name it. But computers don't have those failings. Data follows her logic:"},
#     1: {'name': 'None',
#      'text': "You conclude from this that I am impartial... hence you accept my recommendations. She nods. DATA (cont'd) Yet Gosheven does not. (thinks) Perhaps he might reconsider his position if someone other than myself were to present the arguments."}}}],
#  '19': [{'header': 'NEW ANGLE',
#    'part': {0: {'name': 'None',
#      'text': "as Data's communicator TRILLS. He touches the insignia."},
#     1: {'name': 'None', 'text': 'Data, here.'},
#     2: {'name': 'None', 'text': "The Sheliak won't bargain."}}},
#   {'header': 'CONTINUED:', 'part': {}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "Yes, sir. Data cuts the communication, turns to Ard'rian. We must speak with Gosheven immediately. Ard'rian grabs a coat, and they EXIT."}}}],
#  '19A': [{'header': 'INT. TRANSPORTER ROOM (OPTICAL) (FORMERLY SC. 16)',
#    'part': {0: {'name': 'None',
#      'text': "Geordi, O'Brien and WESLEY have the panels removed from the wall behind the transporter console. Geordi's tool box is nearby. Sophisticated tools litter the floor. Off to the left side of the transporter are six test objects. The trio is watching tensely as O'Brien touches the console. A test object MATERIALIZES looking like swiss cheese. Geordi picks it up. Riker ENTERS."},
#     1: {'name': 'None',
#      'text': 'Gentlemen, how are you coming? (spots the object) What the hell is that? Geordi sets aside the mutilated object.'},
#     2: {'name': 'None', 'text': 'Our first attempt.'},
#     3: {'name': 'None',
#      'text': 'We recalibrated the transporter setting for the tightest possible beam.'},
#     4: {'name': 'None',
#      'text': "But we've got plenty of things left to try. Geordi is studying the test object again."}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None', 'text': 'Teremi-thorons.'},
#     1: {'name': 'None', 'text': 'This just got a lot harder.'},
#     2: {'name': 'None',
#      'text': "They're one of the most elusive sub-atomic particles known, and they really shred a transporter signal."},
#     3: {'name': 'None',
#      'text': 'Thank you, Ensign, I passed physics. (to Geordi) Keep at it. We need those transporters. Riker EXITS.'},
#     4: {'name': 'None',
#      'text': "We're going to have a lot of fun cracking this one."}}}],
#  '20': [{'header': '',
#    'part': {0: {'name': 'None', 'text': 'thru\tOMITTED'}}}],
#  '22': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': {0: {'name': 'None',
#      'text': "Gosheven, Data, and Ard'rian are standing near the pool of water. Gosheven cups some water in a hand."},
#     1: {'name': 'None',
#      'text': 'See that? Do you have any idea what it is? What it means?'},
#     2: {'name': 'None',
#      'text': 'It is water, a substance composed of two atoms of hydrogen --'},
#     3: {'name': 'None',
#      'text': "It's not water. It's blood and sweat -- the result of a hundred and forty years of combined effort. (ALTERNATE: ninety years) This isn't a town."}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "GOSHEVEN (Cont'd) It's a monument to every man, woman, and child who has lived and died on Tau Cygna Five."},
#     1: {'name': 'None', 'text': "Gosheven, you're talking nonsense."},
#     2: {'name': 'None',
#      'text': "Am I? My grandfather's buried on that mountain. (points to the distant line of hills) He died in a rock slide surveying the route for this aqueduct. This colony exists because of his sacrifice, and the sacrifices of thousands of others. No, we're not leaving."},
#     3: {'name': 'None',
#      'text': 'The Sheliak will not accept humans on their planet. And they will not hesitate to use force to remove you.'},
#     4: {'name': 'None',
#      'text': '(calmly) And we will not hesitate to fight back.'},
#     5: {'name': 'None', 'text': 'You cannot win.'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': '(re Gosheven; bitter) Stubborn and irrational. Now what do we do?'},
#     1: {'name': 'None',
#      'text': 'Are his sentiments typical among the colonists?'},
#     2: {'name': 'None',
#      'text': 'I hope not. Are you thinking of bypassing Gosheven and taking your case directly to the people?'},
#     3: {'name': 'None',
#      'text': '(nods) I see no other course of action. If I can convince enough people of the necessity of leaving --'},
#     4: {'name': 'None',
#      'text': '(a smile) Don\'t you mean "if we can convince?"'},
#     5: {'name': 'None',
#      'text': "You are offering assistance? Ard'rian nods, extends her arm -- c'mon, let's get going. As they move off:"}}}],
#  '22A': [{'header': 'EXT. SPACE - ENTERPRISE (OPTICAL) (FORMERLY SC. 20)',
#    'part': {0: {'name': 'None', 'text': 'In orbit around Tau Cygna V.'}}}],
#  '22B': [{'header': "INT. CAPTAIN'S READY ROOM (FORMERLY SC. 21)",
#    'part': {0: {'name': 'None',
#      'text': 'Picard is pacing rapidly about the office. Riker'},
#     1: {'name': 'None', 'text': ''}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'Three weeks. Starfleet is profuse in their apologies, but it will still be three weeks.'},
#     1: {'name': 'None', 'text': 'Until?'},
#     2: {'name': 'None',
#      'text': 'Until the arrival of a colony transport ship equipped with dedicated personnel shuttles.'},
#     3: {'name': 'None', 'text': "We can't wait three weeks."},
#     4: {'name': 'None',
#      'text': "The Sheliak must agree to extend our deadline. Picard sits in silence for a beat. PICARD (cont'd) If they plan to settle Tau Cygna Five two days from now..."},
#     5: {'name': 'None',
#      'text': '... one of their ships must already be en route.'},
#     6: {'name': 'None',
#      'text': "(decides) We're going to intercept that ship."},
#     7: {'name': 'None',
#      'text': 'The Sheliak may interpret that as a hostile act.'},
#     8: {'name': 'None',
#      'text': "We have to take the risk. Off Picard's determined expression as we:"},
#     9: {'name': 'None', 'text': ''},
#     10: {'name': 'None', 'text': ''},
#     11: {'name': 'None', 'text': ''}}}],
#  '23': [{'header': 'INT. OBSERVATION LOUNGE',
#    'part': {0: {'name': 'None',
#      'text': 'Riker pacing slowly, looking out at the stars.'},
#     1: {'name': 'None',
#      'text': 'The Enterprise is going to try to intercept the Sheliak colony ship. Your job ... well, you know your job.'}}}],
#  '24': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': {0: {'name': 'None',
#      'text': 'Data standing alone in an archway.'}}}],
#  '25': [{'header': 'INTERCUTS',
#    'part': {0: {'name': 'None', 'text': "What's the situation?"},
#     1: {'name': 'None',
#      'text': 'Their leader has rejected my counsel. He denies the logic of my arguments and talks of structures they have built.'},
#     2: {'name': 'None', 'text': 'Then try something else.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "(more to himself) I don't have time for this."}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': '(cutting him) Data, I can\'t help you -- I don\'t know these people; I haven\'t talked to them. You have. Use that fancy positronic brain of yours -- and carry out your mission. Ard\'rian walks up to join the android, politely keeps a few paces away to let him complete his "phone call" with privacy.'},
#     1: {'name': 'None',
#      'text': 'If I do not succeed, how violent is the Sheliak reaction likely to be?'},
#     2: {'name': 'None',
#      'text': 'The treaty is the only thing which kept them from eradicating the colony the moment they discovered it.'},
#     3: {'name': 'None', 'text': 'Ah.'},
#     4: {'name': 'None',
#      'text': '"Ah" is right. The lives of fifteen thousand people are riding on you. You\'d better get innovative. Riker out. Data gazes into space, thinking. Ard\'rian steps up. Her mood is upbeat.'}}},
#   {'header': 'CONTINUED: (3)',
#    'part': {0: {'name': 'None',
#      'text': 'Is there any indication that Gosheven has changed his position?'},
#     1: {'name': 'None',
#      'text': 'No. But a meeting will give you the chance to present your recommendations.'},
#     2: {'name': 'None',
#      'text': "First, will Gosheven allow me to speak? Second, even if he does, what good will it do? So far, my attempts at persuasion have been ineffective. Ard'rian looks at him with compassion for a beat -- then suddenly gives Data a quick kiss on the lips. DATA (cont'd) Why did you do that?"},
#     3: {'name': 'None', 'text': 'You appeared to need it.'}}},
#   {'header': 'CONTINUED: (4)',
#    'part': {0: {'name': 'None',
#      'text': "DATA (cont'd) In this context, I would assume your intention was to express support."},
#     1: {'name': 'None',
#      'text': "That was my primary motivation. The implication being that there were secondary motivations. But if Data is aware of the implication, he makes no sign. ARD'RIAN (cont'd) You don't really understand human behavior, do you?"},
#     2: {'name': 'None', 'text': 'That is something of an understatement.'},
#     3: {'name': 'None',
#      'text': "(sighs) Sometimes I don't either. androids are a lot more rational."},
#     4: {'name': 'None',
#      'text': 'Thus far, that quality has not helped me accomplish my mission.'},
#     5: {'name': 'None',
#      'text': "A rational argument isn't always enough. Maybe to be more persuasive, you need to use a little reverse psychology."},
#     6: {'name': 'None',
#      'text': '(accessing) Elicit a desired behavior by advocating its opposite? (a beat) That implies deception, does it not?'}}},
#   {'header': 'CONTINUED: (5)',
#    'part': {0: {'name': 'None',
#      'text': '(considers) Perhaps this is a situation in which excessive honesty is detrimental. As they walk off:'}}}],
#  '26': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': {0: {'name': 'None', 'text': 'Travelling at warp speed.'}}}],
#  '27': [{'header': 'INT. TRANSPORTER ROOM',
#    'part': {0: {'name': 'None',
#      'text': "As before, except there are more high tech tools and equipment lying about. Geordi is lifting yet another trashed test object off the platform. He holds it mutely out to Wesley and O'Brien who stare dully at this latest failure. There are now four intact objects and three blasted ones. Picard ENTERS."},
#     1: {'name': 'None',
#      'text': '(you will get it done) How are we progressing, Mister La Forge?'},
#     2: {'name': 'None', 'text': "(it's impossible) About like you'd expect."},
#     3: {'name': 'None', 'text': '(get it done) Splendid. Picard EXITS.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': '(with a grin) That\'s the short definition for "captain." Geordi and O\'Brien have already returned to work. Wes looks at them bemused, then shrugs and pitches in.'}}}],
#  '28': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': {0: {'name': 'None',
#      'text': 'A large horseshoe-shaped amphitheater with a place for the engineers and Gosheven. A number of citizens -- including Haritath and Kentor -- have turned out for the debate so the place is filled. In the b.g. is the aqueduct purifying plant.'},
#     1: {'name': 'None',
#      'text': "You've all heard about the android Starfleet sent here, and you've been discussing why he's come. Data and Ard'rian ENTER. Gosheven ignores them. GOSHEVEN (cont'd) I called this meeting to replace misinformation with cold, hard fact. The colonists are craning their necks to look at Data. Gosheven realizes Data's presence can't be ignored. He strides over to confront Data. Leave. Immediately."},
#     2: {'name': 'None', 'text': 'I wish to speak.'},
#     3: {'name': 'None', 'text': 'No.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None', 'text': 'This meeting is not for outsiders.'},
#     1: {'name': 'None',
#      'text': 'Do you consider your position so weak that it cannot withstand debate?'},
#     2: {'name': 'None',
#      'text': "Let him talk. MURMURS of assent from the crowd. Gosheven gives a terse nod. In a sense Data's called him a coward and he has to stand up to this city slicker, this outsider. Data steps front and center. In an effort to pull this off, he attempts to use human rhetorical devices (timing, dynamics, inflection, gestures, etc.) -- but, as there's no real passion behind them, they come off as studied and not quite sincere. A good performance, but still a performance."}}}],
#  '29': [{'header': 'ANGLE ON',
#    'part': {0: {'name': 'None',
#      'text': "The crowd. Data's starting to get a reaction. People are beginning to eye each other nervously. It's one thing to thumb your nose at a distant enemy, quite another to talk about dying."}}}],
#  '30': [{'header': 'ANGLE ON DATA',
#    'part': {0: {'name': 'None',
#      'text': 'As he reaches down, and takes a YOUNG BOY (twelve or so) by the arm, and pulls the child up next to him.'},
#     1: {'name': 'None',
#      'text': 'Your children will understand that they are dying for a worthy cause. Big crowd reaction here. Murmurs from various people. Mothers pull their children closer to them. Data steals a glance at Ard\'rian -- "how am I doing?" Ard\'rian nods encouragingly back -- "fine." (continuing) Long after the battle is over, their courage will be remembered and extolled. Ard\'rian jumps in to support him.'},
#     2: {'name': 'None', 'text': 'Remembered by who?'}}}],
#  '31': [{'header': 'ANGLE ON GOSHEVEN',
#    'part': {0: {'name': 'None', 'text': 'as he begins to applaud slowly.'},
#     1: {'name': 'None',
#      'text': "A valiant try, android, but what a low opinion you must have of us. The boy's MOTHER snatches her son back from Data, and pulls him down in her lap."}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': '(standing) And he did it pretty damned well. MURMURS of agreement from the crowd.'},
#     1: {'name': 'None',
#      'text': "Are you ready to follow this machine, Haritath? Give up everything? Without a fight? He says we're going to lose, I think that's his own cowardice talking! Kentor stands. He has a calm but commanding presence."},
#     2: {'name': 'None',
#      'text': "And what if he's right, and you're wrong? Shouldn't we consider that possibility? More crowd reaction. Sympathy is swinging away from Gosheven."},
#     3: {'name': 'None',
#      'text': 'We may be sacrificing ourselves for nothing --'},
#     4: {'name': 'None',
#      'text': 'Last winter we buried your little girl -- laid her to rest next to your mother, and you dare speak of sacrifice? Gosheven whirls and nails Kentor with a look. (continuing) And you, Kentor, we built you a new house after the fire wiped you out. Can you simply walk away from that?'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': '(addressing them all) This colony exists because generations gave their lives for it. Many people died before we found a way to adapt to the radiation. Many more died bringing water to the desert. My father --'},
#     1: {'name': 'None',
#      'text': "(interrupting) -- is buried on that mountain. Well, who's going to be left to bury you? A vote of confidence is about to take place, and Gosheven realizes he's about to lose it. He falls back on the innate authority of an elected leader."}}}],
#  '32': [{'header': 'ANGLE ON DATA',
#    'part': {0: {'name': 'None', 'text': "standing with Ard'rian."},
#     1: {'name': 'None', 'text': '(almost to himself) Then here you die.'},
#     2: {'name': 'None', 'text': ''},
#     3: {'name': 'None', 'text': ''},
#     4: {'name': 'None', 'text': ''}}}],
#  '33': [{'header': 'INT. TRANSPORTER ROOM (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': "Wesley, Geordi and O'Brien. There are now three intact test object and four trashed ones. These are three exhausted people. They've been working round the clock."},
#     1: {'name': 'None',
#      'text': 'Maybe if we bypassed the autosequence and decompiled the pattern buffer... ?'},
#     2: {'name': 'None',
#      'text': "(shrugs) It's no crazier than anything else we've tried. Wesley drops down by the panel, and begins to tinker while Geordi places the last test object on the platform. Suddenly the transporter console blows a fuse. Electricity races across the panel, and the console goes dark. O'Brien is not a happy man. Wesley slowly stands up. O'Brien struggles with himself, but can't master it."},
#     3: {'name': 'None', 'text': 'Ensign Crusher.'},
#     4: {'name': 'None', 'text': 'Yes, sir.'},
#     5: {'name': 'None',
#      'text': "If you ever touch my transporter again... I'll kill you."},
#     6: {'name': 'None', 'text': 'Sorry, sir.'}}}],
#  '33A': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': {0: {'name': 'None',
#      'text': "Data watches the town meeting break up into small groups of people TALKING among themselves. Ard'rian approaches."}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'Haritath and Kentor step up furtively.'},
#     1: {'name': 'None',
#      'text': "Mister Data -- I want to tell you that... well, Gosheven doesn't speak for all of us. Ard'rian looks at Data hopefully -- maybe the early returns aren't so bad after all. HARITATH (cont'd) I see no point in dying needlessly."},
#     2: {'name': 'None', 'text': 'And you, Kentor?'},
#     3: {'name': 'None',
#      'text': "I'm not sure. Gosheven has done well for us. But I'd like to hear more of what you have to say."},
#     4: {'name': 'None',
#      'text': 'There are many others that feel the same way but are uneasy about confronting Gosheven.'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': "Ard'rian leads Data toward her house. They EXIT."}}}],
#  '34': [{'header': '',
#    'part': {0: {'name': 'None', 'text': 'thru\tOMITTED'}}}],
#  '36': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': {0: {'name': 'None', 'text': 'Traveling at warp speed.'}}}],
#  '37': [{'header': "INT. CAPTAIN'S READY ROOM (OPTICAL)",
#    'part': {0: {'name': 'None',
#      'text': 'Picard has brought Troi in for consultation.'},
#     1: {'name': 'None',
#      'text': 'In our dealings with other non-humanoid races there has been some point of reference; not so with the Sheliak.'},
#     2: {'name': 'None',
#      'text': 'We must have something in common. We communicate.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None', 'text': '(have we tried?) Telepaths?'},
#     1: {'name': 'None', 'text': 'Attempted and failed.'},
#     2: {'name': 'None', 'text': 'This is ludicrous!'},
#     3: {'name': 'None',
#      'text': "No, sir, the fact that any alien race communicates with another is quite remarkable. She lifts Picard's tea cup from the desk. (continuing) We are stranded on a planet. No language in common, but I want to teach you mine. Troi points to the cup. (continuing) S'smarith. What did I just say?"},
#     4: {'name': 'None', 'text': 'Cup? Glass?'},
#     5: {'name': 'None',
#      'text': 'Are you sure? I might have meant liquid, clear, brown, hot. And we conceptualize the universe in relatively the same way.'},
#     6: {'name': 'None', 'text': 'Point taken.'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': 'Captain, we have the vessel carrying the Sheliak colonists on visual.'}}}],
#  '38': [{'header': 'INT. MAIN BRIDGE',
#    'part': {0: {'name': 'None',
#      'text': 'The tension on the bridge is palpable. Picard moves swiftly to the command station. Riker relinquishes command.'}}}],
#  '39': [{'header': 'ANGLE ON VIEWSCREEN (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'Where a Sheliak ship hangs ominously.'},
#     1: {'name': 'None',
#      'text': 'Open hailing frequencies. This is Captain Jean-Luc Picard of the Starship Enterprise. We again have a vision of the mirrored, shadowed, shifting place. A hint of a watcher in the shadows.'},
#     2: {'name': 'None', 'text': 'Your purpose, Enterprise?'},
#     3: {'name': 'None',
#      'text': 'We desire face-to-face negotiation to settle the crisis on Tau Cygna Five. Troi hands him a PADD. (continuing) We are entitled to consultation under paragraph five hundred and sixty-three subparagraph nine. A beat as the Sheliak look it up.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'The screen again shows the Sheliak vessel.'},
#     1: {'name': 'None', 'text': 'Was that an invitation?'},
#     2: {'name': 'None',
#      'text': "I'm going to take it as such. Number One, you have the bridge. Troi and Picard EXIT. HOLD on Riker."},
#     3: {'name': 'None',
#      'text': 'Helm, maintain relative position. Mister Worf, have Transporter Room Two stand by.'},
#     4: {'name': 'None', 'text': 'Aye, sir.'}}}],
#  '40': [{'header': "INT. ARD'RIAN'S LIVING ROOM - DAY",
#    'part': {0: {'name': 'None',
#      'text': "Haritath, Kentor, and a group of other colonists are gathered around Data and Ard'rian."},
#     1: {'name': 'None',
#      'text': "... and once the Federation resettles us, we'll be left alone?"},
#     2: {'name': 'None', 'text': 'If you so desire.'},
#     3: {'name': 'None', 'text': 'We do. We like doing things on our own.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "Nods all around; they are impressed. Data is the perfect no-pressure salesman; he simply presents the facts. Ard'rian looks expectantly to Kentor; Kentor's still uncertain."},
#     1: {'name': 'None',
#      'text': 'Kentor -- are you with us? Kentor makes up his mind:'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None', 'text': 'Why do we need to?'},
#     1: {'name': 'None',
#      'text': "Because he's respected. Most people will do as he says."},
#     2: {'name': 'None',
#      'text': "The people respect you, too. If you take a stand, they'll fall in line."},
#     3: {'name': 'None',
#      'text': "I don't know. Gosheven's got a lot of supporters..."}}}],
#  '40B': [{'header': 'NEW ANGLE (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'Gosheven fills the doorway. He ENTERS and looks around the room.'},
#     1: {'name': 'None',
#      'text': "I'm disappointed. I thought we had settled this."},
#     2: {'name': 'None',
#      'text': 'Apparently, that is not correct. Gosheven steps up to Data.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'Since when is talk trouble? Gosheven ignores her -- looking only at Data.'},
#     1: {'name': 'None',
#      'text': "It's over. Don't you get it? You had your say, and you lost."},
#     2: {'name': 'None', 'text': 'I appear to be reversing that defeat.'},
#     3: {'name': 'None',
#      'text': "No, you're not -- you're just stubborn. (getting closer) Well, let me tell you something... Gosheven touches Data with an electronic prod -- BLUE SPARKS dance over Data. Data's whole body stiffens -- then goes limp and falls. (completes his thought) ... so am I."},
#     4: {'name': 'None',
#      'text': "Damn you, Gosheven -- Ard'rian rushes to Data's aid."},
#     5: {'name': 'None', 'text': 'You killed him?'}}}],
#  '40C': [{'header': "ON ARD'RIAN",
#    'part': {0: {'name': 'None',
#      'text': "She's pulled out an electronic scanner from her piles of computer junk and is checking out the fallen Data."}}}],
#  '40D': [{'header': 'WIDER',
#    'part': {0: {'name': 'None', 'text': 'to include Gosheven.'},
#     1: {'name': 'None',
#      'text': "(to Ard'rian) You'll see I'm right. He EXITS. We hold on Ard'rian and Data."}}}],
#  '41': [{'header': 'INT. SHELIAK SHIP (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': "Picard and Troi MATERIALIZE. What surrounds them bears little resemblance to a ship. Darkness hangs like bats in the corners. What little light there is filters through swirling mist. As they look down the effect is as if they are walking on black ice, and tiny lights, like flickering eyes twinkle beneath the floor's surface."},
#     1: {'name': 'None',
#      'text': 'Advance and speak. Troi and Picard exchange glances for they can see no sign of the creature they are speaking with. They step forward, and are pinned in a bright light.'},
#     2: {'name': 'None',
#      'text': 'Director, we will comply with your request to remove the colony on Tau Cygna Five, but we need time.'},
#     3: {'name': 'None',
#      'text': 'The given time has elapsed. We carry the membership and we will proceed with their debarkation.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'Unacceptable. You must remove the creatures.'},
#     1: {'name': 'None',
#      'text': "I'm trying! But the needed ship won't be available for three weeks."},
#     2: {'name': 'None', 'text': 'Then you are in violation.'},
#     3: {'name': 'None',
#      'text': "I have admitted that! I'm only asking for a little tolerance."},
#     4: {'name': 'None',
#      'text': 'Section five hundred and one, paragraph seven hundred and sixteen, subparagraph five -- unwanted lifeforms inhabiting H class worlds may be removed at the discretion of the Sheliak corporate.'},
#     5: {'name': 'None',
#      'text': 'We will remove them. But you must grant us the time we require.'},
#     6: {'name': 'None',
#      'text': 'You need time, Picard of the Enterprise, we will save you time. We will eradicate the human infestation.'}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': 'Intelligent converse is impossible. You do not discuss, you gibber.'}}}],
#  '42': [{'header': 'INT. MAIN BRIDGE (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'The startling EFFECT of the Sheliak transporter and Picard and Troi APPEAR. Riker, Worf, and the supernumeraries at Conn and Ops react. Picard and Troi are both very disoriented, staggering slightly. Riker steadies them both.'},
#     1: {'name': 'None',
#      'text': 'I take it the Sheliak just hung up on us. Again.'},
#     2: {'name': 'None', 'text': ''},
#     3: {'name': 'None', 'text': ''},
#     4: {'name': 'None', 'text': ''}}}],
#  '42A': [{'header': "INT. ARD'RIAN'S LIVING ROOM",
#    'part': {0: {'name': 'None',
#      'text': 'Ard\'rian worriedly inspects the unmoving Data with an electronic scanner. Data twitches, "reboots," comes back to life, and sits up. Ard\'rian SIGHS, relieved.'},
#     1: {'name': 'None',
#      'text': 'I was afraid your neural pathways were scrambled beyond repair.'},
#     2: {'name': 'None',
#      'text': 'I am equipped with diagnostic circuits and can correct many malfunctions. Data moves his head, arms, and legs, testing his responses.'},
#     3: {'name': 'None',
#      'text': "I'm not surprised at Gosheven's behavior. But Kentor and the others... they said they were on our side. (bitter) I guess words don't mean very much. Data mulls this over carefully."},
#     4: {'name': 'None',
#      'text': "Perhaps that has been part of our difficulty. Words are all we have been using. (thinking) Humans seem to take much stronger notice of actions. Data makes a decision, gets to his feet. DATA (cont'd) I require a phaser."},
#     5: {'name': 'None', 'text': "What's a phaser?"}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "Data ponders this new problem for a beat, then shrugs it off: DATA (cont'd) I will have to be innovative."}}}],
#  '42B': [{'header': 'INT. SHUTTLECRAFT - CYGNA FIVE - DAY',
#    'part': {0: {'name': 'None',
#      'text': 'Data has opened up a phaser and is adapting it. His forearm is opened, revealing his arm\'s inner workings; Data is "cannibalizing" his arm for parts to modify the phaser. Ard\'rian looks on in fascination.'},
#     1: {'name': 'None',
#      'text': 'Hyperonic radiation randomizes phaser beams. But I believe I can improvise a servocircuit which will compensate by continuously recollimating the output.'},
#     2: {'name': 'None',
#      'text': "You're using your own neural subprocessors to build a smarter phaser."},
#     3: {'name': 'None',
#      'text': "Essentially correct. Ard'rian's impressed. Data completes his work. DATA (cont'd) Get word to Gosheven. Tell him I am coming to the pumping station. Tell him I am going to destroy the aqueduct. Ard'rian is gaping like a carp over this, doesn't know what to say. Finally manages:"},
#     4: {'name': 'None', 'text': "He'll try to stop you --"},
#     5: {'name': 'None',
#      'text': "I sincerely hope so. Off Ard'rian's expression:"}}}],
#  '43': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'The Enterprise hanging motionless in space with the Sheliak ship.'}}}],
#  '44': [{'header': 'INT. MAIN BRIDGE',
#    'part': {0: {'name': 'None', 'text': 'As before.'},
#     1: {'name': 'None', 'text': '(to Worf) Go to Yellow Alert. Shields up.'},
#     2: {'name': 'None', 'text': 'Aye, sir.'},
#     3: {'name': 'None',
#      'text': 'Mister Riker, put us nose to nose with the Sheliak ship. If she makes a move, match it.'},
#     4: {'name': 'None', 'text': 'Aye, sir.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None', 'text': "They're not responding, sir."}}}],
#  '45': [{'header': '',
#    'part': {0: {'name': 'None', 'text': 'thru\tOMITTED'}}}],
#  '47': [{'header': 'INT. MAIN BRIDGE - CONTINUOUS',
#    'part': {0: {'name': 'None', 'text': 'No response.'},
#     1: {'name': 'None',
#      'text': "Close channel -- and get me that treaty! They've been beating us over the head with it for three days. Let's see if we can't find something in it that can be turned to our advantage."},
#     2: {'name': 'None',
#      'text': "We're going to try to beat them at their own game?"},
#     3: {'name': 'None', 'text': 'The treaty is how long?'},
#     4: {'name': 'None', 'text': 'Five hundred thousand words.'},
#     5: {'name': 'None',
#      'text': "(glumly) We are going to regret Data's absence."}}}],
#  '48': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'The square. FOUR MEN armed with rifles stand shoulder to shoulder in front of the plant and aqueduct. Standing defiant and unarmed, save for the probe at his belt, on an upper level is Gosheven.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "Off to one side are a number of colonists (including Ard'rian, Haritath, and Kentor), nervously awaiting the outcome. Then a PHASER STUN hits one of the armed men; he drops. As the others whirl to take aim --"}}}],
#  '48A': [{'header': 'NEW ANGLE (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': "A PHASER BEAM sweeps across the line of armed men, STUNNING them instantly. No one even gets a shot off. Gosheven, astonished, reaches for the probe at his belt. Data calmly stands up from his hiding place, aims his phaser. Gosheven freezes -- it's futile; obviously Data could stun him before he could get anywhere near Data."}}}],
#  '48B': [{'header': 'WIDER (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'as Data steps out into the street, holds his phaser up for all to see.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "DATA (cont'd) And the Sheliak may not even offer you a target. They can obliterate this colony from orbit. You will die never having seen the faces of your killers. Data walks deliberately to one of the stunned defenders, picks up the rifle with his free hand, holds it out to the group of colonists. DATA (cont'd) The choice is yours. The colonists look at one another. Finally:"}}}],
#  '48C': [{'header': 'NEW ANGLE',
#    'part': {0: {'name': 'None',
#      'text': 'Gosheven, slump shouldered, bends and scoops up a handful of dirt at the base of the silent pool. Data moves to join him.'},
#     1: {'name': 'None',
#      'text': 'I really was willing to stay and die for this.'}}}],
#  '50': [{'header': 'ANGLE ON DATA',
#    'part': {0: {'name': 'None',
#      'text': "watching Gosheven go. Data looks down at the phaser for several moments, then holsters it. He looks up to find Ard'rian gazing at him with an expression of pride and love."}}}],
#  '52': [{'header': 'INT. MAIN BRIDGE (OPTICAL)',
#    'part': {0: {'name': 'None',
#      'text': 'Troi is seated at Science One with Picard hanging over her shoulder. Riker and Worf are at Science Two. Pages of treaty crawl past on both screens.'},
#     1: {'name': 'None',
#      'text': 'This is hopeless. Fighting would be preferable. A look from Riker.'},
#     2: {'name': 'None', 'text': "That's it. He indicates a clause."},
#     3: {'name': 'None', 'text': "I don't follow you, sir."},
#     4: {'name': 'None', 'text': 'Worf, get me the Sheliak.'},
#     5: {'name': 'None',
#      'text': '(just heard the reprieve) Yes, sir! Picard, Riker and Troi return to the command station. The strange Sheliak scene replaces a view of the ship.'},
#     6: {'name': 'None',
#      'text': 'Pursuant to paragraph one thousand two hundred and ninety I formally request third party arbitration of our dispute. A beat while they look it up.'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': 'And further, pursuant to subsection D, three, I name the Grizzelas to arbitrate.'},
#     1: {'name': 'None', 'text': 'Grizzelas? Riker glances, puzzled, at Troi.'},
#     2: {'name': 'None',
#      'text': '(mouths) Grizzelas? Troi quells him with a look.'},
#     3: {'name': 'None',
#      'text': "Unfortunately they are currently in their hibernation cycle, but they'll awaken in six months, and then we'll get this matter settled. Now, do you want to wait... or give me my three weeks?"},
#     4: {'name': 'None',
#      'text': 'Absurd. We carry the membership! We can brook no delay!'},
#     5: {'name': 'None', 'text': 'Then I declare the treaty in abeyance!'},
#     6: {'name': 'None',
#      'text': 'Wait! Negotiation is -- Picard gestures to Worf -- cut the transmission. Worf obeys. A long beat.'},
#     7: {'name': 'None', 'text': '(smiling) You enjoyed that.'},
#     8: {'name': 'None', 'text': "You're damn right."}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None', 'text': '(continuing) Sir?'},
#     1: {'name': 'None', 'text': '(a beat) On screen. The Sheliak reappear.'},
#     2: {'name': 'None',
#      'text': 'You may have your three weeks, Picard of the Enterprise.'},
#     3: {'name': 'None',
#      'text': '(with careful enunciation) Thank you. The screen returns to a view of the Sheliak ship pulling away. Instant release of tension. Suddenly the turbolift doors open, and Geordi ENTERS. He is looking frazzled. People\'s expressions reflect the thought that "dear God, he did it."'},
#     4: {'name': 'None',
#      'text': 'Captain, we can do it! We can modify the transporters.'},
#     5: {'name': 'None', 'text': 'Excellent.'},
#     6: {'name': 'None',
#      'text': "It'll take fifteen years, and a research team of a hundred --"},
#     7: {'name': 'None',
#      'text': '(dryly) Mister La Forge, I believe we will postpone.'},
#     8: {'name': 'None', 'text': '(with a grin) Yes, sir. Geordi EXITS.'}}}],
#  '53': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': {0: {'name': 'None',
#      'text': 'Data is inside the shuttle making preparations for departure.'},
#     1: {'name': 'None',
#      'text': 'Commander Data to Enterprise. I am preparing to leave Tau Cygna Five and await rendezvous instructions.'},
#     2: {'name': 'None',
#      'text': "Acknowledged. Stand by. Outside the shuttle, Ard'rian approaches. Data sees her, emerges from the shuttle to meet her."},
#     3: {'name': 'None', 'text': 'Hi.'},
#     4: {'name': 'None', 'text': "Hello, Ard'rian."},
#     5: {'name': 'None',
#      'text': "The evacuation plan is going well. When the transport ship arrives, we'll be ready. (a beat) You succeeded."},
#     6: {'name': 'None',
#      'text': 'I would not have succeeded without your support and insight, and I appreciate your assistance.'},
#     7: {'name': 'None', 'text': "Good. Then you won't forget me?"},
#     8: {'name': 'None',
#      'text': 'I am incapable of forgetting. I will remember every detail of my visit with perfect clarity.'},
#     9: {'name': 'None', 'text': 'But nothing more?'}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None', 'text': "Ard'rian bites the bullet:"},
#     1: {'name': 'None',
#      'text': 'I guess what I really want to know is -- do you have any feelings for me?'},
#     2: {'name': 'None',
#      'text': "I have no feelings of any kind. Ard'rian is silent."},
#     3: {'name': 'None',
#      'text': "No. Of course you don't. Data studies her. She's downcast. Mimicking her behavior earlier, he gives her a quick kiss on the lips, startling her. ARD'RIAN (cont'd) What was that for?"},
#     4: {'name': 'None', 'text': 'You appeared to require it.'},
#     5: {'name': 'None',
#      'text': "You observed I was unhappy and did what you concluded would make me feel better. A purely rational deduction. She's still downcast."},
#     6: {'name': 'None', 'text': 'Have I disappointed you?'},
#     7: {'name': 'None',
#      'text': "No, I'm disappointed in myself -- for wanting something I know I can't have. (a beat) Data, in so many ways you're superior to humans. But you are still a machine... without emotion."}}},
#   {'header': 'CONTINUED: (2)',
#    'part': {0: {'name': 'None',
#      'text': "It's so easy to believe otherwise. It's so easy to read things into your behavior... and perceive feelings where none exist. (a beat) Well, I am human and I do have feelings... silly though they may be at times. I like you, Data. You're my favorite android."},
#     1: {'name': 'None',
#      'text': 'But I am the only android you have ever met.'}}},
#   {'header': 'CONTINUED: (3)',
#    'part': {0: {'name': 'None',
#      'text': "And with a smile, Ard'rian EXITS. Data climbs into the shuttle, and the door closes."}}}],
#  '55': [{'header': "INT. CAPTAIN'S READY ROOM",
#    'part': {0: {'name': 'None',
#      'text': "Picard is listening to a recording of Data's string quartet concert in Ten Forward. DOOR CHIME."},
#     1: {'name': 'None',
#      'text': "Come. Data ENTERS. PICARD (cont'd) Welcome home, Mister Data. Well done."},
#     2: {'name': 'None', 'text': 'Thank you, sir.'},
#     3: {'name': 'None',
#      'text': 'The good doctor was kind enough to provide me with a recording of your concert. Your performance shows a good deal of feeling.'},
#     4: {'name': 'None',
#      'text': 'As I have lately had to remind others, I have no feelings.'},
#     5: {'name': 'None',
#      'text': "That's hard to believe; your playing is quite beautiful."}}},
#   {'header': 'CONTINUED:',
#    'part': {0: {'name': 'None',
#      'text': "And is there nothing of Data in what I'm hearing? Data ponders this. PICARD (cont'd) You chose the violinists. Heifetz and Bron-Ken had radically different styles, but you combined them -- successfully."},
#     1: {'name': 'None',
#      'text': "I suppose I have learned to be innovative... when necessary, sir. Picard nods. He's made his point."}}}]}

# %%
y = separate_lines_by_character(q, chars)

# %%
y
# Out:
# {'1': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['Moving at impulse near some extraordinarily interesting',
#     'astronomical object.']}],
#  '2': [{'header': 'INT. TEN-FORWARD',
#    'part': ['Present are PICARD, BEVERLY, and TWELVE N.D.',
#     'CREWMEMBERS. A VULCAN and ONE WOMAN are seated,',
#     'holding their instruments -- a violin and a viola.',
#     "O'BRIEN tunes his cello. DATA ENTERS carrying a",
#     'violin. He checks at the door, startled to see the',
#     'captain. Picard beckons, and Data crosses to him.',
#     'DATA',
#     'Captain, Doctor, I am honored by',
#     'your presence, but may I suggest',
#     'you attend the second concert.',
#     'BEVERLY',
#     'Why, Data?',
#     'DATA',
#     'Ensign Ortiz will perform the',
#     'violin part. My rendition will',
#     'be less enjoyable.',
#     'PICARD',
#     'Oh?',
#     'DATA',
#     'While I am quite proficient',
#     'Technically, according to my',
#     'fellow performers, I lack soul.',
#     'BEVERLY',
#     "Data, telling us why you're going",
#     'to fail before you make the',
#     'attempt is never wise.',
#     'DATA',
#     'But is not honesty always the',
#     'preferred choice?']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Excessive honesty can be',
#     'disastrous... particularly in a',
#     'commander.',
#     'DATA',
#     '(very intrigued)',
#     'Indeed?',
#     'PICARD',
#     'Knowing your limitations is one',
#     'thing. Advertising them to a crew',
#     'can damage your ability to lead.',
#     'DATA',
#     'Because you lose their respect?',
#     'BEVERLY',
#     'No, because you may begin to',
#     'believe in those limitations',
#     'yourself.',
#     'Data considers this, then moves to take his place with',
#     'the other performers.']}],
#  '2A': [{'header': 'ANGLE ON PICARD AND BEVERLY',
#    'part': ['O.s., the string quartet TUNES. There is the SOUND of',
#     'the communicator hail.',
#     "RIKER'S COM VOICE",
#     "Captain, we're receiving a message",
#     'from the Sheliak Corporate.',
#     'Picard reacts with surprise, stands and EXITS. As he',
#     'leaves, the quartet starts to PLAY.',
#     'CUT TO:']}],
#  '3': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['Picard ENTERS. RIKER and WORF at their usual stations.',
#     'Supernumeraries at CONN and OPS.']},
#   {'header': 'CONTINUED:',
#    'part': ['WORF',
#     'Origin point of the message',
#     'confirmed. It is from the Shelia',
#     'star system.',
#     'RIKER',
#     'The Sheliak have not attempted',
#     'to communicate with the Federation',
#     'for a hundred and eleven years.',
#     'PICARD',
#     'On screen.']}],
#  '4': [{'header': 'ANGLE ON VIEWSCREEN (OPTICAL)',
#    'part': ['What appears is the text of a treaty. English on one',
#     'side, Sheliak on the other. Sheliak is not symbols',
#     'as we know them, but rather a pattern of lights. A',
#     'recorded message begins.',
#     'SHELIAK VOICE',
#     'Federation creatures, there are',
#     'humans on the fifth planet of Tau',
#     'Cygna. This planet was ceded',
#     'to the corporate in section one',
#     'hundred and thirty-three,',
#     'paragraph seventy-seven of the',
#     'Treaty of Armens. We will begin',
#     'settlement of this world in four',
#     'days. Remove the humans.',
#     'Riker is up, and heading for Science One.',
#     'PICARD',
#     'What the devil --',
#     'SHELIAK VOICE',
#     'Federation creatures, there are',
#     'humans on the fifth planet --',
#     'PICARD',
#     'Cancel message.',
#     'Inquiring look to Riker.',
#     'RIKER',
#     'Tau Cygna Five is in the de Laure',
#     'belt -- heavy concentrations of',
#     'hyperonic radiation.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     "Humans can't survive in such an",
#     'environment. Exposure to',
#     'hyperonic radiation is fatal.',
#     'RIKER',
#     'Then the Sheliak are asking us',
#     'to chase ghosts.',
#     'PICARD',
#     'No, Number One. The Sheliak',
#     "haven't broken a century of",
#     'silence to send us after phantoms.',
#     'An investigation is in order.',
#     'Set course for Tau Cygna Five.',
#     "Off Picard's expression:",
#     'FADE OUT.',
#     'END OF THE TEASER                        ',
#     'ACT ONE                             ',
#     'FADE IN:']}],
#  '5': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['entering orbit around a planet.']}],
#  '6': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['Picard, Riker, Data, Beverly and Worf. Supernumerary',
#     'at CONN.',
#     'WORF',
#     'Human life form readings from the',
#     'planet.',
#     'RIKER',
#     "So, the Sheliak weren't",
#     'hallucinating.',
#     'PICARD',
#     'Numbers?',
#     'WORF',
#     'Impossible to get an accurate',
#     'reading, Captain. The high',
#     'radiation levels are disrupting',
#     'our sensors.',
#     'DATA',
#     'Hyperonic radiation also',
#     "interferes with ship's",
#     'transporters; they are now',
#     'inoperable.',
#     'WORF',
#     "So are the ship's phasers.",
#     'RIKER',
#     'How can humans survive down there?',
#     'BEVERLY',
#     'They must have found a way to',
#     'adapt.',
#     '(thinks it over)',
#     "Milan's work in radiation",
#     "sensitivity suggests it's",
#     'possible. Perhaps with extensive',
#     'virotherapy...',
#     '(grimly)',
#     'Until they found the answer, their',
#     'mortality rate must have been',
#     'staggering.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Well, whoever they are and however',
#     "they've survived, we've got to",
#     'get them off the planet.',
#     'RIKER',
#     'By treaty, this world does belong',
#     'to the Sheliak...',
#     'PICARD',
#     '... who are within their rights',
#     'to demand the removal of these',
#     '"trespassers."',
#     'RIKER',
#     "And if we don't remove them, the",
#     'Sheliak will.',
#     'BEVERLY',
#     'How forcefully?',
#     'RIKER',
#     'To the Sheliak, humans are a lower',
#     "life form. They'd have no",
#     'compunctions about exterminating',
#     'the intruders.',
#     "Beverly is taken aback. Riker's dead serious.",
#     'PICARD',
#     'Mister Data. As you are unaffected',
#     'by hyperonic radiation, you will',
#     'go to the planet via shuttlecraft',
#     'and commence evacuation',
#     'procedures.',
#     'DATA',
#     'Aye, sir.',
#     'Without a word wasted the android is out of his chair,',
#     'and EXITS the bridge.',
#     'PICARD',
#     "Any speculation as to what he'll",
#     'find, Number One?',
#     'RIKER',
#     'A lost survey ship would be my',
#     'guess. A dozen or so survivors',
#     'at most.',
#     'CUT TO:']}],
#  '7': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': ['Data is outside the shuttle, scanning with his', 'tricorder.']}],
#  '7A': [{'header': 'NEW ANGLE',
#    'part': ['as HARITATH and KENTOR (two male humans) and TWO N.D.',
#     'WORKERS cautiously approach the shuttle from the other',
#     'side (the shuttle blocks their view of Data).',
#     'HARITATH',
#     '(in wonder)',
#     'A shuttlecraft!',
#     'KENTOR',
#     "Where's it from?",
#     'HARITATH',
#     'Look at the markings. I think',
#     "it's from the Federation.",
#     'Data steps into their view from around the shuttle.',
#     'DATA',
#     'Hello.',
#     'The four humans jump, startled.',
#     'HARITATH',
#     "We saw your ship... You're the",
#     "first visitor we've had in..."]},
#   {'header': 'CONTINUED: (2)',
#    'part': ['KENTOR',
#     "The first visitor we've ever had.",
#     'They take a closer look at Data.',
#     'HARITATH',
#     "You're -- not human.",
#     'DATA',
#     'That is correct. I am an android.',
#     'I am Lieutenant Commander Data',
#     'of the Federation Starship',
#     'Enterprise.',
#     'HARITATH',
#     '(excited)',
#     'Our great-grandparents were',
#     'citizens of the Federation.',
#     '(realizing)',
#     "But you don't want to waste time",
#     'talking to us...',
#     'KENTOR',
#     "You'll want to speak with",
#     "Gosheven. We'll take you to him.",
#     'DATA',
#     'Excellent.',
#     'HARITATH',
#     "I'm sure the Federation will be",
#     'very proud of us. Wait until you',
#     "see all we've accomplished.",
#     'DATA',
#     'And who, precisely, is "we?"',
#     'HARITATH',
#     "You don't know? No, I guess you",
#     "wouldn't, would you? We are the",
#     'descendants of the original',
#     'settlers -- from the colony ship',
#     'Artemis.',
#     'CUT TO:']}],
#  '8': [{'header': 'INT. ENTERPRISE - MAIN BRIDGE',
#    'part': ['Picard and Worf in their usual places. Riker at',
#     'Science One. Supernumeraries at Conn and Ops.']},
#   {'header': 'CONTINUED:',
#    'part': ['RIKER',
#     'Got it. The Artemis, launched one',
#     'hundred forty-two years ago,',
#     'destination Septimis Minor. When',
#     'they failed to check in, Starfleet',
#     'began an extensive search.',
#     'PICARD',
#     'What carried the Artemis so far',
#     'off course?']}],
#  '9': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': ['Haritath and Kentor wait patiently for Data to finish',
#     'him communication.',
#     'DATA',
#     'My local informant does not know.',
#     'In the early days survival on Tau',
#     'Cygna Five was more important than',
#     'history.']}],
#  '10': [{'header': 'INTERCUTS',
#    'part': ['PICARD',
#     'Understood. How many are there?',
#     'DATA',
#     'Approximately fifteen thousand.',
#     'Reactions from the bridge crew. Now they really have',
#     'got a problem.',
#     'RIKER',
#     '(to Picard)',
#     "We've only got three days.",
#     'Without working transporters, we',
#     "couldn't have them out in time.",
#     'PICARD',
#     'Shuttles?',
#     'Worf does some figuring on his console.',
#     'WORF',
#     'Loading all the Enterprise',
#     'shuttlecraft to capacity --',
#     'evacuation would take four weeks,',
#     'four days.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Then we need more time. Mister',
#     'Data, prepare the colonists for',
#     'an evacuation.',
#     "DATA'S COM VOICE",
#     'Aye, sir.',
#     'Picard closes the com line.',
#     'PICARD',
#     '(continuing)',
#     'Mister Worf, get me the Sheliak.',
#     'WORF',
#     'Their home world is quite distant,',
#     'Captain. This will take some',
#     'time.',
#     'CUT TO:']}],
#  '11': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['The main pumping station of Tau Cygna V. In the',
#     'distance are mountains. A thin white line descends',
#     'from the mountains, and as it comes closer we realize',
#     'it is an aqueduct. Along the line of the aqueduct are',
#     'lush fields, a veritable Garden of Eden, which ends',
#     'like a knife-cut and the desert returns. It culminates',
#     'in a strange cubistic-shaped purifying station. In a',
#     'pool, the water churns into a white froth.',
#     'GOSHEVEN, the leader, supervises TWO WORKERS testing',
#     'the water in the pool.',
#     'Data, Haritath, and Kentor approach.',
#     'HARITATH',
#     "Gosheven, look what's come --",
#     'Gosheven sees Data, looks him up and down very',
#     "carefully. Gosheven's as surprised as Haritath was,",
#     'but keeps a lid on it -- Data may represent a threat,',
#     "so Gosheven's attempting a poker face.",
#     'DATA',
#     'Lieutenant Commander Data of the',
#     'Starship Enterprise.']},
#   {'header': 'CONTINUED:',
#    'part': ['KENTOR',
#     "He's an android.",
#     'GOSHEVEN',
#     'So he is.',
#     '(a beat)',
#     "Well, you're here -- what do you",
#     'want?',
#     'DATA',
#     'My mission is to prepare this',
#     'colony for evacuation.',
#     'Reactions from the men. Gosheven is calm, almost',
#     'amused:',
#     'GOSHEVEN',
#     'Why?',
#     'DATA',
#     'Because this planet belongs to',
#     'the Sheliak.',
#     'GOSHEVEN',
#     'And just who is this Sheliak?',
#     'DATA',
#     'The term is plural. The Sheliak',
#     'are an intelligent, non-humanoid',
#     'life form, classification R-3 --',
#     'GOSHEVEN',
#     '(interrupting)',
#     "This colony's been here for a",
#     'hundred and forty years -- and',
#     "no one's ever seen a Sheliak.",
#     "I'd say that makes Tau Cygna",
#     'Five our planet. (ALTERNATE:',
#     'ninety years)',
#     'DATA',
#     'But the original destination of',
#     'the Artemis was Septimis Minor.',
#     'GOSHEVEN',
#     'The guidance systems on the',
#     'Artemis failed -- and sent them',
#     'off course. Far off course.',
#     'Our ancestors were lucky to find',
#     'any place to land.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['HARITATH',
#     'And when they did, the radiation',
#     'started killing them.',
#     'GOSHEVEN',
#     'Hyperonic radiation took the lives',
#     'of a third of the colonists before',
#     'they learned they could adapt',
#     'to it.',
#     'KENTOR',
#     'But the colony survived -- and',
#     'prospered.',
#     'GOSHEVEN',
#     '(with pride)',
#     "Look around. We've brought",
#     'water to the desert, built a',
#     'community.',
#     'DATA',
#     'Your accomplishments are indeed',
#     'remarkable. However, the',
#     'Sheliak and the Federation',
#     'have a treaty that clearly makes',
#     'this planet Sheliak domain.',
#     'GOSHEVEN',
#     'Then change the treaty.',
#     'DATA',
#     'That may not be possible. The',
#     'Sheliak wish to colonize this',
#     'planet, and they are unwilling',
#     'to share it with humans.',
#     '(MORE)']},
#   {'header': 'CONTINUED: (3)',
#    'part': ["DATA (cont'd)",
#     'If you are still here when the',
#     'Sheliak colony ship arrives,',
#     'they will eradicate you.',
#     'Haritath and Kentor exchange a worried glance, but',
#     'Gosheven is unfazed.',
#     'HARITATH',
#     'They would kill us all?',
#     'DATA',
#     'They have little regard for',
#     'human life. Thus, our most',
#     'sensible course is to prepare a',
#     'contingency plan for the',
#     'evacuation of your people.',
#     'GOSHEVEN',
#     "We're not evacuating.",
#     'Data is taken aback.']},
#   {'header': 'CONTINUED: (4)',
#    'part': ['DATA',
#     'Perhaps I have not made myself',
#     'clear.',
#     'GOSHEVEN',
#     'Yes, you have. Now let me be',
#     "equally clear. There's going",
#     'to be no evacuation.',
#     '(a beat)',
#     "You've delivered your message --",
#     'so go back to your ship. I have',
#     'work to do.',
#     'Gosheven returns to his work on the pumping station.']}],
#  '11A': [{'header': 'ON DATA',
#    'part': ['as he considers his next move. Then -- an object comes',
#     'flying at Data.',
#     'With android speed and reflexes, Data catches the',
#     'object and examines it. It is an iron bar.',
#     "ARD'RIAN (O.S.)",
#     'Nice catch. Wonderful reflexes.',
#     'Data turns to see --']}],
#  '11B': [{'header': 'WIDER',
#    'part': ["ARD'RIAN, an attractive female, approaches.",
#     "ARD'RIAN",
#     'Sorry to test you like that --',
#     'but I was curious.',
#     'GOSHEVEN',
#     '(amused)',
#     'Found a new toy, have we, Ardy?',
#     "ARD'RIAN",
#     'Toy? This is the most incredible',
#     "android I've ever seen.",
#     'DATA',
#     'Have you seen many?',
#     "ARD'RIAN",
#     "Actually, no. You're the first.",
#     'GOSHEVEN',
#     "(to Ard'rian)",
#     'Only you would get this excited',
#     'over a walking calculator.',
#     "ARD'RIAN",
#     '(bridling)',
#     "He's more interesting than",
#     'anything else walking around',
#     'here...',
#     "Gosheven CHUCKLES -- he's succeeded in getting under",
#     'her skin.',
#     'GOSHEVEN',
#     'Depends on what you find',
#     'interesting.']},
#   {'header': 'CONTINUED:',
#    'part': ["Ard'rian's had enough of Gosheven's male conceit. She",
#     'moves away, motions for Data to follow. Data does.',
#     "ARD'RIAN",
#     '(to Data)',
#     'Cybernetic intelligence fascinates',
#     'me. Are your neural pathways',
#     'duotronic?',
#     'DATA',
#     'No -- they are positronic.',
#     "ARD'RIAN",
#     "I didn't know that was possible!",
#     "What's your memory capacity? How",
#     'many operations per second? I',
#     'have a million questions...',
#     'DATA',
#     'I am afraid I have no time to',
#     'answer one million questions.',
#     'I have a mission to accomplish.',
#     '(MORE)']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["DATA (cont'd)",
#     'I need to know more about your',
#     'people, and Gosheven seems',
#     'unwilling to talk to me further.',
#     "ARD'RIAN",
#     '(extending a hand)',
#     "I'm Ard'rian McKenzie. Perhaps",
#     'I can help you.',
#     'As Data shakes her hand, we:',
#     'CUT TO:']}],
#  '12': [{'header': 'INT. OBSERVATION LOUNGE',
#    'part': ["Picard, Riker and TROI are seated as GEORDI, O'Brien",
#     'ENTER.',
#     'RIKER',
#     "Gentlemen, we're giving you an",
#     'assignment, and the one thing we',
#     "don't want to hear is that it is",
#     'impossible.',
#     "Riker defers to Picard. Geordi and O'Brien cast wary",
#     'glances at Picard. Now what the hell is he going to',
#     'want?',
#     'PICARD',
#     'I need the transporters to',
#     'function despite the hyperonic',
#     'radiation.',
#     'GEORDI',
#     'Impossi -- Yes, sir.',
#     "Geordi and O'Brien EXIT. Riker, Troi and Picard study",
#     'each other seriously.',
#     'RIKER',
#     'Even if we can get the Sheliak',
#     "to talk to us, they're not likely",
#     'to be accommodating.']},
#   {'header': 'CONTINUED:',
#    'part': ['TROI',
#     'Captain, when the treaty was',
#     'negotiated the Federation sent',
#     'three hundred and seventy-two',
#     'legal experts. What have we got?',
#     'PICARD',
#     'Thee... and me.',
#     "Off Troi's very dubious expression as we:",
#     'FADE OUT.',
#     'END OF ACT ONE                          ',
#     'ACT TWO                             ',
#     'FADE IN:']}],
#  '13': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['in orbit around Tau Cygna V.']}],
#  '14': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['Picard pacing, Troi seated as they wait for the call.',
#     'Worf at his station. Supernumeraries at Conn and Ops.',
#     'WORF',
#     'No response.',
#     'PICARD',
#     'Try again. Boost signal strength.',
#     'Worf makes adjustments.',
#     'WORF',
#     'Sheliak Corporate. This is the',
#     'Starship Enterprise. Respond',
#     'please.']}],
#  '15': [{'header': 'ANGLE ON VIEWSCREEN - (OPTICAL)',
#    'part': ['as it changes from a view of stars to -- someplace? a',
#     'bridge? Wherever the SHELIAK are calling from it is',
#     'a disturbing place for humans. Darkness, mirrored',
#     'surfaces, and hidden in the shadows a creature who is',
#     'decidedly unsettling for the crew. Its shape is',
#     'constantly shifting like oozing sludge, and there is',
#     'a hint of flickering eyes -- too many eyes.',
#     'SHELIAK',
#     'Conversation is neither required',
#     'nor desired.',
#     'Picard schools his features into an expression of',
#     'polite interest.',
#     'PICARD',
#     'Conversation is necessary if we',
#     'are to find a solution to our',
#     'mutual problem.',
#     'SHELIAK',
#     'Our involvement in Federation',
#     'illegality is not indicated.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Both parties are involved, sir.',
#     'SHELIAK',
#     'Remove the humans from the Tau',
#     'Cygna system. Three Earth days',
#     'remain.',
#     'Troi leans in, and whispers:',
#     'TROI',
#     'Their culture is extremely formal,',
#     'almost ritualistic. An apology',
#     'might smooth matters.',
#     'PICARD',
#     'I apologize for our inadvertent',
#     'violation of the treaty.',
#     'SHELIAK',
#     'Acknowledged and accepted. Now',
#     'remove the human creatures.',
#     'PICARD',
#     'Let us negotiate in good faith...',
#     'SHELIAK',
#     'Negotiate to what purpose? The',
#     'treaty is signed.',
#     'PICARD',
#     'There is a thriving colony on the',
#     'planet. Rather than uproot these',
#     'people may I offer a compromise?',
#     'SHELIAK',
#     'Denied.',
#     'PICARD',
#     'Why?!',
#     'SHELIAK',
#     'The law is paramount. We are',
#     'entitled.',
#     'PICARD',
#     'This is not a law. It is a',
#     'treaty. It is designed to smooth',
#     'relations between peoples. Not',
#     'to act as a strait...']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["But Picard's talking to a blank screen. The Sheliak",
#     'have hung up on him.',
#     'PICARD',
#     '... jacket.',
#     "Off Picard's annoyed expression.",
#     'CUT TO:']}],
#  '17': [{'header': "INT. ARD'RIAN'S FRONT ROOM - DAY",
#    'part': ['A comfortable room constructed of stone with a heavy',
#     'beamed ceiling. The furniture is hand hewn, durable',
#     'but comfortable. Contrasting with this are various',
#     'computer parts and consoles, both assembled and in',
#     'pieces, strewn about.',
#     "Ard'rian and Data ENTER.",
#     "ARD'RIAN",
#     "... you really think we'll have",
#     'to leave Tau Cygna Five?',
#     'DATA',
#     'The possibility exists, and',
#     'Gosheven appears unwilling to',
#     'prepare for it. Why?']},
#   {'header': 'CONTINUED:',
#    'part': ["ARD'RIAN",
#     "Maybe because you're an",
#     "android. I don't think Gosheven",
#     'likes the idea of machines',
#     'ordering him around.',
#     'DATA',
#     'I am not ordering him to do',
#     'anything; I am merely trying to',
#     'persuade him that his people',
#     'should prepare to evacuate.',
#     '(thinks)',
#     'Do you believe my suggested',
#     'course of action should be followed?',
#     "ARD'RIAN",
#     'Of course.',
#     'DATA',
#     'In spite of the fact that I am',
#     'an android?',
#     "ARD'RIAN",
#     "Because of that fact. I don't",
#     'have any silly prejudices against',
#     'computers -- I like them.',
#     'SHe gestures around the room, a bit apologetically:',
#     "ARD'RIAN (cont'd)",
#     'Not that any computer we have is',
#     'half as sophisticated as you...',
#     'Data looks at a particularly "primitive" computer:',
#     'DATA',
#     'No, I would say not.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["ARD'RIAN (cont'd)",
#     'People can be selfish,',
#     'irrational, stubborn, malicious',
#     '-- you name it. But computers',
#     "don't have those failings.",
#     'Data follows her logic:',
#     'DATA',
#     'You conclude from this that I am',
#     'impartial... hence you accept',
#     'my recommendations.',
#     'She nods.',
#     "DATA (cont'd)",
#     'Yet Gosheven does not.',
#     '(thinks)',
#     'Perhaps he might reconsider his',
#     'position if someone other than',
#     'myself were to present the',
#     'arguments.',
#     "ARD'RIAN",
#     "Well, I'm willing to talk to him,",
#     "but I don't think he'll take me",
#     'seriously.',
#     '(with distaste)',
#     "He finds me attractive -- but I'm",
#     'not interested in him at all.',
#     'So he belittles me to protect his',
#     'ego --']}],
#  '19': [{'header': 'NEW ANGLE',
#    'part': ["as Data's communicator TRILLS. He touches the",
#     'insignia.',
#     'DATA',
#     'Data, here.',
#     "PICARD'S COM VOICE",
#     "The Sheliak won't bargain.",
#     'DATA',
#     'Understood.']},
#   {'header': 'CONTINUED:',
#    'part': ["PICARD'S COM VOICE",
#     "I'm contacting Starfleet to",
#     'arrange for transport. Get those',
#     'people prepared for evacuation.',
#     'We may have to move very quickly.']},
#   {'header': 'CONTINUED:',
#    'part': ['DATA',
#     'Yes, sir.',
#     "Data cuts the communication, turns to Ard'rian.",
#     'DATA',
#     'We must speak with Gosheven',
#     'immediately.',
#     "Ard'rian grabs a coat, and they EXIT.",
#     'CUT TO:']}],
#  '19A': [{'header': 'INT. TRANSPORTER ROOM (OPTICAL) (FORMERLY SC. 16)',
#    'part': ["Geordi, O'Brien and WESLEY have the panels removed",
#     "from the wall behind the transporter console. Geordi's",
#     'tool box is nearby. Sophisticated tools litter the',
#     'floor. Off to the left side of the transporter are',
#     'six test objects. The trio is watching tensely as',
#     "O'Brien touches the console. A test object",
#     'MATERIALIZES looking like swiss cheese. Geordi picks',
#     'it up. Riker ENTERS.',
#     'RIKER',
#     'Gentlemen, how are you coming?',
#     '(spots the object)',
#     'What the hell is that?',
#     'Geordi sets aside the mutilated object.',
#     'GEORDI',
#     'Our first attempt.',
#     "O'BRIEN",
#     'We recalibrated the transporter',
#     'setting for the tightest possible',
#     'beam.',
#     'WESLEY',
#     "But we've got plenty of things",
#     'left to try.',
#     'Geordi is studying the test object again.',
#     'GEORDI',
#     "There's some really interesting",
#     'residue . . . reminds me of --',
#     '(a beat)',
#     "There's that damn pulsar in the",
#     'neighborhood.']},
#   {'header': 'CONTINUED:',
#    'part': ['WESLEY',
#     'Teremi-thorons.',
#     "O'BRIEN",
#     'This just got a lot harder.',
#     'WESLEY',
#     "They're one of the most elusive",
#     'sub-atomic particles known, and',
#     'they really shred a transporter',
#     'signal.',
#     'RIKER',
#     'Thank you, Ensign, I passed',
#     'physics.',
#     '(to Geordi)',
#     'Keep at it. We need those',
#     'transporters.',
#     'Riker EXITS.',
#     'GEORDI',
#     "We're going to have a lot of fun",
#     'cracking this one.',
#     'CUT TO:']}],
#  '20': [{'header': '', 'part': ['thru\tOMITTED']}],
#  '22': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ["Gosheven, Data, and Ard'rian are standing near the pool",
#     'of water. Gosheven cups some water in a hand.',
#     'GOSHEVEN',
#     'See that? Do you have any idea',
#     'what it is? What it means?',
#     'DATA',
#     'It is water, a substance composed',
#     'of two atoms of hydrogen --',
#     'GOSHEVEN',
#     "It's not water. It's blood and",
#     'sweat -- the result of a hundred',
#     'and forty years of combined',
#     'effort. (ALTERNATE: ninety',
#     "years) This isn't a town.",
#     '(MORE)']},
#   {'header': 'CONTINUED:',
#    'part': ["GOSHEVEN (Cont'd)",
#     "It's a monument to every man,",
#     'woman, and child who has lived',
#     'and died on Tau Cygna Five.',
#     "ARD'RIAN",
#     "Gosheven, you're talking nonsense.",
#     'GOSHEVEN',
#     "Am I? My grandfather's buried",
#     'on that mountain.',
#     '(points to the distant',
#     'line of hills)',
#     'He died in a rock slide surveying',
#     'the route for this aqueduct. This',
#     'colony exists because of his',
#     'sacrifice, and the sacrifices of',
#     "thousands of others. No, we're",
#     'not leaving.',
#     'DATA',
#     'The Sheliak will not accept humans',
#     'on their planet. And they will',
#     'not hesitate to use force to',
#     'remove you.',
#     'GOSHEVEN',
#     '(calmly)',
#     'And we will not hesitate to fight',
#     'back.',
#     'DATA',
#     'You cannot win.',
#     'GOSHEVEN',
#     "You just don't understand, do you?",
#     'We will not be bullied off our',
#     'land... not by you, and not by',
#     'the Sheliak.',
#     'Gosheven whirls and walks away. End of conversation.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["ARD'RIAN",
#     '(re Gosheven; bitter)',
#     'Stubborn and irrational. Now what',
#     'do we do?',
#     'DATA',
#     'Are his sentiments typical among',
#     'the colonists?',
#     "ARD'RIAN",
#     'I hope not. Are you thinking',
#     'of bypassing Gosheven and taking',
#     'your case directly to the people?',
#     'DATA',
#     '(nods)',
#     'I see no other course of action.',
#     'If I can convince enough people',
#     'of the necessity of leaving --',
#     "ARD'RIAN",
#     '(a smile)',
#     'Don\'t you mean "if we can',
#     'convince?"',
#     'DATA',
#     'You are offering assistance?',
#     "Ard'rian nods, extends her arm -- c'mon, let's get",
#     'going. As they move off:',
#     'CUT TO:']}],
#  '22A': [{'header': 'EXT. SPACE - ENTERPRISE (OPTICAL) (FORMERLY SC. 20)',
#    'part': ['In orbit around Tau Cygna V.']}],
#  '22B': [{'header': "INT. CAPTAIN'S READY ROOM (FORMERLY SC. 21)",
#    'part': ['Picard is pacing rapidly about the office. Riker',
#     'ENTERS.',
#     'RIKER',
#     'Yes, sir?']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Three weeks. Starfleet is profuse',
#     'in their apologies, but it will',
#     'still be three weeks.',
#     'RIKER',
#     'Until?',
#     'PICARD',
#     'Until the arrival of a colony',
#     'transport ship equipped with',
#     'dedicated personnel shuttles.',
#     'RIKER',
#     "We can't wait three weeks.",
#     'PICARD',
#     'The Sheliak must agree to extend',
#     'our deadline.',
#     'Picard sits in silence for a beat.',
#     "PICARD (cont'd)",
#     'If they plan to settle Tau Cygna',
#     'Five two days from now...',
#     'RIKER',
#     '... one of their ships must already',
#     'be en route.',
#     'PICARD',
#     '(decides)',
#     "We're going to intercept that",
#     'ship.',
#     'RIKER',
#     'The Sheliak may interpret that',
#     'as a hostile act.',
#     'PICARD',
#     'We have to take the risk.',
#     "Off Picard's determined expression as we:",
#     'FADE OUT.',
#     'END OF ACT TWO                          ',
#     'ACT THREE                            ',
#     'FADE IN:']}],
#  '23': [{'header': 'INT. OBSERVATION LOUNGE',
#    'part': ['Riker pacing slowly, looking out at the stars.',
#     'RIKER',
#     'The Enterprise is going to try',
#     'to intercept the Sheliak colony',
#     'ship. Your job ... well, you know',
#     'your job.',
#     'CUT TO:']}],
#  '24': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['Data standing alone in an archway.',
#     'DATA',
#     'Commander, in human parlance, I do',
#     'not believe I can "get the job',
#     'done." My training has prepared',
#     'me for starship command duties.',
#     'As a cultural contact I am',
#     'proving to be less than exemplary.']}],
#  '25': [{'header': 'INTERCUTS',
#    'part': ['RIKER',
#     "What's the situation?",
#     'DATA',
#     'Their leader has rejected my',
#     'counsel. He denies the logic of',
#     'my arguments and talks of',
#     'structures they have built.',
#     'RIKER',
#     'Then try something else.',
#     'DATA',
#     'I have. In the last three hours',
#     'and eight minutes, I have spoken',
#     'to fifty-six colonists. Ten',
#     'refused to believe a threat',
#     'exists. Twenty-two favored',
#     'staying and fighting the Sheliak.']},
#   {'header': 'CONTINUED:',
#    'part': ['RIKER',
#     '(more to himself)',
#     "I don't have time for this.",
#     'DATA',
#     'Sixteen preferred negotiation or',
#     'some form of passive resistance.',
#     'Only eight were willing to',
#     'consider evacuation. And of those',
#     'eight --']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['RIKER',
#     '(cutting him)',
#     "Data, I can't help you -- I don't",
#     "know these people; I haven't",
#     'talked to them. You have. Use',
#     'that fancy positronic brain of',
#     'yours -- and carry out your',
#     'mission.',
#     "Ard'rian walks up to join the android, politely keeps",
#     'a few paces away to let him complete his "phone call"',
#     'with privacy.',
#     'DATA',
#     'If I do not succeed, how violent',
#     'is the Sheliak reaction likely',
#     'to be?',
#     'RIKER',
#     'The treaty is the only thing which',
#     'kept them from eradicating the',
#     'colony the moment they discovered',
#     'it.',
#     'DATA',
#     'Ah.',
#     'RIKER',
#     '"Ah" is right. The lives of',
#     'fifteen thousand people are riding',
#     "on you. You'd better get",
#     'innovative. Riker out.',
#     "Data gazes into space, thinking. Ard'rian steps up.",
#     'Her mood is upbeat.',
#     "ARD'RIAN",
#     "Data -- we're having an effect.",
#     'So many people are asking',
#     'questions about the Sheliak that',
#     "Gosheven's called a public",
#     'meeting.']},
#   {'header': 'CONTINUED: (3)',
#    'part': ['DATA',
#     'Is there any indication that',
#     'Gosheven has changed his position?',
#     "ARD'RIAN",
#     'No. But a meeting will give you',
#     'the chance to present your',
#     'recommendations.',
#     'DATA',
#     'First, will Gosheven allow me to',
#     'speak? Second, even if he does,',
#     'what good will it do? So far,',
#     'my attempts at persuasion have',
#     'been ineffective.',
#     "Ard'rian looks at him with compassion for a beat --",
#     'then suddenly gives Data a quick kiss on the lips.',
#     "DATA (cont'd)",
#     'Why did you do that?',
#     "ARD'RIAN",
#     'You appeared to need it.',
#     'DATA',
#     'Among humans, a kiss normally',
#     'serves to seal a friendship or',
#     'to indicate support, attraction,',
#     'affection.',
#     "Ard'rian nods."]},
#   {'header': 'CONTINUED: (4)',
#    'part': ["DATA (cont'd)",
#     'In this context, I would assume',
#     'your intention was to express',
#     'support.',
#     "ARD'RIAN",
#     'That was my primary motivation.',
#     'The implication being that there were secondary',
#     'motivations. But if Data is aware of the implication,',
#     'he makes no sign.',
#     "ARD'RIAN (cont'd)",
#     "You don't really understand human",
#     'behavior, do you?',
#     'DATA',
#     'That is something of an',
#     'understatement.',
#     "ARD'RIAN",
#     '(sighs)',
#     "Sometimes I don't either.",
#     'androids are a lot more rational.',
#     'DATA',
#     'Thus far, that quality has not',
#     'helped me accomplish my mission.',
#     "ARD'RIAN",
#     "A rational argument isn't always",
#     'enough. Maybe to be more',
#     'persuasive, you need to use a',
#     'little reverse psychology.',
#     'DATA',
#     '(accessing)',
#     'Elicit a desired behavior by',
#     'advocating its opposite?',
#     '(a beat)',
#     'That implies deception, does it',
#     'not?',
#     "ARD'RIAN",
#     'A little. But if it helps us',
#     'get our point across...']},
#   {'header': 'CONTINUED: (5)',
#    'part': ['DATA',
#     '(considers)',
#     'Perhaps this is a situation in',
#     'which excessive honesty is',
#     'detrimental.',
#     'As they walk off:',
#     'CUT TO:']}],
#  '26': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['Travelling at warp speed.']}],
#  '27': [{'header': 'INT. TRANSPORTER ROOM',
#    'part': ['As before, except there are more high tech tools and',
#     'equipment lying about. Geordi is lifting yet another',
#     'trashed test object off the platform. He holds it',
#     "mutely out to Wesley and O'Brien who stare dully at",
#     'this latest failure. There are now four intact',
#     'objects and three blasted ones. Picard ENTERS.',
#     'PICARD',
#     '(you will get it done)',
#     'How are we progressing, Mister',
#     'La Forge?',
#     'GEORDI',
#     "(it's impossible)",
#     "About like you'd expect.",
#     'PICARD',
#     '(get it done)',
#     'Splendid.',
#     'Picard EXITS.',
#     'WESLEY',
#     '(wearily)',
#     'He wants the impossible.']},
#   {'header': 'CONTINUED:',
#    'part': ['GEORDI',
#     '(with a grin)',
#     "That's the short definition for",
#     '"captain."',
#     "Geordi and O'Brien have already returned to work. Wes",
#     'looks at them bemused, then shrugs and pitches in.',
#     'CUT TO:']}],
#  '28': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['A large horseshoe-shaped amphitheater with a place for',
#     'the engineers and Gosheven. A number of citizens --',
#     'including Haritath and Kentor -- have turned out for',
#     'the debate so the place is filled. In the b.g. is the',
#     'aqueduct purifying plant.',
#     'GOSHEVEN',
#     "You've all heard about the android",
#     "Starfleet sent here, and you've",
#     "been discussing why he's come.",
#     "Data and Ard'rian ENTER. Gosheven ignores them.",
#     "GOSHEVEN (cont'd)",
#     'I called this meeting to replace',
#     'misinformation with cold, hard',
#     'fact.',
#     'The colonists are craning their necks to look at Data.',
#     "Gosheven realizes Data's presence can't be ignored. He",
#     'strides over to confront Data.',
#     'GOSHEVEN',
#     'Leave. Immediately.',
#     'DATA',
#     'I wish to speak.',
#     'GOSHEVEN',
#     'No.',
#     'DATA',
#     "(loud, for the crowd's",
#     'benefit)',
#     'You deny me the opportunity to',
#     'address the assemblage?']},
#   {'header': 'CONTINUED:',
#    'part': ['GOSHEVEN',
#     'This meeting is not for outsiders.',
#     'DATA',
#     'Do you consider your position so',
#     'weak that it cannot withstand',
#     'debate?',
#     'HARITATH',
#     'Let him talk.',
#     'MURMURS of assent from the crowd. Gosheven gives a',
#     "terse nod. In a sense Data's called him a coward and",
#     'he has to stand up to this city slicker, this outsider.',
#     'Data steps front and center. In an effort to pull this',
#     'off, he attempts to use human rhetorical devices',
#     '(timing, dynamics, inflection, gestures, etc.) -- but,',
#     "as there's no real passion behind them, they come off",
#     'as studied and not quite sincere. A good performance,',
#     'but still a performance.',
#     'DATA',
#     'You know of the Sheliak threat.',
#     'Starfleet wishes to evacuate you',
#     'for your own protection.',
#     'Gosheven has decided otherwise.',
#     'That is his right. And I will',
#     'not waste time trying to reverse',
#     'that decision.',
#     'Surprised reactions from the crowd. This is not what',
#     'they expected to hear.',
#     "DATA (cont'd)",
#     'I admire your conviction in the',
#     'face of certain defeat. Your',
#     'effort will be valiant, though',
#     'doomed. Still, when you die,',
#     'you will die for land and honor.']}],
#  '29': [{'header': 'ANGLE ON',
#    'part': ["The crowd. Data's starting to get a reaction. People",
#     "are beginning to eye each other nervously. It's one",
#     'thing to thumb your nose at a distant enemy, quite',
#     'another to talk about dying.']}],
#  '30': [{'header': 'ANGLE ON DATA',
#    'part': ['As he reaches down, and takes a YOUNG BOY (twelve or',
#     'so) by the arm, and pulls the child up next to him.',
#     'DATA',
#     'Your children will understand that',
#     'they are dying for a worthy cause.',
#     'Big crowd reaction here. Murmurs from various people.',
#     'Mothers pull their children closer to them. Data',
#     'steals a glance at Ard\'rian -- "how am I doing?"',
#     'Ard\'rian nods encouragingly back -- "fine."',
#     'DATA',
#     '(continuing)',
#     'Long after the battle is over,',
#     'their courage will be remembered',
#     'and extolled.',
#     "Ard'rian jumps in to support him.",
#     "ARD'RIAN",
#     'Remembered by who?',
#     'DATA',
#     "(as if he hadn't",
#     'considered that)',
#     'Ah, that is true. There will be',
#     'no one left alive to remember.']}],
#  '31': [{'header': 'ANGLE ON GOSHEVEN',
#    'part': ['as he begins to applaud slowly.',
#     'GOSHEVEN',
#     'A valiant try, android, but what',
#     'a low opinion you must have of',
#     'us.',
#     "The boy's MOTHER snatches her son back from Data, and",
#     'pulls him down in her lap.',
#     'DATA',
#     'I was simply attempting to',
#     'describe your inevitable',
#     'destruction in a manner that',
#     'would have an emotional effect.']},
#   {'header': 'CONTINUED:',
#    'part': ['HARITATH',
#     '(standing)',
#     'And he did it pretty damned well.',
#     'MURMURS of agreement from the crowd.',
#     'GOSHEVEN',
#     'Are you ready to follow this',
#     'machine, Haritath? Give up',
#     'everything? Without a fight?',
#     "He says we're going to lose, I",
#     "think that's his own cowardice",
#     'talking!',
#     'Kentor stands. He has a calm but commanding presence.',
#     'KENTOR',
#     "And what if he's right, and you're",
#     "wrong? Shouldn't we consider that",
#     'possibility?',
#     'More crowd reaction. Sympathy is swinging away from',
#     'Gosheven.',
#     'HARITATH',
#     'We may be sacrificing ourselves',
#     'for nothing --',
#     'GOSHEVEN',
#     'Last winter we buried your little',
#     'girl -- laid her to rest next to',
#     'your mother, and you dare speak',
#     'of sacrifice?',
#     'Gosheven whirls and nails Kentor with a look.',
#     'GOSHEVEN',
#     '(continuing)',
#     'And you, Kentor, we built you',
#     'a new house after the fire wiped',
#     'you out. Can you simply walk away',
#     'from that?',
#     'KENTOR',
#     'Better to walk away than to be',
#     'annihilated.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['GOSHEVEN',
#     '(addressing them all)',
#     'This colony exists because',
#     'generations gave their lives for',
#     'it. Many people died before we',
#     'found a way to adapt to the',
#     'radiation. Many more died',
#     'bringing water to the desert.',
#     'My father --',
#     "ARD'RIAN",
#     '(interrupting)',
#     '-- is buried on that mountain.',
#     "Well, who's going to be left to",
#     'bury you?',
#     'A vote of confidence is about to take place, and',
#     "Gosheven realizes he's about to lose it. He falls back",
#     'on the innate authority of an elected leader.',
#     'GOSHEVEN',
#     'Have you considered what this',
#     'evacuation means? Everything we',
#     'have, we abandon. Everything',
#     "we've built turns into dust.",
#     "Everything we've accomplished",
#     'means nothing.',
#     '(shakes head)',
#     'Well, I say NO! You elected me',
#     'to be your leader -- follow me',
#     "now! I don't think our chances",
#     'are as hopeless as he says. And',
#     "I'm willing to stake our lives",
#     'on it. Any objections?',
#     'He rakes the crowd with a look. Some mutterings, but',
#     "nobody's quite ready to lead the revolution.",
#     'GOSHEVEN',
#     '(continuing)',
#     'Good, because here... we...',
#     'stand.',
#     'A few people step up to pound Gosheven on the back, but',
#     'most of the crowd remains huddled, glancing from Data',
#     'to Gosheven and back again. Haritath and Kentor step',
#     'away to talk in private.']}],
#  '32': [{'header': 'ANGLE ON DATA',
#    'part': ["standing with Ard'rian.",
#     'DATA',
#     '(almost to himself)',
#     'Then here you die.',
#     'FADE OUT.',
#     'END OF ACT THREE                         ',
#     'ACT FOUR                             ',
#     'FADE IN:']}],
#  '33': [{'header': 'INT. TRANSPORTER ROOM (OPTICAL)',
#    'part': ["Wesley, Geordi and O'Brien. There are now three",
#     'intact test object and four trashed ones. These are',
#     "three exhausted people. They've been working round",
#     'the clock.',
#     'WESLEY',
#     'Maybe if we bypassed the autosequence',
#     'and decompiled the',
#     'pattern buffer... ?',
#     'GEORDI',
#     '(shrugs)',
#     "It's no crazier than anything",
#     "else we've tried.",
#     'Wesley drops down by the panel, and begins to tinker',
#     'while Geordi places the last test object on the',
#     'platform. Suddenly the transporter console blows a',
#     'fuse. Electricity races across the panel, and the',
#     "console goes dark. O'Brien is not a happy man. Wesley",
#     "slowly stands up. O'Brien struggles with himself, but",
#     "can't master it.",
#     "O'BRIEN",
#     'Ensign Crusher.',
#     'WESLEY',
#     'Yes, sir.',
#     "O'BRIEN",
#     'If you ever touch my transporter',
#     "again... I'll kill you.",
#     'WESLEY',
#     'Sorry, sir.',
#     'CUT TO:']}],
#  '33A': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['Data watches the town meeting break up into small',
#     "groups of people TALKING among themselves. Ard'rian",
#     'approaches.']},
#   {'header': 'CONTINUED:',
#    'part': ['Haritath and Kentor step up furtively.',
#     'HARITATH',
#     'Mister Data -- I want to tell you',
#     "that... well, Gosheven doesn't",
#     'speak for all of us.',
#     "Ard'rian looks at Data hopefully -- maybe the early",
#     "returns aren't so bad after all.",
#     "HARITATH (cont'd)",
#     'I see no point in dying',
#     'needlessly.',
#     'DATA',
#     'And you, Kentor?',
#     'KENTOR',
#     "I'm not sure. Gosheven has done",
#     "well for us. But I'd like to hear",
#     'more of what you have to say.',
#     'HARITATH',
#     'There are many others that feel',
#     'the same way but are uneasy about',
#     'confronting Gosheven.',
#     "ARD'RIAN",
#     "Get them together. We'll meet",
#     'at my house.',
#     'Haritath and Kentor nod agreement then slip away.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["Ard'rian leads Data toward her house. They EXIT."]}],
#  '34': [{'header': '', 'part': ['thru\tOMITTED']}],
#  '36': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['Traveling at warp speed.']}],
#  '37': [{'header': "INT. CAPTAIN'S READY ROOM (OPTICAL)",
#    'part': ['Picard has brought Troi in for consultation.',
#     'TROI',
#     'In our dealings with other',
#     'non-humanoid races there has been',
#     'some point of reference; not so',
#     'with the Sheliak.',
#     'PICARD',
#     'We must have something in common.',
#     'We communicate.',
#     'TROI',
#     'Barely. The Sheliak have learned',
#     'several Federation languages, but',
#     'theirs continues to elude us.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     '(have we tried?)',
#     'Telepaths?',
#     'TROI',
#     'Attempted and failed.',
#     'PICARD',
#     'This is ludicrous!',
#     'TROI',
#     'No, sir, the fact that any alien',
#     'race communicates with another',
#     'is quite remarkable.',
#     "She lifts Picard's tea cup from the desk.",
#     'TROI',
#     '(continuing)',
#     'We are stranded on a planet. No',
#     'language in common, but I want',
#     'to teach you mine.',
#     'Troi points to the cup.',
#     'TROI',
#     '(continuing)',
#     "S'smarith. What did I just say?",
#     'PICARD',
#     'Cup? Glass?',
#     'TROI',
#     'Are you sure? I might have meant',
#     'liquid, clear, brown, hot. And',
#     'we conceptualize the universe in',
#     'relatively the same way.',
#     'PICARD',
#     'Point taken.',
#     'TROI',
#     'During your talks you must be',
#     'extremely accurate. The treaty',
#     'is 500,000 words. The length was',
#     'to accommodate the Sheliak. They',
#     'consider our language irrational,',
#     'and demanded this level of',
#     'complexity to avoid any future',
#     'misunderstandings.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["RIKER'S COM VOICE",
#     'Captain, we have the vessel',
#     'carrying the Sheliak colonists',
#     'on visual.',
#     'PICARD',
#     'On my way.',
#     '(to Troi)',
#     'So it begins.',
#     'They EXIT onto:']}],
#  '38': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['The tension on the bridge is palpable. Picard moves',
#     'swiftly to the command station. Riker relinquishes',
#     'command.']}],
#  '39': [{'header': 'ANGLE ON VIEWSCREEN (OPTICAL)',
#    'part': ['Where a Sheliak ship hangs ominously.',
#     'PICARD',
#     'Open hailing frequencies. This',
#     'is Captain Jean-Luc Picard of the',
#     'Starship Enterprise.',
#     'We again have a vision of the mirrored, shadowed,',
#     'shifting place. A hint of a watcher in the shadows.',
#     'SHELIAK',
#     'Your purpose, Enterprise?',
#     'PICARD',
#     'We desire face-to-face negotiation',
#     'to settle the crisis on Tau Cygna',
#     'Five.',
#     'Troi hands him a PADD.',
#     'PICARD',
#     '(continuing)',
#     'We are entitled to consultation',
#     'under paragraph five hundred and',
#     'sixty-three subparagraph nine.',
#     'A beat as the Sheliak look it up.',
#     'SHELIAK',
#     'Granted.']},
#   {'header': 'CONTINUED:',
#    'part': ['The screen again shows the Sheliak vessel.',
#     'RIKER',
#     'Was that an invitation?',
#     'PICARD',
#     "I'm going to take it as such.",
#     'Number One, you have the bridge.',
#     'Troi and Picard EXIT. HOLD on Riker.',
#     'RIKER',
#     'Helm, maintain relative position.',
#     'Mister Worf, have Transporter Room',
#     'Two stand by.',
#     'WORF',
#     'Aye, sir.',
#     'CUT TO:']}],
#  '40': [{'header': "INT. ARD'RIAN'S LIVING ROOM - DAY",
#    'part': ['Haritath, Kentor, and a group of other colonists are',
#     "gathered around Data and Ard'rian.",
#     'KENTOR',
#     '... and once the Federation',
#     "resettles us, we'll be left",
#     'alone?',
#     'DATA',
#     'If you so desire.',
#     'HARITATH',
#     'We do. We like doing things on',
#     'our own.',
#     'DATA',
#     'The Federation will offer as',
#     'little or as much help as you',
#     'dictate.']},
#   {'header': 'CONTINUED:',
#    'part': ['Nods all around; they are impressed. Data is the',
#     'perfect no-pressure salesman; he simply presents the',
#     "facts. Ard'rian looks expectantly to Kentor;",
#     "Kentor's still uncertain.",
#     "ARD'RIAN",
#     'Kentor -- are you with us?',
#     'Kentor makes up his mind:',
#     'KENTOR',
#     'Yes.',
#     '(a beat)',
#     'The question is, how do we',
#     'convince Gosheven?']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['HARITATH',
#     'Why do we need to?',
#     'KENTOR',
#     "Because he's respected. Most",
#     'people will do as he says.',
#     "ARD'RIAN",
#     'The people respect you, too.',
#     "If you take a stand, they'll",
#     'fall in line.',
#     'KENTOR',
#     "I don't know. Gosheven's got a",
#     'lot of supporters...',
#     'GOSHEVEN (O.S.)',
#     "Don't forget that, Kentor.",
#     'Everyone turns to see --']}],
#  '40B': [{'header': 'NEW ANGLE (OPTICAL)',
#    'part': ['Gosheven fills the doorway. He ENTERS and looks',
#     'around the room.',
#     'GOSHEVEN',
#     "I'm disappointed. I thought we",
#     'had settled this.',
#     'DATA',
#     'Apparently, that is not correct.',
# ...
#     'paragraph seven hundred and',
#     'sixteen, subparagraph five --',
#     'unwanted lifeforms inhabiting H',
#     'class worlds may be removed at',
#     'the discretion of the Sheliak',
#     'corporate.',
#     'PICARD',
#     'We will remove them. But you',
#     'must grant us the time we require.',
#     'SHELIAK',
#     'You need time, Picard of the',
#     'Enterprise, we will save you time.',
#     'We will eradicate the human',
#     'infestation.',
#     'PICARD',
#     '(outraged)',
#     'They are not vermin! They are',
#     'citizens of the Federation and',
#     'I will not permit this travesty!']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['SHELIAK',
#     'Intelligent converse is',
#     'impossible. You do not discuss,',
#     'you gibber.',
#     'PICARD',
#     'Between intelligent species of',
#     'good will --',
#     'Suddenly the Sheliak transporter kicks in, and slams',
#     'Picard and Troi back to the Enterprise. They have been',
#     'rudely thrown out on their ears.']}],
#  '42': [{'header': 'INT. MAIN BRIDGE (OPTICAL)',
#    'part': ['The startling EFFECT of the Sheliak transporter and',
#     'Picard and Troi APPEAR. Riker, Worf, and the',
#     'supernumeraries at Conn and Ops react.',
#     'Picard and Troi are both very disoriented, staggering',
#     'slightly. Riker steadies them both.',
#     'RIKER',
#     'I take it the Sheliak just hung',
#     'up on us. Again.',
#     'FADE OUT.',
#     'END OF ACT FOUR                         ',
#     'ACT FIVE                             ',
#     'FADE IN:']}],
#  '42A': [{'header': "INT. ARD'RIAN'S LIVING ROOM",
#    'part': ["Ard'rian worriedly inspects the unmoving Data with an",
#     'electronic scanner. Data twitches, "reboots," comes',
#     "back to life, and sits up. Ard'rian SIGHS, relieved.",
#     "ARD'RIAN",
#     'I was afraid your neural pathways',
#     'were scrambled beyond repair.',
#     'DATA',
#     'I am equipped with diagnostic',
#     'circuits and can correct many',
#     'malfunctions.',
#     'Data moves his head, arms, and legs, testing his',
#     'responses.',
#     "ARD'RIAN",
#     "I'm not surprised at Gosheven's",
#     'behavior. But Kentor and the',
#     'others... they said they were',
#     'on our side.',
#     '(bitter)',
#     "I guess words don't mean very",
#     'much.',
#     'Data mulls this over carefully.',
#     'DATA',
#     'Perhaps that has been part of our',
#     'difficulty. Words are all we have',
#     'been using.',
#     '(thinking)',
#     'Humans seem to take much stronger',
#     'notice of actions.',
#     'Data makes a decision, gets to his feet.',
#     "DATA (cont'd)",
#     'I require a phaser.',
#     "ARD'RIAN",
#     "What's a phaser?",
#     'DATA',
#     'A type of weapon. Unfortunately',
#     'it will not function in the',
#     'presence of hyperonic radiation.']},
#   {'header': 'CONTINUED:',
#    'part': ['Data ponders this new problem for a beat, then shrugs',
#     'it off:',
#     "DATA (cont'd)",
#     'I will have to be innovative.',
#     'CUT TO:']}],
#  '42B': [{'header': 'INT. SHUTTLECRAFT - CYGNA FIVE - DAY',
#    'part': ['Data has opened up a phaser and is adapting it. His',
#     "forearm is opened, revealing his arm's inner workings;",
#     'Data is "cannibalizing" his arm for parts to modify the',
#     "phaser. Ard'rian looks on in fascination.",
#     'DATA',
#     'Hyperonic radiation randomizes',
#     'phaser beams. But I believe I',
#     'can improvise a servocircuit which',
#     'will compensate by continuously',
#     'recollimating the output.',
#     "ARD'RIAN",
#     "You're using your own neural",
#     'subprocessors to build a smarter',
#     'phaser.',
#     'DATA',
#     'Essentially correct.',
#     "Ard'rian's impressed. Data completes his work.",
#     "DATA (cont'd)",
#     'Get word to Gosheven. Tell him',
#     'I am coming to the pumping',
#     'station. Tell him I am going',
#     'to destroy the aqueduct.',
#     "Ard'rian is gaping like a carp over this, doesn't know",
#     'what to say. Finally manages:',
#     "ARD'RIAN",
#     "He'll try to stop you --",
#     'DATA',
#     'I sincerely hope so.',
#     "Off Ard'rian's expression:",
#     'CUT TO:']}],
#  '43': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['The Enterprise hanging motionless in space with the',
#     'Sheliak ship.']}],
#  '44': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['As before.',
#     'PICARD',
#     '(to Worf)',
#     'Go to Yellow Alert. Shields up.',
#     'WORF',
#     'Aye, sir.',
#     'PICARD',
#     'Mister Riker, put us nose to nose',
#     'with the Sheliak ship. If she',
#     'makes a move, match it.',
#     'RIKER',
#     'Aye, sir.',
#     'PICARD',
#     'Open a hailing frequency.']},
#   {'header': 'CONTINUED:',
#    'part': ['WORF',
#     "They're not responding, sir.",
#     'PICARD',
#     '(tight control)',
#     "They don't have to answer. They",
#     'just have to listen! Sheliak',
#     'vessel, you will have to go',
#     'through me to get at the colony',
#     'on Tau Cygna Five!']}],
#  '45': [{'header': '', 'part': ['thru\tOMITTED']}],
#  '47': [{'header': 'INT. MAIN BRIDGE - CONTINUOUS',
#    'part': ['WORF',
#     'No response.',
#     'PICARD',
#     'Close channel -- and get me that',
#     "treaty! They've been beating us",
#     'over the head with it for three',
#     "days. Let's see if we can't find",
#     'something in it that can be',
#     'turned to our advantage.',
#     'RIKER',
#     "We're going to try to beat them",
#     'at their own game?',
#     'WORF',
#     'The treaty is how long?',
#     'TROI',
#     'Five hundred thousand words.',
#     'WORF',
#     '(glumly)',
#     "We are going to regret Data's",
#     'absence.',
#     'CUT TO:']}],
#  '48': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY (OPTICAL)',
#    'part': ['The square. FOUR MEN armed with rifles stand',
#     'shoulder to shoulder in front of the plant and',
#     'aqueduct. Standing defiant and unarmed, save for the',
#     'probe at his belt, on an upper level is Gosheven.']},
#   {'header': 'CONTINUED:',
#    'part': ['Off to one side are a number of colonists (including',
#     "Ard'rian, Haritath, and Kentor), nervously awaiting",
#     'the outcome.',
#     'Then a PHASER STUN hits one of the armed men; he',
#     'drops. As the others whirl to take aim --']}],
#  '48A': [{'header': 'NEW ANGLE (OPTICAL)',
#    'part': ['A PHASER BEAM sweeps across the line of armed men,',
#     'STUNNING them instantly. No one even gets a shot off.',
#     'Gosheven, astonished, reaches for the probe at his',
#     'belt. Data calmly stands up from his hiding place,',
#     "aims his phaser. Gosheven freezes -- it's futile;",
#     'obviously Data could stun him before he could get',
#     'anywhere near Data.']}],
#  '48B': [{'header': 'WIDER (OPTICAL)',
#    'part': ['as Data steps out into the street, holds his phaser',
#     'up for all to see.',
#     'DATA',
#     'That was the "stun" setting.',
#     'Data switches the setting on the phaser --',
#     "DATA (cont'd)",
#     'This is not.',
#     'Data turns, BLASTS the control panel on the aqueduct.',
#     'A shower of SPARKS. EFFECT as the reaction races up',
#     'the aqueduct. The water stops flowing. Gosheven is',
#     'speechless. Data addresses the colonists:',
#     "DATA (cont'd)",
#     'I could reduce this pumping',
#     'station to a pile of debris...',
#     'but I trust my point is clear.',
#     'I am one android with a single',
#     'weapon. There are hundreds of',
#     'Sheliak on the way... and their',
#     'weapons are far more powerful.',
#     'Data pauses. The colonists are dead silent.']},
#   {'header': 'CONTINUED:',
#    'part': ["DATA (cont'd)",
#     'And the Sheliak may not even offer',
#     'you a target. They can obliterate',
#     'this colony from orbit. You will',
#     'die never having seen the faces',
#     'of your killers.',
#     'Data walks deliberately to one of the stunned',
#     'defenders, picks up the rifle with his free hand, holds',
#     'it out to the group of colonists.',
#     "DATA (cont'd)",
#     'The choice is yours.',
#     'The colonists look at one another. Finally:',
#     'KENTOR',
#     'There are other places -- other',
#     "challenges. It's time to move",
#     'on.',
#     'And Kentor EXITS. One by one, the colonists follow',
#     'him. The mantle of leadership has passed.']}],
#  '48C': [{'header': 'NEW ANGLE',
#    'part': ['Gosheven, slump shouldered, bends and scoops up a',
#     'handful of dirt at the base of the silent pool. Data',
#     'moves to join him.',
#     'GOSHEVEN',
#     'I really was willing to stay and',
#     'die for this.',
#     'DATA',
#     'I know that, but it is just a',
#     'thing, and things can be replaced.',
#     'Lives cannot. Live, rebuild and',
#     'be remembered.',
#     'A long beat. Then Gosheven wipes his hand on his',
#     'pants, and walks back to join his people.']}],
#  '50': [{'header': 'ANGLE ON DATA',
#    'part': ['watching Gosheven go. Data looks down at the phaser',
#     'for several moments, then holsters it. He looks up to',
#     "find Ard'rian gazing at him with an expression of pride",
#     'and love.']}],
#  '52': [{'header': 'INT. MAIN BRIDGE (OPTICAL)',
#    'part': ['Troi is seated at Science One with Picard hanging over',
#     'her shoulder. Riker and Worf are at Science Two.',
#     'Pages of treaty crawl past on both screens.',
#     'WORF',
#     'This is hopeless. Fighting would',
#     'be preferable.',
#     'A look from Riker.',
#     'PICARD',
#     "That's it.",
#     'He indicates a clause.',
#     'TROI',
#     "I don't follow you, sir.",
#     'PICARD',
#     'Worf, get me the Sheliak.',
#     'WORF',
#     '(just heard the',
#     'reprieve)',
#     'Yes, sir!',
#     'Picard, Riker and Troi return to the command station.',
#     'The strange Sheliak scene replaces a view of the ship.',
#     'PICARD',
#     'Pursuant to paragraph one thousand',
#     'two hundred and ninety I formally',
#     'request third party arbitration',
#     'of our dispute.',
#     'A beat while they look it up.',
#     'SHELIAK',
#     'Agreed.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'And further, pursuant to',
#     'subsection D, three, I name the',
#     'Grizzelas to arbitrate.',
#     'SHELIAK',
#     'Grizzelas?',
#     'Riker glances, puzzled, at Troi.',
#     'RIKER',
#     '(mouths)',
#     'Grizzelas?',
#     'Troi quells him with a look.',
#     'PICARD',
#     'Unfortunately they are currently',
#     'in their hibernation cycle, but',
#     "they'll awaken in six months, and",
#     "then we'll get this matter",
#     'settled. Now, do you want to',
#     'wait... or give me my three weeks?',
#     'SHELIAK',
#     'Absurd. We carry the membership!',
#     'We can brook no delay!',
#     'PICARD',
#     'Then I declare the treaty in',
#     'abeyance!',
#     'SHELIAK',
#     'Wait! Negotiation is --',
#     'Picard gestures to Worf -- cut the transmission. Worf',
#     'obeys. A long beat.',
#     'RIKER',
#     '(smiling)',
#     'You enjoyed that.',
#     'PICARD',
#     "You're damn right.",
#     'WORF',
#     'Captain, they are hailing us.',
#     'Picard studies his nails. Takes a turn around the',
#     'bridge. Settles himself back in the command chair.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['WORF',
#     '(continuing)',
#     'Sir?',
#     'PICARD',
#     '(a beat)',
#     'On screen.',
#     'The Sheliak reappear.',
#     'SHELIAK',
#     'You may have your three weeks,',
#     'Picard of the Enterprise.',
#     'PICARD',
#     '(with careful',
#     'enunciation)',
#     'Thank you.',
#     'The screen returns to a view of the Sheliak ship',
#     'pulling away. Instant release of tension. Suddenly',
#     'the turbolift doors open, and Geordi ENTERS. He is',
#     "looking frazzled. People's expressions reflect the",
#     'thought that "dear God, he did it."',
#     'GEORDI',
#     'Captain, we can do it! We can',
#     'modify the transporters.',
#     'PICARD',
#     'Excellent.',
#     'GEORDI',
#     "It'll take fifteen years, and a",
#     'research team of a hundred --',
#     'PICARD',
#     '(dryly)',
#     'Mister La Forge, I believe we will',
#     'postpone.',
#     'GEORDI',
#     '(with a grin)',
#     'Yes, sir.',
#     'Geordi EXITS.',
#     'CUT TO:']}],
#  '53': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': ['Data is inside the shuttle making preparations for',
#     'departure.',
#     'DATA',
#     'Commander Data to Enterprise.',
#     'I am preparing to leave Tau Cygna',
#     'Five and await rendezvous',
#     'instructions.',
#     "WORF'S COM VOICE",
#     'Acknowledged. Stand by.',
#     "Outside the shuttle, Ard'rian approaches. Data sees",
#     'her, emerges from the shuttle to meet her.',
#     "ARD'RIAN",
#     'Hi.',
#     'DATA',
#     "Hello, Ard'rian.",
#     "ARD'RIAN",
#     'The evacuation plan is going well.',
#     'When the transport ship arrives,',
#     "we'll be ready.",
#     '(a beat)',
#     'You succeeded.',
#     'DATA',
#     'I would not have succeeded without',
#     'your support and insight, and I',
#     'appreciate your assistance.',
#     "ARD'RIAN",
#     "Good. Then you won't forget me?",
#     'DATA',
#     'I am incapable of forgetting.',
#     'I will remember every detail of',
#     'my visit with perfect clarity.',
#     "ARD'RIAN",
#     'But nothing more?',
#     'DATA',
#     'I do not understand.']},
#   {'header': 'CONTINUED:',
#    'part': ["Ard'rian bites the bullet:",
#     "ARD'RIAN",
#     'I guess what I really want to know',
#     'is -- do you have any feelings',
#     'for me?',
#     'DATA',
#     'I have no feelings of any kind.',
#     "Ard'rian is silent.",
#     "ARD'RIAN",
#     "No. Of course you don't.",
#     "Data studies her. She's downcast. Mimicking her",
#     'behavior earlier, he gives her a quick kiss on the',
#     'lips, startling her.',
#     "ARD'RIAN (cont'd)",
#     'What was that for?',
#     'DATA',
#     'You appeared to require it.',
#     "ARD'RIAN",
#     'You observed I was unhappy and',
#     'did what you concluded would make',
#     'me feel better. A purely rational',
#     'deduction.',
#     "She's still downcast.",
#     'DATA',
#     'Have I disappointed you?',
#     "ARD'RIAN",
#     "No, I'm disappointed in myself",
#     '-- for wanting something I know',
#     "I can't have.",
#     '(a beat)',
#     "Data, in so many ways you're",
#     'superior to humans. But you are',
#     'still a machine... without',
#     'emotion.',
#     'DATA',
#     'Yes.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["ARD'RIAN",
#     "It's so easy to believe otherwise.",
#     "It's so easy to read things into",
#     'your behavior... and perceive',
#     'feelings where none exist.',
#     '(a beat)',
#     'Well, I am human and I do have',
#     'feelings... silly though they may',
#     'be at times. I like you, Data.',
#     "You're my favorite android.",
#     'DATA',
#     'But I am the only android you have',
#     'ever met.',
#     "ARD'RIAN",
#     'Rational to the last.']},
#   {'header': 'CONTINUED: (3)',
#    'part': ["And with a smile, Ard'rian EXITS. Data climbs into",
#     'the shuttle, and the door closes.',
#     'CUT TO:']}],
#  '55': [{'header': "INT. CAPTAIN'S READY ROOM",
#    'part': ["Picard is listening to a recording of Data's string",
#     'quartet concert in Ten Forward. DOOR CHIME.',
#     'PICARD',
#     'Come.',
#     'Data ENTERS.',
#     "PICARD (cont'd)",
#     'Welcome home, Mister Data. Well',
#     'done.',
#     'DATA',
#     'Thank you, sir.',
#     'PICARD',
#     'The good doctor was kind enough',
#     'to provide me with a recording',
#     'of your concert. Your',
#     'performance shows a good deal',
#     'of feeling.',
#     'DATA',
#     'As I have lately had to remind',
#     'others, I have no feelings.',
#     'PICARD',
#     "That's hard to believe; your",
#     'playing is quite beautiful.',
#     'DATA',
#     'Strictly speaking, it is not',
#     '"my" playing. It is a precise',
#     'imitation of the techniques of',
#     'Jascha Heifetz and Trenka Bron-Ken.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'And is there nothing of Data in',
#     "what I'm hearing?",
#     'Data ponders this.',
#     "PICARD (cont'd)",
#     'You chose the violinists.',
#     'Heifetz and Bron-Ken had',
#     'radically different styles, but',
#     'you combined them -- successfully.',
#     'DATA',
#     'I suppose I have learned to be',
#     'innovative... when necessary, sir.',
#     "Picard nods. He's made his point.",
#     'PICARD',
#     'Mister Data... I look forward to',
#     'your next concert.',
#     "On Data's thoughtful expression, we:"]}]}

# %%
q

# %%
separate_lines_by_character(b, chars)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-0ba65f69effe> in <module>
# ----> 1 separate_lines_by_character(b, chars)
#
# <ipython-input-213-dcc472ed9b93> in separate_lines_by_character(dialogue, indices)
#      68
#      69 def separate_lines_by_character(dialogue, indices):
# ---> 70     temp_sectioned = sectioned_script(dialogue, indices)
#      71     sectioned = copy.deepcopy(temp_sectioned)
#      72     for number, section in sectioned.items():
#
# <ipython-input-213-dcc472ed9b93> in sectioned_script(dialogue, header_indices)
#      87
#      88     for pair in index_pairs:
# ---> 89         part = get_between_indices(dialogue, *pair)
#      90         head = part.pop(0)
#      91         number, header = number_header_from_line(head)
#
# <ipython-input-127-b1be1d96a5b4> in get_between_indices(s, begin, end)
#       1 def get_between_indices(s, begin, end):
# ----> 2     return s[begin:end]
#
# TypeError: unhashable type: 'slice'

# %%
replace_character_names(b, chars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-201-d876c3d55cc4> in <module>
# ----> 1 replace_character_names(b, chars)
#
# <ipython-input-200-c25db9ee4b28> in replace_character_names(dialogue, characters)
#      53         for piece in content:
#      54             parts = piece['part']
# ---> 55             for section, stuff in parts.items():
#      56                 name = stuff['name']
#      57                 for check in characters:
#
# AttributeError: 'list' object has no attribute 'items'

# %%
replace_character_names(e, chars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-188-3fcd66c937a2> in <module>
# ----> 1 replace_character_names(e, chars)
#
# <ipython-input-186-c80142db0444> in replace_character_names(dialogue, characters)
#       5         for piece in content:
#       6             parts = piece['part']
# ----> 7             for section, stuff in parts.items():
#       8                 name = stuff['name']
#       9                 for check in characters:
#
# AttributeError: 'list' object has no attribute 'items'

# %%
d = separate_lines_by_character(b, indices)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-198-10cc62f63812> in <module>
# ----> 1 d = separate_lines_by_character(b, indices)
#
# <ipython-input-195-ef7d5c2cbe21> in separate_lines_by_character(dialogue, indices)
#      69
#      70 def separate_lines_by_character(dialogue, indices):
# ---> 71     temp_sectioned = sectioned_script(dialogue, indices)
#      72     sectioned = copy.deepcopy(temp_sectioned)
#      73     for number, section in sectioned.items():
#
# <ipython-input-49-f0d840b35481> in sectioned_script(dialogue, headers)
#       5
#       6     for pair in index_pairs:
# ----> 7         part = get_between_indices(dialogue, *pair)
#       8         head = part.pop(0)
#       9         number, header = number_header_from_line(head)
#
# <ipython-input-127-b1be1d96a5b4> in get_between_indices(s, begin, end)
#       1 def get_between_indices(s, begin, end):
# ----> 2     return s[begin:end]
#
# TypeError: unhashable type: 'slice'

# %%
d
# Out:
# {'1': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['Moving at impulse near some extraordinarily interesting',
#     'astronomical object.']}],
#  '2': [{'header': 'INT. TEN-FORWARD',
#    'part': ['Present are PICARD, BEVERLY, and TWELVE N.D.',
#     'CREWMEMBERS. A VULCAN and ONE WOMAN are seated,',
#     'holding their instruments -- a violin and a viola.',
#     "O'BRIEN tunes his cello. DATA ENTERS carrying a",
#     'violin. He checks at the door, startled to see the',
#     'captain. Picard beckons, and Data crosses to him.',
#     'DATA',
#     'Captain, Doctor, I am honored by',
#     'your presence, but may I suggest',
#     'you attend the second concert.',
#     'BEVERLY',
#     'Why, Data?',
#     'DATA',
#     'Ensign Ortiz will perform the',
#     'violin part. My rendition will',
#     'be less enjoyable.',
#     'PICARD',
#     'Oh?',
#     'DATA',
#     'While I am quite proficient',
#     'Technically, according to my',
#     'fellow performers, I lack soul.',
#     'BEVERLY',
#     "Data, telling us why you're going",
#     'to fail before you make the',
#     'attempt is never wise.',
#     'DATA',
#     'But is not honesty always the',
#     'preferred choice?']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Excessive honesty can be',
#     'disastrous... particularly in a',
#     'commander.',
#     'DATA',
#     '(very intrigued)',
#     'Indeed?',
#     'PICARD',
#     'Knowing your limitations is one',
#     'thing. Advertising them to a crew',
#     'can damage your ability to lead.',
#     'DATA',
#     'Because you lose their respect?',
#     'BEVERLY',
#     'No, because you may begin to',
#     'believe in those limitations',
#     'yourself.',
#     'Data considers this, then moves to take his place with',
#     'the other performers.']}],
#  '2A': [{'header': 'ANGLE ON PICARD AND BEVERLY',
#    'part': ['O.s., the string quartet TUNES. There is the SOUND of',
#     'the communicator hail.',
#     "RIKER'S COM VOICE",
#     "Captain, we're receiving a message",
#     'from the Sheliak Corporate.',
#     'Picard reacts with surprise, stands and EXITS. As he',
#     'leaves, the quartet starts to PLAY.',
#     'CUT TO:']}],
#  '3': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['Picard ENTERS. RIKER and WORF at their usual stations.',
#     'Supernumeraries at CONN and OPS.']},
#   {'header': 'CONTINUED:',
#    'part': ['WORF',
#     'Origin point of the message',
#     'confirmed. It is from the Shelia',
#     'star system.',
#     'RIKER',
#     'The Sheliak have not attempted',
#     'to communicate with the Federation',
#     'for a hundred and eleven years.',
#     'PICARD',
#     'On screen.']}],
#  '4': [{'header': 'ANGLE ON VIEWSCREEN (OPTICAL)',
#    'part': ['What appears is the text of a treaty. English on one',
#     'side, Sheliak on the other. Sheliak is not symbols',
#     'as we know them, but rather a pattern of lights. A',
#     'recorded message begins.',
#     'SHELIAK VOICE',
#     'Federation creatures, there are',
#     'humans on the fifth planet of Tau',
#     'Cygna. This planet was ceded',
#     'to the corporate in section one',
#     'hundred and thirty-three,',
#     'paragraph seventy-seven of the',
#     'Treaty of Armens. We will begin',
#     'settlement of this world in four',
#     'days. Remove the humans.',
#     'Riker is up, and heading for Science One.',
#     'PICARD',
#     'What the devil --',
#     'SHELIAK VOICE',
#     'Federation creatures, there are',
#     'humans on the fifth planet --',
#     'PICARD',
#     'Cancel message.',
#     'Inquiring look to Riker.',
#     'RIKER',
#     'Tau Cygna Five is in the de Laure',
#     'belt -- heavy concentrations of',
#     'hyperonic radiation.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     "Humans can't survive in such an",
#     'environment. Exposure to',
#     'hyperonic radiation is fatal.',
#     'RIKER',
#     'Then the Sheliak are asking us',
#     'to chase ghosts.',
#     'PICARD',
#     'No, Number One. The Sheliak',
#     "haven't broken a century of",
#     'silence to send us after phantoms.',
#     'An investigation is in order.',
#     'Set course for Tau Cygna Five.',
#     "Off Picard's expression:",
#     'FADE OUT.',
#     'END OF THE TEASER                        ',
#     'ACT ONE                             ',
#     'FADE IN:']}],
#  '5': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['entering orbit around a planet.']}],
#  '6': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['Picard, Riker, Data, Beverly and Worf. Supernumerary',
#     'at CONN.',
#     'WORF',
#     'Human life form readings from the',
#     'planet.',
#     'RIKER',
#     "So, the Sheliak weren't",
#     'hallucinating.',
#     'PICARD',
#     'Numbers?',
#     'WORF',
#     'Impossible to get an accurate',
#     'reading, Captain. The high',
#     'radiation levels are disrupting',
#     'our sensors.',
#     'DATA',
#     'Hyperonic radiation also',
#     "interferes with ship's",
#     'transporters; they are now',
#     'inoperable.',
#     'WORF',
#     "So are the ship's phasers.",
#     'RIKER',
#     'How can humans survive down there?',
#     'BEVERLY',
#     'They must have found a way to',
#     'adapt.',
#     '(thinks it over)',
#     "Milan's work in radiation",
#     "sensitivity suggests it's",
#     'possible. Perhaps with extensive',
#     'virotherapy...',
#     '(grimly)',
#     'Until they found the answer, their',
#     'mortality rate must have been',
#     'staggering.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Well, whoever they are and however',
#     "they've survived, we've got to",
#     'get them off the planet.',
#     'RIKER',
#     'By treaty, this world does belong',
#     'to the Sheliak...',
#     'PICARD',
#     '... who are within their rights',
#     'to demand the removal of these',
#     '"trespassers."',
#     'RIKER',
#     "And if we don't remove them, the",
#     'Sheliak will.',
#     'BEVERLY',
#     'How forcefully?',
#     'RIKER',
#     'To the Sheliak, humans are a lower',
#     "life form. They'd have no",
#     'compunctions about exterminating',
#     'the intruders.',
#     "Beverly is taken aback. Riker's dead serious.",
#     'PICARD',
#     'Mister Data. As you are unaffected',
#     'by hyperonic radiation, you will',
#     'go to the planet via shuttlecraft',
#     'and commence evacuation',
#     'procedures.',
#     'DATA',
#     'Aye, sir.',
#     'Without a word wasted the android is out of his chair,',
#     'and EXITS the bridge.',
#     'PICARD',
#     "Any speculation as to what he'll",
#     'find, Number One?',
#     'RIKER',
#     'A lost survey ship would be my',
#     'guess. A dozen or so survivors',
#     'at most.',
#     'CUT TO:']}],
#  '7': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': ['Data is outside the shuttle, scanning with his', 'tricorder.']}],
#  '7A': [{'header': 'NEW ANGLE',
#    'part': ['as HARITATH and KENTOR (two male humans) and TWO N.D.',
#     'WORKERS cautiously approach the shuttle from the other',
#     'side (the shuttle blocks their view of Data).',
#     'HARITATH',
#     '(in wonder)',
#     'A shuttlecraft!',
#     'KENTOR',
#     "Where's it from?",
#     'HARITATH',
#     'Look at the markings. I think',
#     "it's from the Federation.",
#     'Data steps into their view from around the shuttle.',
#     'DATA',
#     'Hello.',
#     'The four humans jump, startled.',
#     'HARITATH',
#     "We saw your ship... You're the",
#     "first visitor we've had in..."]},
#   {'header': 'CONTINUED: (2)',
#    'part': ['KENTOR',
#     "The first visitor we've ever had.",
#     'They take a closer look at Data.',
#     'HARITATH',
#     "You're -- not human.",
#     'DATA',
#     'That is correct. I am an android.',
#     'I am Lieutenant Commander Data',
#     'of the Federation Starship',
#     'Enterprise.',
#     'HARITATH',
#     '(excited)',
#     'Our great-grandparents were',
#     'citizens of the Federation.',
#     '(realizing)',
#     "But you don't want to waste time",
#     'talking to us...',
#     'KENTOR',
#     "You'll want to speak with",
#     "Gosheven. We'll take you to him.",
#     'DATA',
#     'Excellent.',
#     'HARITATH',
#     "I'm sure the Federation will be",
#     'very proud of us. Wait until you',
#     "see all we've accomplished.",
#     'DATA',
#     'And who, precisely, is "we?"',
#     'HARITATH',
#     "You don't know? No, I guess you",
#     "wouldn't, would you? We are the",
#     'descendants of the original',
#     'settlers -- from the colony ship',
#     'Artemis.',
#     'CUT TO:']}],
#  '8': [{'header': 'INT. ENTERPRISE - MAIN BRIDGE',
#    'part': ['Picard and Worf in their usual places. Riker at',
#     'Science One. Supernumeraries at Conn and Ops.']},
#   {'header': 'CONTINUED:',
#    'part': ['RIKER',
#     'Got it. The Artemis, launched one',
#     'hundred forty-two years ago,',
#     'destination Septimis Minor. When',
#     'they failed to check in, Starfleet',
#     'began an extensive search.',
#     'PICARD',
#     'What carried the Artemis so far',
#     'off course?']}],
#  '9': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': ['Haritath and Kentor wait patiently for Data to finish',
#     'him communication.',
#     'DATA',
#     'My local informant does not know.',
#     'In the early days survival on Tau',
#     'Cygna Five was more important than',
#     'history.']}],
#  '10': [{'header': 'INTERCUTS',
#    'part': ['PICARD',
#     'Understood. How many are there?',
#     'DATA',
#     'Approximately fifteen thousand.',
#     'Reactions from the bridge crew. Now they really have',
#     'got a problem.',
#     'RIKER',
#     '(to Picard)',
#     "We've only got three days.",
#     'Without working transporters, we',
#     "couldn't have them out in time.",
#     'PICARD',
#     'Shuttles?',
#     'Worf does some figuring on his console.',
#     'WORF',
#     'Loading all the Enterprise',
#     'shuttlecraft to capacity --',
#     'evacuation would take four weeks,',
#     'four days.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Then we need more time. Mister',
#     'Data, prepare the colonists for',
#     'an evacuation.',
#     "DATA'S COM VOICE",
#     'Aye, sir.',
#     'Picard closes the com line.',
#     'PICARD',
#     '(continuing)',
#     'Mister Worf, get me the Sheliak.',
#     'WORF',
#     'Their home world is quite distant,',
#     'Captain. This will take some',
#     'time.',
#     'CUT TO:']}],
#  '11': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['The main pumping station of Tau Cygna V. In the',
#     'distance are mountains. A thin white line descends',
#     'from the mountains, and as it comes closer we realize',
#     'it is an aqueduct. Along the line of the aqueduct are',
#     'lush fields, a veritable Garden of Eden, which ends',
#     'like a knife-cut and the desert returns. It culminates',
#     'in a strange cubistic-shaped purifying station. In a',
#     'pool, the water churns into a white froth.',
#     'GOSHEVEN, the leader, supervises TWO WORKERS testing',
#     'the water in the pool.',
#     'Data, Haritath, and Kentor approach.',
#     'HARITATH',
#     "Gosheven, look what's come --",
#     'Gosheven sees Data, looks him up and down very',
#     "carefully. Gosheven's as surprised as Haritath was,",
#     'but keeps a lid on it -- Data may represent a threat,',
#     "so Gosheven's attempting a poker face.",
#     'DATA',
#     'Lieutenant Commander Data of the',
#     'Starship Enterprise.']},
#   {'header': 'CONTINUED:',
#    'part': ['KENTOR',
#     "He's an android.",
#     'GOSHEVEN',
#     'So he is.',
#     '(a beat)',
#     "Well, you're here -- what do you",
#     'want?',
#     'DATA',
#     'My mission is to prepare this',
#     'colony for evacuation.',
#     'Reactions from the men. Gosheven is calm, almost',
#     'amused:',
#     'GOSHEVEN',
#     'Why?',
#     'DATA',
#     'Because this planet belongs to',
#     'the Sheliak.',
#     'GOSHEVEN',
#     'And just who is this Sheliak?',
#     'DATA',
#     'The term is plural. The Sheliak',
#     'are an intelligent, non-humanoid',
#     'life form, classification R-3 --',
#     'GOSHEVEN',
#     '(interrupting)',
#     "This colony's been here for a",
#     'hundred and forty years -- and',
#     "no one's ever seen a Sheliak.",
#     "I'd say that makes Tau Cygna",
#     'Five our planet. (ALTERNATE:',
#     'ninety years)',
#     'DATA',
#     'But the original destination of',
#     'the Artemis was Septimis Minor.',
#     'GOSHEVEN',
#     'The guidance systems on the',
#     'Artemis failed -- and sent them',
#     'off course. Far off course.',
#     'Our ancestors were lucky to find',
#     'any place to land.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['HARITATH',
#     'And when they did, the radiation',
#     'started killing them.',
#     'GOSHEVEN',
#     'Hyperonic radiation took the lives',
#     'of a third of the colonists before',
#     'they learned they could adapt',
#     'to it.',
#     'KENTOR',
#     'But the colony survived -- and',
#     'prospered.',
#     'GOSHEVEN',
#     '(with pride)',
#     "Look around. We've brought",
#     'water to the desert, built a',
#     'community.',
#     'DATA',
#     'Your accomplishments are indeed',
#     'remarkable. However, the',
#     'Sheliak and the Federation',
#     'have a treaty that clearly makes',
#     'this planet Sheliak domain.',
#     'GOSHEVEN',
#     'Then change the treaty.',
#     'DATA',
#     'That may not be possible. The',
#     'Sheliak wish to colonize this',
#     'planet, and they are unwilling',
#     'to share it with humans.',
#     '(MORE)']},
#   {'header': 'CONTINUED: (3)',
#    'part': ["DATA (cont'd)",
#     'If you are still here when the',
#     'Sheliak colony ship arrives,',
#     'they will eradicate you.',
#     'Haritath and Kentor exchange a worried glance, but',
#     'Gosheven is unfazed.',
#     'HARITATH',
#     'They would kill us all?',
#     'DATA',
#     'They have little regard for',
#     'human life. Thus, our most',
#     'sensible course is to prepare a',
#     'contingency plan for the',
#     'evacuation of your people.',
#     'GOSHEVEN',
#     "We're not evacuating.",
#     'Data is taken aback.']},
#   {'header': 'CONTINUED: (4)',
#    'part': ['DATA',
#     'Perhaps I have not made myself',
#     'clear.',
#     'GOSHEVEN',
#     'Yes, you have. Now let me be',
#     "equally clear. There's going",
#     'to be no evacuation.',
#     '(a beat)',
#     "You've delivered your message --",
#     'so go back to your ship. I have',
#     'work to do.',
#     'Gosheven returns to his work on the pumping station.']}],
#  '11A': [{'header': 'ON DATA',
#    'part': ['as he considers his next move. Then -- an object comes',
#     'flying at Data.',
#     'With android speed and reflexes, Data catches the',
#     'object and examines it. It is an iron bar.',
#     "ARD'RIAN (O.S.)",
#     'Nice catch. Wonderful reflexes.',
#     'Data turns to see --']}],
#  '11B': [{'header': 'WIDER',
#    'part': ["ARD'RIAN, an attractive female, approaches.",
#     "ARD'RIAN",
#     'Sorry to test you like that --',
#     'but I was curious.',
#     'GOSHEVEN',
#     '(amused)',
#     'Found a new toy, have we, Ardy?',
#     "ARD'RIAN",
#     'Toy? This is the most incredible',
#     "android I've ever seen.",
#     'DATA',
#     'Have you seen many?',
#     "ARD'RIAN",
#     "Actually, no. You're the first.",
#     'GOSHEVEN',
#     "(to Ard'rian)",
#     'Only you would get this excited',
#     'over a walking calculator.',
#     "ARD'RIAN",
#     '(bridling)',
#     "He's more interesting than",
#     'anything else walking around',
#     'here...',
#     "Gosheven CHUCKLES -- he's succeeded in getting under",
#     'her skin.',
#     'GOSHEVEN',
#     'Depends on what you find',
#     'interesting.']},
#   {'header': 'CONTINUED:',
#    'part': ["Ard'rian's had enough of Gosheven's male conceit. She",
#     'moves away, motions for Data to follow. Data does.',
#     "ARD'RIAN",
#     '(to Data)',
#     'Cybernetic intelligence fascinates',
#     'me. Are your neural pathways',
#     'duotronic?',
#     'DATA',
#     'No -- they are positronic.',
#     "ARD'RIAN",
#     "I didn't know that was possible!",
#     "What's your memory capacity? How",
#     'many operations per second? I',
#     'have a million questions...',
#     'DATA',
#     'I am afraid I have no time to',
#     'answer one million questions.',
#     'I have a mission to accomplish.',
#     '(MORE)']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["DATA (cont'd)",
#     'I need to know more about your',
#     'people, and Gosheven seems',
#     'unwilling to talk to me further.',
#     "ARD'RIAN",
#     '(extending a hand)',
#     "I'm Ard'rian McKenzie. Perhaps",
#     'I can help you.',
#     'As Data shakes her hand, we:',
#     'CUT TO:']}],
#  '12': [{'header': 'INT. OBSERVATION LOUNGE',
#    'part': ["Picard, Riker and TROI are seated as GEORDI, O'Brien",
#     'ENTER.',
#     'RIKER',
#     "Gentlemen, we're giving you an",
#     'assignment, and the one thing we',
#     "don't want to hear is that it is",
#     'impossible.',
#     "Riker defers to Picard. Geordi and O'Brien cast wary",
#     'glances at Picard. Now what the hell is he going to',
#     'want?',
#     'PICARD',
#     'I need the transporters to',
#     'function despite the hyperonic',
#     'radiation.',
#     'GEORDI',
#     'Impossi -- Yes, sir.',
#     "Geordi and O'Brien EXIT. Riker, Troi and Picard study",
#     'each other seriously.',
#     'RIKER',
#     'Even if we can get the Sheliak',
#     "to talk to us, they're not likely",
#     'to be accommodating.']},
#   {'header': 'CONTINUED:',
#    'part': ['TROI',
#     'Captain, when the treaty was',
#     'negotiated the Federation sent',
#     'three hundred and seventy-two',
#     'legal experts. What have we got?',
#     'PICARD',
#     'Thee... and me.',
#     "Off Troi's very dubious expression as we:",
#     'FADE OUT.',
#     'END OF ACT ONE                          ',
#     'ACT TWO                             ',
#     'FADE IN:']}],
#  '13': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['in orbit around Tau Cygna V.']}],
#  '14': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['Picard pacing, Troi seated as they wait for the call.',
#     'Worf at his station. Supernumeraries at Conn and Ops.',
#     'WORF',
#     'No response.',
#     'PICARD',
#     'Try again. Boost signal strength.',
#     'Worf makes adjustments.',
#     'WORF',
#     'Sheliak Corporate. This is the',
#     'Starship Enterprise. Respond',
#     'please.']}],
#  '15': [{'header': 'ANGLE ON VIEWSCREEN - (OPTICAL)',
#    'part': ['as it changes from a view of stars to -- someplace? a',
#     'bridge? Wherever the SHELIAK are calling from it is',
#     'a disturbing place for humans. Darkness, mirrored',
#     'surfaces, and hidden in the shadows a creature who is',
#     'decidedly unsettling for the crew. Its shape is',
#     'constantly shifting like oozing sludge, and there is',
#     'a hint of flickering eyes -- too many eyes.',
#     'SHELIAK',
#     'Conversation is neither required',
#     'nor desired.',
#     'Picard schools his features into an expression of',
#     'polite interest.',
#     'PICARD',
#     'Conversation is necessary if we',
#     'are to find a solution to our',
#     'mutual problem.',
#     'SHELIAK',
#     'Our involvement in Federation',
#     'illegality is not indicated.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Both parties are involved, sir.',
#     'SHELIAK',
#     'Remove the humans from the Tau',
#     'Cygna system. Three Earth days',
#     'remain.',
#     'Troi leans in, and whispers:',
#     'TROI',
#     'Their culture is extremely formal,',
#     'almost ritualistic. An apology',
#     'might smooth matters.',
#     'PICARD',
#     'I apologize for our inadvertent',
#     'violation of the treaty.',
#     'SHELIAK',
#     'Acknowledged and accepted. Now',
#     'remove the human creatures.',
#     'PICARD',
#     'Let us negotiate in good faith...',
#     'SHELIAK',
#     'Negotiate to what purpose? The',
#     'treaty is signed.',
#     'PICARD',
#     'There is a thriving colony on the',
#     'planet. Rather than uproot these',
#     'people may I offer a compromise?',
#     'SHELIAK',
#     'Denied.',
#     'PICARD',
#     'Why?!',
#     'SHELIAK',
#     'The law is paramount. We are',
#     'entitled.',
#     'PICARD',
#     'This is not a law. It is a',
#     'treaty. It is designed to smooth',
#     'relations between peoples. Not',
#     'to act as a strait...']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["But Picard's talking to a blank screen. The Sheliak",
#     'have hung up on him.',
#     'PICARD',
#     '... jacket.',
#     "Off Picard's annoyed expression.",
#     'CUT TO:']}],
#  '16': [{'header': 'OMITTED', 'part': []}],
#  '17': [{'header': "INT. ARD'RIAN'S FRONT ROOM - DAY",
#    'part': ['A comfortable room constructed of stone with a heavy',
#     'beamed ceiling. The furniture is hand hewn, durable',
#     'but comfortable. Contrasting with this are various',
#     'computer parts and consoles, both assembled and in',
#     'pieces, strewn about.',
#     "Ard'rian and Data ENTER.",
#     "ARD'RIAN",
#     "... you really think we'll have",
#     'to leave Tau Cygna Five?',
#     'DATA',
#     'The possibility exists, and',
#     'Gosheven appears unwilling to',
#     'prepare for it. Why?']},
#   {'header': 'CONTINUED:',
#    'part': ["ARD'RIAN",
#     "Maybe because you're an",
#     "android. I don't think Gosheven",
#     'likes the idea of machines',
#     'ordering him around.',
#     'DATA',
#     'I am not ordering him to do',
#     'anything; I am merely trying to',
#     'persuade him that his people',
#     'should prepare to evacuate.',
#     '(thinks)',
#     'Do you believe my suggested',
#     'course of action should be followed?',
#     "ARD'RIAN",
#     'Of course.',
#     'DATA',
#     'In spite of the fact that I am',
#     'an android?',
#     "ARD'RIAN",
#     "Because of that fact. I don't",
#     'have any silly prejudices against',
#     'computers -- I like them.',
#     'SHe gestures around the room, a bit apologetically:',
#     "ARD'RIAN (cont'd)",
#     'Not that any computer we have is',
#     'half as sophisticated as you...',
#     'Data looks at a particularly "primitive" computer:',
#     'DATA',
#     'No, I would say not.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["ARD'RIAN (cont'd)",
#     'People can be selfish,',
#     'irrational, stubborn, malicious',
#     '-- you name it. But computers',
#     "don't have those failings.",
#     'Data follows her logic:',
#     'DATA',
#     'You conclude from this that I am',
#     'impartial... hence you accept',
#     'my recommendations.',
#     'She nods.',
#     "DATA (cont'd)",
#     'Yet Gosheven does not.',
#     '(thinks)',
#     'Perhaps he might reconsider his',
#     'position if someone other than',
#     'myself were to present the',
#     'arguments.',
#     "ARD'RIAN",
#     "Well, I'm willing to talk to him,",
#     "but I don't think he'll take me",
#     'seriously.',
#     '(with distaste)',
#     "He finds me attractive -- but I'm",
#     'not interested in him at all.',
#     'So he belittles me to protect his',
#     'ego --']}],
#  '18': [{'header': 'OMITTED', 'part': []}],
#  '19': [{'header': 'NEW ANGLE',
#    'part': ["as Data's communicator TRILLS. He touches the",
#     'insignia.',
#     'DATA',
#     'Data, here.',
#     "PICARD'S COM VOICE",
#     "The Sheliak won't bargain.",
#     'DATA',
#     'Understood.']},
#   {'header': 'CONTINUED:',
#    'part': ["PICARD'S COM VOICE",
#     "I'm contacting Starfleet to",
#     'arrange for transport. Get those',
#     'people prepared for evacuation.',
#     'We may have to move very quickly.']},
#   {'header': 'CONTINUED:',
#    'part': ['DATA',
#     'Yes, sir.',
#     "Data cuts the communication, turns to Ard'rian.",
#     'DATA',
#     'We must speak with Gosheven',
#     'immediately.',
#     "Ard'rian grabs a coat, and they EXIT.",
#     'CUT TO:']}],
#  '19A': [{'header': 'INT. TRANSPORTER ROOM (OPTICAL) (FORMERLY SC. 16)',
#    'part': ["Geordi, O'Brien and WESLEY have the panels removed",
#     "from the wall behind the transporter console. Geordi's",
#     'tool box is nearby. Sophisticated tools litter the',
#     'floor. Off to the left side of the transporter are',
#     'six test objects. The trio is watching tensely as',
#     "O'Brien touches the console. A test object",
#     'MATERIALIZES looking like swiss cheese. Geordi picks',
#     'it up. Riker ENTERS.',
#     'RIKER',
#     'Gentlemen, how are you coming?',
#     '(spots the object)',
#     'What the hell is that?',
#     'Geordi sets aside the mutilated object.',
#     'GEORDI',
#     'Our first attempt.',
#     "O'BRIEN",
#     'We recalibrated the transporter',
#     'setting for the tightest possible',
#     'beam.',
#     'WESLEY',
#     "But we've got plenty of things",
#     'left to try.',
#     'Geordi is studying the test object again.',
#     'GEORDI',
#     "There's some really interesting",
#     'residue . . . reminds me of --',
#     '(a beat)',
#     "There's that damn pulsar in the",
#     'neighborhood.']},
#   {'header': 'CONTINUED:',
#    'part': ['WESLEY',
#     'Teremi-thorons.',
#     "O'BRIEN",
#     'This just got a lot harder.',
#     'WESLEY',
#     "They're one of the most elusive",
#     'sub-atomic particles known, and',
#     'they really shred a transporter',
#     'signal.',
#     'RIKER',
#     'Thank you, Ensign, I passed',
#     'physics.',
#     '(to Geordi)',
#     'Keep at it. We need those',
#     'transporters.',
#     'Riker EXITS.',
#     'GEORDI',
#     "We're going to have a lot of fun",
#     'cracking this one.',
#     'CUT TO:']}],
#  '20': [{'header': '', 'part': ['thru\tOMITTED']}],
#  '21': [{'header': '', 'part': []}],
#  '22': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ["Gosheven, Data, and Ard'rian are standing near the pool",
#     'of water. Gosheven cups some water in a hand.',
#     'GOSHEVEN',
#     'See that? Do you have any idea',
#     'what it is? What it means?',
#     'DATA',
#     'It is water, a substance composed',
#     'of two atoms of hydrogen --',
#     'GOSHEVEN',
#     "It's not water. It's blood and",
#     'sweat -- the result of a hundred',
#     'and forty years of combined',
#     'effort. (ALTERNATE: ninety',
#     "years) This isn't a town.",
#     '(MORE)']},
#   {'header': 'CONTINUED:',
#    'part': ["GOSHEVEN (Cont'd)",
#     "It's a monument to every man,",
#     'woman, and child who has lived',
#     'and died on Tau Cygna Five.',
#     "ARD'RIAN",
#     "Gosheven, you're talking nonsense.",
#     'GOSHEVEN',
#     "Am I? My grandfather's buried",
#     'on that mountain.',
#     '(points to the distant',
#     'line of hills)',
#     'He died in a rock slide surveying',
#     'the route for this aqueduct. This',
#     'colony exists because of his',
#     'sacrifice, and the sacrifices of',
#     "thousands of others. No, we're",
#     'not leaving.',
#     'DATA',
#     'The Sheliak will not accept humans',
#     'on their planet. And they will',
#     'not hesitate to use force to',
#     'remove you.',
#     'GOSHEVEN',
#     '(calmly)',
#     'And we will not hesitate to fight',
#     'back.',
#     'DATA',
#     'You cannot win.',
#     'GOSHEVEN',
#     "You just don't understand, do you?",
#     'We will not be bullied off our',
#     'land... not by you, and not by',
#     'the Sheliak.',
#     'Gosheven whirls and walks away. End of conversation.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["ARD'RIAN",
#     '(re Gosheven; bitter)',
#     'Stubborn and irrational. Now what',
#     'do we do?',
#     'DATA',
#     'Are his sentiments typical among',
#     'the colonists?',
#     "ARD'RIAN",
#     'I hope not. Are you thinking',
#     'of bypassing Gosheven and taking',
#     'your case directly to the people?',
#     'DATA',
#     '(nods)',
#     'I see no other course of action.',
#     'If I can convince enough people',
#     'of the necessity of leaving --',
#     "ARD'RIAN",
#     '(a smile)',
#     'Don\'t you mean "if we can',
#     'convince?"',
#     'DATA',
#     'You are offering assistance?',
#     "Ard'rian nods, extends her arm -- c'mon, let's get",
#     'going. As they move off:',
#     'CUT TO:']}],
#  '22A': [{'header': 'EXT. SPACE - ENTERPRISE (OPTICAL) (FORMERLY SC. 20)',
#    'part': ['In orbit around Tau Cygna V.']}],
#  '22B': [{'header': "INT. CAPTAIN'S READY ROOM (FORMERLY SC. 21)",
#    'part': ['Picard is pacing rapidly about the office. Riker',
#     'ENTERS.',
#     'RIKER',
#     'Yes, sir?']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Three weeks. Starfleet is profuse',
#     'in their apologies, but it will',
#     'still be three weeks.',
#     'RIKER',
#     'Until?',
#     'PICARD',
#     'Until the arrival of a colony',
#     'transport ship equipped with',
#     'dedicated personnel shuttles.',
#     'RIKER',
#     "We can't wait three weeks.",
#     'PICARD',
#     'The Sheliak must agree to extend',
#     'our deadline.',
#     'Picard sits in silence for a beat.',
#     "PICARD (cont'd)",
#     'If they plan to settle Tau Cygna',
#     'Five two days from now...',
#     'RIKER',
#     '... one of their ships must already',
#     'be en route.',
#     'PICARD',
#     '(decides)',
#     "We're going to intercept that",
#     'ship.',
#     'RIKER',
#     'The Sheliak may interpret that',
#     'as a hostile act.',
#     'PICARD',
#     'We have to take the risk.',
#     "Off Picard's determined expression as we:",
#     'FADE OUT.',
#     'END OF ACT TWO                          ',
#     'ACT THREE                            ',
#     'FADE IN:']}],
#  '23': [{'header': 'INT. OBSERVATION LOUNGE',
#    'part': ['Riker pacing slowly, looking out at the stars.',
#     'RIKER',
#     'The Enterprise is going to try',
#     'to intercept the Sheliak colony',
#     'ship. Your job ... well, you know',
#     'your job.',
#     'CUT TO:']}],
#  '24': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['Data standing alone in an archway.',
#     'DATA',
#     'Commander, in human parlance, I do',
#     'not believe I can "get the job',
#     'done." My training has prepared',
#     'me for starship command duties.',
#     'As a cultural contact I am',
#     'proving to be less than exemplary.']}],
#  '25': [{'header': 'INTERCUTS',
#    'part': ['RIKER',
#     "What's the situation?",
#     'DATA',
#     'Their leader has rejected my',
#     'counsel. He denies the logic of',
#     'my arguments and talks of',
#     'structures they have built.',
#     'RIKER',
#     'Then try something else.',
#     'DATA',
#     'I have. In the last three hours',
#     'and eight minutes, I have spoken',
#     'to fifty-six colonists. Ten',
#     'refused to believe a threat',
#     'exists. Twenty-two favored',
#     'staying and fighting the Sheliak.']},
#   {'header': 'CONTINUED:',
#    'part': ['RIKER',
#     '(more to himself)',
#     "I don't have time for this.",
#     'DATA',
#     'Sixteen preferred negotiation or',
#     'some form of passive resistance.',
#     'Only eight were willing to',
#     'consider evacuation. And of those',
#     'eight --']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['RIKER',
#     '(cutting him)',
#     "Data, I can't help you -- I don't",
#     "know these people; I haven't",
#     'talked to them. You have. Use',
#     'that fancy positronic brain of',
#     'yours -- and carry out your',
#     'mission.',
#     "Ard'rian walks up to join the android, politely keeps",
#     'a few paces away to let him complete his "phone call"',
#     'with privacy.',
#     'DATA',
#     'If I do not succeed, how violent',
#     'is the Sheliak reaction likely',
#     'to be?',
#     'RIKER',
#     'The treaty is the only thing which',
#     'kept them from eradicating the',
#     'colony the moment they discovered',
#     'it.',
#     'DATA',
#     'Ah.',
#     'RIKER',
#     '"Ah" is right. The lives of',
#     'fifteen thousand people are riding',
#     "on you. You'd better get",
#     'innovative. Riker out.',
#     "Data gazes into space, thinking. Ard'rian steps up.",
#     'Her mood is upbeat.',
#     "ARD'RIAN",
#     "Data -- we're having an effect.",
#     'So many people are asking',
#     'questions about the Sheliak that',
#     "Gosheven's called a public",
#     'meeting.']},
#   {'header': 'CONTINUED: (3)',
#    'part': ['DATA',
#     'Is there any indication that',
#     'Gosheven has changed his position?',
#     "ARD'RIAN",
#     'No. But a meeting will give you',
#     'the chance to present your',
#     'recommendations.',
#     'DATA',
#     'First, will Gosheven allow me to',
#     'speak? Second, even if he does,',
#     'what good will it do? So far,',
#     'my attempts at persuasion have',
#     'been ineffective.',
#     "Ard'rian looks at him with compassion for a beat --",
#     'then suddenly gives Data a quick kiss on the lips.',
#     "DATA (cont'd)",
#     'Why did you do that?',
#     "ARD'RIAN",
#     'You appeared to need it.',
#     'DATA',
#     'Among humans, a kiss normally',
#     'serves to seal a friendship or',
#     'to indicate support, attraction,',
#     'affection.',
#     "Ard'rian nods."]},
#   {'header': 'CONTINUED: (4)',
#    'part': ["DATA (cont'd)",
#     'In this context, I would assume',
#     'your intention was to express',
#     'support.',
#     "ARD'RIAN",
#     'That was my primary motivation.',
#     'The implication being that there were secondary',
#     'motivations. But if Data is aware of the implication,',
#     'he makes no sign.',
#     "ARD'RIAN (cont'd)",
#     "You don't really understand human",
#     'behavior, do you?',
#     'DATA',
#     'That is something of an',
#     'understatement.',
#     "ARD'RIAN",
#     '(sighs)',
#     "Sometimes I don't either.",
#     'androids are a lot more rational.',
#     'DATA',
#     'Thus far, that quality has not',
#     'helped me accomplish my mission.',
#     "ARD'RIAN",
#     "A rational argument isn't always",
#     'enough. Maybe to be more',
#     'persuasive, you need to use a',
#     'little reverse psychology.',
#     'DATA',
#     '(accessing)',
#     'Elicit a desired behavior by',
#     'advocating its opposite?',
#     '(a beat)',
#     'That implies deception, does it',
#     'not?',
#     "ARD'RIAN",
#     'A little. But if it helps us',
#     'get our point across...']},
#   {'header': 'CONTINUED: (5)',
#    'part': ['DATA',
#     '(considers)',
#     'Perhaps this is a situation in',
#     'which excessive honesty is',
#     'detrimental.',
#     'As they walk off:',
#     'CUT TO:']}],
#  '26': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['Travelling at warp speed.']}],
#  '27': [{'header': 'INT. TRANSPORTER ROOM',
#    'part': ['As before, except there are more high tech tools and',
#     'equipment lying about. Geordi is lifting yet another',
#     'trashed test object off the platform. He holds it',
#     "mutely out to Wesley and O'Brien who stare dully at",
#     'this latest failure. There are now four intact',
#     'objects and three blasted ones. Picard ENTERS.',
#     'PICARD',
#     '(you will get it done)',
#     'How are we progressing, Mister',
#     'La Forge?',
#     'GEORDI',
#     "(it's impossible)",
#     "About like you'd expect.",
#     'PICARD',
#     '(get it done)',
#     'Splendid.',
#     'Picard EXITS.',
#     'WESLEY',
#     '(wearily)',
#     'He wants the impossible.']},
#   {'header': 'CONTINUED:',
#    'part': ['GEORDI',
#     '(with a grin)',
#     "That's the short definition for",
#     '"captain."',
#     "Geordi and O'Brien have already returned to work. Wes",
#     'looks at them bemused, then shrugs and pitches in.',
#     'CUT TO:']}],
#  '28': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['A large horseshoe-shaped amphitheater with a place for',
#     'the engineers and Gosheven. A number of citizens --',
#     'including Haritath and Kentor -- have turned out for',
#     'the debate so the place is filled. In the b.g. is the',
#     'aqueduct purifying plant.',
#     'GOSHEVEN',
#     "You've all heard about the android",
#     "Starfleet sent here, and you've",
#     "been discussing why he's come.",
#     "Data and Ard'rian ENTER. Gosheven ignores them.",
#     "GOSHEVEN (cont'd)",
#     'I called this meeting to replace',
#     'misinformation with cold, hard',
#     'fact.',
#     'The colonists are craning their necks to look at Data.',
#     "Gosheven realizes Data's presence can't be ignored. He",
#     'strides over to confront Data.',
#     'GOSHEVEN',
#     'Leave. Immediately.',
#     'DATA',
#     'I wish to speak.',
#     'GOSHEVEN',
#     'No.',
#     'DATA',
#     "(loud, for the crowd's",
#     'benefit)',
#     'You deny me the opportunity to',
#     'address the assemblage?']},
#   {'header': 'CONTINUED:',
#    'part': ['GOSHEVEN',
#     'This meeting is not for outsiders.',
#     'DATA',
#     'Do you consider your position so',
#     'weak that it cannot withstand',
#     'debate?',
#     'HARITATH',
#     'Let him talk.',
#     'MURMURS of assent from the crowd. Gosheven gives a',
#     "terse nod. In a sense Data's called him a coward and",
#     'he has to stand up to this city slicker, this outsider.',
#     'Data steps front and center. In an effort to pull this',
#     'off, he attempts to use human rhetorical devices',
#     '(timing, dynamics, inflection, gestures, etc.) -- but,',
#     "as there's no real passion behind them, they come off",
#     'as studied and not quite sincere. A good performance,',
#     'but still a performance.',
#     'DATA',
#     'You know of the Sheliak threat.',
#     'Starfleet wishes to evacuate you',
#     'for your own protection.',
#     'Gosheven has decided otherwise.',
#     'That is his right. And I will',
#     'not waste time trying to reverse',
#     'that decision.',
#     'Surprised reactions from the crowd. This is not what',
#     'they expected to hear.',
#     "DATA (cont'd)",
#     'I admire your conviction in the',
#     'face of certain defeat. Your',
#     'effort will be valiant, though',
#     'doomed. Still, when you die,',
#     'you will die for land and honor.']}],
#  '29': [{'header': 'ANGLE ON',
#    'part': ["The crowd. Data's starting to get a reaction. People",
#     "are beginning to eye each other nervously. It's one",
#     'thing to thumb your nose at a distant enemy, quite',
#     'another to talk about dying.']}],
#  '30': [{'header': 'ANGLE ON DATA',
#    'part': ['As he reaches down, and takes a YOUNG BOY (twelve or',
#     'so) by the arm, and pulls the child up next to him.',
#     'DATA',
#     'Your children will understand that',
#     'they are dying for a worthy cause.',
#     'Big crowd reaction here. Murmurs from various people.',
#     'Mothers pull their children closer to them. Data',
#     'steals a glance at Ard\'rian -- "how am I doing?"',
#     'Ard\'rian nods encouragingly back -- "fine."',
#     'DATA',
#     '(continuing)',
#     'Long after the battle is over,',
#     'their courage will be remembered',
#     'and extolled.',
#     "Ard'rian jumps in to support him.",
#     "ARD'RIAN",
#     'Remembered by who?',
#     'DATA',
#     "(as if he hadn't",
#     'considered that)',
#     'Ah, that is true. There will be',
#     'no one left alive to remember.']}],
#  '31': [{'header': 'ANGLE ON GOSHEVEN',
#    'part': ['as he begins to applaud slowly.',
#     'GOSHEVEN',
#     'A valiant try, android, but what',
#     'a low opinion you must have of',
#     'us.',
#     "The boy's MOTHER snatches her son back from Data, and",
#     'pulls him down in her lap.',
#     'DATA',
#     'I was simply attempting to',
#     'describe your inevitable',
#     'destruction in a manner that',
#     'would have an emotional effect.']},
#   {'header': 'CONTINUED:',
#    'part': ['HARITATH',
#     '(standing)',
#     'And he did it pretty damned well.',
#     'MURMURS of agreement from the crowd.',
#     'GOSHEVEN',
#     'Are you ready to follow this',
#     'machine, Haritath? Give up',
#     'everything? Without a fight?',
#     "He says we're going to lose, I",
#     "think that's his own cowardice",
#     'talking!',
#     'Kentor stands. He has a calm but commanding presence.',
#     'KENTOR',
#     "And what if he's right, and you're",
#     "wrong? Shouldn't we consider that",
#     'possibility?',
#     'More crowd reaction. Sympathy is swinging away from',
#     'Gosheven.',
#     'HARITATH',
#     'We may be sacrificing ourselves',
#     'for nothing --',
#     'GOSHEVEN',
#     'Last winter we buried your little',
#     'girl -- laid her to rest next to',
#     'your mother, and you dare speak',
#     'of sacrifice?',
#     'Gosheven whirls and nails Kentor with a look.',
#     'GOSHEVEN',
#     '(continuing)',
#     'And you, Kentor, we built you',
#     'a new house after the fire wiped',
#     'you out. Can you simply walk away',
#     'from that?',
#     'KENTOR',
#     'Better to walk away than to be',
#     'annihilated.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['GOSHEVEN',
#     '(addressing them all)',
#     'This colony exists because',
#     'generations gave their lives for',
#     'it. Many people died before we',
#     'found a way to adapt to the',
#     'radiation. Many more died',
#     'bringing water to the desert.',
#     'My father --',
#     "ARD'RIAN",
#     '(interrupting)',
#     '-- is buried on that mountain.',
#     "Well, who's going to be left to",
#     'bury you?',
#     'A vote of confidence is about to take place, and',
#     "Gosheven realizes he's about to lose it. He falls back",
#     'on the innate authority of an elected leader.',
#     'GOSHEVEN',
#     'Have you considered what this',
#     'evacuation means? Everything we',
#     'have, we abandon. Everything',
#     "we've built turns into dust.",
#     "Everything we've accomplished",
#     'means nothing.',
#     '(shakes head)',
#     'Well, I say NO! You elected me',
#     'to be your leader -- follow me',
#     "now! I don't think our chances",
#     'are as hopeless as he says. And',
#     "I'm willing to stake our lives",
#     'on it. Any objections?',
#     'He rakes the crowd with a look. Some mutterings, but',
#     "nobody's quite ready to lead the revolution.",
#     'GOSHEVEN',
#     '(continuing)',
#     'Good, because here... we...',
#     'stand.',
#     'A few people step up to pound Gosheven on the back, but',
#     'most of the crowd remains huddled, glancing from Data',
#     'to Gosheven and back again. Haritath and Kentor step',
#     'away to talk in private.']}],
#  '32': [{'header': 'ANGLE ON DATA',
#    'part': ["standing with Ard'rian.",
#     'DATA',
#     '(almost to himself)',
#     'Then here you die.',
#     'FADE OUT.',
#     'END OF ACT THREE                         ',
#     'ACT FOUR                             ',
#     'FADE IN:']}],
#  '33': [{'header': 'INT. TRANSPORTER ROOM (OPTICAL)',
#    'part': ["Wesley, Geordi and O'Brien. There are now three",
#     'intact test object and four trashed ones. These are',
#     "three exhausted people. They've been working round",
#     'the clock.',
#     'WESLEY',
#     'Maybe if we bypassed the autosequence',
#     'and decompiled the',
#     'pattern buffer... ?',
#     'GEORDI',
#     '(shrugs)',
#     "It's no crazier than anything",
#     "else we've tried.",
#     'Wesley drops down by the panel, and begins to tinker',
#     'while Geordi places the last test object on the',
#     'platform. Suddenly the transporter console blows a',
#     'fuse. Electricity races across the panel, and the',
#     "console goes dark. O'Brien is not a happy man. Wesley",
#     "slowly stands up. O'Brien struggles with himself, but",
#     "can't master it.",
#     "O'BRIEN",
#     'Ensign Crusher.',
#     'WESLEY',
#     'Yes, sir.',
#     "O'BRIEN",
#     'If you ever touch my transporter',
#     "again... I'll kill you.",
#     'WESLEY',
#     'Sorry, sir.',
#     'CUT TO:']}],
#  '33A': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['Data watches the town meeting break up into small',
#     "groups of people TALKING among themselves. Ard'rian",
#     'approaches.']},
#   {'header': 'CONTINUED:',
#    'part': ['Haritath and Kentor step up furtively.',
#     'HARITATH',
#     'Mister Data -- I want to tell you',
#     "that... well, Gosheven doesn't",
#     'speak for all of us.',
#     "Ard'rian looks at Data hopefully -- maybe the early",
#     "returns aren't so bad after all.",
#     "HARITATH (cont'd)",
#     'I see no point in dying',
#     'needlessly.',
#     'DATA',
#     'And you, Kentor?',
#     'KENTOR',
#     "I'm not sure. Gosheven has done",
#     "well for us. But I'd like to hear",
#     'more of what you have to say.',
#     'HARITATH',
#     'There are many others that feel',
#     'the same way but are uneasy about',
#     'confronting Gosheven.',
#     "ARD'RIAN",
#     "Get them together. We'll meet",
#     'at my house.',
#     'Haritath and Kentor nod agreement then slip away.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["Ard'rian leads Data toward her house. They EXIT."]}],
#  '34': [{'header': '', 'part': ['thru\tOMITTED']}],
#  '35': [{'header': '', 'part': []}],
#  '36': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['Traveling at warp speed.']}],
#  '37': [{'header': "INT. CAPTAIN'S READY ROOM (OPTICAL)",
#    'part': ['Picard has brought Troi in for consultation.',
#     'TROI',
#     'In our dealings with other',
#     'non-humanoid races there has been',
#     'some point of reference; not so',
#     'with the Sheliak.',
#     'PICARD',
#     'We must have something in common.',
#     'We communicate.',
#     'TROI',
#     'Barely. The Sheliak have learned',
#     'several Federation languages, but',
#     'theirs continues to elude us.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     '(have we tried?)',
#     'Telepaths?',
#     'TROI',
#     'Attempted and failed.',
#     'PICARD',
#     'This is ludicrous!',
#     'TROI',
#     'No, sir, the fact that any alien',
#     'race communicates with another',
#     'is quite remarkable.',
#     "She lifts Picard's tea cup from the desk.",
#     'TROI',
#     '(continuing)',
#     'We are stranded on a planet. No',
#     'language in common, but I want',
#     'to teach you mine.',
#     'Troi points to the cup.',
#     'TROI',
#     '(continuing)',
#     "S'smarith. What did I just say?",
#     'PICARD',
#     'Cup? Glass?',
#     'TROI',
#     'Are you sure? I might have meant',
#     'liquid, clear, brown, hot. And',
#     'we conceptualize the universe in',
#     'relatively the same way.',
#     'PICARD',
#     'Point taken.',
#     'TROI',
#     'During your talks you must be',
#     'extremely accurate. The treaty',
#     'is 500,000 words. The length was',
#     'to accommodate the Sheliak. They',
#     'consider our language irrational,',
#     'and demanded this level of',
#     'complexity to avoid any future',
#     'misunderstandings.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["RIKER'S COM VOICE",
#     'Captain, we have the vessel',
#     'carrying the Sheliak colonists',
#     'on visual.',
#     'PICARD',
#     'On my way.',
#     '(to Troi)',
#     'So it begins.',
#     'They EXIT onto:']}],
#  '38': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['The tension on the bridge is palpable. Picard moves',
#     'swiftly to the command station. Riker relinquishes',
#     'command.']}],
#  '39': [{'header': 'ANGLE ON VIEWSCREEN (OPTICAL)',
#    'part': ['Where a Sheliak ship hangs ominously.',
#     'PICARD',
#     'Open hailing frequencies. This',
#     'is Captain Jean-Luc Picard of the',
#     'Starship Enterprise.',
#     'We again have a vision of the mirrored, shadowed,',
#     'shifting place. A hint of a watcher in the shadows.',
#     'SHELIAK',
#     'Your purpose, Enterprise?',
#     'PICARD',
#     'We desire face-to-face negotiation',
#     'to settle the crisis on Tau Cygna',
#     'Five.',
#     'Troi hands him a PADD.',
#     'PICARD',
#     '(continuing)',
#     'We are entitled to consultation',
#     'under paragraph five hundred and',
#     'sixty-three subparagraph nine.',
#     'A beat as the Sheliak look it up.',
#     'SHELIAK',
#     'Granted.']},
#   {'header': 'CONTINUED:',
#    'part': ['The screen again shows the Sheliak vessel.',
#     'RIKER',
#     'Was that an invitation?',
#     'PICARD',
#     "I'm going to take it as such.",
#     'Number One, you have the bridge.',
#     'Troi and Picard EXIT. HOLD on Riker.',
#     'RIKER',
#     'Helm, maintain relative position.',
#     'Mister Worf, have Transporter Room',
#     'Two stand by.',
#     'WORF',
#     'Aye, sir.',
#     'CUT TO:']}],
#  '40': [{'header': "INT. ARD'RIAN'S LIVING ROOM - DAY",
#    'part': ['Haritath, Kentor, and a group of other colonists are',
#     "gathered around Data and Ard'rian.",
#     'KENTOR',
#     '... and once the Federation',
#     "resettles us, we'll be left",
#     'alone?',
#     'DATA',
#     'If you so desire.',
#     'HARITATH',
#     'We do. We like doing things on',
#     'our own.',
#     'DATA',
#     'The Federation will offer as',
#     'little or as much help as you',
#     'dictate.']},
#   {'header': 'CONTINUED:',
#    'part': ['Nods all around; they are impressed. Data is the',
#     'perfect no-pressure salesman; he simply presents the',
#     "facts. Ard'rian looks expectantly to Kentor;",
#     "Kentor's still uncertain.",
#     "ARD'RIAN",
#     'Kentor -- are you with us?',
#     'Kentor makes up his mind:',
#     'KENTOR',
#     'Yes.',
#     '(a beat)',
#     'The question is, how do we',
#     'convince Gosheven?']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['HARITATH',
#     'Why do we need to?',
#     'KENTOR',
#     "Because he's respected. Most",
#     'people will do as he says.',
#     "ARD'RIAN",
#     'The people respect you, too.',
#     "If you take a stand, they'll",
#     'fall in line.',
#     'KENTOR',
#     "I don't know. Gosheven's got a",
#     'lot of supporters...',
#     'GOSHEVEN (O.S.)',
#     "Don't forget that, Kentor.",
#     'Everyone turns to see --']}],
#  '40A': [{'header': 'OMITTED', 'part': []}],
#  '40B': [{'header': 'NEW ANGLE (OPTICAL)',
# ...
#     'the discretion of the Sheliak',
#     'corporate.',
#     'PICARD',
#     'We will remove them. But you',
#     'must grant us the time we require.',
#     'SHELIAK',
#     'You need time, Picard of the',
#     'Enterprise, we will save you time.',
#     'We will eradicate the human',
#     'infestation.',
#     'PICARD',
#     '(outraged)',
#     'They are not vermin! They are',
#     'citizens of the Federation and',
#     'I will not permit this travesty!']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['SHELIAK',
#     'Intelligent converse is',
#     'impossible. You do not discuss,',
#     'you gibber.',
#     'PICARD',
#     'Between intelligent species of',
#     'good will --',
#     'Suddenly the Sheliak transporter kicks in, and slams',
#     'Picard and Troi back to the Enterprise. They have been',
#     'rudely thrown out on their ears.']}],
#  '42': [{'header': 'INT. MAIN BRIDGE (OPTICAL)',
#    'part': ['The startling EFFECT of the Sheliak transporter and',
#     'Picard and Troi APPEAR. Riker, Worf, and the',
#     'supernumeraries at Conn and Ops react.',
#     'Picard and Troi are both very disoriented, staggering',
#     'slightly. Riker steadies them both.',
#     'RIKER',
#     'I take it the Sheliak just hung',
#     'up on us. Again.',
#     'FADE OUT.',
#     'END OF ACT FOUR                         ',
#     'ACT FIVE                             ',
#     'FADE IN:']}],
#  '42A': [{'header': "INT. ARD'RIAN'S LIVING ROOM",
#    'part': ["Ard'rian worriedly inspects the unmoving Data with an",
#     'electronic scanner. Data twitches, "reboots," comes',
#     "back to life, and sits up. Ard'rian SIGHS, relieved.",
#     "ARD'RIAN",
#     'I was afraid your neural pathways',
#     'were scrambled beyond repair.',
#     'DATA',
#     'I am equipped with diagnostic',
#     'circuits and can correct many',
#     'malfunctions.',
#     'Data moves his head, arms, and legs, testing his',
#     'responses.',
#     "ARD'RIAN",
#     "I'm not surprised at Gosheven's",
#     'behavior. But Kentor and the',
#     'others... they said they were',
#     'on our side.',
#     '(bitter)',
#     "I guess words don't mean very",
#     'much.',
#     'Data mulls this over carefully.',
#     'DATA',
#     'Perhaps that has been part of our',
#     'difficulty. Words are all we have',
#     'been using.',
#     '(thinking)',
#     'Humans seem to take much stronger',
#     'notice of actions.',
#     'Data makes a decision, gets to his feet.',
#     "DATA (cont'd)",
#     'I require a phaser.',
#     "ARD'RIAN",
#     "What's a phaser?",
#     'DATA',
#     'A type of weapon. Unfortunately',
#     'it will not function in the',
#     'presence of hyperonic radiation.']},
#   {'header': 'CONTINUED:',
#    'part': ['Data ponders this new problem for a beat, then shrugs',
#     'it off:',
#     "DATA (cont'd)",
#     'I will have to be innovative.',
#     'CUT TO:']}],
#  '42B': [{'header': 'INT. SHUTTLECRAFT - CYGNA FIVE - DAY',
#    'part': ['Data has opened up a phaser and is adapting it. His',
#     "forearm is opened, revealing his arm's inner workings;",
#     'Data is "cannibalizing" his arm for parts to modify the',
#     "phaser. Ard'rian looks on in fascination.",
#     'DATA',
#     'Hyperonic radiation randomizes',
#     'phaser beams. But I believe I',
#     'can improvise a servocircuit which',
#     'will compensate by continuously',
#     'recollimating the output.',
#     "ARD'RIAN",
#     "You're using your own neural",
#     'subprocessors to build a smarter',
#     'phaser.',
#     'DATA',
#     'Essentially correct.',
#     "Ard'rian's impressed. Data completes his work.",
#     "DATA (cont'd)",
#     'Get word to Gosheven. Tell him',
#     'I am coming to the pumping',
#     'station. Tell him I am going',
#     'to destroy the aqueduct.',
#     "Ard'rian is gaping like a carp over this, doesn't know",
#     'what to say. Finally manages:',
#     "ARD'RIAN",
#     "He'll try to stop you --",
#     'DATA',
#     'I sincerely hope so.',
#     "Off Ard'rian's expression:",
#     'CUT TO:']}],
#  '43': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['The Enterprise hanging motionless in space with the',
#     'Sheliak ship.']}],
#  '44': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['As before.',
#     'PICARD',
#     '(to Worf)',
#     'Go to Yellow Alert. Shields up.',
#     'WORF',
#     'Aye, sir.',
#     'PICARD',
#     'Mister Riker, put us nose to nose',
#     'with the Sheliak ship. If she',
#     'makes a move, match it.',
#     'RIKER',
#     'Aye, sir.',
#     'PICARD',
#     'Open a hailing frequency.']},
#   {'header': 'CONTINUED:',
#    'part': ['WORF',
#     "They're not responding, sir.",
#     'PICARD',
#     '(tight control)',
#     "They don't have to answer. They",
#     'just have to listen! Sheliak',
#     'vessel, you will have to go',
#     'through me to get at the colony',
#     'on Tau Cygna Five!']}],
#  '45': [{'header': '', 'part': ['thru\tOMITTED']}],
#  '46': [{'header': '', 'part': []}],
#  '47': [{'header': 'INT. MAIN BRIDGE - CONTINUOUS',
#    'part': ['WORF',
#     'No response.',
#     'PICARD',
#     'Close channel -- and get me that',
#     "treaty! They've been beating us",
#     'over the head with it for three',
#     "days. Let's see if we can't find",
#     'something in it that can be',
#     'turned to our advantage.',
#     'RIKER',
#     "We're going to try to beat them",
#     'at their own game?',
#     'WORF',
#     'The treaty is how long?',
#     'TROI',
#     'Five hundred thousand words.',
#     'WORF',
#     '(glumly)',
#     "We are going to regret Data's",
#     'absence.',
#     'CUT TO:']}],
#  '48': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY (OPTICAL)',
#    'part': ['The square. FOUR MEN armed with rifles stand',
#     'shoulder to shoulder in front of the plant and',
#     'aqueduct. Standing defiant and unarmed, save for the',
#     'probe at his belt, on an upper level is Gosheven.']},
#   {'header': 'CONTINUED:',
#    'part': ['Off to one side are a number of colonists (including',
#     "Ard'rian, Haritath, and Kentor), nervously awaiting",
#     'the outcome.',
#     'Then a PHASER STUN hits one of the armed men; he',
#     'drops. As the others whirl to take aim --']}],
#  '48A': [{'header': 'NEW ANGLE (OPTICAL)',
#    'part': ['A PHASER BEAM sweeps across the line of armed men,',
#     'STUNNING them instantly. No one even gets a shot off.',
#     'Gosheven, astonished, reaches for the probe at his',
#     'belt. Data calmly stands up from his hiding place,',
#     "aims his phaser. Gosheven freezes -- it's futile;",
#     'obviously Data could stun him before he could get',
#     'anywhere near Data.']}],
#  '48B': [{'header': 'WIDER (OPTICAL)',
#    'part': ['as Data steps out into the street, holds his phaser',
#     'up for all to see.',
#     'DATA',
#     'That was the "stun" setting.',
#     'Data switches the setting on the phaser --',
#     "DATA (cont'd)",
#     'This is not.',
#     'Data turns, BLASTS the control panel on the aqueduct.',
#     'A shower of SPARKS. EFFECT as the reaction races up',
#     'the aqueduct. The water stops flowing. Gosheven is',
#     'speechless. Data addresses the colonists:',
#     "DATA (cont'd)",
#     'I could reduce this pumping',
#     'station to a pile of debris...',
#     'but I trust my point is clear.',
#     'I am one android with a single',
#     'weapon. There are hundreds of',
#     'Sheliak on the way... and their',
#     'weapons are far more powerful.',
#     'Data pauses. The colonists are dead silent.']},
#   {'header': 'CONTINUED:',
#    'part': ["DATA (cont'd)",
#     'And the Sheliak may not even offer',
#     'you a target. They can obliterate',
#     'this colony from orbit. You will',
#     'die never having seen the faces',
#     'of your killers.',
#     'Data walks deliberately to one of the stunned',
#     'defenders, picks up the rifle with his free hand, holds',
#     'it out to the group of colonists.',
#     "DATA (cont'd)",
#     'The choice is yours.',
#     'The colonists look at one another. Finally:',
#     'KENTOR',
#     'There are other places -- other',
#     "challenges. It's time to move",
#     'on.',
#     'And Kentor EXITS. One by one, the colonists follow',
#     'him. The mantle of leadership has passed.']}],
#  '48C': [{'header': 'NEW ANGLE',
#    'part': ['Gosheven, slump shouldered, bends and scoops up a',
#     'handful of dirt at the base of the silent pool. Data',
#     'moves to join him.',
#     'GOSHEVEN',
#     'I really was willing to stay and',
#     'die for this.',
#     'DATA',
#     'I know that, but it is just a',
#     'thing, and things can be replaced.',
#     'Lives cannot. Live, rebuild and',
#     'be remembered.',
#     'A long beat. Then Gosheven wipes his hand on his',
#     'pants, and walks back to join his people.']}],
#  '49': [{'header': 'OMITTED', 'part': []}],
#  '50': [{'header': 'ANGLE ON DATA',
#    'part': ['watching Gosheven go. Data looks down at the phaser',
#     'for several moments, then holsters it. He looks up to',
#     "find Ard'rian gazing at him with an expression of pride",
#     'and love.']}],
#  '51': [{'header': 'OMITTED', 'part': []}],
#  '52': [{'header': 'INT. MAIN BRIDGE (OPTICAL)',
#    'part': ['Troi is seated at Science One with Picard hanging over',
#     'her shoulder. Riker and Worf are at Science Two.',
#     'Pages of treaty crawl past on both screens.',
#     'WORF',
#     'This is hopeless. Fighting would',
#     'be preferable.',
#     'A look from Riker.',
#     'PICARD',
#     "That's it.",
#     'He indicates a clause.',
#     'TROI',
#     "I don't follow you, sir.",
#     'PICARD',
#     'Worf, get me the Sheliak.',
#     'WORF',
#     '(just heard the',
#     'reprieve)',
#     'Yes, sir!',
#     'Picard, Riker and Troi return to the command station.',
#     'The strange Sheliak scene replaces a view of the ship.',
#     'PICARD',
#     'Pursuant to paragraph one thousand',
#     'two hundred and ninety I formally',
#     'request third party arbitration',
#     'of our dispute.',
#     'A beat while they look it up.',
#     'SHELIAK',
#     'Agreed.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'And further, pursuant to',
#     'subsection D, three, I name the',
#     'Grizzelas to arbitrate.',
#     'SHELIAK',
#     'Grizzelas?',
#     'Riker glances, puzzled, at Troi.',
#     'RIKER',
#     '(mouths)',
#     'Grizzelas?',
#     'Troi quells him with a look.',
#     'PICARD',
#     'Unfortunately they are currently',
#     'in their hibernation cycle, but',
#     "they'll awaken in six months, and",
#     "then we'll get this matter",
#     'settled. Now, do you want to',
#     'wait... or give me my three weeks?',
#     'SHELIAK',
#     'Absurd. We carry the membership!',
#     'We can brook no delay!',
#     'PICARD',
#     'Then I declare the treaty in',
#     'abeyance!',
#     'SHELIAK',
#     'Wait! Negotiation is --',
#     'Picard gestures to Worf -- cut the transmission. Worf',
#     'obeys. A long beat.',
#     'RIKER',
#     '(smiling)',
#     'You enjoyed that.',
#     'PICARD',
#     "You're damn right.",
#     'WORF',
#     'Captain, they are hailing us.',
#     'Picard studies his nails. Takes a turn around the',
#     'bridge. Settles himself back in the command chair.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['WORF',
#     '(continuing)',
#     'Sir?',
#     'PICARD',
#     '(a beat)',
#     'On screen.',
#     'The Sheliak reappear.',
#     'SHELIAK',
#     'You may have your three weeks,',
#     'Picard of the Enterprise.',
#     'PICARD',
#     '(with careful',
#     'enunciation)',
#     'Thank you.',
#     'The screen returns to a view of the Sheliak ship',
#     'pulling away. Instant release of tension. Suddenly',
#     'the turbolift doors open, and Geordi ENTERS. He is',
#     "looking frazzled. People's expressions reflect the",
#     'thought that "dear God, he did it."',
#     'GEORDI',
#     'Captain, we can do it! We can',
#     'modify the transporters.',
#     'PICARD',
#     'Excellent.',
#     'GEORDI',
#     "It'll take fifteen years, and a",
#     'research team of a hundred --',
#     'PICARD',
#     '(dryly)',
#     'Mister La Forge, I believe we will',
#     'postpone.',
#     'GEORDI',
#     '(with a grin)',
#     'Yes, sir.',
#     'Geordi EXITS.',
#     'CUT TO:']}],
#  '53': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': ['Data is inside the shuttle making preparations for',
#     'departure.',
#     'DATA',
#     'Commander Data to Enterprise.',
#     'I am preparing to leave Tau Cygna',
#     'Five and await rendezvous',
#     'instructions.',
#     "WORF'S COM VOICE",
#     'Acknowledged. Stand by.',
#     "Outside the shuttle, Ard'rian approaches. Data sees",
#     'her, emerges from the shuttle to meet her.',
#     "ARD'RIAN",
#     'Hi.',
#     'DATA',
#     "Hello, Ard'rian.",
#     "ARD'RIAN",
#     'The evacuation plan is going well.',
#     'When the transport ship arrives,',
#     "we'll be ready.",
#     '(a beat)',
#     'You succeeded.',
#     'DATA',
#     'I would not have succeeded without',
#     'your support and insight, and I',
#     'appreciate your assistance.',
#     "ARD'RIAN",
#     "Good. Then you won't forget me?",
#     'DATA',
#     'I am incapable of forgetting.',
#     'I will remember every detail of',
#     'my visit with perfect clarity.',
#     "ARD'RIAN",
#     'But nothing more?',
#     'DATA',
#     'I do not understand.']},
#   {'header': 'CONTINUED:',
#    'part': ["Ard'rian bites the bullet:",
#     "ARD'RIAN",
#     'I guess what I really want to know',
#     'is -- do you have any feelings',
#     'for me?',
#     'DATA',
#     'I have no feelings of any kind.',
#     "Ard'rian is silent.",
#     "ARD'RIAN",
#     "No. Of course you don't.",
#     "Data studies her. She's downcast. Mimicking her",
#     'behavior earlier, he gives her a quick kiss on the',
#     'lips, startling her.',
#     "ARD'RIAN (cont'd)",
#     'What was that for?',
#     'DATA',
#     'You appeared to require it.',
#     "ARD'RIAN",
#     'You observed I was unhappy and',
#     'did what you concluded would make',
#     'me feel better. A purely rational',
#     'deduction.',
#     "She's still downcast.",
#     'DATA',
#     'Have I disappointed you?',
#     "ARD'RIAN",
#     "No, I'm disappointed in myself",
#     '-- for wanting something I know',
#     "I can't have.",
#     '(a beat)',
#     "Data, in so many ways you're",
#     'superior to humans. But you are',
#     'still a machine... without',
#     'emotion.',
#     'DATA',
#     'Yes.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["ARD'RIAN",
#     "It's so easy to believe otherwise.",
#     "It's so easy to read things into",
#     'your behavior... and perceive',
#     'feelings where none exist.',
#     '(a beat)',
#     'Well, I am human and I do have',
#     'feelings... silly though they may',
#     'be at times. I like you, Data.',
#     "You're my favorite android.",
#     'DATA',
#     'But I am the only android you have',
#     'ever met.',
#     "ARD'RIAN",
#     'Rational to the last.']},
#   {'header': 'CONTINUED: (3)',
#    'part': ["And with a smile, Ard'rian EXITS. Data climbs into",
#     'the shuttle, and the door closes.',
#     'CUT TO:']}],
#  '54': [{'header': 'OMITTED', 'part': []}],
#  '55': [{'header': "INT. CAPTAIN'S READY ROOM",
#    'part': ["Picard is listening to a recording of Data's string",
#     'quartet concert in Ten Forward. DOOR CHIME.',
#     'PICARD',
#     'Come.',
#     'Data ENTERS.',
#     "PICARD (cont'd)",
#     'Welcome home, Mister Data. Well',
#     'done.',
#     'DATA',
#     'Thank you, sir.',
#     'PICARD',
#     'The good doctor was kind enough',
#     'to provide me with a recording',
#     'of your concert. Your',
#     'performance shows a good deal',
#     'of feeling.',
#     'DATA',
#     'As I have lately had to remind',
#     'others, I have no feelings.',
#     'PICARD',
#     "That's hard to believe; your",
#     'playing is quite beautiful.',
#     'DATA',
#     'Strictly speaking, it is not',
#     '"my" playing. It is a precise',
#     'imitation of the techniques of',
#     'Jascha Heifetz and Trenka Bron-Ken.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'And is there nothing of Data in',
#     "what I'm hearing?",
#     'Data ponders this.',
#     "PICARD (cont'd)",
#     'You chose the violinists.',
#     'Heifetz and Bron-Ken had',
#     'radically different styles, but',
#     'you combined them -- successfully.',
#     'DATA',
#     'I suppose I have learned to be',
#     'innovative... when necessary, sir.',
#     "Picard nods. He's made his point.",
#     'PICARD',
#     'Mister Data... I look forward to',
#     'your next concert.',
#     "On Data's thoughtful expression, we:"]}]}

# %%
c = replace_character_names(e, chars)
# Out:
# [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)', 'part': ['Moving at impulse near some extraordinarily interesting', 'astronomical object.']}]
# {'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)', 'part': ['Moving at impulse near some extraordinarily interesting', 'astronomical object.']}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-156-ad5554e90cc4> in <module>
# ----> 1 c = replace_character_names(e, chars)
#
# <ipython-input-143-2ff6b78eee04> in replace_character_names(dialogue, characters)
#       7             print(piece)
#       8             parts = piece['part']
# ----> 9             for section, stuff in parts.items():
#      10                 print(section, stuff)
#      11                 name = stuff['name']
#
# AttributeError: 'list' object has no attribute 'items'

# %%
a.sectioned_script()
