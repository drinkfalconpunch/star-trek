# %%
from startrek.script import Script
from collections import defaultdict, deque

# %%
a = Script('tng', script_path='./scripts/tng/Episode 49 - The Ensigns of Command.txt')

# %%
b = a.script.splitlines()

# %%
b

# %%
# TODO: store tab counts in attribute to save time.

def _script_str_or_list(script):
    if isinstance(script, str):
        return script.splitlines()
    elif isinstance(script, list):
        return script
    else:
        raise ValueError('Invalid script.')

def _count_tabs_in_line(line):
    return line.count('\t')

def count_tabs_in_script(script):
    script = _script_str_or_list(script) # may be redundant
    counts = defaultdict(list)
    for line in script:
        tabs = _count_tabs_in_line(line)
        counts[tabs].append(line)
    return counts

def raw_numbered_lines(script):
    script = _script_str_or_list(script)
    return [line for line in script if line and line[0].isdigit()]

def raw_character_list(script):
    script = _script_str_or_list(script) # may be redundant
    c = count_tabs_in_script(script)
    return set(c[5])

def _strip_character_name(character_line):
    name = character_line
    parens = name.find('(')
    if parens != -1:
        name = name[:parens - 1]
    quote = name.find('\'')
    if quote != -1:
        # Taking a stab at possesive names instead of names with random asterisks 
        # in them to sound all scify and bullshit for this project.
        if name[quote+1] == 'S':
            name = name[:quote]
    if 'VOICE' in name:
        name = name.replace('VOICE', '')
    if name.endswith('.'):
        while name.endswith('.'):
            name = name[:-1]
    name = name.replace('"', '').strip()
    
    return name

def processed_character_list(script=None, characters=None):
    if script:
        script = _script_str_or_list(script)
    if not characters:
        characters = raw_character_list(script)
    processed_characters = set()
    for character in characters:
        name = _strip_character_name(character)
        if name:
            processed_characters.add(name)
        
    return processed_characters

def number_header_from_line(line):
    line = line.split()
    return line[0], ' '.join(line[1:])

# def raw_header_lines(script):
#     script = _script_str_or_list(script)
#     c = count_tabs_in_script(script)
#     return c[0]

# def _is_header_line(line):
#     return line[0].isdigit()

# def _is_character_line_from_raw(line):
#     return _count_tabs_in_line(line) == 5

def _remove_star_trek(script):
    # TODO: Fix this
    if STAR_TREK in line:
        del line

def _part_of_script(line, with_page_headers=True):
    tabs = _count_tabs_in_line(line)
    if tabs == 0 and not line[0].isdigit() and with_page_headers:
        # found a page header since it doesn't start with a number
        tabs = -1
    parts = {-1: 'page_header', 0: 'section_header', 1: 'external_action', 3: 'dialogue', 
             4: 'internal_action', 5: 'character_name', 9: 'scene_transition'}
    return parts[tabs]

def cleaned_part_of_script(line, with_page_headers=True):
    PARTS = {
        -1: 'page_header', 
        0: 'section_header', 
        1: 'external_action', 
        3: 'dialogue', 
        4: 'internal_action', 
        5: 'character_name', 
        9: 'scene_transition'
    }
    part = _part_of_script(line, with_page_headers)
    
    return PARTS.get(part, 'Invalid line')(line)
    
def _separate_front_matter(script, remove_blank_lines=True):
    script = _script_str_or_list(script)
    if remove_blank_lines:
        script = list(filter(None, script))
    script = deque(script)
    front_matter = []
    while True:
        try:
            line = script.popleft()
        except IndexError:
            return [], []
        if not line:
            continue
        if line[0].isdigit():
            script.appendleft(line)
            break
        else:
            front_matter.append(line)
    return front_matter, script
    
    
def scr(script):
    front_matter, script = _separate_front_matter(script)
    tabs = []
    for line in script:
        print(_part_of_script(line), line) #tabs.append(_count_tabs_in_line(line))
        
def big_ass_script_dict(script, *, use_front_matter=False, remove_blank_lines=True, with_page_headers=True):
    front_matter, script = _separate_front_matter(script, remove_blank_lines)
    script_dict = {}
    for line in script:
        part = _part_of_script(line, with_page_headers)
        if part == 'page_header' and with_page_headers:
            # We don't want page headers.
            continue
        if part == 'character_name':
            continue
            # while next lines are dialogue
            # attach the dialogue to the character name

# %%
class Dialogue:
    def __init__(self, character_name=None, dialogue=None):
        self.character_name = character_name
        self.dialogue = dialogue
        
    def __repr__(self):
        return f'<class Dialogue - character_name={self.character_name} - dialogue={self.dialogue}>'
    
    def __str__(self):
        return f'{self.character_name}: {self.dialogue}'
    
    def clean_dialogue(self):
        pass
    
class Section:
    def __init__(self, section_number=0, section_name=None):
        self.section_number = section_number
        self.section_name = section_name
        self.dialogue = {}
        self.dialogue_index = 0
    
    def __repr__(self):
        return f'<class Section - section_number={self.section_number} - section_name={self.section_name}>'
    
    def __str__(self):
        return f'{self.section_number}: {self.section_name}'
    
    def add_dialogue(self, dialogue):
        self.dialogue[self.dialogue_index] = dialogue
        self.dialogue_index += 1

# %%
repr(Dialogue('DATA', 'Test'))
# Out:
# '<class Dialogue - character_name=DATA - dialogue=Test>'

# %%
scr(a.script)
# Out:
# section_header 1    EXT. SPACE - THE ENTERPRISE (OPTICAL)
# external_action 	Moving at impulse near some extraordinarily interesting
# external_action 	astronomical object.
# section_header 2    INT. TEN-FORWARD
# external_action 	Present are PICARD, BEVERLY, and TWELVE N.D.
# external_action 	CREWMEMBERS. A VULCAN and ONE WOMAN are seated,
# external_action 	holding their instruments -- a violin and a viola.
# external_action 	O'BRIEN tunes his cello. DATA ENTERS carrying a
# external_action 	violin. He checks at the door, startled to see the
# external_action 	captain. Picard beckons, and Data crosses to him.
# character_name 					DATA
# dialogue 			Captain, Doctor, I am honored by
# dialogue 			your presence, but may I suggest
# dialogue 			you attend the second concert.
# character_name 					BEVERLY
# dialogue 			Why, Data?
# character_name 					DATA
# dialogue 			Ensign Ortiz will perform the
# dialogue 			violin part. My rendition will
# dialogue 			be less enjoyable.
# character_name 					PICARD
# dialogue 			Oh?
# character_name 					DATA
# dialogue 			While I am quite proficient
# dialogue 			Technically, according to my
# dialogue 			fellow performers, I lack soul.
# character_name 					BEVERLY
# dialogue 			Data, telling us why you're going
# dialogue 			to fail before you make the
# dialogue 			attempt is never wise.
# character_name 					DATA
# dialogue 			But is not honesty always the
# dialogue 			preferred choice?
# page_header    STAR TREK: "Ensigns of Command" - REV. 7/14/89 - TEASER   2.
# section_header 2    CONTINUED:
# character_name 					PICARD
# dialogue 			Excessive honesty can be
# dialogue 			disastrous... particularly in a
# dialogue 			commander.
# character_name 					DATA
# internal_action 				(very intrigued)
# dialogue 			Indeed?
# character_name 					PICARD
# dialogue 			Knowing your limitations is one
# dialogue 			thing. Advertising them to a crew
# dialogue 			can damage your ability to lead.
# character_name 					DATA
# dialogue 			Because you lose their respect?
# character_name 					BEVERLY
# dialogue 			No, because you may begin to
# dialogue 			believe in those limitations
# dialogue 			yourself.
# external_action 	Data considers this, then moves to take his place with
# external_action 	the other performers.
# section_header 2A   ANGLE ON PICARD AND BEVERLY
# external_action 	O.s., the string quartet TUNES. There is the SOUND of
# external_action 	the communicator hail.
# character_name 					RIKER'S COM VOICE
# dialogue 			Captain, we're receiving a message
# dialogue 			from the Sheliak Corporate.
# external_action 	Picard reacts with surprise, stands and EXITS. As he
# external_action 	leaves, the quartet starts to PLAY.
# scene_transition 									CUT TO:
# section_header 3    INT. MAIN BRIDGE
# external_action 	Picard ENTERS. RIKER and WORF at their usual stations.
# external_action 	Supernumeraries at CONN and OPS.
# page_header    STAR TREK: "Ensigns of Command" - REV. 7/14/89 - TEASER   3.
# section_header 3    CONTINUED:
# character_name 					WORF
# dialogue 			Origin point of the message
# dialogue 			confirmed. It is from the Shelia
# dialogue 			star system.
# character_name 					RIKER
# dialogue 			The Sheliak have not attempted
# dialogue 			to communicate with the Federation
# dialogue 			for a hundred and eleven years.
# character_name 					PICARD
# dialogue 			On screen.
# section_header 4    ANGLE ON VIEWSCREEN (OPTICAL)
# external_action 	What appears is the text of a treaty. English on one
# external_action 	side, Sheliak on the other. Sheliak is not symbols
# external_action 	as we know them, but rather a pattern of lights. A
# external_action 	recorded message begins.
# character_name 					SHELIAK VOICE
# dialogue 			Federation creatures, there are
# dialogue 			humans on the fifth planet of Tau
# dialogue 			Cygna. This planet was ceded
# dialogue 			to the corporate in section one
# dialogue 			hundred and thirty-three,
# dialogue 			paragraph seventy-seven of the
# dialogue 			Treaty of Armens. We will begin
# dialogue 			settlement of this world in four
# dialogue 			days. Remove the humans.
# external_action 	Riker is up, and heading for Science One.
# character_name 					PICARD
# dialogue 			What the devil --
# character_name 					SHELIAK VOICE
# dialogue 			Federation creatures, there are
# dialogue 			humans on the fifth planet --
# character_name 					PICARD
# dialogue 			Cancel message.
# external_action 	Inquiring look to Riker.
# character_name 					RIKER
# dialogue 			Tau Cygna Five is in the de Laure
# dialogue 			belt -- heavy concentrations of
# dialogue 			hyperonic radiation.
# page_header    STAR TREK: "Ensigns of Command" - REV. 7/14/89 - TEASER   4.
# section_header 4    CONTINUED:
# character_name 					PICARD
# dialogue 			Humans can't survive in such an
# dialogue 			environment. Exposure to
# dialogue 			hyperonic radiation is fatal.
# character_name 					RIKER
# dialogue 			Then the Sheliak are asking us
# dialogue 			to chase ghosts.
# character_name 					PICARD
# dialogue 			No, Number One. The Sheliak
# dialogue 			haven't broken a century of
# dialogue 			silence to send us after phantoms.
# dialogue 			An investigation is in order.
# dialogue 			Set course for Tau Cygna Five.
# external_action 	Off Picard's expression:
# scene_transition 									FADE OUT.
# page_header                        END OF THE TEASER
# page_header    STAR TREK: "Ensigns of Command" REV. 7/19/89 - ACT ONE   5.
# page_header                             ACT ONE
# external_action 	FADE IN:
# section_header 5    EXT. SPACE - THE ENTERPRISE (OPTICAL)
# external_action 	entering orbit around a planet.
# section_header 6    INT. MAIN BRIDGE
# external_action 	Picard, Riker, Data, Beverly and Worf. Supernumerary
# external_action 	at CONN.
# character_name 					WORF
# dialogue 			Human life form readings from the
# dialogue 			planet.
# character_name 					RIKER
# dialogue 			So, the Sheliak weren't
# dialogue 			hallucinating.
# character_name 					PICARD
# dialogue 			Numbers?
# character_name 					WORF
# dialogue 			Impossible to get an accurate
# dialogue 			reading, Captain. The high
# dialogue 			radiation levels are disrupting
# dialogue 			our sensors.
# character_name 					DATA
# dialogue 			Hyperonic radiation also
# dialogue 			interferes with ship's
# dialogue 			transporters; they are now
# dialogue 			inoperable.
# character_name 					WORF
# dialogue 			So are the ship's phasers.
# character_name 					RIKER
# dialogue 			How can humans survive down there?
# character_name 					BEVERLY
# dialogue 			They must have found a way to
# dialogue 			adapt.
# internal_action 				(thinks it over)
# dialogue 			Milan's work in radiation
# dialogue 			sensitivity suggests it's
# dialogue 			possible. Perhaps with extensive
# dialogue 			virotherapy...
# internal_action 				(grimly)
# dialogue 			Until they found the answer, their
# dialogue 			mortality rate must have been
# dialogue 			staggering.
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/18/79 - ACT ONE  6.
# section_header 6    CONTINUED:
# character_name 					PICARD
# dialogue 			Well, whoever they are and however
# dialogue 			they've survived, we've got to
# dialogue 			get them off the planet.
# character_name 					RIKER
# dialogue 			By treaty, this world does belong
# dialogue 			to the Sheliak...
# character_name 					PICARD
# dialogue 			... who are within their rights
# dialogue 			to demand the removal of these
# dialogue 			"trespassers."
# character_name 					RIKER
# dialogue 			And if we don't remove them, the
# dialogue 			Sheliak will.
# character_name 					BEVERLY
# dialogue 			How forcefully?
# character_name 					RIKER
# dialogue 			To the Sheliak, humans are a lower
# dialogue 			life form. They'd have no
# dialogue 			compunctions about exterminating
# dialogue 			the intruders.
# external_action 	Beverly is taken aback. Riker's dead serious.
# character_name 					PICARD
# dialogue 			Mister Data. As you are unaffected
# dialogue 			by hyperonic radiation, you will
# dialogue 			go to the planet via shuttlecraft
# dialogue 			and commence evacuation
# dialogue 			procedures.
# character_name 					DATA
# dialogue 			Aye, sir.
# external_action 	Without a word wasted the android is out of his chair,
# external_action 	and EXITS the bridge.
# character_name 					PICARD
# dialogue 			Any speculation as to what he'll
# dialogue 			find, Number One?
# character_name 					RIKER
# dialogue 			A lost survey ship would be my
# dialogue 			guess. A dozen or so survivors
# dialogue 			at most.
# scene_transition 									CUT TO:
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/17/89 - ACT ONE  6A.
# section_header 7    EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY
# external_action 	Data is outside the shuttle, scanning with his
# external_action 	tricorder.
# section_header 7A   NEW ANGLE
# external_action 	as HARITATH and KENTOR (two male humans) and TWO N.D.
# external_action 	WORKERS cautiously approach the shuttle from the other
# external_action 	side (the shuttle blocks their view of Data).
# character_name 					HARITATH
# internal_action 				(in wonder)
# dialogue 			A shuttlecraft!
# character_name 					KENTOR
# dialogue 			Where's it from?
# character_name 					HARITATH
# dialogue 			Look at the markings. I think
# dialogue 			it's from the Federation.
# external_action 	Data steps into their view from around the shuttle.
# character_name 					DATA
# dialogue 			Hello.
# external_action 	The four humans jump, startled.
# character_name 					HARITATH
# dialogue 			We saw your ship... You're the
# dialogue 			first visitor we've had in...
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/14/89 - ACT ONE  7.
# section_header 7A   CONTINUED: (2)
# character_name 					KENTOR
# dialogue 			The first visitor we've ever had.
# external_action 	They take a closer look at Data.
# character_name 					HARITATH
# dialogue 			You're -- not human.
# character_name 					DATA
# dialogue 			That is correct. I am an android.
# dialogue 			I am Lieutenant Commander Data
# dialogue 			of the Federation Starship
# dialogue 			Enterprise.
# character_name 					HARITATH
# internal_action 				(excited)
# dialogue 			Our great-grandparents were
# dialogue 			citizens of the Federation.
# internal_action 				(realizing)
# dialogue 			But you don't want to waste time
# dialogue 			talking to us...
# character_name 					KENTOR
# dialogue 			You'll want to speak with
# dialogue 			Gosheven. We'll take you to him.
# character_name 					DATA
# dialogue 			Excellent.
# character_name 					HARITATH
# dialogue 			I'm sure the Federation will be
# dialogue 			very proud of us. Wait until you
# dialogue 			see all we've accomplished.
# character_name 					DATA
# dialogue 			And who, precisely, is "we?"
# character_name 					HARITATH
# dialogue 			You don't know? No, I guess you
# dialogue 			wouldn't, would you? We are the
# dialogue 			descendants of the original
# dialogue 			settlers -- from the colony ship
# dialogue 			Artemis.
# scene_transition 									CUT TO:
# section_header 8    INT. ENTERPRISE - MAIN BRIDGE
# external_action 	Picard and Worf in their usual places. Riker at
# external_action 	Science One. Supernumeraries at Conn and Ops.
# page_header    STAR TREK: "Ensigns of Command" REV. 7/19/89 - ACT ONE   8.
# section_header 8    CONTINUED:
# character_name 					RIKER
# dialogue 			Got it. The Artemis, launched one
# dialogue 			hundred forty-two years ago,
# dialogue 			destination Septimis Minor. When
# dialogue 			they failed to check in, Starfleet
# dialogue 			began an extensive search.
# character_name 					PICARD
# dialogue 			What carried the Artemis so far
# dialogue 			off course?
# section_header 9    EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY
# external_action 	Haritath and Kentor wait patiently for Data to finish
# external_action 	him communication.
# character_name 					DATA
# dialogue 			My local informant does not know.
# dialogue 			In the early days survival on Tau
# dialogue 			Cygna Five was more important than
# dialogue 			history.
# section_header 10   INTERCUTS
# character_name 					PICARD
# dialogue 			Understood. How many are there?
# character_name 					DATA
# dialogue 			Approximately fifteen thousand.
# external_action 	Reactions from the bridge crew. Now they really have
# external_action 	got a problem.
# character_name 					RIKER
# internal_action 				(to Picard)
# dialogue 			We've only got three days.
# dialogue 			Without working transporters, we
# dialogue 			couldn't have them out in time.
# character_name 					PICARD
# dialogue 			Shuttles?
# external_action 	Worf does some figuring on his console.
# character_name 					WORF
# dialogue 			Loading all the Enterprise
# dialogue 			shuttlecraft to capacity --
# dialogue 			evacuation would take four weeks,
# dialogue 			four days.
# page_header    STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE   9.
# section_header 10   CONTINUED:
# character_name 					PICARD
# dialogue 			Then we need more time. Mister
# dialogue 			Data, prepare the colonists for
# dialogue 			an evacuation.
# character_name 					DATA'S COM VOICE
# dialogue 			Aye, sir.
# external_action 	Picard closes the com line.
# character_name 					PICARD
# internal_action 				(continuing)
# dialogue 			Mister Worf, get me the Sheliak.
# character_name 					WORF
# dialogue 			Their home world is quite distant,
# dialogue 			Captain. This will take some
# dialogue 			time.
# scene_transition 									CUT TO:
# section_header 11   EXT. PLANET SURFACE - MAIN STREET - DAY
# external_action 	The main pumping station of Tau Cygna V. In the
# external_action 	distance are mountains. A thin white line descends
# external_action 	from the mountains, and as it comes closer we realize
# external_action 	it is an aqueduct. Along the line of the aqueduct are
# external_action 	lush fields, a veritable Garden of Eden, which ends
# external_action 	like a knife-cut and the desert returns. It culminates
# external_action 	in a strange cubistic-shaped purifying station. In a
# external_action 	pool, the water churns into a white froth.
# external_action 	GOSHEVEN, the leader, supervises TWO WORKERS testing
# external_action 	the water in the pool.
# external_action 	Data, Haritath, and Kentor approach.
# character_name 					HARITATH
# dialogue 			Gosheven, look what's come --
# external_action 	Gosheven sees Data, looks him up and down very
# external_action 	carefully. Gosheven's as surprised as Haritath was,
# external_action 	but keeps a lid on it -- Data may represent a threat,
# external_action 	so Gosheven's attempting a poker face.
# character_name 					DATA
# dialogue 			Lieutenant Commander Data of the
# dialogue 			Starship Enterprise.
# page_header    STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT ONE   10.
# section_header 11   CONTINUED:
# character_name 					KENTOR
# dialogue 			He's an android.
# character_name 					GOSHEVEN
# dialogue 			So he is.
# internal_action 				(a beat)
# dialogue 			Well, you're here -- what do you
# dialogue 			want?
# character_name 					DATA
# dialogue 			My mission is to prepare this
# dialogue 			colony for evacuation.
# external_action 	Reactions from the men. Gosheven is calm, almost
# external_action 	amused:
# character_name 					GOSHEVEN
# dialogue 			Why?
# character_name 					DATA
# dialogue 			Because this planet belongs to
# dialogue 			the Sheliak.
# character_name 					GOSHEVEN
# dialogue 			And just who is this Sheliak?
# character_name 					DATA
# dialogue 			The term is plural. The Sheliak
# dialogue 			are an intelligent, non-humanoid
# dialogue 			life form, classification R-3 --
# character_name 					GOSHEVEN
# internal_action 				(interrupting)
# dialogue 			This colony's been here for a
# dialogue 			hundred and forty years -- and
# dialogue 			no one's ever seen a Sheliak.
# dialogue 			I'd say that makes Tau Cygna
# dialogue 			Five our planet. (ALTERNATE:
# dialogue 			ninety years)
# character_name 					DATA
# dialogue 			But the original destination of
# dialogue 			the Artemis was Septimis Minor.
# character_name 					GOSHEVEN
# dialogue 			The guidance systems on the
# dialogue 			Artemis failed -- and sent them
# dialogue 			off course. Far off course.
# dialogue 			Our ancestors were lucky to find
# dialogue 			any place to land.
# page_header    STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE   11.
# section_header 11   CONTINUED: (2)
# character_name 					HARITATH
# dialogue 			And when they did, the radiation
# dialogue 			started killing them.
# character_name 					GOSHEVEN
# dialogue 			Hyperonic radiation took the lives
# dialogue 			of a third of the colonists before
# dialogue 			they learned they could adapt
# dialogue 			to it.
# character_name 					KENTOR
# dialogue 			But the colony survived -- and
# dialogue 			prospered.
# character_name 					GOSHEVEN
# internal_action 				(with pride)
# dialogue 			Look around. We've brought
# dialogue 			water to the desert, built a
# dialogue 			community.
# character_name 					DATA
# dialogue 			Your accomplishments are indeed
# dialogue 			remarkable. However, the
# dialogue 			Sheliak and the Federation
# dialogue 			have a treaty that clearly makes
# dialogue 			this planet Sheliak domain.
# character_name 					GOSHEVEN
# dialogue 			Then change the treaty.
# character_name 					DATA
# dialogue 			That may not be possible. The
# dialogue 			Sheliak wish to colonize this
# dialogue 			planet, and they are unwilling
# dialogue 			to share it with humans.
# character_name 					(MORE)
# page_header    STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE   12.
# section_header 11   CONTINUED: (3)
# character_name 					DATA (cont'd)
# dialogue 			If you are still here when the
# dialogue 			Sheliak colony ship arrives,
# dialogue 			they will eradicate you.
# external_action 	Haritath and Kentor exchange a worried glance, but
# external_action 	Gosheven is unfazed.
# character_name 					HARITATH
# dialogue 			They would kill us all?
# character_name 					DATA
# dialogue 			They have little regard for
# dialogue 			human life. Thus, our most
# dialogue 			sensible course is to prepare a
# dialogue 			contingency plan for the
# dialogue 			evacuation of your people.
# character_name 					GOSHEVEN
# dialogue 			We're not evacuating.
# external_action 	Data is taken aback.
# page_header  STAR TREK: "Ensigns of Command" - REV. 7/18/79 - ACT ONE 12A.
# section_header 11   CONTINUED: (4)
# character_name 					DATA
# dialogue 			Perhaps I have not made myself
# dialogue 			clear.
# character_name 					GOSHEVEN
# dialogue 			Yes, you have. Now let me be
# dialogue 			equally clear. There's going
# dialogue 			to be no evacuation.
# internal_action 				(a beat)
# dialogue 			You've delivered your message --
# dialogue 			so go back to your ship. I have
# dialogue 			work to do.
# external_action 	Gosheven returns to his work on the pumping station.
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/18/89 - ACT ONE  13.
# section_header 11A  ON DATA
# external_action 	as he considers his next move. Then -- an object comes
# external_action 	flying at Data.
# external_action 	With android speed and reflexes, Data catches the
# external_action 	object and examines it. It is an iron bar.
# character_name 					ARD'RIAN (O.S.)
# dialogue 			Nice catch. Wonderful reflexes.
# external_action 	Data turns to see --
# section_header 11B  WIDER
# external_action 	ARD'RIAN, an attractive female, approaches.
# character_name 					ARD'RIAN
# dialogue 			Sorry to test you like that --
# dialogue 			but I was curious.
# character_name 					GOSHEVEN
# internal_action 				(amused)
# dialogue 			Found a new toy, have we, Ardy?
# character_name 					ARD'RIAN
# dialogue 			Toy? This is the most incredible
# dialogue 			android I've ever seen.
# character_name 					DATA
# dialogue 			Have you seen many?
# character_name 					ARD'RIAN
# dialogue 			Actually, no. You're the first.
# character_name 					GOSHEVEN
# internal_action 				(to Ard'rian)
# dialogue 			Only you would get this excited
# dialogue 			over a walking calculator.
# character_name 					ARD'RIAN
# internal_action 				(bridling)
# dialogue 			He's more interesting than
# dialogue 			anything else walking around
# dialogue 			here...
# external_action 	Gosheven CHUCKLES -- he's succeeded in getting under
# external_action 	her skin.
# character_name 					GOSHEVEN
# dialogue 			Depends on what you find
# dialogue 			interesting.
# page_header   STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE  13A.
# section_header 11B  CONTINUED:
# external_action 	Ard'rian's had enough of Gosheven's male conceit. She
# external_action 	moves away, motions for Data to follow. Data does.
# character_name 					ARD'RIAN
# internal_action 				(to Data)
# dialogue 			Cybernetic intelligence fascinates
# dialogue 			me. Are your neural pathways
# dialogue 			duotronic?
# character_name 					DATA
# dialogue 			No -- they are positronic.
# character_name 					ARD'RIAN
# dialogue 			I didn't know that was possible!
# dialogue 			What's your memory capacity? How
# dialogue 			many operations per second? I
# dialogue 			have a million questions...
# character_name 					DATA
# dialogue 			I am afraid I have no time to
# dialogue 			answer one million questions.
# dialogue 			I have a mission to accomplish.
# character_name 					(MORE)
# page_header    STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE   14.
# section_header 11B  CONTINUED: (2)
# character_name 					DATA (cont'd)
# dialogue 			I need to know more about your
# dialogue 			people, and Gosheven seems
# dialogue 			unwilling to talk to me further.
# character_name 					ARD'RIAN
# internal_action 				(extending a hand)
# dialogue 			I'm Ard'rian McKenzie. Perhaps
# dialogue 			I can help you.
# external_action 	As Data shakes her hand, we:
# scene_transition 									CUT TO:
# section_header 12   INT. OBSERVATION LOUNGE
# external_action 	Picard, Riker and TROI are seated as GEORDI, O'Brien
# external_action 	ENTER.
# character_name 					RIKER
# dialogue 			Gentlemen, we're giving you an
# dialogue 			assignment, and the one thing we
# dialogue 			don't want to hear is that it is
# dialogue 			impossible.
# external_action 	Riker defers to Picard. Geordi and O'Brien cast wary
# external_action 	glances at Picard. Now what the hell is he going to
# external_action 	want?
# character_name 					PICARD
# dialogue 			I need the transporters to
# dialogue 			function despite the hyperonic
# dialogue 			radiation.
# character_name 					GEORDI
# dialogue 			Impossi -- Yes, sir.
# external_action 	Geordi and O'Brien EXIT. Riker, Troi and Picard study
# external_action 	each other seriously.
# character_name 					RIKER
# dialogue 			Even if we can get the Sheliak
# dialogue 			to talk to us, they're not likely
# dialogue 			to be accommodating.
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/13/89 - ACT ONE  15.
# section_header 12   CONTINUED:
# character_name 					TROI
# dialogue 			Captain, when the treaty was
# dialogue 			negotiated the Federation sent
# dialogue 			three hundred and seventy-two
# dialogue 			legal experts. What have we got?
# character_name 					PICARD
# dialogue 			Thee... and me.
# external_action 	Off Troi's very dubious expression as we:
# scene_transition 									FADE OUT.
# page_header                         END OF ACT ONE
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/14/89 - ACT TWO  16.
# page_header                             ACT TWO
# external_action 	FADE IN:
# section_header 13   EXT. SPACE - THE ENTERPRISE (OPTICAL)
# external_action 	in orbit around Tau Cygna V.
# section_header 14   INT. MAIN BRIDGE
# external_action 	Picard pacing, Troi seated as they wait for the call.
# external_action 	Worf at his station. Supernumeraries at Conn and Ops.
# character_name 					WORF
# dialogue 			No response.
# character_name 					PICARD
# dialogue 			Try again. Boost signal strength.
# external_action 	Worf makes adjustments.
# character_name 					WORF
# dialogue 			Sheliak Corporate. This is the
# dialogue 			Starship Enterprise. Respond
# dialogue 			please.
# section_header 15   ANGLE ON VIEWSCREEN - (OPTICAL)
# external_action 	as it changes from a view of stars to -- someplace? a
# external_action 	bridge? Wherever the SHELIAK are calling from it is
# external_action 	a disturbing place for humans. Darkness, mirrored
# external_action 	surfaces, and hidden in the shadows a creature who is
# external_action 	decidedly unsettling for the crew. Its shape is
# external_action 	constantly shifting like oozing sludge, and there is
# external_action 	a hint of flickering eyes -- too many eyes.
# character_name 					SHELIAK
# dialogue 			Conversation is neither required
# dialogue 			nor desired.
# external_action 	Picard schools his features into an expression of
# external_action 	polite interest.
# character_name 					PICARD
# dialogue 			Conversation is necessary if we
# dialogue 			are to find a solution to our
# dialogue 			mutual problem.
# character_name 					SHELIAK
# dialogue 			Our involvement in Federation
# dialogue 			illegality is not indicated.
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/14/89 - ACT TWO  17.
# section_header 15   CONTINUED:
# character_name 					PICARD
# dialogue 			Both parties are involved, sir.
# character_name 					SHELIAK
# dialogue 			Remove the humans from the Tau
# dialogue 			Cygna system. Three Earth days
# dialogue 			remain.
# external_action 	Troi leans in, and whispers:
# character_name 					TROI
# dialogue 			Their culture is extremely formal,
# dialogue 			almost ritualistic. An apology
# dialogue 			might smooth matters.
# character_name 					PICARD
# dialogue 			I apologize for our inadvertent
# dialogue 			violation of the treaty.
# character_name 					SHELIAK
# dialogue 			Acknowledged and accepted. Now
# dialogue 			remove the human creatures.
# character_name 					PICARD
# dialogue 			Let us negotiate in good faith...
# character_name 					SHELIAK
# dialogue 			Negotiate to what purpose? The
# dialogue 			treaty is signed.
# character_name 					PICARD
# dialogue 			There is a thriving colony on the
# dialogue 			planet. Rather than uproot these
# dialogue 			people may I offer a compromise?
# character_name 					SHELIAK
# dialogue 			Denied.
# character_name 					PICARD
# dialogue 			Why?!
# character_name 					SHELIAK
# dialogue 			The law is paramount. We are
# dialogue 			entitled.
# character_name 					PICARD
# dialogue 			This is not a law. It is a
# dialogue 			treaty. It is designed to smooth
# dialogue 			relations between peoples. Not
# dialogue 			to act as a strait...
# page_header    STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT TWO   18.
# section_header 15   CONTINUED: (2)
# external_action 	But Picard's talking to a blank screen. The Sheliak
# external_action 	have hung up on him.
# character_name 					PICARD
# dialogue 			... jacket.
# external_action 	Off Picard's annoyed expression.
# scene_transition 									CUT TO:
# section_header 16   OMITTED
# section_header 17   INT. ARD'RIAN'S FRONT ROOM - DAY
# external_action 	A comfortable room constructed of stone with a heavy
# external_action 	beamed ceiling. The furniture is hand hewn, durable
# external_action 	but comfortable. Contrasting with this are various
# external_action 	computer parts and consoles, both assembled and in
# external_action 	pieces, strewn about.
# external_action 	Ard'rian and Data ENTER.
# character_name 					ARD'RIAN
# dialogue 			... you really think we'll have
# dialogue 			to leave Tau Cygna Five?
# character_name 					DATA
# dialogue 			The possibility exists, and
# dialogue 			Gosheven appears unwilling to
# dialogue 			prepare for it. Why?
# page_header    STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT TWO   19.
# section_header 17   CONTINUED:
# character_name 					ARD'RIAN
# dialogue 			Maybe because you're an
# dialogue 			android. I don't think Gosheven
# dialogue 			likes the idea of machines
# dialogue 			ordering him around.
# character_name 					DATA
# dialogue 			I am not ordering him to do
# dialogue 			anything; I am merely trying to
# dialogue 			persuade him that his people
# dialogue 			should prepare to evacuate.
# internal_action 				(thinks)
# dialogue 			Do you believe my suggested
# dialogue 			course of action should be followed?
# character_name 					ARD'RIAN
# dialogue 			Of course.
# character_name 					DATA
# dialogue 			In spite of the fact that I am
# dialogue 			an android?
# character_name 					ARD'RIAN
# dialogue 			Because of that fact. I don't
# dialogue 			have any silly prejudices against
# dialogue 			computers -- I like them.
# external_action 	SHe gestures around the room, a bit apologetically:
# character_name 					ARD'RIAN (cont'd)
# dialogue 			Not that any computer we have is
# dialogue 			half as sophisticated as you...
# external_action 	Data looks at a particularly "primitive" computer:
# character_name 					DATA
# dialogue 			No, I would say not.
# page_header    STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT TWO   20.
# section_header 17   CONTINUED: (2)
# character_name 					ARD'RIAN (cont'd)
# dialogue 			People can be selfish,
# dialogue 			irrational, stubborn, malicious
# dialogue 			-- you name it. But computers
# dialogue 			don't have those failings.
# external_action 	Data follows her logic:
# character_name 					DATA
# dialogue 			You conclude from this that I am
# dialogue 			impartial... hence you accept
# dialogue 			my recommendations.
# external_action 	She nods.
# character_name 					DATA (cont'd)
# dialogue 			Yet Gosheven does not.
# internal_action 				(thinks)
# dialogue 			Perhaps he might reconsider his
# dialogue 			position if someone other than
# dialogue 			myself were to present the
# dialogue 			arguments.
# character_name 					ARD'RIAN
# dialogue 			Well, I'm willing to talk to him,
# dialogue 			but I don't think he'll take me
# dialogue 			seriously.
# internal_action 				(with distaste)
# dialogue 			He finds me attractive -- but I'm
# dialogue 			not interested in him at all.
# dialogue 			So he belittles me to protect his
# dialogue 			ego --
# section_header 18   OMITTED
# section_header 19   NEW ANGLE
# external_action 	as Data's communicator TRILLS. He touches the
# external_action 	insignia.
# character_name 					DATA
# dialogue 			Data, here.
# character_name 					PICARD'S COM VOICE
# dialogue 			The Sheliak won't bargain.
# character_name 					DATA
# dialogue 			Understood.
# page_header  STAR TREK: "Ensigns of Command" - REV. 7/18/89 - ACT TWO 20A.
# section_header 19   CONTINUED:
# character_name 					PICARD'S COM VOICE
# dialogue 			I'm contacting Starfleet to
# dialogue 			arrange for transport. Get those
# dialogue 			people prepared for evacuation.
# dialogue 			We may have to move very quickly.
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/13/89 - ACT TWO  21.
# section_header 19   CONTINUED:
# character_name 					DATA
# dialogue 			Yes, sir.
# external_action 	Data cuts the communication, turns to Ard'rian.
# character_name 					DATA
# dialogue 			We must speak with Gosheven
# dialogue 			immediately.
# external_action 	Ard'rian grabs a coat, and they EXIT.
# scene_transition 									CUT TO:
# section_header 19A  INT. TRANSPORTER ROOM (OPTICAL) (FORMERLY SC. 16)
# external_action 	Geordi, O'Brien and WESLEY have the panels removed
# external_action 	from the wall behind the transporter console. Geordi's
# external_action 	tool box is nearby. Sophisticated tools litter the
# external_action 	floor. Off to the left side of the transporter are
# external_action 	six test objects. The trio is watching tensely as
# external_action 	O'Brien touches the console. A test object
# external_action 	MATERIALIZES looking like swiss cheese. Geordi picks
# external_action 	it up. Riker ENTERS.
# character_name 					RIKER
# dialogue 			Gentlemen, how are you coming?
# internal_action 				(spots the object)
# dialogue 			What the hell is that?
# external_action 	Geordi sets aside the mutilated object.
# character_name 					GEORDI
# dialogue 			Our first attempt.
# character_name 					O'BRIEN
# dialogue 			We recalibrated the transporter
# dialogue 			setting for the tightest possible
# dialogue 			beam.
# character_name 					WESLEY
# dialogue 			But we've got plenty of things
# dialogue 			left to try.
# external_action 	Geordi is studying the test object again.
# character_name 					GEORDI
# dialogue 			There's some really interesting
# dialogue 			residue . . . reminds me of --
# internal_action 				(a beat)
# dialogue 			There's that damn pulsar in the
# dialogue 			neighborhood.
# page_header    STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT TWO   22.
# section_header 19A  CONTINUED:
# character_name 					WESLEY
# dialogue 			Teremi-thorons.
# character_name 					O'BRIEN
# dialogue 			This just got a lot harder.
# character_name 					WESLEY
# dialogue 			They're one of the most elusive
# dialogue 			sub-atomic particles known, and
# dialogue 			they really shred a transporter
# dialogue 			signal.
# character_name 					RIKER
# dialogue 			Thank you, Ensign, I passed
# dialogue 			physics.
# internal_action 				(to Geordi)
# dialogue 			Keep at it. We need those
# dialogue 			transporters.
# external_action 	Riker EXITS.
# character_name 					GEORDI
# dialogue 			We're going to have a lot of fun
# dialogue 			cracking this one.
# scene_transition 									CUT TO:
# section_header 20
# external_action thru	OMITTED
# section_header 21
# section_header 22   EXT. PLANET SURFACE - MAIN STREET - DAY
# external_action 	Gosheven, Data, and Ard'rian are standing near the pool
# external_action 	of water. Gosheven cups some water in a hand.
# character_name 					GOSHEVEN
# dialogue 			See that? Do you have any idea
# dialogue 			what it is? What it means?
# character_name 					DATA
# dialogue 			It is water, a substance composed
# dialogue 			of two atoms of hydrogen --
# character_name 					GOSHEVEN
# dialogue 			It's not water. It's blood and
# dialogue 			sweat -- the result of a hundred
# dialogue 			and forty years of combined
# dialogue 			effort. (ALTERNATE: ninety
# dialogue 			years) This isn't a town.
# character_name 					(MORE)
# page_header    STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT TWO   23.
# section_header 22   CONTINUED:
# character_name 					GOSHEVEN (Cont'd)
# dialogue 			It's a monument to every man,
# dialogue 			woman, and child who has lived
# dialogue 			and died on Tau Cygna Five.
# character_name 					ARD'RIAN
# dialogue 			Gosheven, you're talking nonsense.
# character_name 					GOSHEVEN
# dialogue 			Am I? My grandfather's buried
# dialogue 			on that mountain.
# internal_action 				(points to the distant
# internal_action 				 line of hills)
# dialogue 			He died in a rock slide surveying
# dialogue 			the route for this aqueduct. This
# dialogue 			colony exists because of his
# dialogue 			sacrifice, and the sacrifices of
# dialogue 			thousands of others. No, we're
# dialogue 			not leaving.
# character_name 					DATA
# dialogue 			The Sheliak will not accept humans
# dialogue 			on their planet. And they will
# dialogue 			not hesitate to use force to
# dialogue 			remove you.
# character_name 					GOSHEVEN
# internal_action 				(calmly)
# dialogue 			And we will not hesitate to fight
# dialogue 			back.
# character_name 					DATA
# dialogue 			You cannot win.
# character_name 					GOSHEVEN
# dialogue 			You just don't understand, do you?
# dialogue 			We will not be bullied off our
# dialogue 			land... not by you, and not by
# dialogue 			the Sheliak.
# external_action 	Gosheven whirls and walks away. End of conversation.
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/18/89 - ACT TWO  24.
# section_header 22   CONTINUED: (2)
# character_name 					ARD'RIAN
# internal_action 				(re Gosheven; bitter)
# dialogue 			Stubborn and irrational. Now what
# dialogue 			do we do?
# character_name 					DATA
# dialogue 			Are his sentiments typical among
# dialogue 			the colonists?
# character_name 					ARD'RIAN
# dialogue 			I hope not. Are you thinking
# dialogue 			of bypassing Gosheven and taking
# dialogue 			your case directly to the people?
# character_name 					DATA
# internal_action 				(nods)
# dialogue 			I see no other course of action.
# dialogue 			If I can convince enough people
# dialogue 			of the necessity of leaving --
# character_name 					ARD'RIAN
# internal_action 				(a smile)
# dialogue 			Don't you mean "if we can
# dialogue 			convince?"
# character_name 					DATA
# dialogue 			You are offering assistance?
# external_action 	Ard'rian nods, extends her arm -- c'mon, let's get
# external_action 	going. As they move off:
# scene_transition 									CUT TO:
# section_header 22A  EXT. SPACE - ENTERPRISE (OPTICAL) (FORMERLY SC. 20)
# external_action 	In orbit around Tau Cygna V.
# section_header 22B  INT. CAPTAIN'S READY ROOM (FORMERLY SC. 21)
# external_action 	Picard is pacing rapidly about the office. Riker
# external_action 	ENTERS.
# character_name 					RIKER
# dialogue 			Yes, sir?
# page_header   STAR TREK: "Ensigns of Command" - REV. 7/18/89 - ACT TWO  25.
# section_header 22B  CONTINUED:
# character_name 					PICARD
# dialogue 			Three weeks. Starfleet is profuse
# dialogue 			in their apologies, but it will
# dialogue 			still be three weeks.
# character_name 					RIKER
# dialogue 			Until?
# character_name 					PICARD
# dialogue 			Until the arrival of a colony
# dialogue 			transport ship equipped with
# dialogue 			dedicated personnel shuttles.
# character_name 					RIKER
# dialogue 			We can't wait three weeks.
# character_name 					PICARD
# dialogue 			The Sheliak must agree to extend
# dialogue 			our deadline.
# external_action 	Picard sits in silence for a beat.
# character_name 					PICARD (cont'd)
# dialogue 			If they plan to settle Tau Cygna
# dialogue 			Five two days from now...
# character_name 					RIKER
# dialogue 			... one of their ships must already
# dialogue 			be en route.
# character_name 					PICARD
# internal_action 				(decides)
# dialogue 			We're going to intercept that
# dialogue 			ship.
# character_name 					RIKER
# dialogue 			The Sheliak may interpret that
# dialogue 			as a hostile act.
# character_name 					PICARD
# dialogue 			We have to take the risk.
# external_action 	Off Picard's determined expression as we:
# scene_transition 									FADE OUT.
# page_header                         END OF ACT TWO
# page_header  STAR TREK: "Ensigns of Command" - REV. 7/18/89 - ACT THREE 26.
# page_header                            ACT THREE
# external_action 	FADE IN:
# section_header 23   INT. OBSERVATION LOUNGE
# external_action 	Riker pacing slowly, looking out at the stars.
# character_name 					RIKER
# dialogue 			The Enterprise is going to try
# dialogue 			to intercept the Sheliak colony
# dialogue 			ship. Your job ... well, you know
# dialogue 			your job.
# scene_transition 									CUT TO:
# section_header 24   EXT. PLANET SURFACE - MAIN STREET - DAY
# external_action 	Data standing alone in an archway.
# character_name 					DATA
# dialogue 			Commander, in human parlance, I do
# dialogue 			not believe I can "get the job
# dialogue 			done." My training has prepared
# dialogue 			me for starship command duties.
# dialogue 			As a cultural contact I am
# dialogue 			proving to be less than exemplary.
# section_header 25   INTERCUTS
# character_name 					RIKER
# dialogue 			What's the situation?
# character_name 					DATA
# dialogue 			Their leader has rejected my
# dialogue 			counsel. He denies the logic of
# dialogue 			my arguments and talks of
# dialogue 			structures they have built.
# character_name 					RIKER
# dialogue 			Then try something else.
# character_name 					DATA
# dialogue 			I have. In the last three hours
# dialogue 			and eight minutes, I have spoken
# dialogue 			to fifty-six colonists. Ten
# dialogue 			refused to believe a threat
# dialogue 			exists. Twenty-two favored
# dialogue 			staying and fighting the Sheliak.
# page_header STAR TREK: "Ensigns of Command" - REV. 7/14/89 - ACT THREE26A.
# section_header 25   CONTINUED:
# character_name 					RIKER
# internal_action 				(more to himself)
# dialogue 			I don't have time for this.
# character_name 					DATA
# dialogue 			Sixteen preferred negotiation or
# dialogue 			some form of passive resistance.
# dialogue 			Only eight were willing to
# dialogue 			consider evacuation. And of those
# dialogue 			eight --
# page_header   STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT THREE  27.
# section_header 25   CONTINUED: (2)
# character_name 					RIKER
# internal_action 				(cutting him)
# dialogue 			Data, I can't help you -- I don't
# dialogue 			know these people; I haven't
# dialogue 			talked to them. You have. Use
# dialogue 			that fancy positronic brain of
# dialogue 			yours -- and carry out your
# dialogue 			mission.
# external_action 	Ard'rian walks up to join the android, politely keeps
# external_action 	a few paces away to let him complete his "phone call"
# external_action 	with privacy.
# character_name 					DATA
# dialogue 			If I do not succeed, how violent
# dialogue 			is the Sheliak reaction likely
# dialogue 			to be?
# character_name 					RIKER
# dialogue 			The treaty is the only thing which
# dialogue 			kept them from eradicating the
# dialogue 			colony the moment they discovered
# dialogue 			it.
# character_name 					DATA
# dialogue 			Ah.
# character_name 					RIKER
# dialogue 			"Ah" is right. The lives of
# dialogue 			fifteen thousand people are riding
# dialogue 			on you. You'd better get
# dialogue 			innovative. Riker out.
# external_action 	Data gazes into space, thinking. Ard'rian steps up.
# external_action 	Her mood is upbeat.
# character_name 					ARD'RIAN
# dialogue 			Data -- we're having an effect.
# dialogue 			So many people are asking
# dialogue 			questions about the Sheliak that
# dialogue 			Gosheven's called a public
# dialogue 			meeting.
# page_header   STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT THREE  28.
# section_header 25   CONTINUED: (3)
# character_name 					DATA
# dialogue 			Is there any indication that
# dialogue 			Gosheven has changed his position?
# character_name 					ARD'RIAN
# dialogue 			No. But a meeting will give you
# dialogue 			the chance to present your
# dialogue 			recommendations.
# character_name 					DATA
# dialogue 			First, will Gosheven allow me to
# dialogue 			speak? Second, even if he does,
# dialogue 			what good will it do? So far,
# dialogue 			my attempts at persuasion have
# dialogue 			been ineffective.
# external_action 	Ard'rian looks at him with compassion for a beat --
# external_action 	then suddenly gives Data a quick kiss on the lips.
# character_name 					DATA (cont'd)
# dialogue 			Why did you do that?
# character_name 					ARD'RIAN
# dialogue 			You appeared to need it.
# character_name 					DATA
# dialogue 			Among humans, a kiss normally
# dialogue 			serves to seal a friendship or
# dialogue 			to indicate support, attraction,
# dialogue 			affection.
# external_action 	Ard'rian nods.
# page_header   STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT THREE  29.
# section_header 25   CONTINUED: (4)
# character_name 					DATA (cont'd)
# dialogue 			In this context, I would assume
# dialogue 			your intention was to express
# dialogue 			support.
# character_name 					ARD'RIAN
# dialogue 			That was my primary motivation.
# external_action 	The implication being that there were secondary
# external_action 	motivations. But if Data is aware of the implication,
# external_action 	he makes no sign.
# character_name 					ARD'RIAN (cont'd)
# dialogue 			You don't really understand human
# dialogue 			behavior, do you?
# character_name 					DATA
# dialogue 			That is something of an
# dialogue 			understatement.
# character_name 					ARD'RIAN
# internal_action 				(sighs)
# dialogue 			Sometimes I don't either.
# dialogue 			androids are a lot more rational.
# character_name 					DATA
# dialogue 			Thus far, that quality has not
# dialogue 			helped me accomplish my mission.
# character_name 					ARD'RIAN
# dialogue 			A rational argument isn't always
# dialogue 			enough. Maybe to be more
# dialogue 			persuasive, you need to use a
# dialogue 			little reverse psychology.
# character_name 					DATA
# internal_action 				(accessing)
# dialogue 			Elicit a desired behavior by
# dialogue 			advocating its opposite?
# internal_action 				(a beat)
# dialogue 			That implies deception, does it
# dialogue 			not?
# character_name 					ARD'RIAN
# dialogue 			A little. But if it helps us
# dialogue 			get our point across...
# page_header   STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT THREE  30.
# section_header 25   CONTINUED: (5)
# character_name 					DATA
# internal_action 				(considers)
# dialogue 			Perhaps this is a situation in
# dialogue 			which excessive honesty is
# dialogue 			detrimental.
# external_action 	As they walk off:
# scene_transition 									CUT TO:
# section_header 26   EXT. SPACE - THE ENTERPRISE (OPTICAL)
# external_action 	Travelling at warp speed.
# section_header 27   INT. TRANSPORTER ROOM
# external_action 	As before, except there are more high tech tools and
# external_action 	equipment lying about. Geordi is lifting yet another
# external_action 	trashed test object off the platform. He holds it
# external_action 	mutely out to Wesley and O'Brien who stare dully at
# external_action 	this latest failure. There are now four intact
# external_action 	objects and three blasted ones. Picard ENTERS.
# character_name 					PICARD
# internal_action 				(you will get it done)
# dialogue 			How are we progressing, Mister
# dialogue 			La Forge?
# character_name 					GEORDI
# internal_action 				(it's impossible)
# dialogue 			About like you'd expect.
# character_name 					PICARD
# internal_action 				(get it done)
# dialogue 			Splendid.
# external_action 	Picard EXITS.
# character_name 					WESLEY
# internal_action 				(wearily)
# dialogue 			He wants the impossible.
# page_header  STAR TREK: "Ensigns of Command" - REV. 7/14/89 - ACT THREE 31.
# section_header 27   CONTINUED:
# character_name 					GEORDI
# internal_action 				(with a grin)
# dialogue 			That's the short definition for
# dialogue 			"captain."
# external_action 	Geordi and O'Brien have already returned to work. Wes
# external_action 	looks at them bemused, then shrugs and pitches in.
# scene_transition 									CUT TO:
# section_header 28   EXT. PLANET SURFACE - MAIN STREET - DAY
# external_action 	A large horseshoe-shaped amphitheater with a place for
# external_action 	the engineers and Gosheven. A number of citizens --
# external_action 	including Haritath and Kentor -- have turned out for
# external_action 	the debate so the place is filled. In the b.g. is the
# external_action 	aqueduct purifying plant.
# character_name 					GOSHEVEN
# dialogue 			You've all heard about the android
# dialogue 			Starfleet sent here, and you've
# dialogue 			been discussing why he's come.
# external_action 	Data and Ard'rian ENTER. Gosheven ignores them.
# character_name 					GOSHEVEN (cont'd)
# dialogue 			I called this meeting to replace
# dialogue 			misinformation with cold, hard
# dialogue 			fact.
# external_action 	The colonists are craning their necks to look at Data.
# external_action 	Gosheven realizes Data's presence can't be ignored. He
# external_action 	strides over to confront Data.
# character_name 					GOSHEVEN
# dialogue 			Leave. Immediately.
# character_name 					DATA
# dialogue 			I wish to speak.
# character_name 					GOSHEVEN
# dialogue 			No.
# character_name 					DATA
# internal_action 				(loud, for the crowd's
# internal_action 				 benefit)
# dialogue 			You deny me the opportunity to
# dialogue 			address the assemblage?
# page_header   STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT THREE  32.
# section_header 28   CONTINUED:
# character_name 					GOSHEVEN
# dialogue 			This meeting is not for outsiders.
# character_name 					DATA
# dialogue 			Do you consider your position so
# dialogue 			weak that it cannot withstand
# dialogue 			debate?
# character_name 					HARITATH
# dialogue 			Let him talk.
# external_action 	MURMURS of assent from the crowd. Gosheven gives a
# external_action 	terse nod. In a sense Data's called him a coward and
# external_action 	he has to stand up to this city slicker, this outsider.
# external_action 	Data steps front and center. In an effort to pull this
# external_action 	off, he attempts to use human rhetorical devices
# external_action 	(timing, dynamics, inflection, gestures, etc.) -- but,
# external_action 	as there's no real passion behind them, they come off
# external_action 	as studied and not quite sincere. A good performance,
# external_action 	but still a performance.
# character_name 					DATA
# dialogue 			You know of the Sheliak threat.
# dialogue 			Starfleet wishes to evacuate you
# dialogue 			for your own protection.
# dialogue 			Gosheven has decided otherwise.
# dialogue 			That is his right. And I will
# dialogue 			not waste time trying to reverse
# dialogue 			that decision.
# external_action 	Surprised reactions from the crowd. This is not what
# external_action 	they expected to hear.
# character_name 					DATA (cont'd)
# dialogue 			I admire your conviction in the
# dialogue 			face of certain defeat. Your
# dialogue 			effort will be valiant, though
# dialogue 			doomed. Still, when you die,
# dialogue 			you will die for land and honor.
# section_header 29   ANGLE ON
# external_action 	The crowd. Data's starting to get a reaction. People
# external_action 	are beginning to eye each other nervously. It's one
# external_action 	thing to thumb your nose at a distant enemy, quite
# external_action 	another to talk about dying.
# page_header   STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT THREE  33.
# section_header 30   ANGLE ON DATA
# ...
# section_header 43   EXT. SPACE - THE ENTERPRISE (OPTICAL)
# external_action 	The Enterprise hanging motionless in space with the
# external_action 	Sheliak ship.
# section_header 44   INT. MAIN BRIDGE
# external_action 	As before.
# character_name 					PICARD
# internal_action 				(to Worf)
# dialogue 			Go to Yellow Alert. Shields up.
# character_name 					WORF
# dialogue 			Aye, sir.
# character_name 					PICARD
# dialogue 			Mister Riker, put us nose to nose
# dialogue 			with the Sheliak ship. If she
# dialogue 			makes a move, match it.
# character_name 					RIKER
# dialogue 			Aye, sir.
# character_name 					PICARD
# dialogue 			Open a hailing frequency.
# page_header        STAR TREK: "Ensigns of Command" REV. 7/17/89 - ACT FIVE      50.
# section_header 44   CONTINUED:
# character_name 					WORF
# dialogue 			They're not responding, sir.
# character_name 					PICARD
# internal_action 				(tight control)
# dialogue 			They don't have to answer. They
# dialogue 			just have to listen! Sheliak
# dialogue 			vessel, you will have to go
# dialogue 			through me to get at the colony
# dialogue 			on Tau Cygna Five!
# section_header 45
# external_action thru	OMITTED
# section_header 46
# section_header 47   INT. MAIN BRIDGE - CONTINUOUS
# character_name 					WORF
# dialogue 			No response.
# character_name 					PICARD
# dialogue 			Close channel -- and get me that
# dialogue 			treaty! They've been beating us
# dialogue 			over the head with it for three
# dialogue 			days. Let's see if we can't find
# dialogue 			something in it that can be
# dialogue 			turned to our advantage.
# character_name 					RIKER
# dialogue 			We're going to try to beat them
# dialogue 			at their own game?
# character_name 					WORF
# dialogue 			The treaty is how long?
# character_name 					TROI
# dialogue 			Five hundred thousand words.
# character_name 					WORF
# internal_action 				(glumly)
# dialogue 			We are going to regret Data's
# dialogue 			absence.
# scene_transition 									CUT TO:
# section_header 48   EXT. PLANET SURFACE - MAIN STREET - DAY (OPTICAL)
# external_action 	The square. FOUR MEN armed with rifles stand
# external_action 	shoulder to shoulder in front of the plant and
# external_action 	aqueduct. Standing defiant and unarmed, save for the
# external_action 	probe at his belt, on an upper level is Gosheven.
# page_header        STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT FIVE      51.
# section_header 48   CONTINUED:
# external_action 	Off to one side are a number of colonists (including
# external_action 	Ard'rian, Haritath, and Kentor), nervously awaiting
# external_action 	the outcome.
# external_action 	Then a PHASER STUN hits one of the armed men; he
# external_action 	drops. As the others whirl to take aim --
# section_header 48A  NEW ANGLE (OPTICAL)
# external_action 	A PHASER BEAM sweeps across the line of armed men,
# external_action 	STUNNING them instantly. No one even gets a shot off.
# external_action 	Gosheven, astonished, reaches for the probe at his
# external_action 	belt. Data calmly stands up from his hiding place,
# external_action 	aims his phaser. Gosheven freezes -- it's futile;
# external_action 	obviously Data could stun him before he could get
# external_action 	anywhere near Data.
# section_header 48B  WIDER (OPTICAL)
# external_action 	as Data steps out into the street, holds his phaser
# external_action 	up for all to see.
# character_name 					DATA
# dialogue 			That was the "stun" setting.
# external_action 	Data switches the setting on the phaser --
# character_name 					DATA (cont'd)
# dialogue 			This is not.
# external_action 	Data turns, BLASTS the control panel on the aqueduct.
# external_action 	A shower of SPARKS. EFFECT as the reaction races up
# external_action 	the aqueduct. The water stops flowing. Gosheven is
# external_action 	speechless. Data addresses the colonists:
# character_name 					DATA (cont'd)
# dialogue 			I could reduce this pumping
# dialogue 			station to a pile of debris...
# dialogue 			but I trust my point is clear.
# dialogue 			I am one android with a single
# dialogue 			weapon. There are hundreds of
# dialogue 			Sheliak on the way... and their
# dialogue 			weapons are far more powerful.
# external_action 	Data pauses. The colonists are dead silent.
# page_header        STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT FIVE      52.
# section_header 48B  CONTINUED:
# character_name 					DATA (cont'd)
# dialogue 			And the Sheliak may not even offer
# dialogue 			you a target. They can obliterate
# dialogue 			this colony from orbit. You will
# dialogue 			die never having seen the faces
# dialogue 			of your killers.
# external_action 	Data walks deliberately to one of the stunned
# external_action 	defenders, picks up the rifle with his free hand, holds
# external_action 	it out to the group of colonists.
# character_name 					DATA (cont'd)
# dialogue 			The choice is yours.
# external_action 	The colonists look at one another. Finally:
# character_name 					KENTOR
# dialogue 			There are other places -- other
# dialogue 			challenges. It's time to move
# dialogue 			on.
# external_action 	And Kentor EXITS. One by one, the colonists follow
# external_action 	him. The mantle of leadership has passed.
# section_header 48C  NEW ANGLE
# external_action 	Gosheven, slump shouldered, bends and scoops up a
# external_action 	handful of dirt at the base of the silent pool. Data
# external_action 	moves to join him.
# character_name 					GOSHEVEN
# dialogue 			I really was willing to stay and
# dialogue 			die for this.
# character_name 					DATA
# dialogue 			I know that, but it is just a
# dialogue 			thing, and things can be replaced.
# dialogue 			Lives cannot. Live, rebuild and
# dialogue 			be remembered.
# external_action 	A long beat. Then Gosheven wipes his hand on his
# external_action 	pants, and walks back to join his people.
# section_header 49   OMITTED
# page_header        STAR TREK: "Ensigns of Command" REV. 7/13/89 - ACT FIVE      53.
# section_header 50   ANGLE ON DATA
# external_action 	watching Gosheven go. Data looks down at the phaser
# external_action 	for several moments, then holsters it. He looks up to
# external_action 	find Ard'rian gazing at him with an expression of pride
# external_action 	and love.
# section_header 51   OMITTED
# section_header 52   INT. MAIN BRIDGE (OPTICAL)
# external_action 	Troi is seated at Science One with Picard hanging over
# external_action 	her shoulder. Riker and Worf are at Science Two.
# external_action 	Pages of treaty crawl past on both screens.
# character_name 					WORF
# dialogue 			This is hopeless. Fighting would
# dialogue 			be preferable.
# external_action 	A look from Riker.
# character_name 					PICARD
# dialogue 			That's it.
# external_action 	He indicates a clause.
# character_name 					TROI
# dialogue 			I don't follow you, sir.
# character_name 					PICARD
# dialogue 			Worf, get me the Sheliak.
# character_name 					WORF
# internal_action 				(just heard the
# internal_action 				 reprieve)
# dialogue 			Yes, sir!
# external_action 	Picard, Riker and Troi return to the command station.
# external_action 	The strange Sheliak scene replaces a view of the ship.
# character_name 					PICARD
# dialogue 			Pursuant to paragraph one thousand
# dialogue 			two hundred and ninety I formally
# dialogue 			request third party arbitration
# dialogue 			of our dispute.
# external_action 	A beat while they look it up.
# character_name 					SHELIAK
# dialogue 			Agreed.
# page_header        STAR TREK: "Ensigns of Command" REV. 7/13/89 - ACT FIVE      54.
# section_header 52   CONTINUED:
# character_name 					PICARD
# dialogue 			And further, pursuant to
# dialogue 			subsection D, three, I name the
# dialogue 			Grizzelas to arbitrate.
# character_name 					SHELIAK
# dialogue 			Grizzelas?
# external_action 	Riker glances, puzzled, at Troi.
# character_name 					RIKER
# internal_action 				(mouths)
# dialogue 			Grizzelas?
# external_action 	Troi quells him with a look.
# character_name 					PICARD
# dialogue 			Unfortunately they are currently
# dialogue 			in their hibernation cycle, but
# dialogue 			they'll awaken in six months, and
# dialogue 			then we'll get this matter
# dialogue 			settled. Now, do you want to
# dialogue 			wait... or give me my three weeks?
# character_name 					SHELIAK
# dialogue 			Absurd. We carry the membership!
# dialogue 			We can brook no delay!
# character_name 					PICARD
# dialogue 			Then I declare the treaty in
# dialogue 			abeyance!
# character_name 					SHELIAK
# dialogue 			Wait! Negotiation is --
# external_action 	Picard gestures to Worf -- cut the transmission. Worf
# external_action 	obeys. A long beat.
# character_name 					RIKER
# internal_action 				(smiling)
# dialogue 			You enjoyed that.
# character_name 					PICARD
# dialogue 			You're damn right.
# character_name 					WORF
# dialogue 			Captain, they are hailing us.
# external_action 	Picard studies his nails. Takes a turn around the
# external_action 	bridge. Settles himself back in the command chair.
# page_header        STAR TREK: "Ensigns of Command" REV. 7/13/89 - ACT FIVE      55.
# section_header 52   CONTINUED: (2)
# character_name 					WORF
# internal_action 				(continuing)
# dialogue 			Sir?
# character_name 					PICARD
# internal_action 				(a beat)
# dialogue 			On screen.
# external_action 	The Sheliak reappear.
# character_name 					SHELIAK
# dialogue 			You may have your three weeks,
# dialogue 			Picard of the Enterprise.
# character_name 					PICARD
# internal_action 				(with careful
# internal_action 				 enunciation)
# dialogue 			Thank you.
# external_action 	The screen returns to a view of the Sheliak ship
# external_action 	pulling away. Instant release of tension. Suddenly
# external_action 	the turbolift doors open, and Geordi ENTERS. He is
# external_action 	looking frazzled. People's expressions reflect the
# external_action 	thought that "dear God, he did it."
# character_name 					GEORDI
# dialogue 			Captain, we can do it! We can
# dialogue 			modify the transporters.
# character_name 					PICARD
# dialogue 			Excellent.
# character_name 					GEORDI
# dialogue 			It'll take fifteen years, and a
# dialogue 			research team of a hundred --
# character_name 					PICARD
# internal_action 				(dryly)
# dialogue 			Mister La Forge, I believe we will
# dialogue 			postpone.
# character_name 					GEORDI
# internal_action 				(with a grin)
# dialogue 			Yes, sir.
# external_action 	Geordi EXITS.
# scene_transition 									CUT TO:
# page_header        STAR TREK: "Ensigns of Command" REV. 7/14/89 - ACT FIVE      56.
# section_header 53   EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY
# external_action 	Data is inside the shuttle making preparations for
# external_action 	departure.
# character_name 					DATA
# dialogue 			Commander Data to Enterprise.
# dialogue 			I am preparing to leave Tau Cygna
# dialogue 			Five and await rendezvous
# dialogue 			instructions.
# character_name 					WORF'S COM VOICE
# dialogue 			Acknowledged. Stand by.
# external_action 	Outside the shuttle, Ard'rian approaches. Data sees
# external_action 	her, emerges from the shuttle to meet her.
# character_name 					ARD'RIAN
# dialogue 			Hi.
# character_name 					DATA
# dialogue 			Hello, Ard'rian.
# character_name 					ARD'RIAN
# dialogue 			The evacuation plan is going well.
# dialogue 			When the transport ship arrives,
# dialogue 			we'll be ready.
# internal_action 				(a beat)
# dialogue 			You succeeded.
# character_name 					DATA
# dialogue 			I would not have succeeded without
# dialogue 			your support and insight, and I
# dialogue 			appreciate your assistance.
# character_name 					ARD'RIAN
# dialogue 			Good. Then you won't forget me?
# character_name 					DATA
# dialogue 			I am incapable of forgetting.
# dialogue 			I will remember every detail of
# dialogue 			my visit with perfect clarity.
# character_name 					ARD'RIAN
# dialogue 			But nothing more?
# character_name 					DATA
# dialogue 			I do not understand.
# page_header        STAR TREK: "Ensigns of Command" REV. 7/14/89 - ACT FIVE      57.
# section_header 53   CONTINUED:
# external_action 	Ard'rian bites the bullet:
# character_name 					ARD'RIAN
# dialogue 			I guess what I really want to know
# dialogue 			is -- do you have any feelings
# dialogue 			for me?
# character_name 					DATA
# dialogue 			I have no feelings of any kind.
# external_action 	Ard'rian is silent.
# character_name 					ARD'RIAN
# dialogue 			No. Of course you don't.
# external_action 	Data studies her. She's downcast. Mimicking her
# external_action 	behavior earlier, he gives her a quick kiss on the
# external_action 	lips, startling her.
# character_name 					ARD'RIAN (cont'd)
# dialogue 			What was that for?
# character_name 					DATA
# dialogue 			You appeared to require it.
# character_name 					ARD'RIAN
# dialogue 			You observed I was unhappy and
# dialogue 			did what you concluded would make
# dialogue 			me feel better. A purely rational
# dialogue 			deduction.
# external_action 	She's still downcast.
# character_name 					DATA
# dialogue 			Have I disappointed you?
# character_name 					ARD'RIAN
# dialogue 			No, I'm disappointed in myself
# dialogue 			-- for wanting something I know
# dialogue 			I can't have.
# internal_action 				(a beat)
# dialogue 			Data, in so many ways you're
# dialogue 			superior to humans. But you are
# dialogue 			still a machine... without
# dialogue 			emotion.
# character_name 					DATA
# dialogue 			Yes.
# page_header        STAR TREK: "Ensigns of Command" REV. 7/14/89 - ACT FIVE     57A.
# section_header 53   CONTINUED: (2)
# character_name 					ARD'RIAN
# dialogue 			It's so easy to believe otherwise.
# dialogue 			It's so easy to read things into
# dialogue 			your behavior... and perceive
# dialogue 			feelings where none exist.
# internal_action 				(a beat)
# dialogue 			Well, I am human and I do have
# dialogue 			feelings... silly though they may
# dialogue 			be at times. I like you, Data.
# dialogue 			You're my favorite android.
# character_name 					DATA
# dialogue 			But I am the only android you have
# dialogue 			ever met.
# character_name 					ARD'RIAN
# dialogue 			Rational to the last.
# page_header        STAR TREK: "Ensigns of Command" REV. 7/17/89 - ACT FIVE      58.
# external_action 53   CONTINUED:	(3)
# external_action 	And with a smile, Ard'rian EXITS. Data climbs into
# external_action 	the shuttle, and the door closes.
# scene_transition 									CUT TO:
# section_header 54   OMITTED
# section_header 55   INT. CAPTAIN'S READY ROOM
# external_action 	Picard is listening to a recording of Data's string
# external_action 	quartet concert in Ten Forward. DOOR CHIME.
# character_name 					PICARD
# dialogue 			Come.
# external_action 	Data ENTERS.
# character_name 					PICARD (cont'd)
# dialogue 			Welcome home, Mister Data. Well
# dialogue 			done.
# character_name 					DATA
# dialogue 			Thank you, sir.
# character_name 					PICARD
# dialogue 			The good doctor was kind enough
# dialogue 			to provide me with a recording
# dialogue 			of your concert. Your
# dialogue 			performance shows a good deal
# dialogue 			of feeling.
# character_name 					DATA
# dialogue 			As I have lately had to remind
# dialogue 			others, I have no feelings.
# character_name 					PICARD
# dialogue 			That's hard to believe; your
# dialogue 			playing is quite beautiful.
# character_name 					DATA
# dialogue 			Strictly speaking, it is not
# dialogue 			"my" playing. It is a precise
# dialogue 			imitation of the techniques of
# dialogue 			Jascha Heifetz and Trenka Bron-Ken.
# page_header        STAR TREK: "Ensigns of Command" REV. 7/17/89 - ACT FIVE      59.
# section_header 55   CONTINUED:
# character_name 					PICARD
# dialogue 			And is there nothing of Data in
# dialogue 			what I'm hearing?
# external_action 	Data ponders this.
# character_name 					PICARD (cont'd)
# dialogue 			You chose the violinists.
# dialogue 			Heifetz and Bron-Ken had
# dialogue 			radically different styles, but
# dialogue 			you combined them -- successfully.
# character_name 					DATA
# dialogue 			I suppose I have learned to be
# dialogue 			innovative... when necessary, sir.
# external_action 	Picard nods. He's made his point.
# character_name 					PICARD
# dialogue 			Mister Data... I look forward to
# dialogue 			your next concert.
# external_action 	On Data's thoughtful expression, we:
# section_header 56   OMITTED
# scene_transition 									FADE OUT.
# page_header                         END OF ACT FIVE
# page_header                             THE END

# %%
_separate_front_matter(_separate_front_matter(a.script))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-237-4068cd17ddfb> in <module>
# ----> 1 _separate_front_matter(_separate_front_matter(a.script))
#
# <ipython-input-232-be33ce930297> in _separate_front_matter(script, remove_blank_lines)
#      85
#      86 def _separate_front_matter(script, remove_blank_lines=True):
# ---> 87     script = _script_str_or_list(script)
#      88     if remove_blank_lines:
#      89         script = list(filter(None, script))
#
# <ipython-input-232-be33ce930297> in _script_str_or_list(script)
#       7         return script
#       8     else:
# ----> 9         raise ValueError('Invalid script.')
#      10
#      11 def _count_tabs_in_line(line):
#
# ValueError: Invalid script.

# %%
raw_numbered_lines(a.script)

# %%
isinstance(a.script, str)
# Out:
# True

# %%
processed_character_list(script=a.script)
# Out:
# {"ARD'RIAN",
#  'BEVERLY',
#  'DATA',
#  'GEORDI',
#  'GOSHEVEN',
#  'HARITATH',
#  'KENTOR',
#  "O'BRIEN",
#  'PICARD',
#  'RIKER',
#  'SHELIAK',
#  'TROI',
#  'WESLEY',
#  'WORF'}

# %%
d = count_tabs_in_script(b)

# %%
set(d.keys())
# Out:
# {0}

# %%
actions = d[1]

# %%
text = d[3]

# %%
internal_actions = d[4]

# %%
names = d[5]

# %%
transitions = d[9]

# %%
find_numbered_lines(b)
# Out:
# ['1    EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#  '2    INT. TEN-FORWARD',
#  '2    CONTINUED:',
#  '2A   ANGLE ON PICARD AND BEVERLY',
#  '3    INT. MAIN BRIDGE',
#  '3    CONTINUED:',
#  '4    ANGLE ON VIEWSCREEN (OPTICAL)',
#  '4    CONTINUED:',
#  '5    EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#  '6    INT. MAIN BRIDGE',
#  '6    CONTINUED:',
#  '7    EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#  '7A   NEW ANGLE',
#  '7A   CONTINUED: (2)',
#  '8    INT. ENTERPRISE - MAIN BRIDGE',
#  '8    CONTINUED:',
#  '9    EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#  '10   INTERCUTS',
#  '10   CONTINUED:',
#  '11   EXT. PLANET SURFACE - MAIN STREET - DAY',
#  '11   CONTINUED:',
#  '11   CONTINUED: (2)',
#  '11   CONTINUED: (3)',
#  '11   CONTINUED: (4)',
#  '11A  ON DATA',
#  '11B  WIDER',
#  '11B  CONTINUED:',
#  '11B  CONTINUED: (2)',
#  '12   INT. OBSERVATION LOUNGE',
#  '12   CONTINUED:',
#  '13   EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#  '14   INT. MAIN BRIDGE',
#  '15   ANGLE ON VIEWSCREEN - (OPTICAL)',
#  '15   CONTINUED:',
#  '15   CONTINUED: (2)',
#  '16   OMITTED',
#  "17   INT. ARD'RIAN'S FRONT ROOM - DAY",
#  '17   CONTINUED:',
#  '17   CONTINUED: (2)',
#  '18   OMITTED',
#  '19   NEW ANGLE',
#  '19   CONTINUED:',
#  '19   CONTINUED:',
#  '19A  INT. TRANSPORTER ROOM (OPTICAL) (FORMERLY SC. 16)',
#  '19A  CONTINUED:',
#  '20',
#  '21',
#  '22   EXT. PLANET SURFACE - MAIN STREET - DAY',
#  '22   CONTINUED:',
#  '22   CONTINUED: (2)',
#  '22A  EXT. SPACE - ENTERPRISE (OPTICAL) (FORMERLY SC. 20)',
#  "22B  INT. CAPTAIN'S READY ROOM (FORMERLY SC. 21)",
#  '22B  CONTINUED:',
#  '23   INT. OBSERVATION LOUNGE',
#  '24   EXT. PLANET SURFACE - MAIN STREET - DAY',
#  '25   INTERCUTS',
#  '25   CONTINUED:',
#  '25   CONTINUED: (2)',
#  '25   CONTINUED: (3)',
#  '25   CONTINUED: (4)',
#  '25   CONTINUED: (5)',
#  '26   EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#  '27   INT. TRANSPORTER ROOM',
#  '27   CONTINUED:',
#  '28   EXT. PLANET SURFACE - MAIN STREET - DAY',
#  '28   CONTINUED:',
#  '29   ANGLE ON',
#  '30   ANGLE ON DATA',
#  '31   ANGLE ON GOSHEVEN',
#  '31   CONTINUED:',
#  '31   CONTINUED: (2)',
#  '32   ANGLE ON DATA',
#  '33   INT. TRANSPORTER ROOM (OPTICAL)',
#  '33A  EXT. PLANET SURFACE - MAIN STREET - DAY',
#  '33A  CONTINUED:',
#  '33A  CONTINUED: (2)',
#  '34',
#  '35',
#  '36   EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#  "37   INT. CAPTAIN'S READY ROOM (OPTICAL)",
#  '37   CONTINUED:',
#  '37   CONTINUED: (2)',
#  '38   INT. MAIN BRIDGE',
#  '39   ANGLE ON VIEWSCREEN (OPTICAL)',
#  '39   CONTINUED:',
#  "40   INT. ARD'RIAN'S LIVING ROOM - DAY",
#  '40   CONTINUED:',
#  '40   CONTINUED: (2)',
#  '40A  OMITTED',
#  '40B  NEW ANGLE (OPTICAL)',
#  '40B  CONTINUED:',
#  "40C  ON ARD'RIAN",
#  '40D  WIDER',
#  '41   INT. SHELIAK SHIP (OPTICAL)',
#  '41   CONTINUED:',
#  '41   CONTINUED: (2)',
#  '42   INT. MAIN BRIDGE (OPTICAL)',
#  "42A  INT. ARD'RIAN'S LIVING ROOM",
#  '42A  CONTINUED:',
#  '42B  INT. SHUTTLECRAFT - CYGNA FIVE - DAY',
#  '43   EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#  '44   INT. MAIN BRIDGE',
#  '44   CONTINUED:',
#  '45',
#  '46',
#  '47   INT. MAIN BRIDGE - CONTINUOUS',
#  '48   EXT. PLANET SURFACE - MAIN STREET - DAY (OPTICAL)',
#  '48   CONTINUED:',
#  '48A  NEW ANGLE (OPTICAL)',
#  '48B  WIDER (OPTICAL)',
#  '48B  CONTINUED:',
#  '48C  NEW ANGLE',
#  '49   OMITTED',
#  '50   ANGLE ON DATA',
#  '51   OMITTED',
#  '52   INT. MAIN BRIDGE (OPTICAL)',
#  '52   CONTINUED:',
#  '52   CONTINUED: (2)',
#  '53   EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#  '53   CONTINUED:',
#  '53   CONTINUED: (2)',
#  '53   CONTINUED:\t(3)',
#  '54   OMITTED',
#  "55   INT. CAPTAIN'S READY ROOM",
#  '55   CONTINUED:',
#  '56   OMITTED']

# %%
a.dialogue

# %%
a.extract_dialogue_from_script()

# %%
from collections import defaultdict
from itertools import tee
import re

# %%
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

# %%
def _number_header_from_line(line):
    line = line.split()
    return line[0], ' '.join(line[1:])

# %%
def get_between_indices(s, begin, end):
    return s[begin:end]

# %%
sections, indices = section_headers(a.dialogue)

# %%
sections

# %%
from collections import deque
import copy
import itertools

# %%
b = sectioned_script(a.dialogue, indices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-4f074f67842e> in <module>
# ----> 1 b = sectioned_script(a.dialogue, indices)
#
# NameError: name 'sectioned_script' is not defined

# %%
chars = get_characters(a.dialogue)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-417702689e02> in <module>
# ----> 1 chars = get_characters(a.dialogue)
#
# <ipython-input-9-493419766679> in get_characters(dialogue)
#      49
#      50     characters = set()
# ---> 51     for line in dialogue:
#      52         matches = re.findall(regex_character, line.strip())
#      53         if matches:
#
# TypeError: 'NoneType' object is not iterable

# %%
chars
# Out:
# {"ARD'RIAN",
#  'BEVERLY',
#  'DATA',
#  'GEORDI',
#  'GOSHEVEN',
#  'HARITATH',
#  'KENTOR',
#  "O'BRIEN",
#  'PICARD',
#  'RIKER',
#  'SHELIAK',
#  'TROI',
#  'WESLEY',
#  'WORF'}

# %%
def section_headers(dialogue):
    '''Returns the section headers from a block of dialogue and their
    respective line numbers in said block. Run once.'''

    sections = {}
    indices = []
    _regex_number = r'^\d{1,3}?[a-zA-Z]{0,1}'
    regex_number = re.compile(_regex_number)

    for index, line in enumerate(dialogue):
        words = line.split()
        if not words:
            continue
        try:
            int(words[0][0])
            number = words[0]
            name = " ".join(words[1:]).replace(':', '')
            if not name:
                name = 'OMITTED'
            # Corner case check if year is in section number
            # if not re.findall(regex_number, number):
            #     print(number, re.findall(regex_number, number))
            if len(number) > 3 and number[3].isdigit():
                continue
            # Check for same section number
            if number in sections.keys():
                sections[number].append(name)
            else:
                sections[number] = [name]
            indices.append(index)
        except:
            continue
    return sections, indices

def get_characters(dialogue):
    """
    Gets a set of all the characters with dialogue from a sectioned script.
    """
    ACT = ['ACT']
    END = ['END OF']
    NUMBERS = ['ONE', 'TWO', 'THREE', 'FOUR', 'FIVE', 'SIX', 'SEVEN', 'EIGHT', 'NINE', 'TEN']
    SKIPS = ['THE END', 'END OF TEASER', 'FADE OUT', 'FADE OUT.', 'FADE OUT:', 'FADE IN', 
             'FADE IN:', 'FADE IN.', 'END OF THE TEASER', 'ENTER.', 'ENTERS.']
    for combo in itertools.product(END, ACT, NUMBERS):
        SKIPS.append(' '.join(combo))
    for combo in itertools.product(ACT, NUMBERS):
        SKIPS.append(' '.join(combo))
    _regex_character = r"^\s*([A-Z-.'\"() ]+)\s*$"
    regex_character = re.compile(_regex_character)

    characters = set()
    for line in dialogue:
        matches = re.findall(regex_character, line.strip())
        if matches:
            for match in matches:
                # Yay random corner cases!
                if match in SKIPS:
                    continue
                parens = match.find('(')
                quote = match.find('\'')
                if parens != -1:
                    match = match[:parens - 1]
                if quote != -1:
                    # Taking a stab at possesive names instead of names with random asterisks 
                    # in them to sound all scify and bullshit for this project.
                    if match[quote+1] == 'S':
                        match = match[:quote]
                if 'VOICE' in match:
                    match = match.replace('VOICE', '')
                if match.endswith('.'):
                    while match.endswith('.'):
                        match = match[:-1]
                if match.startswith('('):
                    continue
                if match.endswith(')'):
                    continue
                characters.add(match.replace('"', '').strip())

    return characters

def _separate_dialogue_block(block, characters):
    """
    Takes a list of lines of dialogue and character names and returns a dictionary
    with each character's lines Dict[name, text].
    """
    block = deque(block)
    dialogue = {}
    temp = ''

    # Check if any initial lines are text and save them.
    while True:
        if not block:
            break
        line = block.popleft()
        if not line.isupper():
            # First line is dialogue/text
            temp = f"{temp} {line}"
        else:
            block.appendleft(line)
            break

    if temp:
        dialogue[0] = dict(name='None', text=temp.strip())
        index = 1
    else:
        index = 0

    name = ''
    text = ''
    for line in block:
        if not line:
            continue
        if line.isupper():
            # Denotes a character's name on it's own line, indicating dialogue.
            if name == line:
                # Character continuing dialogue.
                continue
            else:
                # Different character dialogue.
                if name:
                    # New dialogue. Push dialogue into dict and start over.
                    name = name=_character_name(name, characters)
                    dialogue[index] = dict(name=name, text=text.strip())
                    name = line
                    text = ''
                    index += 1
                else:
                    # Character name
                    name = line
                    continue
        else:
            # Dialogue line
            text = f"{text} {line}"

    return dialogue

def _character_name(input_name, characters):
    """
    Cleans up character names. E.g., remove posession or voice over notes.
    """
    for character in characters:
        if character in input_name:
            return character
    return 'None'

def separate_lines_by_character(dialogue, characters=None):
#     temp_sectioned = _sectioned_script(dialogue, indices)
#     sectioned = copy.deepcopy(temp_sectioned)
    if not characters:
        characters = get_characters(dialogue)
    sectioned = copy.deepcopy(dialogue)
    for number, section in dialogue.items():
        for index, part in enumerate(section):
            block = part['part']
            if block:
                block = _separate_dialogue_block(block, characters)
#                 print(sectioned[number][index])
                sectioned[number][index]['part'] = block
            else:
                del sectioned[number]
                continue
            
    return sectioned

def _sectioned_script(dialogue, header_indices):
    """
    Separates dialogue into sections using the indices of the headers found in the dialogue list of lines.
    """
    sections = {}
    index_pairs = pairwise(header_indices)

    for pair in index_pairs:
        # Get the lines between two indices
        part = get_between_indices(dialogue, *pair)
        # The first line is the header of the section
        head = part.pop(0)
        # The header is composed of a number and text.
        number, header = _number_header_from_line(head)
        # Make a dictionary with the header and text.
        d = dict(header=header, part=part)
        # Check if the section number already exists.
        if number in sections.keys():
            sections[number].append(d)
        else:
            sections[number] = [d]

    return sections

# %%
# a -> extract dialogue into list (extract_dialogue_from_script) -> get headers and locations (section_headers) 
# -> split dialogue into sections (_sectioned_script) -> split lines by characters

# %%
q = _sectioned_script(a.dialogue, indices)

# %%
r = _sectioned_script(a.dialogue, indices)

# %%
get_characters(a.dialogue)
# Out:
# {"ARD'RIAN",
#  'BEVERLY',
#  'DATA',
#  'GEORDI',
#  'GOSHEVEN',
#  'HARITATH',
#  'KENTOR',
#  "O'BRIEN",
#  'PICARD',
#  'RIKER',
#  'SHELIAK',
#  'TROI',
#  'WESLEY',
#  'WORF'}

# %%
j = separate_lines_by_character(q, get_characters(a.dialogue))
# Out:
# {'GOSHEVEN', "O'BRIEN", 'DATA', 'KENTOR', 'RIKER', 'BEVERLY', 'WORF', 'TROI', 'PICARD', 'GEORDI', 'WESLEY', 'HARITATH', 'SHELIAK', "ARD'RIAN"}

# %%
y = separate_lines_by_character(q, chars)

# %%
a.script.splitlines()
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '                STAR TREK: THE NEXT GENERATION ',
#  '                              ',
#  '                   "The Ensigns of Command" ',
#  '                          #40273-149 ',
#  '                              ',
#  '                          Written by ',
#  '                         H. B. Savage ',
#  '                              ',
#  '                          Directed by ',
#  '                          Cliff Bole ',
#  '',
#  '',
#  'THE WRITING CREDITS MAY NOT BE FINAL AND SHOULD NOT BE USED',
#  'FOR PUBLICITY OR ADVERTISING PURPOSES WITHOUT FIRST CHECKING',
#  'WITH THE TELEVISION LEGAL DEPARTMENT.',
#  '',
#  'Copyright 1989 Paramount Pictures Corporation. All Rights',
#  'Reserved. This script is not for publication or',
#  'reproduction. No one is authorized to dispose of same. If',
#  'lost or destroyed, please notify the Script Department.',
#  '',
#  '                    3RD REVISED FINAL DRAFT',
#  ' ',
#  '                         JULY 13, 1989',
#  '',
#  '   STAR TREK: "The Ensigns of Command" - REV. 7/14/89 - CAST ',
#  '',
#  '                STAR TREK: THE NEXT GENERATION ',
#  '                   "The Ensigns of Command" ',
#  '',
#  '                             CAST                               ',
#  '                              ',
#  '                PICARD                 SHELIAK',
#  '                RIKER                  ',
#  "                DATA                   ARD'RIAN",
#  '                BEVERLY                GOSHEVEN',
#  '                TROI                   HARITATH',
#  '                GEORDI                 KENTOR',
#  '                WORF                   ',
#  '                WESLEY                 Non-Speaking',
#  '                                         ENGINEERS (2)',
#  "                O'BRIEN                  OTHER LOCALS (26)",
#  '   ',
#  '                Non-Speaking           ',
#  '                  A VULCAN VIOLINIST     YOUNG BOY (age 12)',
#  "                  A WOMAN VIOLIST        BOY'S MOTHER",
#  '                  N.D. CREWMEMBERS (12)  ',
#  '                  SUPERNUMERARIES (CONN & OPS)',
#  '',
#  '   STAR TREK: "The Ensigns of Command" - REV. 7/14/89 - SETS ',
#  '',
#  '                STAR TREK: THE NEXT GENERATION ',
#  '                   "The Ensigns of Command" ',
#  '                      ',
#  '                             SETS ',
#  '',
#  '            INTERIORS                  EXTERIORS',
#  '          ',
#  '            USS ENTERPRISE             USS ENTERPRISE',
#  '              MAIN BRIDGE',
#  '              TEN FORWARD              TAU CYGNA FIVE',
#  '              OBSERVATION LOUNGE         FRONTIER TOWN',
#  '              TRANSPORTER ROOM',
#  "              CAPTAIN'S READY ROOM       TOWN SQUARE",
#  '                                         AQUEDUCT',
#  '                                         PUMPING STATION',
#  "            TAU CYGNA FIVE               DATA'S SHUTTLE",
#  "              ARD'RIAN'S FRONT ROOM",
#  '                                       SHELIAK WARSHIP',
#  '            SHELIAK WARSHIP',
#  '',
#  '  STAR TREK: "Ensigns of Command" - REV. 7/14/89 PRONUNCIATION ',
#  '',
#  '                STAR TREK: THE NEXT GENERATION ',
#  '                   "The Ensigns of Command" ',
#  '                 ',
#  '                      PRONUNCIATION GUIDE ',
#  '',
#  "              ARD'RIAN               ARD-ree-an",
#  '              ARMENS                 ARE-mens',
#  '              ARTEMIS                ARE-tih-mus',
#  '              GOSHEVEN               GO-sheh-ven',
#  '              HARITATH               HAH-ree-tath',
#  '              KENTOR                 KEN-tor',
#  '              SHELIA                 Shell-LEE-ah',
#  '              SHELIAK                SHELL-lee-awk',
#  "              S'SMARITH              Ss-sa-MAH-rith",
#  '              TEREMI-BOSONS          Teh-REH-mee-BOH-suns',
#  '',
#  '   STAR TREK: "Ensigns of Command" - REV. 7/13/89 - TEASER   1.',
#  '',
#  '                STAR TREK: THE NEXT GENERATION                  ',
#  '                   "The Ensigns of Command"                        ',
#  '                            TEASER                              ',
#  '',
#  '\tFADE IN:',
#  '',
#  '1    EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#  '',
#  '\tMoving at impulse near some extraordinarily interesting',
#  '\tastronomical object.',
#  '',
#  '2    INT. TEN-FORWARD',
#  '',
#  '\tPresent are PICARD, BEVERLY, and TWELVE N.D.',
#  '\tCREWMEMBERS. A VULCAN and ONE WOMAN are seated,',
#  '\tholding their instruments -- a violin and a viola.',
#  "\tO'BRIEN tunes his cello. DATA ENTERS carrying a",
#  '\tviolin. He checks at the door, startled to see the',
#  '\tcaptain. Picard beckons, and Data crosses to him.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tCaptain, Doctor, I am honored by',
#  '\t\t\tyour presence, but may I suggest',
#  '\t\t\tyou attend the second concert.',
#  '',
#  '\t\t\t\t\tBEVERLY',
#  '\t\t\tWhy, Data?',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tEnsign Ortiz will perform the',
#  '\t\t\tviolin part. My rendition will',
#  '\t\t\tbe less enjoyable.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tOh?',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tWhile I am quite proficient',
#  '\t\t\tTechnically, according to my',
#  '\t\t\tfellow performers, I lack soul.',
#  '',
#  '\t\t\t\t\tBEVERLY',
#  "\t\t\tData, telling us why you're going",
#  '\t\t\tto fail before you make the',
#  '\t\t\tattempt is never wise.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tBut is not honesty always the',
#  '\t\t\tpreferred choice?',
#  '',
#  '   STAR TREK: "Ensigns of Command" - REV. 7/14/89 - TEASER   2.',
#  '',
#  '2    CONTINUED:',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tExcessive honesty can be',
#  '\t\t\tdisastrous... particularly in a',
#  '\t\t\tcommander.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\t\t(very intrigued)',
#  '\t\t\tIndeed?',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tKnowing your limitations is one',
#  '\t\t\tthing. Advertising them to a crew',
#  '\t\t\tcan damage your ability to lead.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tBecause you lose their respect?',
#  '',
#  '\t\t\t\t\tBEVERLY',
#  '\t\t\tNo, because you may begin to',
#  '\t\t\tbelieve in those limitations',
#  '\t\t\tyourself.',
#  '',
#  '\tData considers this, then moves to take his place with',
#  '\tthe other performers.',
#  '',
#  '2A   ANGLE ON PICARD AND BEVERLY',
#  '',
#  '\tO.s., the string quartet TUNES. There is the SOUND of',
#  '\tthe communicator hail.',
#  '',
#  "\t\t\t\t\tRIKER'S COM VOICE",
#  "\t\t\tCaptain, we're receiving a message",
#  '\t\t\tfrom the Sheliak Corporate.',
#  '',
#  '\tPicard reacts with surprise, stands and EXITS. As he',
#  '\tleaves, the quartet starts to PLAY.',
#  '',
#  '\t\t\t\t\t\t\t\t\tCUT TO:',
#  '',
#  '3    INT. MAIN BRIDGE',
#  '',
#  '\tPicard ENTERS. RIKER and WORF at their usual stations.',
#  '\tSupernumeraries at CONN and OPS.',
#  '',
#  '   STAR TREK: "Ensigns of Command" - REV. 7/14/89 - TEASER   3.',
#  '',
#  '3    CONTINUED:',
#  '',
#  '\t\t\t\t\tWORF',
#  '\t\t\tOrigin point of the message',
#  '\t\t\tconfirmed. It is from the Shelia',
#  '\t\t\tstar system.',
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\tThe Sheliak have not attempted',
#  '\t\t\tto communicate with the Federation',
#  '\t\t\tfor a hundred and eleven years.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tOn screen.',
#  '',
#  '4    ANGLE ON VIEWSCREEN (OPTICAL)',
#  '',
#  '\tWhat appears is the text of a treaty. English on one',
#  '\tside, Sheliak on the other. Sheliak is not symbols',
#  '\tas we know them, but rather a pattern of lights. A',
#  '\trecorded message begins.',
#  '',
#  '\t\t\t\t\tSHELIAK VOICE',
#  '\t\t\tFederation creatures, there are',
#  '\t\t\thumans on the fifth planet of Tau',
#  '\t\t\tCygna. This planet was ceded',
#  '\t\t\tto the corporate in section one',
#  '\t\t\thundred and thirty-three,',
#  '\t\t\tparagraph seventy-seven of the',
#  '\t\t\tTreaty of Armens. We will begin',
#  '\t\t\tsettlement of this world in four',
#  '\t\t\tdays. Remove the humans.',
#  '',
#  '\tRiker is up, and heading for Science One.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tWhat the devil --',
#  '',
#  '\t\t\t\t\tSHELIAK VOICE',
#  '\t\t\tFederation creatures, there are',
#  '\t\t\thumans on the fifth planet --',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tCancel message.',
#  '',
#  '\tInquiring look to Riker.',
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\tTau Cygna Five is in the de Laure',
#  '\t\t\tbelt -- heavy concentrations of',
#  '\t\t\thyperonic radiation.',
#  '',
#  '   STAR TREK: "Ensigns of Command" - REV. 7/14/89 - TEASER   4.',
#  '',
#  '4    CONTINUED:',
#  '',
#  '\t\t\t\t\tPICARD',
#  "\t\t\tHumans can't survive in such an",
#  '\t\t\tenvironment. Exposure to',
#  '\t\t\thyperonic radiation is fatal.',
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\tThen the Sheliak are asking us',
#  '\t\t\tto chase ghosts.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tNo, Number One. The Sheliak',
#  "\t\t\thaven't broken a century of",
#  '\t\t\tsilence to send us after phantoms.',
#  '\t\t\tAn investigation is in order.',
#  '\t\t\tSet course for Tau Cygna Five.',
#  '',
#  "\tOff Picard's expression:",
#  '',
#  '\t\t\t\t\t\t\t\t\tFADE OUT.',
#  '',
#  '                       END OF THE TEASER                        ',
#  '',
#  '   STAR TREK: "Ensigns of Command" REV. 7/19/89 - ACT ONE   5.',
#  '',
#  '                            ACT ONE                             ',
#  '',
#  '\tFADE IN:',
#  '',
#  '5    EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#  '',
#  '\tentering orbit around a planet.',
#  '',
#  '6    INT. MAIN BRIDGE',
#  '',
#  '\tPicard, Riker, Data, Beverly and Worf. Supernumerary',
#  '\tat CONN.',
#  '',
#  '\t\t\t\t\tWORF',
#  '\t\t\tHuman life form readings from the',
#  '\t\t\tplanet.',
#  '',
#  '\t\t\t\t\tRIKER',
#  "\t\t\tSo, the Sheliak weren't",
#  '\t\t\thallucinating.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tNumbers?',
#  '',
#  '\t\t\t\t\tWORF',
#  '\t\t\tImpossible to get an accurate',
#  '\t\t\treading, Captain. The high',
#  '\t\t\tradiation levels are disrupting',
#  '\t\t\tour sensors.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tHyperonic radiation also',
#  "\t\t\tinterferes with ship's",
#  '\t\t\ttransporters; they are now',
#  '\t\t\tinoperable.',
#  '',
#  '\t\t\t\t\tWORF',
#  "\t\t\tSo are the ship's phasers.",
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\tHow can humans survive down there?',
#  '',
#  '\t\t\t\t\tBEVERLY',
#  '\t\t\tThey must have found a way to',
#  '\t\t\tadapt.',
#  '\t\t\t\t(thinks it over)',
#  "\t\t\tMilan's work in radiation",
#  "\t\t\tsensitivity suggests it's",
#  '\t\t\tpossible. Perhaps with extensive',
#  '\t\t\tvirotherapy...',
#  '\t\t\t\t(grimly)',
#  '\t\t\tUntil they found the answer, their',
#  '\t\t\tmortality rate must have been',
#  '\t\t\tstaggering.',
#  '',
#  '  STAR TREK: "Ensigns of Command" - REV. 7/18/79 - ACT ONE  6.',
#  '',
#  '6    CONTINUED:',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tWell, whoever they are and however',
#  "\t\t\tthey've survived, we've got to",
#  '\t\t\tget them off the planet.',
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\tBy treaty, this world does belong',
#  '\t\t\tto the Sheliak...',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\t... who are within their rights',
#  '\t\t\tto demand the removal of these',
#  '\t\t\t"trespassers."',
#  '',
#  '\t\t\t\t\tRIKER',
#  "\t\t\tAnd if we don't remove them, the",
#  '\t\t\tSheliak will.',
#  '',
#  '\t\t\t\t\tBEVERLY',
#  '\t\t\tHow forcefully?',
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\tTo the Sheliak, humans are a lower',
#  "\t\t\tlife form. They'd have no",
#  '\t\t\tcompunctions about exterminating',
#  '\t\t\tthe intruders.',
#  '',
#  "\tBeverly is taken aback. Riker's dead serious.",
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tMister Data. As you are unaffected',
#  '\t\t\tby hyperonic radiation, you will',
#  '\t\t\tgo to the planet via shuttlecraft',
#  '\t\t\tand commence evacuation',
#  '\t\t\tprocedures.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tAye, sir.',
#  '',
#  '\tWithout a word wasted the android is out of his chair,',
#  '\tand EXITS the bridge.',
#  '',
#  '\t\t\t\t\tPICARD',
#  "\t\t\tAny speculation as to what he'll",
#  '\t\t\tfind, Number One?',
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\tA lost survey ship would be my',
#  '\t\t\tguess. A dozen or so survivors',
#  '\t\t\tat most.',
#  '',
#  '\t\t\t\t\t\t\t\t\tCUT TO:',
#  '',
#  '  STAR TREK: "Ensigns of Command" - REV. 7/17/89 - ACT ONE  6A.',
#  '',
#  '7    EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#  '',
#  '\tData is outside the shuttle, scanning with his',
#  '\ttricorder.',
#  '',
#  '7A   NEW ANGLE',
#  '',
#  '\tas HARITATH and KENTOR (two male humans) and TWO N.D.',
#  '\tWORKERS cautiously approach the shuttle from the other',
#  '\tside (the shuttle blocks their view of Data).',
#  '',
#  '\t\t\t\t\tHARITATH',
#  '\t\t\t\t(in wonder)',
#  '\t\t\tA shuttlecraft!',
#  '',
#  '\t\t\t\t\tKENTOR',
#  "\t\t\tWhere's it from?",
#  '',
#  '\t\t\t\t\tHARITATH',
#  '\t\t\tLook at the markings. I think',
#  "\t\t\tit's from the Federation.",
#  '',
#  '\tData steps into their view from around the shuttle.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tHello.',
#  '',
#  '\tThe four humans jump, startled.',
#  '',
#  '\t\t\t\t\tHARITATH',
#  "\t\t\tWe saw your ship... You're the",
#  "\t\t\tfirst visitor we've had in...",
#  '',
#  '  STAR TREK: "Ensigns of Command" - REV. 7/14/89 - ACT ONE  7.',
#  '',
#  '7A   CONTINUED: (2)',
#  '',
#  '\t\t\t\t\tKENTOR',
#  "\t\t\tThe first visitor we've ever had.",
#  '',
#  '\tThey take a closer look at Data.',
#  '',
#  '\t\t\t\t\tHARITATH',
#  "\t\t\tYou're -- not human.",
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tThat is correct. I am an android.',
#  '\t\t\tI am Lieutenant Commander Data',
#  '\t\t\tof the Federation Starship',
#  '\t\t\tEnterprise.',
#  '',
#  '\t\t\t\t\tHARITATH',
#  '\t\t\t\t(excited)',
#  '\t\t\tOur great-grandparents were',
#  '\t\t\tcitizens of the Federation.',
#  '\t\t\t\t(realizing)',
#  "\t\t\tBut you don't want to waste time",
#  '\t\t\ttalking to us...',
#  '',
#  '\t\t\t\t\tKENTOR',
#  "\t\t\tYou'll want to speak with",
#  "\t\t\tGosheven. We'll take you to him.",
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tExcellent.',
#  '',
#  '\t\t\t\t\tHARITATH',
#  "\t\t\tI'm sure the Federation will be",
#  '\t\t\tvery proud of us. Wait until you',
#  "\t\t\tsee all we've accomplished.",
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tAnd who, precisely, is "we?"',
#  '',
#  '\t\t\t\t\tHARITATH',
#  "\t\t\tYou don't know? No, I guess you",
#  "\t\t\twouldn't, would you? We are the",
#  '\t\t\tdescendants of the original',
#  '\t\t\tsettlers -- from the colony ship',
#  '\t\t\tArtemis.',
#  '',
#  '\t\t\t\t\t\t\t\t\tCUT TO:',
#  '',
#  '8    INT. ENTERPRISE - MAIN BRIDGE',
#  '',
#  '\tPicard and Worf in their usual places. Riker at',
#  '\tScience One. Supernumeraries at Conn and Ops.',
#  '',
#  '   STAR TREK: "Ensigns of Command" REV. 7/19/89 - ACT ONE   8.',
#  '',
#  '8    CONTINUED:',
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\tGot it. The Artemis, launched one',
#  '\t\t\thundred forty-two years ago,',
#  '\t\t\tdestination Septimis Minor. When',
#  '\t\t\tthey failed to check in, Starfleet',
#  '\t\t\tbegan an extensive search.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tWhat carried the Artemis so far',
#  '\t\t\toff course?',
#  '',
#  '9    EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#  '',
#  '\tHaritath and Kentor wait patiently for Data to finish',
#  '\thim communication.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tMy local informant does not know.',
#  '\t\t\tIn the early days survival on Tau',
#  '\t\t\tCygna Five was more important than',
#  '\t\t\thistory.',
#  '',
#  '10   INTERCUTS',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tUnderstood. How many are there?',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tApproximately fifteen thousand.',
#  '',
#  '\tReactions from the bridge crew. Now they really have',
#  '\tgot a problem.',
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\t\t(to Picard)',
#  "\t\t\tWe've only got three days.",
#  '\t\t\tWithout working transporters, we',
#  "\t\t\tcouldn't have them out in time.",
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tShuttles?',
#  '',
#  '\tWorf does some figuring on his console.',
#  '',
#  '\t\t\t\t\tWORF',
#  '\t\t\tLoading all the Enterprise',
#  '\t\t\tshuttlecraft to capacity --',
#  '\t\t\tevacuation would take four weeks,',
#  '\t\t\tfour days.',
#  '',
#  '   STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE   9.',
#  '',
#  '10   CONTINUED:',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tThen we need more time. Mister',
#  '\t\t\tData, prepare the colonists for',
#  '\t\t\tan evacuation.',
#  '',
#  "\t\t\t\t\tDATA'S COM VOICE",
#  '\t\t\tAye, sir.',
#  '',
#  '\tPicard closes the com line.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\t\t(continuing)',
#  '\t\t\tMister Worf, get me the Sheliak.',
#  '',
#  '\t\t\t\t\tWORF',
#  '\t\t\tTheir home world is quite distant,',
#  '\t\t\tCaptain. This will take some',
#  '\t\t\ttime.',
#  '',
#  '\t\t\t\t\t\t\t\t\tCUT TO:',
#  '',
#  '11   EXT. PLANET SURFACE - MAIN STREET - DAY',
#  '',
#  '\tThe main pumping station of Tau Cygna V. In the',
#  '\tdistance are mountains. A thin white line descends',
#  '\tfrom the mountains, and as it comes closer we realize',
#  '\tit is an aqueduct. Along the line of the aqueduct are',
#  '\tlush fields, a veritable Garden of Eden, which ends',
#  '\tlike a knife-cut and the desert returns. It culminates',
#  '\tin a strange cubistic-shaped purifying station. In a',
#  '\tpool, the water churns into a white froth.',
#  '',
#  '\tGOSHEVEN, the leader, supervises TWO WORKERS testing',
#  '\tthe water in the pool.',
#  '',
#  '\tData, Haritath, and Kentor approach.',
#  '',
#  '\t\t\t\t\tHARITATH',
#  "\t\t\tGosheven, look what's come --",
#  '',
#  '\tGosheven sees Data, looks him up and down very',
#  "\tcarefully. Gosheven's as surprised as Haritath was,",
#  '\tbut keeps a lid on it -- Data may represent a threat,',
#  "\tso Gosheven's attempting a poker face.",
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tLieutenant Commander Data of the',
#  '\t\t\tStarship Enterprise.',
#  '',
#  '   STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT ONE   10.',
#  '',
#  '11   CONTINUED:',
#  '',
#  '\t\t\t\t\tKENTOR',
#  "\t\t\tHe's an android.",
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\tSo he is.',
#  '\t\t\t\t(a beat)',
#  "\t\t\tWell, you're here -- what do you",
#  '\t\t\twant?',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tMy mission is to prepare this',
#  '\t\t\tcolony for evacuation.',
#  '',
#  '\tReactions from the men. Gosheven is calm, almost',
#  '\tamused:',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\tWhy?',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tBecause this planet belongs to',
#  '\t\t\tthe Sheliak.',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\tAnd just who is this Sheliak?',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tThe term is plural. The Sheliak',
#  '\t\t\tare an intelligent, non-humanoid',
#  '\t\t\tlife form, classification R-3 --',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\t\t(interrupting)',
#  "\t\t\tThis colony's been here for a",
#  '\t\t\thundred and forty years -- and',
#  "\t\t\tno one's ever seen a Sheliak.",
#  "\t\t\tI'd say that makes Tau Cygna",
#  '\t\t\tFive our planet. (ALTERNATE:',
#  '\t\t\tninety years)',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tBut the original destination of',
#  '\t\t\tthe Artemis was Septimis Minor.',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\tThe guidance systems on the',
#  '\t\t\tArtemis failed -- and sent them',
#  '\t\t\toff course. Far off course.',
#  '\t\t\tOur ancestors were lucky to find',
#  '\t\t\tany place to land.',
#  '',
#  '   STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE   11.',
#  '',
#  '11   CONTINUED: (2)',
#  '',
#  '\t\t\t\t\tHARITATH',
#  '\t\t\tAnd when they did, the radiation',
#  '\t\t\tstarted killing them.',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\tHyperonic radiation took the lives',
#  '\t\t\tof a third of the colonists before',
#  '\t\t\tthey learned they could adapt',
#  '\t\t\tto it.',
#  '',
#  '\t\t\t\t\tKENTOR',
#  '\t\t\tBut the colony survived -- and',
#  '\t\t\tprospered.',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\t\t(with pride)',
#  "\t\t\tLook around. We've brought",
#  '\t\t\twater to the desert, built a',
#  '\t\t\tcommunity.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tYour accomplishments are indeed',
#  '\t\t\tremarkable. However, the',
#  '\t\t\tSheliak and the Federation',
#  '\t\t\thave a treaty that clearly makes',
#  '\t\t\tthis planet Sheliak domain.',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\tThen change the treaty.',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tThat may not be possible. The',
#  '\t\t\tSheliak wish to colonize this',
#  '\t\t\tplanet, and they are unwilling',
#  '\t\t\tto share it with humans.',
#  '\t\t\t\t\t(MORE)',
#  '',
#  '   STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE   12.',
#  '',
#  '11   CONTINUED: (3)',
#  '',
#  "\t\t\t\t\tDATA (cont'd)",
#  '\t\t\tIf you are still here when the',
#  '\t\t\tSheliak colony ship arrives,',
#  '\t\t\tthey will eradicate you.',
#  '',
#  '\tHaritath and Kentor exchange a worried glance, but',
#  '\tGosheven is unfazed.',
#  '',
#  '\t\t\t\t\tHARITATH',
#  '\t\t\tThey would kill us all?',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tThey have little regard for',
#  '\t\t\thuman life. Thus, our most',
#  '\t\t\tsensible course is to prepare a',
#  '\t\t\tcontingency plan for the',
#  '\t\t\tevacuation of your people.',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  "\t\t\tWe're not evacuating.",
#  '',
#  '\tData is taken aback.',
#  '',
#  ' STAR TREK: "Ensigns of Command" - REV. 7/18/79 - ACT ONE 12A.',
#  '',
#  '11   CONTINUED: (4)',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tPerhaps I have not made myself',
#  '\t\t\tclear.',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\tYes, you have. Now let me be',
#  "\t\t\tequally clear. There's going",
#  '\t\t\tto be no evacuation.',
#  '\t\t\t\t(a beat)',
#  "\t\t\tYou've delivered your message --",
#  '\t\t\tso go back to your ship. I have',
#  '\t\t\twork to do.',
#  '',
#  '\tGosheven returns to his work on the pumping station.',
#  '',
#  '  STAR TREK: "Ensigns of Command" - REV. 7/18/89 - ACT ONE  13.',
#  '',
#  '11A  ON DATA',
#  '',
#  '\tas he considers his next move. Then -- an object comes',
#  '\tflying at Data.',
#  '',
#  '\tWith android speed and reflexes, Data catches the',
#  '\tobject and examines it. It is an iron bar.',
#  '',
#  "\t\t\t\t\tARD'RIAN (O.S.)",
#  '\t\t\tNice catch. Wonderful reflexes.',
#  '',
#  '\tData turns to see --',
#  '',
#  '11B  WIDER',
#  '',
#  "\tARD'RIAN, an attractive female, approaches.",
#  '',
#  "\t\t\t\t\tARD'RIAN",
#  '\t\t\tSorry to test you like that --',
#  '\t\t\tbut I was curious.',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\t\t(amused)',
#  '\t\t\tFound a new toy, have we, Ardy?',
#  '',
#  "\t\t\t\t\tARD'RIAN",
#  '\t\t\tToy? This is the most incredible',
#  "\t\t\tandroid I've ever seen.",
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tHave you seen many?',
#  '',
#  "\t\t\t\t\tARD'RIAN",
#  "\t\t\tActually, no. You're the first.",
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  "\t\t\t\t(to Ard'rian)",
#  '\t\t\tOnly you would get this excited',
#  '\t\t\tover a walking calculator.',
#  '',
#  "\t\t\t\t\tARD'RIAN",
#  '\t\t\t\t(bridling)',
#  "\t\t\tHe's more interesting than",
#  '\t\t\tanything else walking around',
#  '\t\t\there...',
#  '',
#  "\tGosheven CHUCKLES -- he's succeeded in getting under",
#  '\ther skin.',
#  '',
#  '\t\t\t\t\tGOSHEVEN',
#  '\t\t\tDepends on what you find',
#  '\t\t\tinteresting.',
#  '',
#  '  STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE  13A.',
#  '',
#  '11B  CONTINUED:',
#  '',
#  "\tArd'rian's had enough of Gosheven's male conceit. She",
#  '\tmoves away, motions for Data to follow. Data does.',
#  '',
#  "\t\t\t\t\tARD'RIAN",
#  '\t\t\t\t(to Data)',
#  '\t\t\tCybernetic intelligence fascinates',
#  '\t\t\tme. Are your neural pathways',
#  '\t\t\tduotronic?',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tNo -- they are positronic.',
#  '',
#  "\t\t\t\t\tARD'RIAN",
#  "\t\t\tI didn't know that was possible!",
#  "\t\t\tWhat's your memory capacity? How",
#  '\t\t\tmany operations per second? I',
#  '\t\t\thave a million questions...',
#  '',
#  '\t\t\t\t\tDATA',
#  '\t\t\tI am afraid I have no time to',
#  '\t\t\tanswer one million questions.',
#  '\t\t\tI have a mission to accomplish.',
#  '\t\t\t\t\t(MORE)',
#  '',
#  '   STAR TREK: "Ensigns of Command" REV. 7/24/89 - ACT ONE   14.',
#  '',
#  '11B  CONTINUED: (2)',
#  '',
#  "\t\t\t\t\tDATA (cont'd)",
#  '\t\t\tI need to know more about your',
#  '\t\t\tpeople, and Gosheven seems',
#  '\t\t\tunwilling to talk to me further.',
#  '',
#  "\t\t\t\t\tARD'RIAN",
#  '\t\t\t\t(extending a hand)',
#  "\t\t\tI'm Ard'rian McKenzie. Perhaps",
#  '\t\t\tI can help you.',
#  '',
#  '\tAs Data shakes her hand, we:',
#  '',
#  '\t\t\t\t\t\t\t\t\tCUT TO:',
#  '',
#  '12   INT. OBSERVATION LOUNGE',
#  '',
#  "\tPicard, Riker and TROI are seated as GEORDI, O'Brien",
#  '\tENTER.',
#  '',
#  '\t\t\t\t\tRIKER',
#  "\t\t\tGentlemen, we're giving you an",
#  '\t\t\tassignment, and the one thing we',
#  "\t\t\tdon't want to hear is that it is",
#  '\t\t\timpossible.',
#  '',
#  "\tRiker defers to Picard. Geordi and O'Brien cast wary",
#  '\tglances at Picard. Now what the hell is he going to',
#  '\twant?',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tI need the transporters to',
#  '\t\t\tfunction despite the hyperonic',
#  '\t\t\tradiation.',
#  '',
#  '\t\t\t\t\tGEORDI',
#  '\t\t\tImpossi -- Yes, sir.',
#  '',
#  "\tGeordi and O'Brien EXIT. Riker, Troi and Picard study",
#  '\teach other seriously.',
#  '',
#  '\t\t\t\t\tRIKER',
#  '\t\t\tEven if we can get the Sheliak',
#  "\t\t\tto talk to us, they're not likely",
#  '\t\t\tto be accommodating.',
#  '',
#  '  STAR TREK: "Ensigns of Command" - REV. 7/13/89 - ACT ONE  15.',
#  '',
#  '12   CONTINUED:',
#  '',
#  '\t\t\t\t\tTROI',
#  '\t\t\tCaptain, when the treaty was',
#  '\t\t\tnegotiated the Federation sent',
#  '\t\t\tthree hundred and seventy-two',
#  '\t\t\tlegal experts. What have we got?',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tThee... and me.',
#  '',
#  "\tOff Troi's very dubious expression as we:",
#  '',
#  '\t\t\t\t\t\t\t\t\tFADE OUT.',
#  '',
#  '                        END OF ACT ONE                          ',
#  '',
#  '  STAR TREK: "Ensigns of Command" - REV. 7/14/89 - ACT TWO  16.',
#  '',
#  '                            ACT TWO                             ',
#  '',
#  '\tFADE IN:',
#  '',
#  '13   EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#  '',
#  '\tin orbit around Tau Cygna V.',
#  '',
#  '14   INT. MAIN BRIDGE',
#  '',
#  '\tPicard pacing, Troi seated as they wait for the call.',
#  '\tWorf at his station. Supernumeraries at Conn and Ops.',
#  '',
#  '\t\t\t\t\tWORF',
#  '\t\t\tNo response.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tTry again. Boost signal strength.',
#  '',
#  '\tWorf makes adjustments.',
#  '',
#  '\t\t\t\t\tWORF',
#  '\t\t\tSheliak Corporate. This is the',
#  '\t\t\tStarship Enterprise. Respond',
#  '\t\t\tplease.',
#  '',
#  '15   ANGLE ON VIEWSCREEN - (OPTICAL)',
#  '',
#  '\tas it changes from a view of stars to -- someplace? a',
#  '\tbridge? Wherever the SHELIAK are calling from it is',
#  '\ta disturbing place for humans. Darkness, mirrored',
#  '\tsurfaces, and hidden in the shadows a creature who is',
#  '\tdecidedly unsettling for the crew. Its shape is',
#  '\tconstantly shifting like oozing sludge, and there is',
#  '\ta hint of flickering eyes -- too many eyes.',
#  '',
#  '\t\t\t\t\tSHELIAK',
#  '\t\t\tConversation is neither required',
#  '\t\t\tnor desired.',
#  '',
#  '\tPicard schools his features into an expression of',
#  '\tpolite interest.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tConversation is necessary if we',
#  '\t\t\tare to find a solution to our',
#  '\t\t\tmutual problem.',
#  '',
#  '\t\t\t\t\tSHELIAK',
#  '\t\t\tOur involvement in Federation',
#  '\t\t\tillegality is not indicated.',
#  '',
#  '  STAR TREK: "Ensigns of Command" - REV. 7/14/89 - ACT TWO  17.',
#  '',
#  '15   CONTINUED:',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tBoth parties are involved, sir.',
#  '',
#  '\t\t\t\t\tSHELIAK',
#  '\t\t\tRemove the humans from the Tau',
#  '\t\t\tCygna system. Three Earth days',
#  '\t\t\tremain.',
#  '',
#  '\tTroi leans in, and whispers:',
#  '',
#  '\t\t\t\t\tTROI',
#  '\t\t\tTheir culture is extremely formal,',
#  '\t\t\talmost ritualistic. An apology',
#  '\t\t\tmight smooth matters.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tI apologize for our inadvertent',
#  '\t\t\tviolation of the treaty.',
#  '',
#  '\t\t\t\t\tSHELIAK',
#  '\t\t\tAcknowledged and accepted. Now',
#  '\t\t\tremove the human creatures.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tLet us negotiate in good faith...',
#  '',
#  '\t\t\t\t\tSHELIAK',
#  '\t\t\tNegotiate to what purpose? The',
#  '\t\t\ttreaty is signed.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tThere is a thriving colony on the',
#  '\t\t\tplanet. Rather than uproot these',
#  '\t\t\tpeople may I offer a compromise?',
#  '',
#  '\t\t\t\t\tSHELIAK',
#  '\t\t\tDenied.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tWhy?!',
#  '',
#  '\t\t\t\t\tSHELIAK',
#  '\t\t\tThe law is paramount. We are',
#  '\t\t\tentitled.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\tThis is not a law. It is a',
#  '\t\t\ttreaty. It is designed to smooth',
#  '\t\t\trelations between peoples. Not',
#  '\t\t\tto act as a strait...',
#  '',
#  '   STAR TREK: "Ensigns of Command" REV. 7/20/89 - ACT TWO   18.',
#  '',
#  '15   CONTINUED: (2)',
#  '',
#  "\tBut Picard's talking to a blank screen. The Sheliak",
#  '\thave hung up on him.',
#  '',
#  '\t\t\t\t\tPICARD',
#  '\t\t\t... jacket.',
#  '',
#  "\tOff Picard's annoyed expression.",
#  '',
#  '\t\t\t\t\t\t\t\t\tCUT TO:',
#  ...]

# %%
q

# %%
separate_lines_by_character(b, chars)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-0ba65f69effe> in <module>
# ----> 1 separate_lines_by_character(b, chars)
#
# <ipython-input-213-dcc472ed9b93> in separate_lines_by_character(dialogue, indices)
#      68
#      69 def separate_lines_by_character(dialogue, indices):
# ---> 70     temp_sectioned = sectioned_script(dialogue, indices)
#      71     sectioned = copy.deepcopy(temp_sectioned)
#      72     for number, section in sectioned.items():
#
# <ipython-input-213-dcc472ed9b93> in sectioned_script(dialogue, header_indices)
#      87
#      88     for pair in index_pairs:
# ---> 89         part = get_between_indices(dialogue, *pair)
#      90         head = part.pop(0)
#      91         number, header = number_header_from_line(head)
#
# <ipython-input-127-b1be1d96a5b4> in get_between_indices(s, begin, end)
#       1 def get_between_indices(s, begin, end):
# ----> 2     return s[begin:end]
#
# TypeError: unhashable type: 'slice'

# %%
replace_character_names(b, chars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-201-d876c3d55cc4> in <module>
# ----> 1 replace_character_names(b, chars)
#
# <ipython-input-200-c25db9ee4b28> in replace_character_names(dialogue, characters)
#      53         for piece in content:
#      54             parts = piece['part']
# ---> 55             for section, stuff in parts.items():
#      56                 name = stuff['name']
#      57                 for check in characters:
#
# AttributeError: 'list' object has no attribute 'items'

# %%
replace_character_names(e, chars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-188-3fcd66c937a2> in <module>
# ----> 1 replace_character_names(e, chars)
#
# <ipython-input-186-c80142db0444> in replace_character_names(dialogue, characters)
#       5         for piece in content:
#       6             parts = piece['part']
# ----> 7             for section, stuff in parts.items():
#       8                 name = stuff['name']
#       9                 for check in characters:
#
# AttributeError: 'list' object has no attribute 'items'

# %%
d = separate_lines_by_character(b, indices)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-198-10cc62f63812> in <module>
# ----> 1 d = separate_lines_by_character(b, indices)
#
# <ipython-input-195-ef7d5c2cbe21> in separate_lines_by_character(dialogue, indices)
#      69
#      70 def separate_lines_by_character(dialogue, indices):
# ---> 71     temp_sectioned = sectioned_script(dialogue, indices)
#      72     sectioned = copy.deepcopy(temp_sectioned)
#      73     for number, section in sectioned.items():
#
# <ipython-input-49-f0d840b35481> in sectioned_script(dialogue, headers)
#       5
#       6     for pair in index_pairs:
# ----> 7         part = get_between_indices(dialogue, *pair)
#       8         head = part.pop(0)
#       9         number, header = number_header_from_line(head)
#
# <ipython-input-127-b1be1d96a5b4> in get_between_indices(s, begin, end)
#       1 def get_between_indices(s, begin, end):
# ----> 2     return s[begin:end]
#
# TypeError: unhashable type: 'slice'

# %%
d
# Out:
# {'1': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['Moving at impulse near some extraordinarily interesting',
#     'astronomical object.']}],
#  '2': [{'header': 'INT. TEN-FORWARD',
#    'part': ['Present are PICARD, BEVERLY, and TWELVE N.D.',
#     'CREWMEMBERS. A VULCAN and ONE WOMAN are seated,',
#     'holding their instruments -- a violin and a viola.',
#     "O'BRIEN tunes his cello. DATA ENTERS carrying a",
#     'violin. He checks at the door, startled to see the',
#     'captain. Picard beckons, and Data crosses to him.',
#     'DATA',
#     'Captain, Doctor, I am honored by',
#     'your presence, but may I suggest',
#     'you attend the second concert.',
#     'BEVERLY',
#     'Why, Data?',
#     'DATA',
#     'Ensign Ortiz will perform the',
#     'violin part. My rendition will',
#     'be less enjoyable.',
#     'PICARD',
#     'Oh?',
#     'DATA',
#     'While I am quite proficient',
#     'Technically, according to my',
#     'fellow performers, I lack soul.',
#     'BEVERLY',
#     "Data, telling us why you're going",
#     'to fail before you make the',
#     'attempt is never wise.',
#     'DATA',
#     'But is not honesty always the',
#     'preferred choice?']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Excessive honesty can be',
#     'disastrous... particularly in a',
#     'commander.',
#     'DATA',
#     '(very intrigued)',
#     'Indeed?',
#     'PICARD',
#     'Knowing your limitations is one',
#     'thing. Advertising them to a crew',
#     'can damage your ability to lead.',
#     'DATA',
#     'Because you lose their respect?',
#     'BEVERLY',
#     'No, because you may begin to',
#     'believe in those limitations',
#     'yourself.',
#     'Data considers this, then moves to take his place with',
#     'the other performers.']}],
#  '2A': [{'header': 'ANGLE ON PICARD AND BEVERLY',
#    'part': ['O.s., the string quartet TUNES. There is the SOUND of',
#     'the communicator hail.',
#     "RIKER'S COM VOICE",
#     "Captain, we're receiving a message",
#     'from the Sheliak Corporate.',
#     'Picard reacts with surprise, stands and EXITS. As he',
#     'leaves, the quartet starts to PLAY.',
#     'CUT TO:']}],
#  '3': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['Picard ENTERS. RIKER and WORF at their usual stations.',
#     'Supernumeraries at CONN and OPS.']},
#   {'header': 'CONTINUED:',
#    'part': ['WORF',
#     'Origin point of the message',
#     'confirmed. It is from the Shelia',
#     'star system.',
#     'RIKER',
#     'The Sheliak have not attempted',
#     'to communicate with the Federation',
#     'for a hundred and eleven years.',
#     'PICARD',
#     'On screen.']}],
#  '4': [{'header': 'ANGLE ON VIEWSCREEN (OPTICAL)',
#    'part': ['What appears is the text of a treaty. English on one',
#     'side, Sheliak on the other. Sheliak is not symbols',
#     'as we know them, but rather a pattern of lights. A',
#     'recorded message begins.',
#     'SHELIAK VOICE',
#     'Federation creatures, there are',
#     'humans on the fifth planet of Tau',
#     'Cygna. This planet was ceded',
#     'to the corporate in section one',
#     'hundred and thirty-three,',
#     'paragraph seventy-seven of the',
#     'Treaty of Armens. We will begin',
#     'settlement of this world in four',
#     'days. Remove the humans.',
#     'Riker is up, and heading for Science One.',
#     'PICARD',
#     'What the devil --',
#     'SHELIAK VOICE',
#     'Federation creatures, there are',
#     'humans on the fifth planet --',
#     'PICARD',
#     'Cancel message.',
#     'Inquiring look to Riker.',
#     'RIKER',
#     'Tau Cygna Five is in the de Laure',
#     'belt -- heavy concentrations of',
#     'hyperonic radiation.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     "Humans can't survive in such an",
#     'environment. Exposure to',
#     'hyperonic radiation is fatal.',
#     'RIKER',
#     'Then the Sheliak are asking us',
#     'to chase ghosts.',
#     'PICARD',
#     'No, Number One. The Sheliak',
#     "haven't broken a century of",
#     'silence to send us after phantoms.',
#     'An investigation is in order.',
#     'Set course for Tau Cygna Five.',
#     "Off Picard's expression:",
#     'FADE OUT.',
#     'END OF THE TEASER                        ',
#     'ACT ONE                             ',
#     'FADE IN:']}],
#  '5': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['entering orbit around a planet.']}],
#  '6': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['Picard, Riker, Data, Beverly and Worf. Supernumerary',
#     'at CONN.',
#     'WORF',
#     'Human life form readings from the',
#     'planet.',
#     'RIKER',
#     "So, the Sheliak weren't",
#     'hallucinating.',
#     'PICARD',
#     'Numbers?',
#     'WORF',
#     'Impossible to get an accurate',
#     'reading, Captain. The high',
#     'radiation levels are disrupting',
#     'our sensors.',
#     'DATA',
#     'Hyperonic radiation also',
#     "interferes with ship's",
#     'transporters; they are now',
#     'inoperable.',
#     'WORF',
#     "So are the ship's phasers.",
#     'RIKER',
#     'How can humans survive down there?',
#     'BEVERLY',
#     'They must have found a way to',
#     'adapt.',
#     '(thinks it over)',
#     "Milan's work in radiation",
#     "sensitivity suggests it's",
#     'possible. Perhaps with extensive',
#     'virotherapy...',
#     '(grimly)',
#     'Until they found the answer, their',
#     'mortality rate must have been',
#     'staggering.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Well, whoever they are and however',
#     "they've survived, we've got to",
#     'get them off the planet.',
#     'RIKER',
#     'By treaty, this world does belong',
#     'to the Sheliak...',
#     'PICARD',
#     '... who are within their rights',
#     'to demand the removal of these',
#     '"trespassers."',
#     'RIKER',
#     "And if we don't remove them, the",
#     'Sheliak will.',
#     'BEVERLY',
#     'How forcefully?',
#     'RIKER',
#     'To the Sheliak, humans are a lower',
#     "life form. They'd have no",
#     'compunctions about exterminating',
#     'the intruders.',
#     "Beverly is taken aback. Riker's dead serious.",
#     'PICARD',
#     'Mister Data. As you are unaffected',
#     'by hyperonic radiation, you will',
#     'go to the planet via shuttlecraft',
#     'and commence evacuation',
#     'procedures.',
#     'DATA',
#     'Aye, sir.',
#     'Without a word wasted the android is out of his chair,',
#     'and EXITS the bridge.',
#     'PICARD',
#     "Any speculation as to what he'll",
#     'find, Number One?',
#     'RIKER',
#     'A lost survey ship would be my',
#     'guess. A dozen or so survivors',
#     'at most.',
#     'CUT TO:']}],
#  '7': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': ['Data is outside the shuttle, scanning with his', 'tricorder.']}],
#  '7A': [{'header': 'NEW ANGLE',
#    'part': ['as HARITATH and KENTOR (two male humans) and TWO N.D.',
#     'WORKERS cautiously approach the shuttle from the other',
#     'side (the shuttle blocks their view of Data).',
#     'HARITATH',
#     '(in wonder)',
#     'A shuttlecraft!',
#     'KENTOR',
#     "Where's it from?",
#     'HARITATH',
#     'Look at the markings. I think',
#     "it's from the Federation.",
#     'Data steps into their view from around the shuttle.',
#     'DATA',
#     'Hello.',
#     'The four humans jump, startled.',
#     'HARITATH',
#     "We saw your ship... You're the",
#     "first visitor we've had in..."]},
#   {'header': 'CONTINUED: (2)',
#    'part': ['KENTOR',
#     "The first visitor we've ever had.",
#     'They take a closer look at Data.',
#     'HARITATH',
#     "You're -- not human.",
#     'DATA',
#     'That is correct. I am an android.',
#     'I am Lieutenant Commander Data',
#     'of the Federation Starship',
#     'Enterprise.',
#     'HARITATH',
#     '(excited)',
#     'Our great-grandparents were',
#     'citizens of the Federation.',
#     '(realizing)',
#     "But you don't want to waste time",
#     'talking to us...',
#     'KENTOR',
#     "You'll want to speak with",
#     "Gosheven. We'll take you to him.",
#     'DATA',
#     'Excellent.',
#     'HARITATH',
#     "I'm sure the Federation will be",
#     'very proud of us. Wait until you',
#     "see all we've accomplished.",
#     'DATA',
#     'And who, precisely, is "we?"',
#     'HARITATH',
#     "You don't know? No, I guess you",
#     "wouldn't, would you? We are the",
#     'descendants of the original',
#     'settlers -- from the colony ship',
#     'Artemis.',
#     'CUT TO:']}],
#  '8': [{'header': 'INT. ENTERPRISE - MAIN BRIDGE',
#    'part': ['Picard and Worf in their usual places. Riker at',
#     'Science One. Supernumeraries at Conn and Ops.']},
#   {'header': 'CONTINUED:',
#    'part': ['RIKER',
#     'Got it. The Artemis, launched one',
#     'hundred forty-two years ago,',
#     'destination Septimis Minor. When',
#     'they failed to check in, Starfleet',
#     'began an extensive search.',
#     'PICARD',
#     'What carried the Artemis so far',
#     'off course?']}],
#  '9': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': ['Haritath and Kentor wait patiently for Data to finish',
#     'him communication.',
#     'DATA',
#     'My local informant does not know.',
#     'In the early days survival on Tau',
#     'Cygna Five was more important than',
#     'history.']}],
#  '10': [{'header': 'INTERCUTS',
#    'part': ['PICARD',
#     'Understood. How many are there?',
#     'DATA',
#     'Approximately fifteen thousand.',
#     'Reactions from the bridge crew. Now they really have',
#     'got a problem.',
#     'RIKER',
#     '(to Picard)',
#     "We've only got three days.",
#     'Without working transporters, we',
#     "couldn't have them out in time.",
#     'PICARD',
#     'Shuttles?',
#     'Worf does some figuring on his console.',
#     'WORF',
#     'Loading all the Enterprise',
#     'shuttlecraft to capacity --',
#     'evacuation would take four weeks,',
#     'four days.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Then we need more time. Mister',
#     'Data, prepare the colonists for',
#     'an evacuation.',
#     "DATA'S COM VOICE",
#     'Aye, sir.',
#     'Picard closes the com line.',
#     'PICARD',
#     '(continuing)',
#     'Mister Worf, get me the Sheliak.',
#     'WORF',
#     'Their home world is quite distant,',
#     'Captain. This will take some',
#     'time.',
#     'CUT TO:']}],
#  '11': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['The main pumping station of Tau Cygna V. In the',
#     'distance are mountains. A thin white line descends',
#     'from the mountains, and as it comes closer we realize',
#     'it is an aqueduct. Along the line of the aqueduct are',
#     'lush fields, a veritable Garden of Eden, which ends',
#     'like a knife-cut and the desert returns. It culminates',
#     'in a strange cubistic-shaped purifying station. In a',
#     'pool, the water churns into a white froth.',
#     'GOSHEVEN, the leader, supervises TWO WORKERS testing',
#     'the water in the pool.',
#     'Data, Haritath, and Kentor approach.',
#     'HARITATH',
#     "Gosheven, look what's come --",
#     'Gosheven sees Data, looks him up and down very',
#     "carefully. Gosheven's as surprised as Haritath was,",
#     'but keeps a lid on it -- Data may represent a threat,',
#     "so Gosheven's attempting a poker face.",
#     'DATA',
#     'Lieutenant Commander Data of the',
#     'Starship Enterprise.']},
#   {'header': 'CONTINUED:',
#    'part': ['KENTOR',
#     "He's an android.",
#     'GOSHEVEN',
#     'So he is.',
#     '(a beat)',
#     "Well, you're here -- what do you",
#     'want?',
#     'DATA',
#     'My mission is to prepare this',
#     'colony for evacuation.',
#     'Reactions from the men. Gosheven is calm, almost',
#     'amused:',
#     'GOSHEVEN',
#     'Why?',
#     'DATA',
#     'Because this planet belongs to',
#     'the Sheliak.',
#     'GOSHEVEN',
#     'And just who is this Sheliak?',
#     'DATA',
#     'The term is plural. The Sheliak',
#     'are an intelligent, non-humanoid',
#     'life form, classification R-3 --',
#     'GOSHEVEN',
#     '(interrupting)',
#     "This colony's been here for a",
#     'hundred and forty years -- and',
#     "no one's ever seen a Sheliak.",
#     "I'd say that makes Tau Cygna",
#     'Five our planet. (ALTERNATE:',
#     'ninety years)',
#     'DATA',
#     'But the original destination of',
#     'the Artemis was Septimis Minor.',
#     'GOSHEVEN',
#     'The guidance systems on the',
#     'Artemis failed -- and sent them',
#     'off course. Far off course.',
#     'Our ancestors were lucky to find',
#     'any place to land.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['HARITATH',
#     'And when they did, the radiation',
#     'started killing them.',
#     'GOSHEVEN',
#     'Hyperonic radiation took the lives',
#     'of a third of the colonists before',
#     'they learned they could adapt',
#     'to it.',
#     'KENTOR',
#     'But the colony survived -- and',
#     'prospered.',
#     'GOSHEVEN',
#     '(with pride)',
#     "Look around. We've brought",
#     'water to the desert, built a',
#     'community.',
#     'DATA',
#     'Your accomplishments are indeed',
#     'remarkable. However, the',
#     'Sheliak and the Federation',
#     'have a treaty that clearly makes',
#     'this planet Sheliak domain.',
#     'GOSHEVEN',
#     'Then change the treaty.',
#     'DATA',
#     'That may not be possible. The',
#     'Sheliak wish to colonize this',
#     'planet, and they are unwilling',
#     'to share it with humans.',
#     '(MORE)']},
#   {'header': 'CONTINUED: (3)',
#    'part': ["DATA (cont'd)",
#     'If you are still here when the',
#     'Sheliak colony ship arrives,',
#     'they will eradicate you.',
#     'Haritath and Kentor exchange a worried glance, but',
#     'Gosheven is unfazed.',
#     'HARITATH',
#     'They would kill us all?',
#     'DATA',
#     'They have little regard for',
#     'human life. Thus, our most',
#     'sensible course is to prepare a',
#     'contingency plan for the',
#     'evacuation of your people.',
#     'GOSHEVEN',
#     "We're not evacuating.",
#     'Data is taken aback.']},
#   {'header': 'CONTINUED: (4)',
#    'part': ['DATA',
#     'Perhaps I have not made myself',
#     'clear.',
#     'GOSHEVEN',
#     'Yes, you have. Now let me be',
#     "equally clear. There's going",
#     'to be no evacuation.',
#     '(a beat)',
#     "You've delivered your message --",
#     'so go back to your ship. I have',
#     'work to do.',
#     'Gosheven returns to his work on the pumping station.']}],
#  '11A': [{'header': 'ON DATA',
#    'part': ['as he considers his next move. Then -- an object comes',
#     'flying at Data.',
#     'With android speed and reflexes, Data catches the',
#     'object and examines it. It is an iron bar.',
#     "ARD'RIAN (O.S.)",
#     'Nice catch. Wonderful reflexes.',
#     'Data turns to see --']}],
#  '11B': [{'header': 'WIDER',
#    'part': ["ARD'RIAN, an attractive female, approaches.",
#     "ARD'RIAN",
#     'Sorry to test you like that --',
#     'but I was curious.',
#     'GOSHEVEN',
#     '(amused)',
#     'Found a new toy, have we, Ardy?',
#     "ARD'RIAN",
#     'Toy? This is the most incredible',
#     "android I've ever seen.",
#     'DATA',
#     'Have you seen many?',
#     "ARD'RIAN",
#     "Actually, no. You're the first.",
#     'GOSHEVEN',
#     "(to Ard'rian)",
#     'Only you would get this excited',
#     'over a walking calculator.',
#     "ARD'RIAN",
#     '(bridling)',
#     "He's more interesting than",
#     'anything else walking around',
#     'here...',
#     "Gosheven CHUCKLES -- he's succeeded in getting under",
#     'her skin.',
#     'GOSHEVEN',
#     'Depends on what you find',
#     'interesting.']},
#   {'header': 'CONTINUED:',
#    'part': ["Ard'rian's had enough of Gosheven's male conceit. She",
#     'moves away, motions for Data to follow. Data does.',
#     "ARD'RIAN",
#     '(to Data)',
#     'Cybernetic intelligence fascinates',
#     'me. Are your neural pathways',
#     'duotronic?',
#     'DATA',
#     'No -- they are positronic.',
#     "ARD'RIAN",
#     "I didn't know that was possible!",
#     "What's your memory capacity? How",
#     'many operations per second? I',
#     'have a million questions...',
#     'DATA',
#     'I am afraid I have no time to',
#     'answer one million questions.',
#     'I have a mission to accomplish.',
#     '(MORE)']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["DATA (cont'd)",
#     'I need to know more about your',
#     'people, and Gosheven seems',
#     'unwilling to talk to me further.',
#     "ARD'RIAN",
#     '(extending a hand)',
#     "I'm Ard'rian McKenzie. Perhaps",
#     'I can help you.',
#     'As Data shakes her hand, we:',
#     'CUT TO:']}],
#  '12': [{'header': 'INT. OBSERVATION LOUNGE',
#    'part': ["Picard, Riker and TROI are seated as GEORDI, O'Brien",
#     'ENTER.',
#     'RIKER',
#     "Gentlemen, we're giving you an",
#     'assignment, and the one thing we',
#     "don't want to hear is that it is",
#     'impossible.',
#     "Riker defers to Picard. Geordi and O'Brien cast wary",
#     'glances at Picard. Now what the hell is he going to',
#     'want?',
#     'PICARD',
#     'I need the transporters to',
#     'function despite the hyperonic',
#     'radiation.',
#     'GEORDI',
#     'Impossi -- Yes, sir.',
#     "Geordi and O'Brien EXIT. Riker, Troi and Picard study",
#     'each other seriously.',
#     'RIKER',
#     'Even if we can get the Sheliak',
#     "to talk to us, they're not likely",
#     'to be accommodating.']},
#   {'header': 'CONTINUED:',
#    'part': ['TROI',
#     'Captain, when the treaty was',
#     'negotiated the Federation sent',
#     'three hundred and seventy-two',
#     'legal experts. What have we got?',
#     'PICARD',
#     'Thee... and me.',
#     "Off Troi's very dubious expression as we:",
#     'FADE OUT.',
#     'END OF ACT ONE                          ',
#     'ACT TWO                             ',
#     'FADE IN:']}],
#  '13': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['in orbit around Tau Cygna V.']}],
#  '14': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['Picard pacing, Troi seated as they wait for the call.',
#     'Worf at his station. Supernumeraries at Conn and Ops.',
#     'WORF',
#     'No response.',
#     'PICARD',
#     'Try again. Boost signal strength.',
#     'Worf makes adjustments.',
#     'WORF',
#     'Sheliak Corporate. This is the',
#     'Starship Enterprise. Respond',
#     'please.']}],
#  '15': [{'header': 'ANGLE ON VIEWSCREEN - (OPTICAL)',
#    'part': ['as it changes from a view of stars to -- someplace? a',
#     'bridge? Wherever the SHELIAK are calling from it is',
#     'a disturbing place for humans. Darkness, mirrored',
#     'surfaces, and hidden in the shadows a creature who is',
#     'decidedly unsettling for the crew. Its shape is',
#     'constantly shifting like oozing sludge, and there is',
#     'a hint of flickering eyes -- too many eyes.',
#     'SHELIAK',
#     'Conversation is neither required',
#     'nor desired.',
#     'Picard schools his features into an expression of',
#     'polite interest.',
#     'PICARD',
#     'Conversation is necessary if we',
#     'are to find a solution to our',
#     'mutual problem.',
#     'SHELIAK',
#     'Our involvement in Federation',
#     'illegality is not indicated.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Both parties are involved, sir.',
#     'SHELIAK',
#     'Remove the humans from the Tau',
#     'Cygna system. Three Earth days',
#     'remain.',
#     'Troi leans in, and whispers:',
#     'TROI',
#     'Their culture is extremely formal,',
#     'almost ritualistic. An apology',
#     'might smooth matters.',
#     'PICARD',
#     'I apologize for our inadvertent',
#     'violation of the treaty.',
#     'SHELIAK',
#     'Acknowledged and accepted. Now',
#     'remove the human creatures.',
#     'PICARD',
#     'Let us negotiate in good faith...',
#     'SHELIAK',
#     'Negotiate to what purpose? The',
#     'treaty is signed.',
#     'PICARD',
#     'There is a thriving colony on the',
#     'planet. Rather than uproot these',
#     'people may I offer a compromise?',
#     'SHELIAK',
#     'Denied.',
#     'PICARD',
#     'Why?!',
#     'SHELIAK',
#     'The law is paramount. We are',
#     'entitled.',
#     'PICARD',
#     'This is not a law. It is a',
#     'treaty. It is designed to smooth',
#     'relations between peoples. Not',
#     'to act as a strait...']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["But Picard's talking to a blank screen. The Sheliak",
#     'have hung up on him.',
#     'PICARD',
#     '... jacket.',
#     "Off Picard's annoyed expression.",
#     'CUT TO:']}],
#  '16': [{'header': 'OMITTED', 'part': []}],
#  '17': [{'header': "INT. ARD'RIAN'S FRONT ROOM - DAY",
#    'part': ['A comfortable room constructed of stone with a heavy',
#     'beamed ceiling. The furniture is hand hewn, durable',
#     'but comfortable. Contrasting with this are various',
#     'computer parts and consoles, both assembled and in',
#     'pieces, strewn about.',
#     "Ard'rian and Data ENTER.",
#     "ARD'RIAN",
#     "... you really think we'll have",
#     'to leave Tau Cygna Five?',
#     'DATA',
#     'The possibility exists, and',
#     'Gosheven appears unwilling to',
#     'prepare for it. Why?']},
#   {'header': 'CONTINUED:',
#    'part': ["ARD'RIAN",
#     "Maybe because you're an",
#     "android. I don't think Gosheven",
#     'likes the idea of machines',
#     'ordering him around.',
#     'DATA',
#     'I am not ordering him to do',
#     'anything; I am merely trying to',
#     'persuade him that his people',
#     'should prepare to evacuate.',
#     '(thinks)',
#     'Do you believe my suggested',
#     'course of action should be followed?',
#     "ARD'RIAN",
#     'Of course.',
#     'DATA',
#     'In spite of the fact that I am',
#     'an android?',
#     "ARD'RIAN",
#     "Because of that fact. I don't",
#     'have any silly prejudices against',
#     'computers -- I like them.',
#     'SHe gestures around the room, a bit apologetically:',
#     "ARD'RIAN (cont'd)",
#     'Not that any computer we have is',
#     'half as sophisticated as you...',
#     'Data looks at a particularly "primitive" computer:',
#     'DATA',
#     'No, I would say not.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["ARD'RIAN (cont'd)",
#     'People can be selfish,',
#     'irrational, stubborn, malicious',
#     '-- you name it. But computers',
#     "don't have those failings.",
#     'Data follows her logic:',
#     'DATA',
#     'You conclude from this that I am',
#     'impartial... hence you accept',
#     'my recommendations.',
#     'She nods.',
#     "DATA (cont'd)",
#     'Yet Gosheven does not.',
#     '(thinks)',
#     'Perhaps he might reconsider his',
#     'position if someone other than',
#     'myself were to present the',
#     'arguments.',
#     "ARD'RIAN",
#     "Well, I'm willing to talk to him,",
#     "but I don't think he'll take me",
#     'seriously.',
#     '(with distaste)',
#     "He finds me attractive -- but I'm",
#     'not interested in him at all.',
#     'So he belittles me to protect his',
#     'ego --']}],
#  '18': [{'header': 'OMITTED', 'part': []}],
#  '19': [{'header': 'NEW ANGLE',
#    'part': ["as Data's communicator TRILLS. He touches the",
#     'insignia.',
#     'DATA',
#     'Data, here.',
#     "PICARD'S COM VOICE",
#     "The Sheliak won't bargain.",
#     'DATA',
#     'Understood.']},
#   {'header': 'CONTINUED:',
#    'part': ["PICARD'S COM VOICE",
#     "I'm contacting Starfleet to",
#     'arrange for transport. Get those',
#     'people prepared for evacuation.',
#     'We may have to move very quickly.']},
#   {'header': 'CONTINUED:',
#    'part': ['DATA',
#     'Yes, sir.',
#     "Data cuts the communication, turns to Ard'rian.",
#     'DATA',
#     'We must speak with Gosheven',
#     'immediately.',
#     "Ard'rian grabs a coat, and they EXIT.",
#     'CUT TO:']}],
#  '19A': [{'header': 'INT. TRANSPORTER ROOM (OPTICAL) (FORMERLY SC. 16)',
#    'part': ["Geordi, O'Brien and WESLEY have the panels removed",
#     "from the wall behind the transporter console. Geordi's",
#     'tool box is nearby. Sophisticated tools litter the',
#     'floor. Off to the left side of the transporter are',
#     'six test objects. The trio is watching tensely as',
#     "O'Brien touches the console. A test object",
#     'MATERIALIZES looking like swiss cheese. Geordi picks',
#     'it up. Riker ENTERS.',
#     'RIKER',
#     'Gentlemen, how are you coming?',
#     '(spots the object)',
#     'What the hell is that?',
#     'Geordi sets aside the mutilated object.',
#     'GEORDI',
#     'Our first attempt.',
#     "O'BRIEN",
#     'We recalibrated the transporter',
#     'setting for the tightest possible',
#     'beam.',
#     'WESLEY',
#     "But we've got plenty of things",
#     'left to try.',
#     'Geordi is studying the test object again.',
#     'GEORDI',
#     "There's some really interesting",
#     'residue . . . reminds me of --',
#     '(a beat)',
#     "There's that damn pulsar in the",
#     'neighborhood.']},
#   {'header': 'CONTINUED:',
#    'part': ['WESLEY',
#     'Teremi-thorons.',
#     "O'BRIEN",
#     'This just got a lot harder.',
#     'WESLEY',
#     "They're one of the most elusive",
#     'sub-atomic particles known, and',
#     'they really shred a transporter',
#     'signal.',
#     'RIKER',
#     'Thank you, Ensign, I passed',
#     'physics.',
#     '(to Geordi)',
#     'Keep at it. We need those',
#     'transporters.',
#     'Riker EXITS.',
#     'GEORDI',
#     "We're going to have a lot of fun",
#     'cracking this one.',
#     'CUT TO:']}],
#  '20': [{'header': '', 'part': ['thru\tOMITTED']}],
#  '21': [{'header': '', 'part': []}],
#  '22': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ["Gosheven, Data, and Ard'rian are standing near the pool",
#     'of water. Gosheven cups some water in a hand.',
#     'GOSHEVEN',
#     'See that? Do you have any idea',
#     'what it is? What it means?',
#     'DATA',
#     'It is water, a substance composed',
#     'of two atoms of hydrogen --',
#     'GOSHEVEN',
#     "It's not water. It's blood and",
#     'sweat -- the result of a hundred',
#     'and forty years of combined',
#     'effort. (ALTERNATE: ninety',
#     "years) This isn't a town.",
#     '(MORE)']},
#   {'header': 'CONTINUED:',
#    'part': ["GOSHEVEN (Cont'd)",
#     "It's a monument to every man,",
#     'woman, and child who has lived',
#     'and died on Tau Cygna Five.',
#     "ARD'RIAN",
#     "Gosheven, you're talking nonsense.",
#     'GOSHEVEN',
#     "Am I? My grandfather's buried",
#     'on that mountain.',
#     '(points to the distant',
#     'line of hills)',
#     'He died in a rock slide surveying',
#     'the route for this aqueduct. This',
#     'colony exists because of his',
#     'sacrifice, and the sacrifices of',
#     "thousands of others. No, we're",
#     'not leaving.',
#     'DATA',
#     'The Sheliak will not accept humans',
#     'on their planet. And they will',
#     'not hesitate to use force to',
#     'remove you.',
#     'GOSHEVEN',
#     '(calmly)',
#     'And we will not hesitate to fight',
#     'back.',
#     'DATA',
#     'You cannot win.',
#     'GOSHEVEN',
#     "You just don't understand, do you?",
#     'We will not be bullied off our',
#     'land... not by you, and not by',
#     'the Sheliak.',
#     'Gosheven whirls and walks away. End of conversation.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["ARD'RIAN",
#     '(re Gosheven; bitter)',
#     'Stubborn and irrational. Now what',
#     'do we do?',
#     'DATA',
#     'Are his sentiments typical among',
#     'the colonists?',
#     "ARD'RIAN",
#     'I hope not. Are you thinking',
#     'of bypassing Gosheven and taking',
#     'your case directly to the people?',
#     'DATA',
#     '(nods)',
#     'I see no other course of action.',
#     'If I can convince enough people',
#     'of the necessity of leaving --',
#     "ARD'RIAN",
#     '(a smile)',
#     'Don\'t you mean "if we can',
#     'convince?"',
#     'DATA',
#     'You are offering assistance?',
#     "Ard'rian nods, extends her arm -- c'mon, let's get",
#     'going. As they move off:',
#     'CUT TO:']}],
#  '22A': [{'header': 'EXT. SPACE - ENTERPRISE (OPTICAL) (FORMERLY SC. 20)',
#    'part': ['In orbit around Tau Cygna V.']}],
#  '22B': [{'header': "INT. CAPTAIN'S READY ROOM (FORMERLY SC. 21)",
#    'part': ['Picard is pacing rapidly about the office. Riker',
#     'ENTERS.',
#     'RIKER',
#     'Yes, sir?']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'Three weeks. Starfleet is profuse',
#     'in their apologies, but it will',
#     'still be three weeks.',
#     'RIKER',
#     'Until?',
#     'PICARD',
#     'Until the arrival of a colony',
#     'transport ship equipped with',
#     'dedicated personnel shuttles.',
#     'RIKER',
#     "We can't wait three weeks.",
#     'PICARD',
#     'The Sheliak must agree to extend',
#     'our deadline.',
#     'Picard sits in silence for a beat.',
#     "PICARD (cont'd)",
#     'If they plan to settle Tau Cygna',
#     'Five two days from now...',
#     'RIKER',
#     '... one of their ships must already',
#     'be en route.',
#     'PICARD',
#     '(decides)',
#     "We're going to intercept that",
#     'ship.',
#     'RIKER',
#     'The Sheliak may interpret that',
#     'as a hostile act.',
#     'PICARD',
#     'We have to take the risk.',
#     "Off Picard's determined expression as we:",
#     'FADE OUT.',
#     'END OF ACT TWO                          ',
#     'ACT THREE                            ',
#     'FADE IN:']}],
#  '23': [{'header': 'INT. OBSERVATION LOUNGE',
#    'part': ['Riker pacing slowly, looking out at the stars.',
#     'RIKER',
#     'The Enterprise is going to try',
#     'to intercept the Sheliak colony',
#     'ship. Your job ... well, you know',
#     'your job.',
#     'CUT TO:']}],
#  '24': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['Data standing alone in an archway.',
#     'DATA',
#     'Commander, in human parlance, I do',
#     'not believe I can "get the job',
#     'done." My training has prepared',
#     'me for starship command duties.',
#     'As a cultural contact I am',
#     'proving to be less than exemplary.']}],
#  '25': [{'header': 'INTERCUTS',
#    'part': ['RIKER',
#     "What's the situation?",
#     'DATA',
#     'Their leader has rejected my',
#     'counsel. He denies the logic of',
#     'my arguments and talks of',
#     'structures they have built.',
#     'RIKER',
#     'Then try something else.',
#     'DATA',
#     'I have. In the last three hours',
#     'and eight minutes, I have spoken',
#     'to fifty-six colonists. Ten',
#     'refused to believe a threat',
#     'exists. Twenty-two favored',
#     'staying and fighting the Sheliak.']},
#   {'header': 'CONTINUED:',
#    'part': ['RIKER',
#     '(more to himself)',
#     "I don't have time for this.",
#     'DATA',
#     'Sixteen preferred negotiation or',
#     'some form of passive resistance.',
#     'Only eight were willing to',
#     'consider evacuation. And of those',
#     'eight --']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['RIKER',
#     '(cutting him)',
#     "Data, I can't help you -- I don't",
#     "know these people; I haven't",
#     'talked to them. You have. Use',
#     'that fancy positronic brain of',
#     'yours -- and carry out your',
#     'mission.',
#     "Ard'rian walks up to join the android, politely keeps",
#     'a few paces away to let him complete his "phone call"',
#     'with privacy.',
#     'DATA',
#     'If I do not succeed, how violent',
#     'is the Sheliak reaction likely',
#     'to be?',
#     'RIKER',
#     'The treaty is the only thing which',
#     'kept them from eradicating the',
#     'colony the moment they discovered',
#     'it.',
#     'DATA',
#     'Ah.',
#     'RIKER',
#     '"Ah" is right. The lives of',
#     'fifteen thousand people are riding',
#     "on you. You'd better get",
#     'innovative. Riker out.',
#     "Data gazes into space, thinking. Ard'rian steps up.",
#     'Her mood is upbeat.',
#     "ARD'RIAN",
#     "Data -- we're having an effect.",
#     'So many people are asking',
#     'questions about the Sheliak that',
#     "Gosheven's called a public",
#     'meeting.']},
#   {'header': 'CONTINUED: (3)',
#    'part': ['DATA',
#     'Is there any indication that',
#     'Gosheven has changed his position?',
#     "ARD'RIAN",
#     'No. But a meeting will give you',
#     'the chance to present your',
#     'recommendations.',
#     'DATA',
#     'First, will Gosheven allow me to',
#     'speak? Second, even if he does,',
#     'what good will it do? So far,',
#     'my attempts at persuasion have',
#     'been ineffective.',
#     "Ard'rian looks at him with compassion for a beat --",
#     'then suddenly gives Data a quick kiss on the lips.',
#     "DATA (cont'd)",
#     'Why did you do that?',
#     "ARD'RIAN",
#     'You appeared to need it.',
#     'DATA',
#     'Among humans, a kiss normally',
#     'serves to seal a friendship or',
#     'to indicate support, attraction,',
#     'affection.',
#     "Ard'rian nods."]},
#   {'header': 'CONTINUED: (4)',
#    'part': ["DATA (cont'd)",
#     'In this context, I would assume',
#     'your intention was to express',
#     'support.',
#     "ARD'RIAN",
#     'That was my primary motivation.',
#     'The implication being that there were secondary',
#     'motivations. But if Data is aware of the implication,',
#     'he makes no sign.',
#     "ARD'RIAN (cont'd)",
#     "You don't really understand human",
#     'behavior, do you?',
#     'DATA',
#     'That is something of an',
#     'understatement.',
#     "ARD'RIAN",
#     '(sighs)',
#     "Sometimes I don't either.",
#     'androids are a lot more rational.',
#     'DATA',
#     'Thus far, that quality has not',
#     'helped me accomplish my mission.',
#     "ARD'RIAN",
#     "A rational argument isn't always",
#     'enough. Maybe to be more',
#     'persuasive, you need to use a',
#     'little reverse psychology.',
#     'DATA',
#     '(accessing)',
#     'Elicit a desired behavior by',
#     'advocating its opposite?',
#     '(a beat)',
#     'That implies deception, does it',
#     'not?',
#     "ARD'RIAN",
#     'A little. But if it helps us',
#     'get our point across...']},
#   {'header': 'CONTINUED: (5)',
#    'part': ['DATA',
#     '(considers)',
#     'Perhaps this is a situation in',
#     'which excessive honesty is',
#     'detrimental.',
#     'As they walk off:',
#     'CUT TO:']}],
#  '26': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['Travelling at warp speed.']}],
#  '27': [{'header': 'INT. TRANSPORTER ROOM',
#    'part': ['As before, except there are more high tech tools and',
#     'equipment lying about. Geordi is lifting yet another',
#     'trashed test object off the platform. He holds it',
#     "mutely out to Wesley and O'Brien who stare dully at",
#     'this latest failure. There are now four intact',
#     'objects and three blasted ones. Picard ENTERS.',
#     'PICARD',
#     '(you will get it done)',
#     'How are we progressing, Mister',
#     'La Forge?',
#     'GEORDI',
#     "(it's impossible)",
#     "About like you'd expect.",
#     'PICARD',
#     '(get it done)',
#     'Splendid.',
#     'Picard EXITS.',
#     'WESLEY',
#     '(wearily)',
#     'He wants the impossible.']},
#   {'header': 'CONTINUED:',
#    'part': ['GEORDI',
#     '(with a grin)',
#     "That's the short definition for",
#     '"captain."',
#     "Geordi and O'Brien have already returned to work. Wes",
#     'looks at them bemused, then shrugs and pitches in.',
#     'CUT TO:']}],
#  '28': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['A large horseshoe-shaped amphitheater with a place for',
#     'the engineers and Gosheven. A number of citizens --',
#     'including Haritath and Kentor -- have turned out for',
#     'the debate so the place is filled. In the b.g. is the',
#     'aqueduct purifying plant.',
#     'GOSHEVEN',
#     "You've all heard about the android",
#     "Starfleet sent here, and you've",
#     "been discussing why he's come.",
#     "Data and Ard'rian ENTER. Gosheven ignores them.",
#     "GOSHEVEN (cont'd)",
#     'I called this meeting to replace',
#     'misinformation with cold, hard',
#     'fact.',
#     'The colonists are craning their necks to look at Data.',
#     "Gosheven realizes Data's presence can't be ignored. He",
#     'strides over to confront Data.',
#     'GOSHEVEN',
#     'Leave. Immediately.',
#     'DATA',
#     'I wish to speak.',
#     'GOSHEVEN',
#     'No.',
#     'DATA',
#     "(loud, for the crowd's",
#     'benefit)',
#     'You deny me the opportunity to',
#     'address the assemblage?']},
#   {'header': 'CONTINUED:',
#    'part': ['GOSHEVEN',
#     'This meeting is not for outsiders.',
#     'DATA',
#     'Do you consider your position so',
#     'weak that it cannot withstand',
#     'debate?',
#     'HARITATH',
#     'Let him talk.',
#     'MURMURS of assent from the crowd. Gosheven gives a',
#     "terse nod. In a sense Data's called him a coward and",
#     'he has to stand up to this city slicker, this outsider.',
#     'Data steps front and center. In an effort to pull this',
#     'off, he attempts to use human rhetorical devices',
#     '(timing, dynamics, inflection, gestures, etc.) -- but,',
#     "as there's no real passion behind them, they come off",
#     'as studied and not quite sincere. A good performance,',
#     'but still a performance.',
#     'DATA',
#     'You know of the Sheliak threat.',
#     'Starfleet wishes to evacuate you',
#     'for your own protection.',
#     'Gosheven has decided otherwise.',
#     'That is his right. And I will',
#     'not waste time trying to reverse',
#     'that decision.',
#     'Surprised reactions from the crowd. This is not what',
#     'they expected to hear.',
#     "DATA (cont'd)",
#     'I admire your conviction in the',
#     'face of certain defeat. Your',
#     'effort will be valiant, though',
#     'doomed. Still, when you die,',
#     'you will die for land and honor.']}],
#  '29': [{'header': 'ANGLE ON',
#    'part': ["The crowd. Data's starting to get a reaction. People",
#     "are beginning to eye each other nervously. It's one",
#     'thing to thumb your nose at a distant enemy, quite',
#     'another to talk about dying.']}],
#  '30': [{'header': 'ANGLE ON DATA',
#    'part': ['As he reaches down, and takes a YOUNG BOY (twelve or',
#     'so) by the arm, and pulls the child up next to him.',
#     'DATA',
#     'Your children will understand that',
#     'they are dying for a worthy cause.',
#     'Big crowd reaction here. Murmurs from various people.',
#     'Mothers pull their children closer to them. Data',
#     'steals a glance at Ard\'rian -- "how am I doing?"',
#     'Ard\'rian nods encouragingly back -- "fine."',
#     'DATA',
#     '(continuing)',
#     'Long after the battle is over,',
#     'their courage will be remembered',
#     'and extolled.',
#     "Ard'rian jumps in to support him.",
#     "ARD'RIAN",
#     'Remembered by who?',
#     'DATA',
#     "(as if he hadn't",
#     'considered that)',
#     'Ah, that is true. There will be',
#     'no one left alive to remember.']}],
#  '31': [{'header': 'ANGLE ON GOSHEVEN',
#    'part': ['as he begins to applaud slowly.',
#     'GOSHEVEN',
#     'A valiant try, android, but what',
#     'a low opinion you must have of',
#     'us.',
#     "The boy's MOTHER snatches her son back from Data, and",
#     'pulls him down in her lap.',
#     'DATA',
#     'I was simply attempting to',
#     'describe your inevitable',
#     'destruction in a manner that',
#     'would have an emotional effect.']},
#   {'header': 'CONTINUED:',
#    'part': ['HARITATH',
#     '(standing)',
#     'And he did it pretty damned well.',
#     'MURMURS of agreement from the crowd.',
#     'GOSHEVEN',
#     'Are you ready to follow this',
#     'machine, Haritath? Give up',
#     'everything? Without a fight?',
#     "He says we're going to lose, I",
#     "think that's his own cowardice",
#     'talking!',
#     'Kentor stands. He has a calm but commanding presence.',
#     'KENTOR',
#     "And what if he's right, and you're",
#     "wrong? Shouldn't we consider that",
#     'possibility?',
#     'More crowd reaction. Sympathy is swinging away from',
#     'Gosheven.',
#     'HARITATH',
#     'We may be sacrificing ourselves',
#     'for nothing --',
#     'GOSHEVEN',
#     'Last winter we buried your little',
#     'girl -- laid her to rest next to',
#     'your mother, and you dare speak',
#     'of sacrifice?',
#     'Gosheven whirls and nails Kentor with a look.',
#     'GOSHEVEN',
#     '(continuing)',
#     'And you, Kentor, we built you',
#     'a new house after the fire wiped',
#     'you out. Can you simply walk away',
#     'from that?',
#     'KENTOR',
#     'Better to walk away than to be',
#     'annihilated.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['GOSHEVEN',
#     '(addressing them all)',
#     'This colony exists because',
#     'generations gave their lives for',
#     'it. Many people died before we',
#     'found a way to adapt to the',
#     'radiation. Many more died',
#     'bringing water to the desert.',
#     'My father --',
#     "ARD'RIAN",
#     '(interrupting)',
#     '-- is buried on that mountain.',
#     "Well, who's going to be left to",
#     'bury you?',
#     'A vote of confidence is about to take place, and',
#     "Gosheven realizes he's about to lose it. He falls back",
#     'on the innate authority of an elected leader.',
#     'GOSHEVEN',
#     'Have you considered what this',
#     'evacuation means? Everything we',
#     'have, we abandon. Everything',
#     "we've built turns into dust.",
#     "Everything we've accomplished",
#     'means nothing.',
#     '(shakes head)',
#     'Well, I say NO! You elected me',
#     'to be your leader -- follow me',
#     "now! I don't think our chances",
#     'are as hopeless as he says. And',
#     "I'm willing to stake our lives",
#     'on it. Any objections?',
#     'He rakes the crowd with a look. Some mutterings, but',
#     "nobody's quite ready to lead the revolution.",
#     'GOSHEVEN',
#     '(continuing)',
#     'Good, because here... we...',
#     'stand.',
#     'A few people step up to pound Gosheven on the back, but',
#     'most of the crowd remains huddled, glancing from Data',
#     'to Gosheven and back again. Haritath and Kentor step',
#     'away to talk in private.']}],
#  '32': [{'header': 'ANGLE ON DATA',
#    'part': ["standing with Ard'rian.",
#     'DATA',
#     '(almost to himself)',
#     'Then here you die.',
#     'FADE OUT.',
#     'END OF ACT THREE                         ',
#     'ACT FOUR                             ',
#     'FADE IN:']}],
#  '33': [{'header': 'INT. TRANSPORTER ROOM (OPTICAL)',
#    'part': ["Wesley, Geordi and O'Brien. There are now three",
#     'intact test object and four trashed ones. These are',
#     "three exhausted people. They've been working round",
#     'the clock.',
#     'WESLEY',
#     'Maybe if we bypassed the autosequence',
#     'and decompiled the',
#     'pattern buffer... ?',
#     'GEORDI',
#     '(shrugs)',
#     "It's no crazier than anything",
#     "else we've tried.",
#     'Wesley drops down by the panel, and begins to tinker',
#     'while Geordi places the last test object on the',
#     'platform. Suddenly the transporter console blows a',
#     'fuse. Electricity races across the panel, and the',
#     "console goes dark. O'Brien is not a happy man. Wesley",
#     "slowly stands up. O'Brien struggles with himself, but",
#     "can't master it.",
#     "O'BRIEN",
#     'Ensign Crusher.',
#     'WESLEY',
#     'Yes, sir.',
#     "O'BRIEN",
#     'If you ever touch my transporter',
#     "again... I'll kill you.",
#     'WESLEY',
#     'Sorry, sir.',
#     'CUT TO:']}],
#  '33A': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY',
#    'part': ['Data watches the town meeting break up into small',
#     "groups of people TALKING among themselves. Ard'rian",
#     'approaches.']},
#   {'header': 'CONTINUED:',
#    'part': ['Haritath and Kentor step up furtively.',
#     'HARITATH',
#     'Mister Data -- I want to tell you',
#     "that... well, Gosheven doesn't",
#     'speak for all of us.',
#     "Ard'rian looks at Data hopefully -- maybe the early",
#     "returns aren't so bad after all.",
#     "HARITATH (cont'd)",
#     'I see no point in dying',
#     'needlessly.',
#     'DATA',
#     'And you, Kentor?',
#     'KENTOR',
#     "I'm not sure. Gosheven has done",
#     "well for us. But I'd like to hear",
#     'more of what you have to say.',
#     'HARITATH',
#     'There are many others that feel',
#     'the same way but are uneasy about',
#     'confronting Gosheven.',
#     "ARD'RIAN",
#     "Get them together. We'll meet",
#     'at my house.',
#     'Haritath and Kentor nod agreement then slip away.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["Ard'rian leads Data toward her house. They EXIT."]}],
#  '34': [{'header': '', 'part': ['thru\tOMITTED']}],
#  '35': [{'header': '', 'part': []}],
#  '36': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['Traveling at warp speed.']}],
#  '37': [{'header': "INT. CAPTAIN'S READY ROOM (OPTICAL)",
#    'part': ['Picard has brought Troi in for consultation.',
#     'TROI',
#     'In our dealings with other',
#     'non-humanoid races there has been',
#     'some point of reference; not so',
#     'with the Sheliak.',
#     'PICARD',
#     'We must have something in common.',
#     'We communicate.',
#     'TROI',
#     'Barely. The Sheliak have learned',
#     'several Federation languages, but',
#     'theirs continues to elude us.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     '(have we tried?)',
#     'Telepaths?',
#     'TROI',
#     'Attempted and failed.',
#     'PICARD',
#     'This is ludicrous!',
#     'TROI',
#     'No, sir, the fact that any alien',
#     'race communicates with another',
#     'is quite remarkable.',
#     "She lifts Picard's tea cup from the desk.",
#     'TROI',
#     '(continuing)',
#     'We are stranded on a planet. No',
#     'language in common, but I want',
#     'to teach you mine.',
#     'Troi points to the cup.',
#     'TROI',
#     '(continuing)',
#     "S'smarith. What did I just say?",
#     'PICARD',
#     'Cup? Glass?',
#     'TROI',
#     'Are you sure? I might have meant',
#     'liquid, clear, brown, hot. And',
#     'we conceptualize the universe in',
#     'relatively the same way.',
#     'PICARD',
#     'Point taken.',
#     'TROI',
#     'During your talks you must be',
#     'extremely accurate. The treaty',
#     'is 500,000 words. The length was',
#     'to accommodate the Sheliak. They',
#     'consider our language irrational,',
#     'and demanded this level of',
#     'complexity to avoid any future',
#     'misunderstandings.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["RIKER'S COM VOICE",
#     'Captain, we have the vessel',
#     'carrying the Sheliak colonists',
#     'on visual.',
#     'PICARD',
#     'On my way.',
#     '(to Troi)',
#     'So it begins.',
#     'They EXIT onto:']}],
#  '38': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['The tension on the bridge is palpable. Picard moves',
#     'swiftly to the command station. Riker relinquishes',
#     'command.']}],
#  '39': [{'header': 'ANGLE ON VIEWSCREEN (OPTICAL)',
#    'part': ['Where a Sheliak ship hangs ominously.',
#     'PICARD',
#     'Open hailing frequencies. This',
#     'is Captain Jean-Luc Picard of the',
#     'Starship Enterprise.',
#     'We again have a vision of the mirrored, shadowed,',
#     'shifting place. A hint of a watcher in the shadows.',
#     'SHELIAK',
#     'Your purpose, Enterprise?',
#     'PICARD',
#     'We desire face-to-face negotiation',
#     'to settle the crisis on Tau Cygna',
#     'Five.',
#     'Troi hands him a PADD.',
#     'PICARD',
#     '(continuing)',
#     'We are entitled to consultation',
#     'under paragraph five hundred and',
#     'sixty-three subparagraph nine.',
#     'A beat as the Sheliak look it up.',
#     'SHELIAK',
#     'Granted.']},
#   {'header': 'CONTINUED:',
#    'part': ['The screen again shows the Sheliak vessel.',
#     'RIKER',
#     'Was that an invitation?',
#     'PICARD',
#     "I'm going to take it as such.",
#     'Number One, you have the bridge.',
#     'Troi and Picard EXIT. HOLD on Riker.',
#     'RIKER',
#     'Helm, maintain relative position.',
#     'Mister Worf, have Transporter Room',
#     'Two stand by.',
#     'WORF',
#     'Aye, sir.',
#     'CUT TO:']}],
#  '40': [{'header': "INT. ARD'RIAN'S LIVING ROOM - DAY",
#    'part': ['Haritath, Kentor, and a group of other colonists are',
#     "gathered around Data and Ard'rian.",
#     'KENTOR',
#     '... and once the Federation',
#     "resettles us, we'll be left",
#     'alone?',
#     'DATA',
#     'If you so desire.',
#     'HARITATH',
#     'We do. We like doing things on',
#     'our own.',
#     'DATA',
#     'The Federation will offer as',
#     'little or as much help as you',
#     'dictate.']},
#   {'header': 'CONTINUED:',
#    'part': ['Nods all around; they are impressed. Data is the',
#     'perfect no-pressure salesman; he simply presents the',
#     "facts. Ard'rian looks expectantly to Kentor;",
#     "Kentor's still uncertain.",
#     "ARD'RIAN",
#     'Kentor -- are you with us?',
#     'Kentor makes up his mind:',
#     'KENTOR',
#     'Yes.',
#     '(a beat)',
#     'The question is, how do we',
#     'convince Gosheven?']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['HARITATH',
#     'Why do we need to?',
#     'KENTOR',
#     "Because he's respected. Most",
#     'people will do as he says.',
#     "ARD'RIAN",
#     'The people respect you, too.',
#     "If you take a stand, they'll",
#     'fall in line.',
#     'KENTOR',
#     "I don't know. Gosheven's got a",
#     'lot of supporters...',
#     'GOSHEVEN (O.S.)',
#     "Don't forget that, Kentor.",
#     'Everyone turns to see --']}],
#  '40A': [{'header': 'OMITTED', 'part': []}],
#  '40B': [{'header': 'NEW ANGLE (OPTICAL)',
# ...
#     'the discretion of the Sheliak',
#     'corporate.',
#     'PICARD',
#     'We will remove them. But you',
#     'must grant us the time we require.',
#     'SHELIAK',
#     'You need time, Picard of the',
#     'Enterprise, we will save you time.',
#     'We will eradicate the human',
#     'infestation.',
#     'PICARD',
#     '(outraged)',
#     'They are not vermin! They are',
#     'citizens of the Federation and',
#     'I will not permit this travesty!']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['SHELIAK',
#     'Intelligent converse is',
#     'impossible. You do not discuss,',
#     'you gibber.',
#     'PICARD',
#     'Between intelligent species of',
#     'good will --',
#     'Suddenly the Sheliak transporter kicks in, and slams',
#     'Picard and Troi back to the Enterprise. They have been',
#     'rudely thrown out on their ears.']}],
#  '42': [{'header': 'INT. MAIN BRIDGE (OPTICAL)',
#    'part': ['The startling EFFECT of the Sheliak transporter and',
#     'Picard and Troi APPEAR. Riker, Worf, and the',
#     'supernumeraries at Conn and Ops react.',
#     'Picard and Troi are both very disoriented, staggering',
#     'slightly. Riker steadies them both.',
#     'RIKER',
#     'I take it the Sheliak just hung',
#     'up on us. Again.',
#     'FADE OUT.',
#     'END OF ACT FOUR                         ',
#     'ACT FIVE                             ',
#     'FADE IN:']}],
#  '42A': [{'header': "INT. ARD'RIAN'S LIVING ROOM",
#    'part': ["Ard'rian worriedly inspects the unmoving Data with an",
#     'electronic scanner. Data twitches, "reboots," comes',
#     "back to life, and sits up. Ard'rian SIGHS, relieved.",
#     "ARD'RIAN",
#     'I was afraid your neural pathways',
#     'were scrambled beyond repair.',
#     'DATA',
#     'I am equipped with diagnostic',
#     'circuits and can correct many',
#     'malfunctions.',
#     'Data moves his head, arms, and legs, testing his',
#     'responses.',
#     "ARD'RIAN",
#     "I'm not surprised at Gosheven's",
#     'behavior. But Kentor and the',
#     'others... they said they were',
#     'on our side.',
#     '(bitter)',
#     "I guess words don't mean very",
#     'much.',
#     'Data mulls this over carefully.',
#     'DATA',
#     'Perhaps that has been part of our',
#     'difficulty. Words are all we have',
#     'been using.',
#     '(thinking)',
#     'Humans seem to take much stronger',
#     'notice of actions.',
#     'Data makes a decision, gets to his feet.',
#     "DATA (cont'd)",
#     'I require a phaser.',
#     "ARD'RIAN",
#     "What's a phaser?",
#     'DATA',
#     'A type of weapon. Unfortunately',
#     'it will not function in the',
#     'presence of hyperonic radiation.']},
#   {'header': 'CONTINUED:',
#    'part': ['Data ponders this new problem for a beat, then shrugs',
#     'it off:',
#     "DATA (cont'd)",
#     'I will have to be innovative.',
#     'CUT TO:']}],
#  '42B': [{'header': 'INT. SHUTTLECRAFT - CYGNA FIVE - DAY',
#    'part': ['Data has opened up a phaser and is adapting it. His',
#     "forearm is opened, revealing his arm's inner workings;",
#     'Data is "cannibalizing" his arm for parts to modify the',
#     "phaser. Ard'rian looks on in fascination.",
#     'DATA',
#     'Hyperonic radiation randomizes',
#     'phaser beams. But I believe I',
#     'can improvise a servocircuit which',
#     'will compensate by continuously',
#     'recollimating the output.',
#     "ARD'RIAN",
#     "You're using your own neural",
#     'subprocessors to build a smarter',
#     'phaser.',
#     'DATA',
#     'Essentially correct.',
#     "Ard'rian's impressed. Data completes his work.",
#     "DATA (cont'd)",
#     'Get word to Gosheven. Tell him',
#     'I am coming to the pumping',
#     'station. Tell him I am going',
#     'to destroy the aqueduct.',
#     "Ard'rian is gaping like a carp over this, doesn't know",
#     'what to say. Finally manages:',
#     "ARD'RIAN",
#     "He'll try to stop you --",
#     'DATA',
#     'I sincerely hope so.',
#     "Off Ard'rian's expression:",
#     'CUT TO:']}],
#  '43': [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)',
#    'part': ['The Enterprise hanging motionless in space with the',
#     'Sheliak ship.']}],
#  '44': [{'header': 'INT. MAIN BRIDGE',
#    'part': ['As before.',
#     'PICARD',
#     '(to Worf)',
#     'Go to Yellow Alert. Shields up.',
#     'WORF',
#     'Aye, sir.',
#     'PICARD',
#     'Mister Riker, put us nose to nose',
#     'with the Sheliak ship. If she',
#     'makes a move, match it.',
#     'RIKER',
#     'Aye, sir.',
#     'PICARD',
#     'Open a hailing frequency.']},
#   {'header': 'CONTINUED:',
#    'part': ['WORF',
#     "They're not responding, sir.",
#     'PICARD',
#     '(tight control)',
#     "They don't have to answer. They",
#     'just have to listen! Sheliak',
#     'vessel, you will have to go',
#     'through me to get at the colony',
#     'on Tau Cygna Five!']}],
#  '45': [{'header': '', 'part': ['thru\tOMITTED']}],
#  '46': [{'header': '', 'part': []}],
#  '47': [{'header': 'INT. MAIN BRIDGE - CONTINUOUS',
#    'part': ['WORF',
#     'No response.',
#     'PICARD',
#     'Close channel -- and get me that',
#     "treaty! They've been beating us",
#     'over the head with it for three',
#     "days. Let's see if we can't find",
#     'something in it that can be',
#     'turned to our advantage.',
#     'RIKER',
#     "We're going to try to beat them",
#     'at their own game?',
#     'WORF',
#     'The treaty is how long?',
#     'TROI',
#     'Five hundred thousand words.',
#     'WORF',
#     '(glumly)',
#     "We are going to regret Data's",
#     'absence.',
#     'CUT TO:']}],
#  '48': [{'header': 'EXT. PLANET SURFACE - MAIN STREET - DAY (OPTICAL)',
#    'part': ['The square. FOUR MEN armed with rifles stand',
#     'shoulder to shoulder in front of the plant and',
#     'aqueduct. Standing defiant and unarmed, save for the',
#     'probe at his belt, on an upper level is Gosheven.']},
#   {'header': 'CONTINUED:',
#    'part': ['Off to one side are a number of colonists (including',
#     "Ard'rian, Haritath, and Kentor), nervously awaiting",
#     'the outcome.',
#     'Then a PHASER STUN hits one of the armed men; he',
#     'drops. As the others whirl to take aim --']}],
#  '48A': [{'header': 'NEW ANGLE (OPTICAL)',
#    'part': ['A PHASER BEAM sweeps across the line of armed men,',
#     'STUNNING them instantly. No one even gets a shot off.',
#     'Gosheven, astonished, reaches for the probe at his',
#     'belt. Data calmly stands up from his hiding place,',
#     "aims his phaser. Gosheven freezes -- it's futile;",
#     'obviously Data could stun him before he could get',
#     'anywhere near Data.']}],
#  '48B': [{'header': 'WIDER (OPTICAL)',
#    'part': ['as Data steps out into the street, holds his phaser',
#     'up for all to see.',
#     'DATA',
#     'That was the "stun" setting.',
#     'Data switches the setting on the phaser --',
#     "DATA (cont'd)",
#     'This is not.',
#     'Data turns, BLASTS the control panel on the aqueduct.',
#     'A shower of SPARKS. EFFECT as the reaction races up',
#     'the aqueduct. The water stops flowing. Gosheven is',
#     'speechless. Data addresses the colonists:',
#     "DATA (cont'd)",
#     'I could reduce this pumping',
#     'station to a pile of debris...',
#     'but I trust my point is clear.',
#     'I am one android with a single',
#     'weapon. There are hundreds of',
#     'Sheliak on the way... and their',
#     'weapons are far more powerful.',
#     'Data pauses. The colonists are dead silent.']},
#   {'header': 'CONTINUED:',
#    'part': ["DATA (cont'd)",
#     'And the Sheliak may not even offer',
#     'you a target. They can obliterate',
#     'this colony from orbit. You will',
#     'die never having seen the faces',
#     'of your killers.',
#     'Data walks deliberately to one of the stunned',
#     'defenders, picks up the rifle with his free hand, holds',
#     'it out to the group of colonists.',
#     "DATA (cont'd)",
#     'The choice is yours.',
#     'The colonists look at one another. Finally:',
#     'KENTOR',
#     'There are other places -- other',
#     "challenges. It's time to move",
#     'on.',
#     'And Kentor EXITS. One by one, the colonists follow',
#     'him. The mantle of leadership has passed.']}],
#  '48C': [{'header': 'NEW ANGLE',
#    'part': ['Gosheven, slump shouldered, bends and scoops up a',
#     'handful of dirt at the base of the silent pool. Data',
#     'moves to join him.',
#     'GOSHEVEN',
#     'I really was willing to stay and',
#     'die for this.',
#     'DATA',
#     'I know that, but it is just a',
#     'thing, and things can be replaced.',
#     'Lives cannot. Live, rebuild and',
#     'be remembered.',
#     'A long beat. Then Gosheven wipes his hand on his',
#     'pants, and walks back to join his people.']}],
#  '49': [{'header': 'OMITTED', 'part': []}],
#  '50': [{'header': 'ANGLE ON DATA',
#    'part': ['watching Gosheven go. Data looks down at the phaser',
#     'for several moments, then holsters it. He looks up to',
#     "find Ard'rian gazing at him with an expression of pride",
#     'and love.']}],
#  '51': [{'header': 'OMITTED', 'part': []}],
#  '52': [{'header': 'INT. MAIN BRIDGE (OPTICAL)',
#    'part': ['Troi is seated at Science One with Picard hanging over',
#     'her shoulder. Riker and Worf are at Science Two.',
#     'Pages of treaty crawl past on both screens.',
#     'WORF',
#     'This is hopeless. Fighting would',
#     'be preferable.',
#     'A look from Riker.',
#     'PICARD',
#     "That's it.",
#     'He indicates a clause.',
#     'TROI',
#     "I don't follow you, sir.",
#     'PICARD',
#     'Worf, get me the Sheliak.',
#     'WORF',
#     '(just heard the',
#     'reprieve)',
#     'Yes, sir!',
#     'Picard, Riker and Troi return to the command station.',
#     'The strange Sheliak scene replaces a view of the ship.',
#     'PICARD',
#     'Pursuant to paragraph one thousand',
#     'two hundred and ninety I formally',
#     'request third party arbitration',
#     'of our dispute.',
#     'A beat while they look it up.',
#     'SHELIAK',
#     'Agreed.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'And further, pursuant to',
#     'subsection D, three, I name the',
#     'Grizzelas to arbitrate.',
#     'SHELIAK',
#     'Grizzelas?',
#     'Riker glances, puzzled, at Troi.',
#     'RIKER',
#     '(mouths)',
#     'Grizzelas?',
#     'Troi quells him with a look.',
#     'PICARD',
#     'Unfortunately they are currently',
#     'in their hibernation cycle, but',
#     "they'll awaken in six months, and",
#     "then we'll get this matter",
#     'settled. Now, do you want to',
#     'wait... or give me my three weeks?',
#     'SHELIAK',
#     'Absurd. We carry the membership!',
#     'We can brook no delay!',
#     'PICARD',
#     'Then I declare the treaty in',
#     'abeyance!',
#     'SHELIAK',
#     'Wait! Negotiation is --',
#     'Picard gestures to Worf -- cut the transmission. Worf',
#     'obeys. A long beat.',
#     'RIKER',
#     '(smiling)',
#     'You enjoyed that.',
#     'PICARD',
#     "You're damn right.",
#     'WORF',
#     'Captain, they are hailing us.',
#     'Picard studies his nails. Takes a turn around the',
#     'bridge. Settles himself back in the command chair.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ['WORF',
#     '(continuing)',
#     'Sir?',
#     'PICARD',
#     '(a beat)',
#     'On screen.',
#     'The Sheliak reappear.',
#     'SHELIAK',
#     'You may have your three weeks,',
#     'Picard of the Enterprise.',
#     'PICARD',
#     '(with careful',
#     'enunciation)',
#     'Thank you.',
#     'The screen returns to a view of the Sheliak ship',
#     'pulling away. Instant release of tension. Suddenly',
#     'the turbolift doors open, and Geordi ENTERS. He is',
#     "looking frazzled. People's expressions reflect the",
#     'thought that "dear God, he did it."',
#     'GEORDI',
#     'Captain, we can do it! We can',
#     'modify the transporters.',
#     'PICARD',
#     'Excellent.',
#     'GEORDI',
#     "It'll take fifteen years, and a",
#     'research team of a hundred --',
#     'PICARD',
#     '(dryly)',
#     'Mister La Forge, I believe we will',
#     'postpone.',
#     'GEORDI',
#     '(with a grin)',
#     'Yes, sir.',
#     'Geordi EXITS.',
#     'CUT TO:']}],
#  '53': [{'header': 'EXT. PLANET SURFACE - SHUTTLE LANDING SITE - DAY',
#    'part': ['Data is inside the shuttle making preparations for',
#     'departure.',
#     'DATA',
#     'Commander Data to Enterprise.',
#     'I am preparing to leave Tau Cygna',
#     'Five and await rendezvous',
#     'instructions.',
#     "WORF'S COM VOICE",
#     'Acknowledged. Stand by.',
#     "Outside the shuttle, Ard'rian approaches. Data sees",
#     'her, emerges from the shuttle to meet her.',
#     "ARD'RIAN",
#     'Hi.',
#     'DATA',
#     "Hello, Ard'rian.",
#     "ARD'RIAN",
#     'The evacuation plan is going well.',
#     'When the transport ship arrives,',
#     "we'll be ready.",
#     '(a beat)',
#     'You succeeded.',
#     'DATA',
#     'I would not have succeeded without',
#     'your support and insight, and I',
#     'appreciate your assistance.',
#     "ARD'RIAN",
#     "Good. Then you won't forget me?",
#     'DATA',
#     'I am incapable of forgetting.',
#     'I will remember every detail of',
#     'my visit with perfect clarity.',
#     "ARD'RIAN",
#     'But nothing more?',
#     'DATA',
#     'I do not understand.']},
#   {'header': 'CONTINUED:',
#    'part': ["Ard'rian bites the bullet:",
#     "ARD'RIAN",
#     'I guess what I really want to know',
#     'is -- do you have any feelings',
#     'for me?',
#     'DATA',
#     'I have no feelings of any kind.',
#     "Ard'rian is silent.",
#     "ARD'RIAN",
#     "No. Of course you don't.",
#     "Data studies her. She's downcast. Mimicking her",
#     'behavior earlier, he gives her a quick kiss on the',
#     'lips, startling her.',
#     "ARD'RIAN (cont'd)",
#     'What was that for?',
#     'DATA',
#     'You appeared to require it.',
#     "ARD'RIAN",
#     'You observed I was unhappy and',
#     'did what you concluded would make',
#     'me feel better. A purely rational',
#     'deduction.',
#     "She's still downcast.",
#     'DATA',
#     'Have I disappointed you?',
#     "ARD'RIAN",
#     "No, I'm disappointed in myself",
#     '-- for wanting something I know',
#     "I can't have.",
#     '(a beat)',
#     "Data, in so many ways you're",
#     'superior to humans. But you are',
#     'still a machine... without',
#     'emotion.',
#     'DATA',
#     'Yes.']},
#   {'header': 'CONTINUED: (2)',
#    'part': ["ARD'RIAN",
#     "It's so easy to believe otherwise.",
#     "It's so easy to read things into",
#     'your behavior... and perceive',
#     'feelings where none exist.',
#     '(a beat)',
#     'Well, I am human and I do have',
#     'feelings... silly though they may',
#     'be at times. I like you, Data.',
#     "You're my favorite android.",
#     'DATA',
#     'But I am the only android you have',
#     'ever met.',
#     "ARD'RIAN",
#     'Rational to the last.']},
#   {'header': 'CONTINUED: (3)',
#    'part': ["And with a smile, Ard'rian EXITS. Data climbs into",
#     'the shuttle, and the door closes.',
#     'CUT TO:']}],
#  '54': [{'header': 'OMITTED', 'part': []}],
#  '55': [{'header': "INT. CAPTAIN'S READY ROOM",
#    'part': ["Picard is listening to a recording of Data's string",
#     'quartet concert in Ten Forward. DOOR CHIME.',
#     'PICARD',
#     'Come.',
#     'Data ENTERS.',
#     "PICARD (cont'd)",
#     'Welcome home, Mister Data. Well',
#     'done.',
#     'DATA',
#     'Thank you, sir.',
#     'PICARD',
#     'The good doctor was kind enough',
#     'to provide me with a recording',
#     'of your concert. Your',
#     'performance shows a good deal',
#     'of feeling.',
#     'DATA',
#     'As I have lately had to remind',
#     'others, I have no feelings.',
#     'PICARD',
#     "That's hard to believe; your",
#     'playing is quite beautiful.',
#     'DATA',
#     'Strictly speaking, it is not',
#     '"my" playing. It is a precise',
#     'imitation of the techniques of',
#     'Jascha Heifetz and Trenka Bron-Ken.']},
#   {'header': 'CONTINUED:',
#    'part': ['PICARD',
#     'And is there nothing of Data in',
#     "what I'm hearing?",
#     'Data ponders this.',
#     "PICARD (cont'd)",
#     'You chose the violinists.',
#     'Heifetz and Bron-Ken had',
#     'radically different styles, but',
#     'you combined them -- successfully.',
#     'DATA',
#     'I suppose I have learned to be',
#     'innovative... when necessary, sir.',
#     "Picard nods. He's made his point.",
#     'PICARD',
#     'Mister Data... I look forward to',
#     'your next concert.',
#     "On Data's thoughtful expression, we:"]}]}

# %%
c = replace_character_names(e, chars)
# Out:
# [{'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)', 'part': ['Moving at impulse near some extraordinarily interesting', 'astronomical object.']}]
# {'header': 'EXT. SPACE - THE ENTERPRISE (OPTICAL)', 'part': ['Moving at impulse near some extraordinarily interesting', 'astronomical object.']}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-156-ad5554e90cc4> in <module>
# ----> 1 c = replace_character_names(e, chars)
#
# <ipython-input-143-2ff6b78eee04> in replace_character_names(dialogue, characters)
#       7             print(piece)
#       8             parts = piece['part']
# ----> 9             for section, stuff in parts.items():
#      10                 print(section, stuff)
#      11                 name = stuff['name']
#
# AttributeError: 'list' object has no attribute 'items'

# %%
a.sectioned_script()
